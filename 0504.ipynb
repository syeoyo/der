# %%
import pandas as pd
pd.options.display.float_format = '{:.3f}'.format
pd.set_option("display.max_rows", None)  # 모든 행 출력
pd.set_option("display.max_columns", None)  # 모든 열 출력
import numpy as np
import matplotlib.pyplot as plt
import gurobipy as gp
from gurobipy import GRB
import os
from itertools import product
from functions import (load_parameters, load_generation_data, load_price_data, generate_randomized_generation,
generate_rt_scenarios, plot_generation_data, plot_randomized_generation, plot_scenarios_for_generator, plot_rt_scenarios, plot_summary)

generation_data, I, T = load_generation_data(date_filter="2022-07-18")
S, R, P_RT, K, K0, M1, M2 = load_parameters(I, T, generation_data)
P_DA, P_PN = load_price_data()
# Out:
# ✅ 총 3개 파일을 불러왔습니다: 1201.csv, 401.csv, 89.csv
# 📊 데이터 Shape: I=3, T=24, S=20
# ✅ 시뮬레이션 초기화 완료: S=20, Randomness='high', M1=768.00, M2=1202.00

# %%
m2 = gp.Model("set")
m2.setParam("MIPGap", 1e-6)
m2.setParam("Heuristics", 0.3)


a = m2.addVars(T, vtype=GRB.CONTINUOUS, name="alpha")
bp = m2.addVars(T, S, vtype=GRB.CONTINUOUS, name="beta_plus")
bm = m2.addVars(T, S, vtype=GRB.CONTINUOUS, name="beta_minus")
gc = m2.addVars(T, S, vtype=GRB.CONTINUOUS, name="gamma_charge")
gd = m2.addVars(T, S, vtype=GRB.CONTINUOUS, name="gamma_discharge")
eta = m2.addVars(T, S, vtype=GRB.BINARY, name="eta")
lam = m2.addVars(T, S, vtype=GRB.BINARY, name="lambda")
mu = m2.addVars(T, S, vtype=GRB.BINARY, name="mu")

x = m2.addVars(I, T, vtype=GRB.CONTINUOUS, lb=0, name="x")
yp = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="y_plus")
ym = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="y_minus")
z = m2.addVars(I, T + 1, S, vtype=GRB.CONTINUOUS, name="z")
zc = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, name="z_charge")
zd = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, name="z_discharge")
zeta = m2.addVars(I, T, S, vtype=GRB.BINARY, name="zeta")
delta = m2.addVars(I, T, S, vtype=GRB.BINARY, name="delta")
rho = m2.addVars(I, T, S, vtype=GRB.BINARY, name="rho")
req1 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="req")

dp = m2.addVars(I, I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="dyp")
dm = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="dym")
dcp = m2.addVars(I, I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="dzc+")
dcm = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="dzc-")
ddp = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="dzd+")
ddm = m2.addVars(I, I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="dzd-")

q1 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q1")
q2 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q2")
q3 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q3")
q4 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q4")
q5 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q5")
q6 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q6")
q7 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q7")

ep = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, name="e_plus")
em = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, name="e_minus")
ec = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, name="e_charge")
ed = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, name="e_discharge")

m2.update()

obj = gp.quicksum(P_DA[t] * a[t] for t in range(T)) + gp.quicksum((1 / S) * (P_RT[t, s] * bp[t, s] - P_PN[t] * bm[t, s]) for t in range(T) for s in range(S))

m2.setObjective(obj, GRB.MAXIMIZE)

# ---------individual-----------
for i, t, s in product(range(I), range(T), range(S)):
    m2.addConstr(R[i, t, s] - x[i, t] == yp[i, t, s] - ym[i, t, s] + zc[i, t, s] - zd[i, t, s])
    m2.addConstr(yp[i, t, s] <= R[i, t, s])
    m2.addConstr(zd[i, t, s] <= z[i, t, s])
    m2.addConstr(zc[i, t, s] <= K[i] - z[i, t, s])
    m2.addConstr(yp[i, t, s] <= M1 * rho[i, t, s])
    m2.addConstr(ym[i, t, s] <= M1 * (1 - rho[i, t, s]))
    m2.addConstr(ym[i, t, s] <= M1 * delta[i, t, s])
    m2.addConstr(zc[i, t, s] <= M1 * (1 - delta[i, t, s]))
    m2.addConstr(zc[i, t, s] <= M1 * zeta[i, t, s])
    m2.addConstr(zd[i, t, s] <= M1 * (1 - zeta[i, t, s]))
    m2.addConstr(z[i, t, s] <= K[i])
for i, s in product(range(I), range(S)):
    m2.addConstr(z[i, 0, s] == K0[i])

# -----------settle------------
for i, t, s in product(range(I), range(T), range(S)):
    m2.addConstr(ep[i, t, s] == yp[i, t, s] - gp.quicksum(dp[i, j, t, s] for j in range(I)))
    m2.addConstr(em[i, t, s] == ym[i, t, s] - dm[i, t, s])
    m2.addConstr(ec[i, t, s] == zc[i, t, s] - gp.quicksum(dcp[i, j, t, s] for j in range(I)) + dcm[i, t, s])
    m2.addConstr(ed[i, t, s] == zd[i, t, s] - ddp[i, t, s] + gp.quicksum(ddm[i, j, t, s] for j in range(I)))
    m2.addConstr(ec[i, t, s] <= K[i] - z[i, t, s])
    m2.addConstr(ed[i, t, s] <= z[i, t, s])
    m2.addConstr(z[i, t + 1, s] == z[i, t, s] + ec[i, t, s] - ed[i, t, s])
    
    m2.addConstr(gp.quicksum(dcp[i, j, t, s] for j in range(I)) <= M1 * q1[i, t, s])
    m2.addConstr(dcm[i, t, s] <= M1 * (1 - q1[i, t, s]))
    m2.addConstr(ddp[i, t, s] <= M1 * q2[i, t, s])
    m2.addConstr(gp.quicksum(ddm[i, j, t, s] for j in range(I)) <= M1 * (1 - q2[i, t, s]))
    m2.addConstr(ep[i, t, s] <= M1 * q3[i, t, s])
    m2.addConstr(em[i, t, s] <= M1 * (1 - q3[i, t, s]))
    m2.addConstr(em[i, t, s] <= M1 * q4[i, t, s])
    m2.addConstr(ec[i, t, s] <= M1 * (1 - q4[i, t, s]))
    m2.addConstr(ec[i, t, s] <= M1 * q5[i, t, s])
    m2.addConstr(ed[i, t, s] <= M1 * (1 - q5[i, t, s]))

#-----------settlement-----------
for t in range(T):
    m2.addConstr(a[t] == gp.quicksum(x[i, t] for i in range(I)))
for t, s in product(range(T), range(S)):
    m2.addConstr(bp[t, s] == gp.quicksum(ep[i, t, s] for i in range(I)))
    m2.addConstr(bm[t, s] == gp.quicksum(em[i, t, s] for i in range(I)))
    m2.addConstr(gc[t, s] == gp.quicksum(ec[i, t, s] for i in range(I)))
    m2.addConstr(gd[t, s] == gp.quicksum(ed[i, t, s] for i in range(I)))

#----------aggregation------------
for t, s in product(range(T), range(S)):
    m2.addConstr(gp.quicksum(R[i, t, s] for i in range(I)) - a[t] == bp[t, s] - bm[t, s] + gc[t, s] - gd[t, s])
    m2.addConstr(bp[t, s] <= gp.quicksum(R[i, t, s] for i in range(I)))
    m2.addConstr(bp[t, s] <= M2 * mu[t, s])
    m2.addConstr(bm[t, s] <= M2 * (1 - mu[t, s]))
    m2.addConstr(bm[t, s] <= M2 * eta[t, s])
    m2.addConstr(gc[t, s] <= M2 * (1 - eta[t, s]))
    
# ------logical sense---------
for i, t, s in product(range(I), range(T), range(S)):
    m2.addConstr(yp[i, t, s] >= gp.quicksum(dp[i, j, t, s] for j in range(I)))
    m2.addConstr(ym[i, t, s] >= dm[i, t, s])
    m2.addConstr(zc[i, t, s] >= gp.quicksum(dcp[i, j, t, s] for j in range(I)))
    m2.addConstr(zd[i, t, s] >= ddp[i, t, s])
    m2.addConstr(req1[i, t, s] <= ym[i, t, s])
    m2.addConstr(req1[i, t, s] <= z[i, t, s])
    m2.addConstr(req1[i, t, s] >= ym[i, t, s] - M1 * (1 - q6[i, t, s]))
    m2.addConstr(req1[i, t, s] >= z[i, t, s] - M1 * q6[i, t, s])
    m2.addConstr(zd[i, t, s] + ddm[i, i, t, s] >= req1[i, t, s])
    m2.addConstr(gp.quicksum(ym[i, t, s] for i in range(I)) >= gp.quicksum(dcp[i, j, t, s] for j in range(I)))
    m2.addConstr(gp.quicksum(ym[i, t, s] for i in range(I)) >= gp.quicksum(ddm[i, j, t, s] for j in range(I)))

m2.optimize()

if m2.status == GRB.OPTIMAL:
    print(f"Optimal solution found! Objective value: {m2.objVal}")
else:
    print("No optimal solution found.")
# Out:
# Set parameter MIPGap to value 1e-06
# Set parameter Heuristics to value 0.3
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.4.0 24E263)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  1e-06
# Heuristics  0.3
#
# Optimize a model with 61044 rows, 49596 columns and 175836 nonzeros
# Model fingerprint: 0x6b2758ea
# Variable types: 32316 continuous, 17280 integer (17280 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Presolve removed 12585 rows and 17778 columns
# Presolve time: 0.21s
# Presolved: 48459 rows, 31818 columns, 131048 nonzeros
# Variable types: 17877 continuous, 13941 integer (13941 binary)
# Found heuristic solution: objective 444018.73360
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
# Extra simplex iterations after uncrush: 9
#
# Root relaxation: objective 8.061623e+05, 12968 iterations, 0.38 seconds (0.55 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 806162.327    0  340 444018.734 806162.327  81.6%     -    0s
# H    0     0                    444462.95010 806162.327  81.4%     -    1s
# H    0     0                    448289.65610 806162.327  79.8%     -    1s
# H    0     0                    453846.68810 806161.700  77.6%     -    1s
#      0     0 805860.067    0  522 453846.688 805860.067  77.6%     -    1s
#      0     0 805860.067    0  513 453846.688 805860.067  77.6%     -    1s
#      0     0 805855.181    0  505 453846.688 805855.181  77.6%     -    1s
#      0     0 805855.158    0  509 453846.688 805855.158  77.6%     -    1s
#      0     0 805350.387    0  509 453846.688 805350.387  77.4%     -    2s
#      0     0 805316.983    0  502 453846.688 805316.983  77.4%     -    2s
# H    0     0                    454978.01960 805314.420  77.0%     -    2s
#      0     0 805314.420    0  513 454978.020 805314.420  77.0%     -    2s
#      0     0 805314.420    0  508 454978.020 805314.420  77.0%     -    2s
#      0     0 805314.344    0  510 454978.020 805314.344  77.0%     -    2s
#      0     0 805314.334    0  468 454978.020 805314.334  77.0%     -    2s
#      0     0 804787.687    0  525 454978.020 804787.687  76.9%     -    3s
#      0     0 804760.696    0  490 454978.020 804760.696  76.9%     -    3s
#      0     0 804754.871    0  520 454978.020 804754.871  76.9%     -    3s
# H    0     0                    455693.74525 804754.290  76.6%     -    3s
# H    0     0                    716023.78013 804754.290  12.4%     -    3s
#      0     0 804754.290    0  518 716023.780 804754.290  12.4%     -    3s
#      0     0 804754.289    0  522 716023.780 804754.289  12.4%     -    3s
#      0     0 804209.227    0  458 716023.780 804209.227  12.3%     -    4s
#      0     0 804208.798    0  438 716023.780 804208.798  12.3%     -    4s
# H    0     0                    716384.25713 804206.519  12.3%     -    4s
# H    0     0                    722051.10467 804206.519  11.4%     -    4s
#      0     0 804206.519    0  472 722051.105 804206.519  11.4%     -    4s
#      0     0 804206.519    0  468 722051.105 804206.519  11.4%     -    4s
#      0     0 804204.640    0  469 722051.105 804204.640  11.4%     -    4s
#      0     0 804203.432    0  503 722051.105 804203.432  11.4%     -    4s
#      0     0 804203.432    0  501 722051.105 804203.432  11.4%     -    4s
#      0     0 804203.410    0  507 722051.105 804203.410  11.4%     -    4s
#      0     0 803787.973    0  427 722051.105 803787.973  11.3%     -    5s
# H  487   444                    801660.62842 803248.837  0.20%   275   17s
# H  520   455                    802572.18671 803248.837  0.08%   273   18s
# H  561   437                    802692.06756 803224.571  0.07%   270   18s
#    754   439 802781.381   20   90 802692.068 803028.481  0.04%   255   20s
# H  764   445                    802702.55041 803028.481  0.04%   253   20s
# H  767   445                    802820.78588 803028.481  0.03%   252   20s
# H 1659   964                    802822.38022 802869.411  0.01%   140   24s
# H 1729   950                    802825.95485 802869.411  0.01%   136   24s
# H 1791   901                    802829.90826 802869.411  0.00%   133   24s
# H 2035   882                    802831.50260 802869.411  0.00%   122   24s
#   2171  1297 802869.411   28   69 802831.503 802869.411  0.00%   117   26s
#   3537  1720 802832.166   60   69 802831.503 802869.411  0.00%  87.9   31s
#   4127  1682 802850.295   55   65 802831.503 802869.411  0.00%  83.3   36s
#   4698  1719     cutoff   27      802831.503 802869.411  0.00%  81.0   41s
#   5171  1768 802832.166   50   67 802831.503 802869.411  0.00%  78.6   46s
#   6006  2040 802854.466   56  314 802831.503 802869.411  0.00%  76.0   50s
#   6013  2045 802841.297   28  137 802831.503 802869.411  0.00%  75.9   55s
#   6018  2048 802839.254   48  175 802831.503 802869.411  0.00%  75.8   60s
#   6023  2051 802846.301   55  173 802831.503 802869.411  0.00%  75.7   65s
#   6027  2054 802847.146   39  150 802831.503 802869.411  0.00%  75.7   70s
#   6031  2057 802839.254   33  129 802831.503 802869.411  0.00%  75.6   75s
#   6181  2018     cutoff   33      802831.503 802869.411  0.00%  97.8   80s
#   6411  2091 802840.865   42  105 802831.503 802869.401  0.00%  97.9   85s
# * 6649  2098             111    802850.37491 802869.181  0.00%  97.2   88s
#   6938  1746 802854.726   43   94 802850.375 802869.173  0.00%  94.7   91s
#
# Cutting planes:
#   Learned: 30
#   Gomory: 134
#   Lift-and-project: 124
#   Cover: 94
#   Implied bound: 526
#   Projected implied bound: 14
#   Clique: 13
#   MIR: 1264
#   Mixing: 20
#   Flow cover: 2434
#   Flow path: 4
#   Network: 25
#   RLT: 261
#   Relax-and-lift: 231
#   BQP: 2
#   PSD: 26
#
# Explored 7677 nodes (763329 simplex iterations) in 93.26 seconds (126.40 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 802850 802832 802832 ... 802703
#
# Optimal solution found (tolerance 1.00e-06)
# Best objective 8.028503749127e+05, best bound 8.028503749127e+05, gap 0.0000%
# Optimal solution found! Objective value: 802850.3749126834

# %%
# m2 = gp.Model("set")
# m2.setParam("MIPGap", 1e-6)
# m2.setParam("Heuristics", 0.3)


# a = m2.addVars(T, vtype=GRB.CONTINUOUS, name="alpha")
# bp = m2.addVars(T, S, vtype=GRB.CONTINUOUS, name="beta_plus")
# bm = m2.addVars(T, S, vtype=GRB.CONTINUOUS, name="beta_minus")
# gc = m2.addVars(T, S, vtype=GRB.CONTINUOUS, name="gamma_charge")
# gd = m2.addVars(T, S, vtype=GRB.CONTINUOUS, name="gamma_discharge")
# eta = m2.addVars(T, S, vtype=GRB.BINARY, name="eta")
# lam = m2.addVars(T, S, vtype=GRB.BINARY, name="lambda")
# mu = m2.addVars(T, S, vtype=GRB.BINARY, name="mu")

# x = m2.addVars(I, T, vtype=GRB.CONTINUOUS, lb=0, name="x")
# yp = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="y_plus")
# ym = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="y_minus")
# z = m2.addVars(I, T + 1, S, vtype=GRB.CONTINUOUS, name="z")
# zc = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, name="z_charge")
# zd = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, name="z_discharge")
# zeta = m2.addVars(I, T, S, vtype=GRB.BINARY, name="zeta")
# delta = m2.addVars(I, T, S, vtype=GRB.BINARY, name="delta")
# rho = m2.addVars(I, T, S, vtype=GRB.BINARY, name="rho")
# req1 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="req1")
# req2 = m2.addVars(I, I, T, S, vtype=GRB.BINARY, name="req2")

# dp = m2.addVars(I, I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="dyp")
# dm = m2.addVars(I, I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="dym")
# dcp = m2.addVars(I, I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="dzc+")
# dcm = m2.addVars(I, I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="dzc-")
# ddp = m2.addVars(I, I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="dzd+")
# ddm = m2.addVars(I, I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="dzd-")

# q1 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q1")
# q2 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q2")
# q3 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q3")
# q4 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q4")
# q5 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q5")
# q6 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q6")
# q7 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q7")

# ep = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, name="e_plus")
# em = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, name="e_minus")
# ec = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, name="e_charge")
# ed = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, name="e_discharge")

# m2.update()

# obj = gp.quicksum(P_DA[t] * a[t] for t in range(T)) + gp.quicksum((1 / S) * (P_RT[t, s] * bp[t, s] - P_PN[t] * bm[t, s]) for t in range(T) for s in range(S))

# m2.setObjective(obj, GRB.MAXIMIZE)

# # ---------individual-----------
# for i, t, s in product(range(I), range(T), range(S)):
#     m2.addConstr(R[i, t, s] - x[i, t] == yp[i, t, s] - ym[i, t, s] + zc[i, t, s] - zd[i, t, s])
#     m2.addConstr(yp[i, t, s] <= R[i, t, s])
#     m2.addConstr(zd[i, t, s] <= z[i, t, s])
#     m2.addConstr(zc[i, t, s] <= K[i] - z[i, t, s])
#     m2.addConstr(yp[i, t, s] <= M1 * rho[i, t, s])
#     m2.addConstr(ym[i, t, s] <= M1 * (1 - rho[i, t, s]))
#     m2.addConstr(ym[i, t, s] <= M1 * delta[i, t, s])
#     m2.addConstr(zc[i, t, s] <= M1 * (1 - delta[i, t, s]))
#     m2.addConstr(zc[i, t, s] <= M1 * zeta[i, t, s])
#     m2.addConstr(zd[i, t, s] <= M1 * (1 - zeta[i, t, s]))
#     m2.addConstr(z[i, t, s] <= K[i])
# for i, s in product(range(I), range(S)):
#     m2.addConstr(z[i, 0, s] == K0[i])

# # -----------settle------------
# for i, t, s in product(range(I), range(T), range(S)):
#     m2.addConstr(ep[i, t, s] == yp[i, t, s] - gp.quicksum(dp[i, j, t, s] for j in range(I)))
#     m2.addConstr(em[i, t, s] == ym[i, t, s] - gp.quicksum(dm[i, j, t, s] for j in range(I)))
#     m2.addConstr(ec[i, t, s] == zc[i, t, s] - gp.quicksum(dcp[i, j, t, s] for j in range(I)) + gp.quicksum(dcm[i, j, t, s] for j in range(I)))
#     m2.addConstr(ed[i, t, s] == zd[i, t, s] - gp.quicksum(ddp[i, j, t, s] for j in range(I)) + gp.quicksum(ddm[i, j, t, s] for j in range(I)))
#     m2.addConstr(ec[i, t, s] <= K[i] - z[i, t, s])
#     m2.addConstr(ed[i, t, s] <= z[i, t, s])
#     m2.addConstr(z[i, t + 1, s] == z[i, t, s] + ec[i, t, s] - ed[i, t, s])
    
#     m2.addConstr(req1[i, t, s] <= ym[i, t, s])
#     m2.addConstr(req1[i, t, s] <= z[i, t, s])
#     m2.addConstr(req1[i, t, s] >= ym[i, t, s] - M1 * (1 - q6[i, t, s]))
#     m2.addConstr(req1[i, t, s] >= z[i, t, s] - M1 * q6[i, t, s])
#     m2.addConstr(ed[i, t, s] >= req1[i, t, s])
    
# for i, t, s in product(range(I), range(T), range(S)):
#     m2.addConstr(yp[i, t, s] >= gp.quicksum(dp[i, j, t, s] for j in range(I)))
#     m2.addConstr(ym[i, t, s] >= gp.quicksum(dm[i, j, t, s] for j in range(I)))
#     m2.addConstr(zc[i, t, s] >= gp.quicksum(dcp[i, j, t, s] for j in range(I)))
#     m2.addConstr(zd[i, t, s] >= gp.quicksum(ddp[i, j, t, s] for j in range(I)))
#     m2.addConstr(gp.quicksum(ym[i, t, s] for i in range(I)) >= gp.quicksum(dcp[i, j, t, s] for j in range(I)))
#     m2.addConstr(gp.quicksum(ym[i, t, s] for i in range(I)) >= gp.quicksum(ddm[i, j, t, s] for j in range(I)))
    
# for i, j, t, s in product(range(I), range(I), range(T), range(S)):
#     m2.addConstr(gp.quicksum(dp[i, j, t, s] for j in range(I)) - gp.quicksum(dp[j, i, t, s] for j in range(I) if j != i) == dp[i, i, t, s])
#     # if j != i:
#     #     dcm[j, i, t, s] == 0
#     #     ddp[j, i, t, s] == 0
#     #     dcm[i, j, t, s] == 0
#     #     ddp[i, j, t, s] == 0
#     # m2.addConstr(req2[i, i, t, s] <= dp[i, i, t, s] - ddp[i, i, t, s] )
#     # m2.addConstr(req2[i, i, t, s] <= K[i] - z[i, t, s] - zc[i, t, s])
#     # m2.addConstr(req2[i, i, t, s] >= (dp[i, i, t, s] - ddp[i, i, t, s]) - M1 * (1 - q7[i, t, s]))
#     # m2.addConstr(req2[i, i, t, s] >= (K[i] - z[i, t, s] - zc[i, t, s]) - M1 * q7[i, t, s])
#     # m2.addConstr(dcm[i, i, t, s] >= req2[i, i, t, s])

# for i, t, s in product(range(I), range(T), range(S)):
#     for j in range(I):
#         if j != i:
#             m2.addConstr(dm[j, i, t, s] >= dp[j, i, t, s] + dcp[j, i, t, s] + ddm[j, i, t, s])
    
# for i, t, s in product(range(I), range(T), range(S)):
#     m2.addConstr(gp.quicksum(dcp[i, j, t, s] for j in range(I)) <= M1 * q1[i, t, s])
#     m2.addConstr(dcm[i, i, t, s] <= M1 * (1 - q1[i, t, s]))
#     m2.addConstr(ddp[i, i, t, s] <= M1 * q2[i, t, s])
#     m2.addConstr(gp.quicksum(ddm[i, j, t, s] for j in range(I)) <= M1 * (1 - q2[i, t, s]))
#     m2.addConstr(ep[i, t, s] <= M1 * q3[i, t, s])
#     m2.addConstr(em[i, t, s] <= M1 * (1 - q3[i, t, s]))
#     m2.addConstr(em[i, t, s] <= M1 * q4[i, t, s])
#     m2.addConstr(ec[i, t, s] <= M1 * (1 - q4[i, t, s]))
#     m2.addConstr(ec[i, t, s] <= M1 * q5[i, t, s])
#     m2.addConstr(ed[i, t, s] <= M1 * (1 - q5[i, t, s]))

# #-----------settlement-----------
# for t in range(T):
#     m2.addConstr(a[t] == gp.quicksum(x[i, t] for i in range(I)))
# for t, s in product(range(T), range(S)):
#     m2.addConstr(bp[t, s] == gp.quicksum(ep[i, t, s] for i in range(I)))
#     m2.addConstr(bm[t, s] == gp.quicksum(em[i, t, s] for i in range(I)))
#     m2.addConstr(gc[t, s] == gp.quicksum(ec[i, t, s] for i in range(I)))
#     m2.addConstr(gd[t, s] == gp.quicksum(ed[i, t, s] for i in range(I)))

# #----------aggregation------------
# for t, s in product(range(T), range(S)):
#     m2.addConstr(gp.quicksum(R[i, t, s] for i in range(I)) - a[t] == bp[t, s] - bm[t, s] + gc[t, s] - gd[t, s])
#     m2.addConstr(bp[t, s] <= gp.quicksum(R[i, t, s] for i in range(I)))
#     m2.addConstr(bp[t, s] <= M2 * mu[t, s])
#     m2.addConstr(bm[t, s] <= M2 * (1 - mu[t, s]))
#     m2.addConstr(bm[t, s] <= M2 * eta[t, s])
#     m2.addConstr(gc[t, s] <= M2 * (1 - eta[t, s]))
    
# m2.optimize()

# if m2.status == GRB.OPTIMAL:
#     print(f"Optimal solution found! Objective value: {m2.objVal}")
# else:
#     print("No optimal solution found.")

# %%
# a_vals = np.array(
#     [m2.getVarByName(f"alpha[{t}]").X for t in range(T)]
# )
# bp_vals = np.array(
#     [[m2.getVarByName(f"beta_plus[{t},{s}]").X for s in range(S)] for t in range(T)]
# )
# bm_vals = np.array(
#     [[m2.getVarByName(f"beta_minus[{t},{s}]").X for s in range(S)] for t in range(T)]
# )
# x_vals = np.array(
#     [
#         [[m2.getVarByName(f"x[{i},{t}]").X for s in range(S)] for t in range(T)]
#         for i in range(I)
#     ]
# )
# yp_vals = np.array(
#     [
#         [
#             [m2.getVarByName(f"y_plus[{i},{t},{s}]").X for s in range(S)]
#             for t in range(T)
#         ]
#         for i in range(I)
#     ]
# )
# ym_vals = np.array(
#     [
#         [
#             [m2.getVarByName(f"y_minus[{i},{t},{s}]").X for s in range(S)]
#             for t in range(T)
#         ]
#         for i in range(I)
#     ]
# )
# zc_vals = np.array(
#     [
#         [
#             [m2.getVarByName(f"z_charge[{i},{t},{s}]").X for s in range(S)]
#             for t in range(T)
#         ]
#         for i in range(I)
#     ]
# )
# zd_vals = np.array(
#     [
#         [
#             [m2.getVarByName(f"z_discharge[{i},{t},{s}]").X for s in range(S)]
#             for t in range(T)
#         ]
#         for i in range(I)
#     ]
# )
# z_vals = np.array(
#     [
#         [[m2.getVarByName(f"z[{i},{t},{s}]").X for s in range(S)] for t in range(T + 1)]
#         for i in range(I)
#     ]
# )
# ep_vals = np.array(
#     [
#         [
#             [m2.getVarByName(f"e_plus[{i},{t},{s}]").X for s in range(S)]
#             for t in range(T)
#         ]
#         for i in range(I)
#     ]
# )
# em_vals = np.array(
#     [
#         [
#             [m2.getVarByName(f"e_minus[{i},{t},{s}]").X for s in range(S)]
#             for t in range(T)
#         ]
#         for i in range(I)
#     ]
# )
# ec_vals = np.array(
#     [
#         [
#             [m2.getVarByName(f"e_charge[{i},{t},{s}]").X for s in range(S)]
#             for t in range(T)
#         ]
#         for i in range(I)
#     ]
# )
# ed_vals = np.array(
#     [
#         [
#             [m2.getVarByName(f"e_discharge[{i},{t},{s}]").X for s in range(S)]
#             for t in range(T)
#         ]
#         for i in range(I)
#     ]
# )
# dp_vals = np.array(
#     [
#         [
#             [
#                 [m2.getVarByName(f"dyp[{i},{j},{t},{s}]").X for s in range(S)]
#                 for t in range(T)
#             ]
#             for i in range(I)
#         ]
#         for j in range(I)
#     ]
# )
# dm_vals = np.array(
#     [
#         [
#             [
#                 [m2.getVarByName(f"dym[{i},{j},{t},{s}]").X for s in range(S)]
#                 for t in range(T)
#             ]
#             for i in range(I)
#         ]
#         for j in range(I)
#     ]
# )
# dcp_vals = np.array(
#     [
#         [
#             [
#                 [m2.getVarByName(f"dzc+[{i},{j},{t},{s}]").X for s in range(S)]
#                 for t in range(T)
#             ]
#             for i in range(I)
#         ]
#         for j in range(I)
#     ]
# )
# dcm_vals = np.array(
#     [
#         [
#             [
#                 [m2.getVarByName(f"dzc-[{i},{j},{t},{s}]").X for s in range(S)]
#                 for t in range(T)
#             ]
#             for i in range(I)
#         ]
#         for j in range(I)
#     ]
# )
# ddp_vals = np.array(
#     [
#         [
#             [
#                 [m2.getVarByName(f"dzd+[{i},{j},{t},{s}]").X for s in range(S)]
#                 for t in range(T)
#             ]
#             for i in range(I)
#         ]
#         for j in range(I)
#     ]
# )
# ddm_vals = np.array(
#     [
#         [
#             [
#                 [m2.getVarByName(f"dzd-[{i},{j},{t},{s}]").X for s in range(S)]
#                 for t in range(T)
#             ]
#             for i in range(I)
#         ]
#         for j in range(I)
#     ]
# )

# %%
m2 = gp.Model("set")
m2.setParam("MIPGap", 1e-6)
m2.setParam("Heuristics", 0.3)

a = m2.addVars(T, vtype=GRB.CONTINUOUS, name="alpha")
bp = m2.addVars(T, S, vtype=GRB.CONTINUOUS, name="beta_plus")
bm = m2.addVars(T, S, vtype=GRB.CONTINUOUS, name="beta_minus")
gc = m2.addVars(T, S, vtype=GRB.CONTINUOUS, name="gamma_charge")
gd = m2.addVars(T, S, vtype=GRB.CONTINUOUS, name="gamma_discharge")
eta = m2.addVars(T, S, vtype=GRB.BINARY, name="eta")
lam = m2.addVars(T, S, vtype=GRB.BINARY, name="lambda")
mu = m2.addVars(T, S, vtype=GRB.BINARY, name="mu")

x = m2.addVars(I, T, vtype=GRB.CONTINUOUS, lb=0, name="x")
yp = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="y_plus")
ym = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="y_minus")
z = m2.addVars(I, T + 1, S, vtype=GRB.CONTINUOUS, name="z")
zc = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, name="z_charge")
zd = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, name="z_discharge")
zeta = m2.addVars(I, T, S, vtype=GRB.BINARY, name="zeta")
delta = m2.addVars(I, T, S, vtype=GRB.BINARY, name="delta")
rho = m2.addVars(I, T, S, vtype=GRB.BINARY, name="rho")
req1 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="req1")
req2 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="req2")

dp = m2.addVars(I, I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="dyp")
dm = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="dym")
dcp = m2.addVars(I, I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="dzc+")
dcm = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="dzc-")
ddp = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="dzd+")
ddm = m2.addVars(I, I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="dzd-")

q1 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q1")
q2 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q2")
q3 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q3")
q4 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q4")
q5 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q5")
q6 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q6")
q7 = m2.addVars(I, T, S, vtype=GRB.BINARY, name="q7")

ep = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, name="e_plus")
em = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, name="e_minus")
ec = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, name="e_charge")
ed = m2.addVars(I, T, S, vtype=GRB.CONTINUOUS, name="e_discharge")

m2.update()

obj = gp.quicksum(P_DA[t] * a[t] for t in range(T)) + gp.quicksum((1 / S) * (P_RT[t, s] * bp[t, s] - P_PN[t] * bm[t, s]) for t in range(T) for s in range(S))

m2.setObjective(obj, GRB.MAXIMIZE)

# ---------individual-----------
for i, t, s in product(range(I), range(T), range(S)):
    m2.addConstr(R[i, t, s] - x[i, t] == yp[i, t, s] - ym[i, t, s] + zc[i, t, s] - zd[i, t, s])
    m2.addConstr(yp[i, t, s] <= R[i, t, s])
    m2.addConstr(zd[i, t, s] <= z[i, t, s])
    m2.addConstr(zc[i, t, s] <= K[i] - z[i, t, s])
    m2.addConstr(yp[i, t, s] <= M1 * rho[i, t, s])
    m2.addConstr(ym[i, t, s] <= M1 * (1 - rho[i, t, s]))
    m2.addConstr(ym[i, t, s] <= M1 * delta[i, t, s])
    m2.addConstr(zc[i, t, s] <= M1 * (1 - delta[i, t, s]))
    m2.addConstr(zc[i, t, s] <= M1 * zeta[i, t, s])
    m2.addConstr(zd[i, t, s] <= M1 * (1 - zeta[i, t, s]))
    m2.addConstr(z[i, t, s] <= K[i])
for i, s in product(range(I), range(S)):
    m2.addConstr(z[i, 0, s] == K0[i])

# -----------settle------------
for i, t, s in product(range(I), range(T), range(S)):
    m2.addConstr(ep[i, t, s] == yp[i, t, s] - gp.quicksum(dp[i, j, t, s] for j in range(I)))
    m2.addConstr(em[i, t, s] == ym[i, t, s] - dm[i, t, s])
    m2.addConstr(ec[i, t, s] == zc[i, t, s] - gp.quicksum(dcp[i, j, t, s] for j in range(I)) + dcm[i, t, s])
    m2.addConstr(ed[i, t, s] == zd[i, t, s] - ddp[i, t, s] + gp.quicksum(ddm[i, j, t, s] for j in range(I)))
    m2.addConstr(ec[i, t, s] <= K[i] - z[i, t, s])
    m2.addConstr(ed[i, t, s] <= z[i, t, s])
    m2.addConstr(z[i, t + 1, s] == z[i, t, s] + ec[i, t, s] - ed[i, t, s])
    
    m2.addConstr(req1[i, t, s] <= ym[i, t, s])
    m2.addConstr(req1[i, t, s] <= z[i, t, s])
    m2.addConstr(req1[i, t, s] >= ym[i, t, s] - M1 * (1 - q6[i, t, s]))
    m2.addConstr(req1[i, t, s] >= z[i, t, s] - M1 * q6[i, t, s])
    m2.addConstr(ed[i, t, s] >= req1[i, t, s])
    
for i, t, s in product(range(I), range(T), range(S)):
    m2.addConstr(yp[i, t, s] >= gp.quicksum(dp[i, j, t, s] for j in range(I)))
    m2.addConstr(ym[i, t, s] >= dm[i, t, s])
    m2.addConstr(zc[i, t, s] >= gp.quicksum(dcp[i, j, t, s] for j in range(I)))
    m2.addConstr(zd[i, t, s] >= ddp[i, t, s])
    # m2.addConstr(gp.quicksum(ym[i, t, s] for i in range(I)) >= gp.quicksum(dcp[i, j, t, s] for j in range(I)))
    # m2.addConstr(gp.quicksum(ym[i, t, s] for i in range(I)) >= gp.quicksum(ddm[i, j, t, s] for j in range(I)))
    
for i, j, t, s in product(range(I), range(I), range(T), range(S)):
    m2.addConstr(gp.quicksum(dp[i, j, t, s] for j in range(I)) - gp.quicksum(dp[j, i, t, s] for j in range(I) if j != i) == dp[i, i, t, s])
    m2.addConstr(req2[i, t, s] <= dp[i, i, t, s] - ddp[i, t, s])
    m2.addConstr(req2[i, t, s] <= K[i] - z[i, t, s] - zc[i, t, s])
    m2.addConstr(req2[i, t, s] >= (dp[i, i, t, s] - ddp[i, t, s]) - M1 * (1 - q7[i, t, s]))
    m2.addConstr(req2[i, t, s] >= (K[i] - z[i, t, s] - zc[i, t, s]) - M1 * q7[i, t, s])
    m2.addConstr(dcm[i, t, s] >= req2[i, t, s])

for i, t, s in product(range(I), range(T), range(S)):
    for j in range(I):
        if j != i:
            m2.addConstr(ym[j, t, s] >= dp[i, j, t, s] + dcp[i, j, t, s] + ddm[i, j, t, s])
        if j == i:
            m2.addConstr(ym[i, t, s] >= dcp[i, j, t, s] + ddm[i, j, t, s])
    
for i, t, s in product(range(I), range(T), range(S)):
    m2.addConstr(gp.quicksum(dcp[i, j, t, s] for j in range(I)) <= M1 * q1[i, t, s])
    m2.addConstr(dcm[i, t, s] <= M1 * (1 - q1[i, t, s]))
    m2.addConstr(ddp[i, t, s] <= M1 * q2[i, t, s])
    m2.addConstr(gp.quicksum(ddm[i, j, t, s] for j in range(I)) <= M1 * (1 - q2[i, t, s]))
    m2.addConstr(ep[i, t, s] <= M1 * q3[i, t, s])
    m2.addConstr(em[i, t, s] <= M1 * (1 - q3[i, t, s]))
    m2.addConstr(em[i, t, s] <= M1 * q4[i, t, s])
    m2.addConstr(ec[i, t, s] <= M1 * (1 - q4[i, t, s]))
    m2.addConstr(ec[i, t, s] <= M1 * q5[i, t, s])
    m2.addConstr(ed[i, t, s] <= M1 * (1 - q5[i, t, s]))

#-----------settlement-----------
for t in range(T):
    m2.addConstr(a[t] == gp.quicksum(x[i, t] for i in range(I)))
for t, s in product(range(T), range(S)):
    m2.addConstr(bp[t, s] == gp.quicksum(ep[i, t, s] for i in range(I)))
    m2.addConstr(bm[t, s] == gp.quicksum(em[i, t, s] for i in range(I)))
    m2.addConstr(gc[t, s] == gp.quicksum(ec[i, t, s] for i in range(I)))
    m2.addConstr(gd[t, s] == gp.quicksum(ed[i, t, s] for i in range(I)))

#----------aggregation------------
for t, s in product(range(T), range(S)):
    m2.addConstr(gp.quicksum(R[i, t, s] for i in range(I)) - a[t] == bp[t, s] - bm[t, s] + gc[t, s] - gd[t, s])
    m2.addConstr(bp[t, s] <= gp.quicksum(R[i, t, s] for i in range(I)))
    m2.addConstr(bp[t, s] <= M2 * mu[t, s])
    m2.addConstr(bm[t, s] <= M2 * (1 - mu[t, s]))
    m2.addConstr(bm[t, s] <= M2 * eta[t, s])
    m2.addConstr(gc[t, s] <= M2 * (1 - eta[t, s]))
    
m2.optimize()

if m2.status == GRB.OPTIMAL:
    print(f"Optimal solution found! Objective value: {m2.objVal}")
else:
    print("No optimal solution found.")
# Out:
# Set parameter MIPGap to value 1e-06
# Set parameter Heuristics to value 0.3
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.4.0 24E263)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# MIPGap  1e-06
# Heuristics  0.3
#
# Optimize a model with 88404 rows, 51036 columns and 259356 nonzeros
# Model fingerprint: 0xb8b6a136
# Variable types: 32316 continuous, 18720 integer (18720 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Presolve removed 36777 rows and 14322 columns
# Presolve time: 0.39s
# Presolved: 51627 rows, 36714 columns, 145479 nonzeros
# Variable types: 21621 continuous, 15093 integer (15093 binary)
# Found heuristic solution: objective 762357.64319
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root relaxation: objective 8.061114e+05, 20356 iterations, 0.53 seconds (0.70 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 806111.352    0  527 762357.643 806111.352  5.74%     -    1s
#      0     0 806111.352    0  531 762357.643 806111.352  5.74%     -    1s
# H    0     0                    762360.11302 806111.352  5.74%     -    1s
#      0     0 805879.583    0  751 762360.113 805879.583  5.71%     -    2s
#      0     0 805879.582    0  748 762360.113 805879.582  5.71%     -    2s
#      0     0 805879.582    0  745 762360.113 805879.582  5.71%     -    2s
#      0     0 805768.546    0  736 762360.113 805768.546  5.69%     -    2s
#      0     0 805768.546    0  737 762360.113 805768.546  5.69%     -    2s
#      0     0 805730.928    0  749 762360.113 805730.928  5.69%     -    2s
#      0     0 805730.928    0  749 762360.113 805730.928  5.69%     -    2s
#      0     0 805711.973    0  748 762360.113 805711.973  5.69%     -    2s
#      0     0 805246.214    0  755 762360.113 805246.214  5.63%     -    4s
#      0     0 805224.013    0  734 762360.113 805224.013  5.62%     -    4s
#      0     0 805224.013    0  730 762360.113 805224.013  5.62%     -    4s
#      0     0 805202.657    0  827 762360.113 805202.657  5.62%     -    4s
#      0     0 805202.657    0  827 762360.113 805202.657  5.62%     -    4s
# H 1442  1067                    801289.30561 802907.217  0.20%   452   46s
# H 1444   998                    801341.14093 802907.217  0.20%   453   46s
# H 1447   990                    801346.01027 802907.217  0.19%   452   46s
# H 1453   456                    801981.74655 802907.217  0.12%   453   46s
# H 1562   496                    801990.79812 802878.414  0.11%   457   47s
# H 1662   438                    801992.29053 802853.874  0.11%   457   49s
# H 1667   438                    801993.02820 802853.874  0.11%   459   49s
#   1672   440 802193.510    7  313 801993.028 802853.874  0.11%   460   50s
# H 1688   444                    801999.78508 802853.874  0.11%   461   51s
# H 1692   444                    802012.58194 802853.874  0.10%   463   51s
#   1961   494 802535.094    8  358 802012.582 802817.104  0.10%   438   57s
#   1964   496 802054.708   11  287 802012.582 802817.104  0.10%   438   62s
#   1969   499 802166.963   16  322 802012.582 802817.104  0.10%   436   66s
# H 1971   475                    802027.73965 802817.104  0.10%   436   70s
#
# Interrupt request received
#
# Cutting planes:
#   Learned: 244
#   Gomory: 86
#   Lift-and-project: 97
#   Cover: 89
#   Implied bound: 521
#   Projected implied bound: 18
#   Clique: 19
#   MIR: 795
#   Mixing: 4
#   Flow cover: 1702
#   Flow path: 4
#   Network: 18
#   RLT: 318
#   Relax-and-lift: 270
#   BQP: 4
#   PSD: 7
#
# Explored 1974 nodes (1082531 simplex iterations) in 75.83 seconds (104.25 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 802028 802013 802013 ... 801982
#
# Solve interrupted
# Best objective 8.020277396519e+05, best bound 8.028171036071e+05, gap 0.0984%
# No optimal solution found.

# %%
# for s, t, i in product(range(1,2), range(T), range(I)):
#     print(f"[i={i} t={t:02}, s={s:02} BEFORE]  "
#           f"R={R[i, t, s]:.2f}, x={x_vals[i, t, s]:.2f}, "
#           f"y⁺={yp_vals[i, t, s]:.2f}, y⁻={ym_vals[i, t, s]:.2f}, "
#           f"zᶜ={zc_vals[i, t, s]:.2f}, zᴰ={zd_vals[i, t, s]:.2f}, "
#           f"z={z_vals[i, t, s]:.2f}")
    
# #     print(f"[i={i} t={t:02}, s={s:02} SET(-)]  "
# #           f"R={R[i, t, s]:.2f}, x={x_vals[i, t, s]:.2f}, "
# #           f"d⁺={dp_vals[i, t, s]:.2f}, d⁻={dm_vals[i, t, s]:.2f}, "
# #           f"dᶜ={dcp_vals[i, t, s]:.2f}, dᴰ={ddp_vals[i, t, s]:.2f}, "
# #           f"z={z_vals[i, t, s]:.2f}")
    
# #     print(f"[i={i} t={t:02}, s={s:02} SET(+)]  "
# #           f"R={R[i, t, s]:.2f}, x={x_vals[i, t, s]:.2f}, "
# #           f"d⁺= -X-, d⁻= -X-,",
# #           f"dᶜ={dcm_vals[i, t, s]:.2f}, dᴰ={ddm_vals[i, t, s]:.2f}, "
# #           f"z={z_vals[i, t, s]:.2f}")

#     print(f"[i={i} t={t:02}, s={s:02} AFTER ]  "
#           f"R={R[i, t, s]:.2f}, x={x_vals[i, t, s]:.2f}, "
#           f"e⁺={ep_vals[i, t, s]:.2f}, e⁻={em_vals[i, t, s]:.2f}, "
#           f"eᶜ={ec_vals[i, t, s]:.2f}, eᴰ={ed_vals[i, t, s]:.2f}, "
#           f"z={z_vals[i, t, s]:.2f}")
#     print()
