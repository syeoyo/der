# %% [markdown]
# ### data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gurobipy as gp
from gurobipy import GRB

R_flat = pd.read_csv("result/result_R.csv")

I_len = R_flat["generator"].nunique()
T_len = R_flat["time"].nunique() 
S_len = R_flat["scenario"].nunique()

R = R_flat.pivot_table(
    values="value",
    index="generator",
    columns=["time", "scenario"]
).to_numpy()
R = R.reshape(I_len, T_len, S_len)

I, T, S = R.shape

price_q = pd.read_csv(
    "/Users/jangseohyun/Documents/workspace/symply/DER/DATA_price.csv"
)
price_q["Time"] = pd.to_datetime(price_q["Time"], format="%Y-%m-%d %H:%M")

price_q["Hour"] = price_q["Time"].dt.floor("h")
price_h = price_q.groupby("Hour").mean(numeric_only=True)

price = price_h.iloc[: S * T]

P_DA = np.array(
    [sum(price["Price"].iloc[t + s * T] for s in range(S)) / S * 1.2 for t in range(T)]
)
P_RT = np.array([[price["Price"].iloc[t + s * T] for s in range(S)] for t in range(T)])
P_PN = np.array(
    [sum(price["Price"].iloc[t + s * T] for s in range(S)) / S * 2 for t in range(T)]
)

only_profit = pd.read_csv('result/result_only_profit.csv').values

# %% [markdown]
# ### settlement model

# %%
def my_callback(model, where):
    if where == GRB.Callback.MIP:
        obj_best = model.cbGet(GRB.Callback.MIP_OBJBST)
        obj_bound = model.cbGet(GRB.Callback.MIP_OBJBND)

        # MIP Gap 계산
        if obj_best != 0:  # obj_best가 0이 아닌 경우에만 계산
            mip_gap = abs(obj_best - obj_bound) / abs(obj_best)
        else:
            mip_gap = float("inf")  # obj_best가 0인 경우 무한대로 설정

        print(f"obj_best: {obj_best}, obj_bound: {obj_bound}, MIP Gap: {mip_gap:.4f}")


set = gp.Model("Settlement")
# set.Params.OutputFlag = 0
# set.setParam('TimeLimit', 600)
# set.setParam('Presolve', 0)
set.setParam("PoolSolutions", 15)
set.setParam("PoolSearchMode", 2)
set.setParam("PoolGap", 0.05)

x = set.addVars(I, T, vtype=GRB.CONTINUOUS, lb=0, name="x")
y_plus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="y_plus")
y_minus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="y_minus")
M_y = max(R[i, t, s] for i in range(I) for t in range(T) for s in range(S))
z_y = set.addVars(I, T, S, vtype=GRB.BINARY, name="z_y")

d = set.addVars(I, I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="d")
e_plus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="e_plus")
e_minus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="e_minus")
M_e = max(sum(R[i, t, s] for i in range(I)) for t in range(T) for s in range(S))
z_e = set.addVars(T, S, vtype=GRB.BINARY, name="z_e")

profit_increase = set.addVars(I, vtype=GRB.CONTINUOUS, lb=0, name="profit_increase")

set.update()

# obj. func.
obj = gp.quicksum(
    P_DA[t] * x[i, t] for i in range(I) for t in range(T)
) + gp.quicksum(
    1/S * (P_RT[t, s] * e_plus[i, t, s] - P_PN[t] * e_minus[i, t, s])
    for i in range(I) for t in range(T) for s in range(S)
)

set.setObjective(obj, GRB.MAXIMIZE)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2611964
# Academic license - for non-commercial use only - expires 2026-01-20
# Set parameter PoolSolutions to value 15
# Set parameter PoolSearchMode to value 2
# Set parameter PoolGap to value 0.05

# %%
# x로 y+, y- 결정 지어주기
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(R[i, t, s] - x[i, t] == y_plus[i, t, s] - y_minus[i, t, s])

# y+, y- 둘 중 하나는 0이어야함
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(y_plus[i, t, s] <= M_y * z_y[i, t, s])
            set.addConstr(y_minus[i, t, s] <= M_y * (1 - z_y[i, t, s]))

# rt 조건
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(y_plus[i, t, s] <= R[i, t, s])

# sum e+, sum e- 결정 지어주기
for t in range(T):
    for s in range(S):
        set.addConstr(
            gp.quicksum(R[i, t, s] for i in range(I))
            - gp.quicksum(x[i, t] for i in range(I))
            == gp.quicksum(e_plus[i, t, s] for i in range(I))
            - gp.quicksum(e_minus[i, t, s] for i in range(I))
        )

# sum e+, sum e- 둘 중 하나는 0이어야 함
for t in range(T):
    for s in range(S):
        set.addConstr(gp.quicksum(e_plus[i, t, s] for i in range(I)) <= M_e * z_e[t, s])
        set.addConstr(
            gp.quicksum(e_minus[i, t, s] for i in range(I)) <= M_e * (1 - z_e[t, s])
        )

# e+, e- 정의
for i in range(I):
    for t in range(T):
        for s in range(S):
            # e_plus: 초과량에서 준 양을 뺀 것
            set.addConstr(
                e_plus[i, t, s]
                == y_plus[i, t, s]
                - gp.quicksum(d[i, j, t, s] for j in range(I) if j != i)
            )
            # e_minus: 부족량에서 받은 양을 뺀 것
            set.addConstr(
                e_minus[i, t, s]
                == y_minus[i, t, s]
                - gp.quicksum(d[j, i, t, s] for j in range(I) if j != i)
            )

# sum e+ <= sum R
for t in range(T):
    for s in range(S):
        set.addConstr(
            gp.quicksum(e_plus[i, t, s] for i in range(I))
            <= gp.quicksum(R[i, t, s] for i in range(I))
        )

# 전력 이동 제한
for i in range(I):
    for t in range(T):
        for s in range(S):
            # 본인이 주는 양은 자신의 y+을 넘을 수 없음
            set.addConstr(
                gp.quicksum(d[i, j, t, s] for j in range(I) if j != i)
                <= y_plus[i, t, s]
            )
            # 본인이 받는 양은 자신의 y-을 넘을 수 없음
            set.addConstr(
                gp.quicksum(d[j, i, t, s] for j in range(I) if j != i)
                <= y_minus[i, t, s]
            )

# 자기 자신과의 거래 방지
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(d[i, i, t, s] == 0)

# 수익증가율 정의
for i in range(I):
    set.addConstr(profit_increase[i] == (
        gp.quicksum(
            P_DA[t] * x[i, t]
            + 1 / S * gp.quicksum(P_RT[t, s] * e_plus[i, t, s] - P_PN[t] * e_minus[i, t, s] for s in range(S))
            for t in range(T)
        ) - only_profit[i].item()
    ) / only_profit[i].item())

# 수익증가율이 사람마다 같아야함
for i in range(I):
    set.addConstr(profit_increase[i] == gp.quicksum(profit_increase[j] for j in range(I)) / I)

# %%
set.optimize()

if set.status == GRB.OPTIMAL:
    x_vals = np.array([[x[i, t].x for t in range(T)] for i in range(I)])
    y_plus_vals = np.array(
        [[[y_plus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    y_minus_vals = np.array(
        [[[y_minus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    d_vals = np.array(
        [
            [[[d[i, j, t, s].x for s in range(S)] for t in range(T)] for j in range(I)]
            for i in range(I)
        ]
    )
    e_plus_vals = np.array(
        [[[e_plus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    e_minus_vals = np.array(
        [[[e_minus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    print("\n- - - - - - - - - - - - - - - - - - - - - - - -")
    print("Optimal solution found!")
    print(set.objVal)
else:
    print("\nNo optimal solution found.")
# Out:
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.3.0 24D70)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# PoolSolutions  15
# PoolSearchMode  2
# PoolGap  0.05
#
# Optimize a model with 45140 rows, 72730 columns and 284490 nonzeros
# Model fingerprint: 0x907edae7
# Variable types: 67450 continuous, 5280 integer (5280 binary)
# Coefficient statistics:
#   Matrix range     [2e-07, 9e+01]
#   Objective range  [4e-04, 4e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-02, 9e+01]
# Presolve removed 34968 rows and 51976 columns
# Presolve time: 0.09s
# Presolved: 10172 rows, 20754 columns, 58225 nonzeros
# Variable types: 15474 continuous, 5280 integer (5280 binary)
#
# Root relaxation: objective 1.203099e+04, 9546 iterations, 0.33 seconds (0.43 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 12030.9909    0   77          - 12030.9909      -     -    0s
#      0     0 12028.5747    0  322          - 12028.5747      -     -    1s
# H    0     0                    11877.911575 11996.1976  1.00%     -    1s
# H    0     0                    11878.130049 11996.1976  0.99%     -    1s
#      0     0 11996.1976    0  312 11878.1300 11996.1976  0.99%     -    1s
#      0     0 11878.7275    0  124 11878.1300 11878.7275  0.01%     -    2s
#      0     0 11878.5202    0  117 11878.1300 11878.5202  0.00%     -    2s
#      0     0 11878.2978    0   44 11878.1300 11878.2978  0.00%     -    2s
#      0     0 11878.1300    0   42 11878.1300 11878.1300  0.00%     -    2s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 11878.1300    0   40          - 11878.1300      -     -    2s
#      0     0 11878.1300    0   30          - 11878.1300      -     -    2s
#      0     0 11878.1300    0   16          - 11878.1300      -     -    2s
#      0     0 11878.1300    0   20          - 11878.1300      -     -    3s
#      0     0 11878.1300    0   13          - 11878.1300      -     -    3s
#      0     0          -    0               - 11878.1300      -     -    3s
#      0     0          -    0               - 11878.1300      -     -    3s
#      0     0          -    0               - 11878.1300      -     -    3s
#      0     2          -    0               - 11878.1300      -     -    3s
#
# Cutting planes:
#   Gomory: 18
#   Cover: 185
#   Implied bound: 596
#   Clique: 318
#   MIR: 44
#   StrongCG: 2
#   Flow cover: 138
#   RLT: 561
#   Relax-and-lift: 133
#   BQP: 12
#   PSD: 10
#
# Explored 123 nodes (42806 simplex iterations) in 3.99 seconds (7.12 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 15: 11878.1 11878.1 11878.1 ... 11878.1
# No other solutions better than 11878.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.187813004865e+04, best bound 1.187813004865e+04, gap 0.0000%
#
# - - - - - - - - - - - - - - - - - - - - - - - -
# Optimal solution found!
# 11878.130048654511

# %% [markdown]
# ### solution pool

# %%
print(f"Status: {set.status}")
if set.status == GRB.OPTIMAL:
    print("모델이 Optimal입니다")

    # Solution pool 확인
    print("\nSolution Pool 정보:")
    print(f"찾은 해의 개수: {set.SolCount}")

    # Best solution의 objective value
    best_obj = set.ObjVal
    print(f"\nBest Solution의 Objective Value: {best_obj}")

    # 각 솔루션의 목적함수 값 출력 및 best solution 여부 확인
    solutions = []
    for i in range(set.SolCount):
        set.params.SolutionNumber = i
        solutions.append((i, set.PoolObjVal))
        print(f"\nSolution {i}:")
        print(f"Objective value: {set.PoolObjVal}")
        print(f"Objective bound: {set.PoolObjBound}")
        print(
            f"Is Best Solution: {abs(set.PoolObjVal - best_obj) < 1e-9}"
        )  # 수치 오차 고려

        # Gap 계산 (best solution에 대해서만)
        if abs(set.PoolObjVal - best_obj) < 1e-9:
            gap = abs(set.PoolObjVal - set.ObjBound) / abs(set.PoolObjVal)
            print(f"Gap: {gap * 100:.2f}%")

    # Solution pool 파라미터 확인
    print("\nSolution Pool 파라미터:")
    print(f"PoolSolutions: {set.Params.PoolSolutions}")
    print(f"PoolSearchMode: {set.Params.PoolSearchMode}")
    print(f"PoolGap: {set.Params.PoolGap}")
elif set.status == GRB.UNBOUNDED:
    print("모델이 Unbounded입니다")
    # Unbounded ray 확인
    set.computeIIS()
    set.write("model.ilp")
elif set.status == GRB.INFEASIBLE:
    print("모델이 Infeasible입니다")
    # IIS 계산
    set.computeIIS()
    set.write("model.ilp")
elif set.status == GRB.INF_OR_UNBD:
    print("모델이 Infeasible 또는 Unbounded입니다")
    # Presolve를 끄고 다시 시도
    set.setParam("Presolve", 0)
    set.optimize()
elif set.status == GRB.TIME_LIMIT:
    print("시간 제한에 도달했습니다")
    if set.SolCount > 0:
        print(f"현재까지의 최선해: {set.objVal}")
        print(f"Optimality Gap: {set.MIPGap}")
# Out:
# Status: 2
# 모델이 Optimal입니다
#
# Solution Pool 정보:
# 찾은 해의 개수: 15
#
# Best Solution의 Objective Value: 11878.130048654511
#
# Solution 0:
# Objective value: 11878.13004865451
# Objective bound: 11878.130048654473
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 1:
# Objective value: 11878.130048654508
# Objective bound: 11878.130048654473
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 2:
# Objective value: 11878.130048654502
# Objective bound: 11878.130048654473
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 3:
# Objective value: 11878.130048654502
# Objective bound: 11878.130048654473
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 4:
# Objective value: 11878.130048654502
# Objective bound: 11878.130048654473
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 5:
# Objective value: 11878.130048654502
# Objective bound: 11878.130048654473
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 6:
# Objective value: 11878.1300486545
# Objective bound: 11878.130048654473
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 7:
# Objective value: 11878.130048654497
# Objective bound: 11878.130048654473
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 8:
# Objective value: 11878.130048654499
# Objective bound: 11878.130048654473
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 9:
# Objective value: 11878.130048654493
# Objective bound: 11878.130048654473
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 10:
# Objective value: 11878.13004865449
# Objective bound: 11878.130048654473
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 11:
# Objective value: 11878.130048654488
# Objective bound: 11878.130048654473
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 12:
# Objective value: 11878.130048654479
# Objective bound: 11878.130048654473
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 13:
# Objective value: 11878.130048654477
# Objective bound: 11878.130048654473
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 14:
# Objective value: 11878.130048654473
# Objective bound: 11878.130048654473
# Is Best Solution: True
# Gap: 0.00%
#
# Solution Pool 파라미터:
# PoolSolutions: 15
# PoolSearchMode: 2
# PoolGap: 0.05

# %%
# 솔루션 풀에서 해 확인
solution_count = set.SolCount
print(f"총 {solution_count}개의 해가 저장되었습니다.")

for i in range(solution_count):
    set.setParam(GRB.Param.SolutionNumber, i)
    print(f"\n해 {i+1}: 목적 함수 값 = {set.PoolObjVal}")
    # x 변수 값 출력
    for t in range(14, 15):
        for i in range(1, 5):
            print(f"x[{i},{t}] = {x[i, t].Xn}")
# Out:
# 총 15개의 해가 저장되었습니다.
#
# 해 1: 목적 함수 값 = 11878.13004865451
# x[1,14] = 2.354447475023517
# x[2,14] = 4.867250388411188
# x[3,14] = 5.03877769214506
# x[4,14] = 3.867679358831497
#
# 해 2: 목적 함수 값 = 11878.130048654508
# x[1,14] = 2.3544474750235143
# x[2,14] = 2.5984868634563707
# x[3,14] = 4.195661531715923
# x[4,14] = 3.867679358831497
#
# 해 3: 목적 함수 값 = 11878.130048654502
# x[1,14] = 2.3544474750235125
# x[2,14] = 4.867250388411188
# x[3,14] = 3.653698821385612
# x[4,14] = 3.867679358831497
#
# 해 4: 목적 함수 값 = 11878.130048654502
# x[1,14] = 2.354447475023518
# x[2,14] = 4.867250388411188
# x[3,14] = 5.03877769214506
# x[4,14] = 3.867679358831497
#
# 해 5: 목적 함수 값 = 11878.130048654502
# x[1,14] = 2.3544474750235165
# x[2,14] = 2.5984868634563707
# x[3,14] = 3.953014050381839
# x[4,14] = 3.867679358831497
#
# 해 6: 목적 함수 값 = 11878.130048654502
# x[1,14] = 2.1626252732828974
# x[2,14] = 6.999679645668031
# x[3,14] = 8.083402797593639
# x[4,14] = 1.3798081710985333
#
# 해 7: 목적 함수 값 = 11878.1300486545
# x[1,14] = 2.1626252732828974
# x[2,14] = 6.999679645668031
# x[3,14] = 8.083402797593639
# x[4,14] = 1.3798081710985333
#
# 해 8: 목적 함수 값 = 11878.130048654497
# x[1,14] = 2.354447475023515
# x[2,14] = 4.867250388411188
# x[3,14] = 5.03877769214506
# x[4,14] = 3.867679358831497
#
# 해 9: 목적 함수 값 = 11878.130048654499
# x[1,14] = 2.1626252732828974
# x[2,14] = 6.999679645668031
# x[3,14] = 8.083402797593639
# x[4,14] = 1.3798081710985333
#
# 해 10: 목적 함수 값 = 11878.130048654493
# x[1,14] = 2.7468254794101683
# x[2,14] = 2.5984868634563707
# x[3,14] = 3.881882852977933
# x[4,14] = 3.867679358831497
#
# 해 11: 목적 함수 값 = 11878.13004865449
# x[1,14] = 2.354447475023513
# x[2,14] = 2.5984868634563707
# x[3,14] = 3.967807979054002
# x[4,14] = 3.867679358831497
#
# 해 12: 목적 함수 값 = 11878.130048654488
# x[1,14] = 2.428835089232882
# x[2,14] = 4.867250388411188
# x[3,14] = 3.3475595242909053
# x[4,14] = 3.867679358831497
#
# 해 13: 목적 함수 값 = 11878.130048654479
# x[1,14] = 2.1626252732828974
# x[2,14] = 6.999679645668031
# x[3,14] = 8.083402797593639
# x[4,14] = 1.3798081710985333
#
# 해 14: 목적 함수 값 = 11878.130048654477
# x[1,14] = 2.354447475023516
# x[2,14] = 4.867250388411188
# x[3,14] = 5.03877769214506
# x[4,14] = 3.867679358831497
#
# 해 15: 목적 함수 값 = 11878.130048654473
# x[1,14] = 2.3544474750235187
# x[2,14] = 2.5984868634563707
# x[3,14] = 2.724518870682889
# x[4,14] = 2.848325325499978

# %% [markdown]
# ### 결과 분석

# %% [markdown]
# #### 수익 분석

# %%
# Day-ahead 수익 비교
total_da_profit_obj = 0
for i in range(I):
    for t in range(T):
        total_da_profit_obj += P_DA[t] * x[i, t].x

# Real-time 수익 비교
total_rt_profit_obj = 0
for i in range(I):
    for t in range(T):
        for s in range(S):
            rt_profit_obj = P_RT[t, s] * e_plus[i, t, s].x
            total_rt_profit_obj += 1 / S * rt_profit_obj

# 패널티 비용 비교
total_penalty_cost_obj = 0
for i in range(I):
    for t in range(T):
        for s in range(S):
            penalty_cost_obj = P_PN[t] * e_minus[i, t, s].x
            total_penalty_cost_obj += 1 / S * penalty_cost_obj

# 총 시스템 이익 (목적 함수 기반)
total_system_profit_obj = (
    total_da_profit_obj + total_rt_profit_obj - total_penalty_cost_obj
)

# 결과 출력
print(f"DA: {total_da_profit_obj:.2f}")
print(f"RT: {total_rt_profit_obj:.2f}")
print(f"Penalty: {total_penalty_cost_obj:.2f}")
print(f"목적 함수 기반 총 이익 (_obj): {total_system_profit_obj:.2f}")
# Out:
# DA: 8602.60
# RT: 3616.68
# Penalty: 341.16
# 목적 함수 기반 총 이익 (_obj): 11878.13

# %%
for t in range(T):
    avg_e_plus = sum(e_plus_vals[i, t, s] for i in range(I) for s in range(S)) / S
    avg_e_minus = sum(e_minus_vals[i, t, s] for i in range(I) for s in range(S)) / S
    print(
        f"[시간 {t}] x: {sum(x_vals[i, t] for i in range(I)):.3f}, e+: {avg_e_plus:.3f}, e-: {avg_e_minus:.3f}"
    )

total_x = sum(x_vals[i, t] for i in range(I) for t in range(T))
print(f"총 하루 commitment: {total_x:.3f}")
# Out:
# [시간 0] x: 0.000, e+: 0.000, e-: 0.000
# [시간 1] x: 0.000, e+: 0.000, e-: 0.000
# [시간 2] x: 0.000, e+: 0.000, e-: 0.000
# [시간 3] x: 0.000, e+: 0.000, e-: 0.000
# [시간 4] x: 0.000, e+: 0.000, e-: 0.000
# [시간 5] x: 0.000, e+: 0.000, e-: 0.000
# [시간 6] x: 0.000, e+: 0.000, e-: 0.000
# [시간 7] x: 0.000, e+: 0.000, e-: 0.000
# [시간 8] x: 0.816, e+: 1.258, e-: 0.077
# [시간 9] x: 7.714, e+: 5.072, e-: 0.318
# [시간 10] x: 24.230, e+: 8.442, e-: 0.089
# [시간 11] x: 28.485, e+: 16.456, e-: 1.217
# [시간 12] x: 38.932, e+: 16.756, e-: 0.429
# [시간 13] x: 39.040, e+: 18.203, e-: 0.250
# [시간 14] x: 34.879, e+: 15.878, e-: 0.759
# [시간 15] x: 25.752, e+: 9.758, e-: 0.873
# [시간 16] x: 11.038, e+: 8.142, e-: 1.000
# [시간 17] x: 1.574, e+: 3.297, e-: 0.116
# [시간 18] x: 0.000, e+: 0.495, e-: 0.000
# [시간 19] x: 0.000, e+: 0.000, e-: 0.000
# [시간 20] x: 0.000, e+: 0.000, e-: 0.000
# [시간 21] x: 0.000, e+: 0.000, e-: 0.000
# [시간 22] x: 0.000, e+: 0.000, e-: 0.000
# [시간 23] x: 0.000, e+: 0.000, e-: 0.000
# 총 하루 commitment: 212.461

# %% [markdown]
# ### exchange process

# %%
for t in range(12,16):
    x_sum = sum(x_vals[i, t] for i in range(I))

    for s in range(S):
        y_plus_sum = sum(y_plus_vals[i, t, s] for i in range(I))
        y_minus_sum = sum(y_minus_vals[i, t, s] for i in range(I))

        e_plus_sum = sum(e_plus_vals[i, t, s] for i in range(I))
        e_minus_sum = sum(e_minus_vals[i, t, s] for i in range(I))

        print(f"[t={t} s={s}]")

        print(f"x 합계: {x_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {x_vals[i,t]:.2f}", end=" ")
        print(")")

        print(f"y+ 합계: {y_plus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {y_plus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print(f"y- 합계: {y_minus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {y_minus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print(f"e+ 합계: {e_plus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {e_plus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print(f"e- 합계: {e_minus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {e_minus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print("거래 내역:")
        for i in range(I):
            for j in range(I):
                if d_vals[i, j, t, s] > 1e-6:
                    print(
                        f"발전기 {i}가 발전기 {j}에게 {d_vals[i,j,t,s]:.2f} 전력을 줌"
                    )
        print()
# Out:
# [t=12 s=0]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 25.85 ([0] 6.57 [1] 0.00 [2] 5.40 [3] 0.00 [4] 5.36 [5] 2.16 [6] 6.36 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 11.08 ([0] 0.00 [1] 2.28 [2] 0.00 [3] 4.14 [4] 0.00 [5] 0.00 [6] 0.00 [7] 2.04 [8] 2.18 [9] 0.44 )
# e+ 합계: 14.78 ([0] 0.86 [1] 0.00 [2] 5.40 [3] 0.00 [4] 0.00 [5] 2.16 [6] 6.36 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 3에게 3.54 전력을 줌
# 발전기 0가 발전기 8에게 2.18 전력을 줌
# 발전기 4가 발전기 1에게 2.28 전력을 줌
# 발전기 4가 발전기 3에게 0.61 전력을 줌
# 발전기 4가 발전기 7에게 2.04 전력을 줌
# 발전기 4가 발전기 9에게 0.44 전력을 줌
#
# [t=12 s=1]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 33.78 ([0] 0.00 [1] 7.37 [2] 10.35 [3] 0.00 [4] 2.20 [5] 0.84 [6] 3.10 [7] 5.95 [8] 0.00 [9] 3.97 )
# y- 합계: 14.41 ([0] 3.62 [1] 0.00 [2] 0.00 [3] 4.14 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 6.64 [9] 0.00 )
# e+ 합계: 19.37 ([0] 0.00 [1] 0.00 [2] 8.29 [3] 0.00 [4] 2.20 [5] 0.00 [6] 3.10 [7] 5.78 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 0에게 3.62 전력을 줌
# 발전기 1가 발전기 8에게 3.74 전력을 줌
# 발전기 2가 발전기 8에게 2.06 전력을 줌
# 발전기 5가 발전기 8에게 0.84 전력을 줌
# 발전기 7가 발전기 3에게 0.17 전력을 줌
# 발전기 9가 발전기 3에게 3.97 전력을 줌
#
# [t=12 s=2]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 31.72 ([0] 7.01 [1] 0.00 [2] 0.00 [3] 6.30 [4] 0.00 [5] 8.83 [6] 7.33 [7] 0.64 [8] 0.00 [9] 1.61 )
# y- 합계: 9.29 ([0] 0.00 [1] 2.28 [2] 0.00 [3] 0.00 [4] 0.37 [5] 0.00 [6] 0.00 [7] 0.00 [8] 6.64 [9] 0.00 )
# e+ 합계: 22.43 ([0] 7.01 [1] 0.00 [2] 0.00 [3] 6.30 [4] 0.00 [5] 0.00 [6] 7.33 [7] 0.18 [8] 0.00 [9] 1.61 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 5가 발전기 1에게 2.28 전력을 줌
# 발전기 5가 발전기 4에게 0.37 전력을 줌
# 발전기 5가 발전기 8에게 6.18 전력을 줌
# 발전기 7가 발전기 8에게 0.46 전력을 줌
#
# [t=12 s=3]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 47.83 ([0] 9.01 [1] 2.34 [2] 13.27 [3] 0.72 [4] 0.00 [5] 6.63 [6] 4.69 [7] 3.78 [8] 0.00 [9] 7.39 )
# y- 합계: 11.06 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 4.42 [5] 0.00 [6] 0.00 [7] 0.00 [8] 6.64 [9] 0.00 )
# e+ 합계: 36.77 ([0] 9.01 [1] 0.00 [2] 13.27 [3] 0.72 [4] 0.00 [5] 4.56 [6] 4.69 [7] 0.00 [8] 0.00 [9] 4.52 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 4에게 2.34 전력을 줌
# 발전기 5가 발전기 4에게 2.08 전력을 줌
# 발전기 7가 발전기 8에게 3.78 전력을 줌
# 발전기 9가 발전기 8에게 2.87 전력을 줌
#
# [t=12 s=4]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 15.53 ([0] 0.00 [1] 5.35 [2] 1.98 [3] 0.00 [4] 4.08 [5] 0.00 [6] 0.00 [7] 4.12 [8] 0.00 [9] 0.00 )
# y- 합계: 17.00 ([0] 4.49 [1] 0.00 [2] 0.00 [3] 1.88 [4] 0.00 [5] 2.44 [6] 5.32 [7] 0.00 [8] 0.00 [9] 2.87 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 1.46 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 1.46 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 0에게 1.04 전력을 줌
# 발전기 1가 발전기 3에게 1.88 전력을 줌
# 발전기 1가 발전기 5에게 2.44 전력을 줌
# 발전기 2가 발전기 9에게 1.98 전력을 줌
# 발전기 4가 발전기 0에게 3.45 전력을 줌
# 발전기 4가 발전기 6에게 0.63 전력을 줌
# 발전기 7가 발전기 6에게 3.22 전력을 줌
# 발전기 7가 발전기 9에게 0.90 전력을 줌
#
# [t=12 s=5]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 23.57 ([0] 6.18 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 11.69 [7] 0.00 [8] 0.00 [9] 5.70 )
# y- 합계: 11.90 ([0] 0.00 [1] 2.28 [2] 0.96 [3] 0.00 [4] 1.78 [5] 2.48 [6] 0.00 [7] 0.00 [8] 4.41 [9] 0.00 )
# e+ 합계: 11.67 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 11.67 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 2에게 0.96 전력을 줌
# 발전기 0가 발전기 4에게 1.78 전력을 줌
# 발전기 0가 발전기 5에게 2.48 전력을 줌
# 발전기 0가 발전기 8에게 0.96 전력을 줌
# 발전기 6가 발전기 1에게 0.02 전력을 줌
# 발전기 9가 발전기 1에게 2.25 전력을 줌
# 발전기 9가 발전기 8에게 3.45 전력을 줌
#
# [t=12 s=6]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 33.20 ([0] 0.00 [1] 0.00 [2] 10.37 [3] 0.00 [4] 5.05 [5] 0.00 [6] 5.84 [7] 4.00 [8] 0.00 [9] 7.94 )
# y- 합계: 17.43 ([0] 4.79 [1] 2.28 [2] 0.00 [3] 4.14 [4] 0.00 [5] 2.48 [6] 0.00 [7] 0.00 [8] 3.74 [9] 0.00 )
# e+ 합계: 15.77 ([0] 0.00 [1] 0.00 [2] 10.37 [3] 0.00 [4] 0.00 [5] 0.00 [6] 5.40 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 4가 발전기 5에게 1.31 전력을 줌
# 발전기 4가 발전기 8에게 3.74 전력을 줌
# 발전기 6가 발전기 5에게 0.44 전력을 줌
# 발전기 7가 발전기 0에게 0.99 전력을 줌
# 발전기 7가 발전기 1에게 2.28 전력을 줌
# 발전기 7가 발전기 5에게 0.73 전력을 줌
# 발전기 9가 발전기 0에게 3.80 전력을 줌
# 발전기 9가 발전기 3에게 4.14 전력을 줌
#
# [t=12 s=7]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 18.96 ([0] 4.87 [1] 7.59 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 6.50 [8] 0.00 [9] 0.00 )
# y- 합계: 17.83 ([0] 0.00 [1] 0.00 [2] 0.19 [3] 4.14 [4] 4.42 [5] 2.48 [6] 1.84 [7] 0.00 [8] 4.76 [9] 0.00 )
# e+ 합계: 1.13 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 1.13 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 4에게 0.11 전력을 줌
# 발전기 0가 발전기 8에게 4.76 전력을 줌
# 발전기 1가 발전기 4에게 4.31 전력을 줌
# 발전기 1가 발전기 5에게 1.43 전력을 줌
# 발전기 1가 발전기 6에게 1.84 전력을 줌
# 발전기 7가 발전기 2에게 0.19 전력을 줌
# 발전기 7가 발전기 3에게 4.14 전력을 줌
# 발전기 7가 발전기 5에게 1.04 전력을 줌
#
# [t=12 s=8]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 29.49 ([0] 6.28 [1] 4.43 [2] 6.40 [3] 2.71 [4] 0.00 [5] 5.55 [6] 2.30 [7] 1.23 [8] 0.00 [9] 0.60 )
# y- 합계: 4.67 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 4.42 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.25 [9] 0.00 )
# e+ 합계: 24.82 ([0] 6.28 [1] 4.43 [2] 6.40 [3] 0.00 [4] 0.00 [5] 5.42 [6] 2.30 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 3가 발전기 4에게 2.71 전력을 줌
# 발전기 5가 발전기 4에게 0.13 전력을 줌
# 발전기 7가 발전기 4에게 1.23 전력을 줌
# 발전기 9가 발전기 4에게 0.35 전력을 줌
# 발전기 9가 발전기 8에게 0.25 전력을 줌
#
# [t=12 s=9]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 14.88 ([0] 0.96 [1] 0.00 [2] 9.42 [3] 0.00 [4] 0.00 [5] 4.20 [6] 0.00 [7] 0.30 [8] 0.00 [9] 0.00 )
# y- 합계: 21.99 ([0] 0.00 [1] 2.28 [2] 0.00 [3] 4.14 [4] 3.18 [5] 0.00 [6] 2.87 [7] 0.00 [8] 6.64 [9] 2.87 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 7.12 ([0] 0.00 [1] 1.06 [2] 0.00 [3] 0.00 [4] 3.18 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 2.87 )
# 거래 내역:
# 발전기 0가 발전기 8에게 0.96 전력을 줌
# 발전기 2가 발전기 3에게 0.86 전력을 줌
# 발전기 2가 발전기 6에게 2.87 전력을 줌
# 발전기 2가 발전기 8에게 5.69 전력을 줌
# 발전기 5가 발전기 1에게 0.92 전력을 줌
# 발전기 5가 발전기 3에게 3.28 전력을 줌
# 발전기 7가 발전기 1에게 0.30 전력을 줌
#
# [t=12 s=10]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 40.32 ([0] 8.26 [1] 0.00 [2] 9.42 [3] 1.54 [4] 0.96 [5] 4.52 [6] 5.92 [7] 0.00 [8] 0.00 [9] 9.70 )
# y- 합계: 8.76 ([0] 0.00 [1] 0.38 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 2.88 [8] 5.49 [9] 0.00 )
# e+ 합계: 31.56 ([0] 7.49 [1] 0.00 [2] 8.45 [3] 0.00 [4] 0.00 [5] 0.00 [6] 5.92 [7] 0.00 [8] 0.00 [9] 9.70 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 7에게 0.77 전력을 줌
# 발전기 2가 발전기 8에게 0.97 전력을 줌
# 발전기 3가 발전기 7에게 1.54 전력을 줌
# 발전기 4가 발전기 1에게 0.38 전력을 줌
# 발전기 4가 발전기 7에게 0.58 전력을 줌
# 발전기 5가 발전기 8에게 4.52 전력을 줌
#
# [t=12 s=11]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 20.51 ([0] 0.00 [1] 6.42 [2] 0.00 [3] 4.78 [4] 0.00 [5] 0.00 [6] 3.90 [7] 0.52 [8] 0.00 [9] 4.89 )
# y- 합계: 14.63 ([0] 5.03 [1] 0.00 [2] 1.55 [3] 0.00 [4] 4.42 [5] 0.71 [6] 0.00 [7] 0.00 [8] 2.93 [9] 0.00 )
# e+ 합계: 5.88 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 4.78 [4] 0.00 [5] 0.00 [6] 1.10 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 0에게 3.49 전력을 줌
# 발전기 1가 발전기 8에게 2.93 전력을 줌
# 발전기 6가 발전기 0에게 0.54 전력을 줌
# 발전기 6가 발전기 2에게 1.55 전력을 줌
# 발전기 6가 발전기 5에게 0.71 전력을 줌
# 발전기 7가 발전기 0에게 0.52 전력을 줌
# 발전기 9가 발전기 0에게 0.48 전력을 줌
# 발전기 9가 발전기 4에게 4.42 전력을 줌
#
# [t=12 s=12]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 14.95 ([0] 2.91 [1] 0.00 [2] 0.00 [3] 2.04 [4] 2.64 [5] 5.37 [6] 0.00 [7] 1.72 [8] 0.00 [9] 0.25 )
# y- 합계: 13.88 ([0] 0.00 [1] 0.74 [2] 2.41 [3] 0.00 [4] 0.00 [5] 0.00 [6] 5.78 [7] 0.00 [8] 4.94 [9] 0.00 )
# e+ 합계: 1.07 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 1.07 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 6에게 2.91 전력을 줌
# 발전기 3가 발전기 2에게 0.90 전력을 줌
# 발전기 3가 발전기 6에게 1.14 전력을 줌
# 발전기 4가 발전기 1에게 0.49 전력을 줌
# 발전기 4가 발전기 8에게 2.15 전력을 줌
# 발전기 5가 발전기 2에게 1.51 전력을 줌
# 발전기 5가 발전기 8에게 2.79 전력을 줌
# 발전기 7가 발전기 6에게 1.72 전력을 줌
# 발전기 9가 발전기 1에게 0.25 전력을 줌
#
# [t=12 s=13]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 20.45 ([0] 0.00 [1] 9.55 [2] 4.62 [3] 5.15 [4] 0.00 [5] 0.00 [6] 1.12 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 20.45 ([0] 4.28 [1] 0.00 [2] 0.00 [3] 0.00 [4] 4.42 [5] 0.00 [6] 0.00 [7] 2.88 [8] 6.64 [9] 2.22 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 0에게 4.28 전력을 줌
# 발전기 1가 발전기 4에게 4.42 전력을 줌
# 발전기 1가 발전기 9에게 0.85 전력을 줌
# 발전기 2가 발전기 8에게 4.38 전력을 줌
# 발전기 2가 발전기 9에게 0.25 전력을 줌
# 발전기 3가 발전기 7에게 2.88 전력을 줌
# 발전기 3가 발전기 8에게 2.27 전력을 줌
# 발전기 6가 발전기 9에게 1.12 전력을 줌
#
# [t=12 s=14]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 29.88 ([0] 0.00 [1] 0.00 [2] 8.62 [3] 1.27 [4] 1.16 [5] 2.92 [6] 0.00 [7] 9.90 [8] 3.20 [9] 2.81 )
# y- 합계: 11.87 ([0] 5.03 [1] 2.28 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 4.57 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 18.01 ([0] 0.00 [1] 0.00 [2] 6.52 [3] 1.27 [4] 0.00 [5] 0.00 [6] 0.00 [7] 7.41 [8] 0.00 [9] 2.81 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 0에게 2.10 전력을 줌
# 발전기 4가 발전기 6에게 1.16 전력을 줌
# 발전기 5가 발전기 0에게 2.92 전력을 줌
# 발전기 7가 발전기 6에게 2.48 전력을 줌
# 발전기 8가 발전기 1에게 2.28 전력을 줌
# 발전기 8가 발전기 6에게 0.92 전력을 줌
#
# [t=12 s=15]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 45.41 ([0] 9.90 [1] 5.39 [2] 10.43 [3] 9.62 [4] 0.00 [5] 3.01 [6] 6.13 [7] 0.00 [8] 0.93 [9] 0.00 )
# y- 합계: 10.17 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 4.42 [5] 0.00 [6] 0.00 [7] 2.88 [8] 0.00 [9] 2.87 )
# e+ 합계: 35.24 ([0] 9.90 [1] 5.39 [2] 7.54 [3] 6.27 [4] 0.00 [5] 0.00 [6] 6.13 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 7에게 2.88 전력을 줌
# 발전기 3가 발전기 4에게 3.35 전력을 줌
# 발전기 5가 발전기 4에게 0.14 전력을 줌
# 발전기 5가 발전기 9에게 2.87 전력을 줌
# 발전기 8가 발전기 4에게 0.93 전력을 줌
#
# [t=12 s=16]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 25.27 ([0] 2.30 [1] 5.58 [2] 0.00 [3] 2.15 [4] 5.41 [5] 5.47 [6] 0.00 [7] 4.36 [8] 0.00 [9] 0.00 )
# y- 합계: 17.10 ([0] 0.00 [1] 0.00 [2] 2.41 [3] 0.00 [4] 0.00 [5] 0.00 [6] 5.17 [7] 0.00 [8] 6.64 [9] 2.87 )
# e+ 합계: 8.17 ([0] 0.00 [1] 3.83 [2] 0.00 [3] 1.35 [4] 3.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 8에게 2.30 전력을 줌
# 발전기 1가 발전기 9에게 1.75 전력을 줌
# 발전기 3가 발전기 6에게 0.81 전력을 줌
# 발전기 4가 발전기 2에게 2.41 전력을 줌
# 발전기 5가 발전기 8에게 4.35 전력을 줌
# 발전기 5가 발전기 9에게 1.12 전력을 줌
# 발전기 7가 발전기 6에게 4.36 전력을 줌
#
# [t=12 s=17]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 35.35 ([0] 8.34 [1] 2.50 [2] 10.46 [3] 0.28 [4] 3.41 [5] 4.03 [6] 6.33 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 8.68 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 2.88 [8] 5.61 [9] 0.18 )
# e+ 합계: 26.67 ([0] 8.34 [1] 0.00 [2] 10.46 [3] 0.28 [4] 1.26 [5] 0.00 [6] 6.33 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 7에게 0.74 전력을 줌
# 발전기 1가 발전기 8에게 1.76 전력을 줌
# 발전기 4가 발전기 7에게 2.15 전력을 줌
# 발전기 5가 발전기 8에게 3.85 전력을 줌
# 발전기 5가 발전기 9에게 0.18 전력을 줌
#
# [t=12 s=18]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 36.71 ([0] 0.00 [1] 3.13 [2] 6.65 [3] 14.26 [4] 0.00 [5] 1.88 [6] 5.52 [7] 0.76 [8] 0.00 [9] 4.50 )
# y- 합계: 5.90 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 4.42 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.48 [9] 0.00 )
# e+ 합계: 30.81 ([0] 0.00 [1] 3.13 [2] 2.63 [3] 14.26 [4] 0.00 [5] 0.00 [6] 5.52 [7] 0.76 [8] 0.00 [9] 4.50 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 4에게 2.54 전력을 줌
# 발전기 2가 발전기 8에게 1.48 전력을 줌
# 발전기 5가 발전기 4에게 1.88 전력을 줌
#
# [t=12 s=19]
# x 합계: 38.93 ([0] 5.03 [1] 2.28 [2] 2.41 [3] 4.14 [4] 4.42 [5] 2.48 [6] 5.78 [7] 2.88 [8] 6.64 [9] 2.87 )
# y+ 합계: 45.84 ([0] 0.00 [1] 10.28 [2] 11.80 [3] 0.00 [4] 0.00 [5] 1.51 [6] 0.75 [7] 7.73 [8] 0.00 [9] 13.76 )
# y- 합계: 14.87 ([0] 3.81 [1] 0.00 [2] 0.00 [3] 4.14 [4] 0.28 [5] 0.00 [6] 0.00 [7] 0.00 [8] 6.64 [9] 0.00 )
# e+ 합계: 30.97 ([0] 0.00 [1] 10.28 [2] 11.80 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.75 [7] 7.73 [8] 0.00 [9] 0.40 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 5가 발전기 3에게 1.51 전력을 줌
# 발전기 9가 발전기 0에게 3.81 전력을 줌
# 발전기 9가 발전기 3에게 2.63 전력을 줌
# 발전기 9가 발전기 4에게 0.28 전력을 줌
# 발전기 9가 발전기 8에게 6.64 전력을 줌
#
# [t=13 s=0]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 37.42 ([0] 11.14 [1] 4.24 [2] 6.85 [3] 6.53 [4] 0.00 [5] 1.26 [6] 4.99 [7] 2.40 [8] 0.00 [9] 0.00 )
# y- 합계: 4.24 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 1.11 [5] 0.00 [6] 0.00 [7] 0.00 [8] 3.13 [9] 0.00 )
# e+ 합계: 33.18 ([0] 11.14 [1] 0.00 [2] 6.85 [3] 6.53 [4] 0.00 [5] 1.26 [6] 4.99 [7] 2.40 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 4에게 1.11 전력을 줌
# 발전기 1가 발전기 8에게 3.13 전력을 줌
#
# [t=13 s=1]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 35.16 ([0] 0.00 [1] 7.84 [2] 5.81 [3] 0.56 [4] 10.29 [5] 0.00 [6] 1.04 [7] 9.64 [8] 0.00 [9] 0.00 )
# y- 합계: 17.35 ([0] 2.22 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 6.31 [6] 0.00 [7] 0.00 [8] 2.39 [9] 6.42 )
# e+ 합계: 17.81 ([0] 0.00 [1] 7.84 [2] 5.81 [3] 0.00 [4] 4.17 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 3가 발전기 8에게 0.56 전력을 줌
# 발전기 4가 발전기 8에게 1.84 전력을 줌
# 발전기 4가 발전기 9에게 4.28 전력을 줌
# 발전기 6가 발전기 0에게 1.04 전력을 줌
# 발전기 7가 발전기 0에게 1.18 전력을 줌
# 발전기 7가 발전기 5에게 6.31 전력을 줌
# 발전기 7가 발전기 9에게 2.14 전력을 줌
#
# [t=13 s=2]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 21.25 ([0] 0.00 [1] 4.01 [2] 3.20 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 8.84 [8] 2.45 [9] 2.74 )
# y- 합계: 9.81 ([0] 2.22 [1] 0.00 [2] 0.00 [3] 3.04 [4] 1.11 [5] 0.36 [6] 3.08 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 11.45 ([0] 0.00 [1] 4.01 [2] 2.86 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 4.57 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 6에게 0.34 전력을 줌
# 발전기 7가 발전기 0에게 2.22 전력을 줌
# 발전기 7가 발전기 3에게 0.59 전력을 줌
# 발전기 7가 발전기 4에게 1.11 전력을 줌
# 발전기 7가 발전기 5에게 0.36 전력을 줌
# 발전기 8가 발전기 3에게 2.45 전력을 줌
# 발전기 9가 발전기 6에게 2.74 전력을 줌
#
# [t=13 s=3]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 53.03 ([0] 10.55 [1] 0.00 [2] 9.58 [3] 10.49 [4] 5.34 [5] 3.15 [6] 0.10 [7] 0.03 [8] 5.08 [9] 8.71 )
# y- 합계: 5.92 ([0] 0.00 [1] 5.92 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 47.11 ([0] 10.55 [1] 0.00 [2] 8.88 [3] 10.49 [4] 5.34 [5] 3.15 [6] 0.00 [7] 0.00 [8] 0.00 [9] 8.71 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 1에게 0.71 전력을 줌
# 발전기 6가 발전기 1에게 0.10 전력을 줌
# 발전기 7가 발전기 1에게 0.03 전력을 줌
# 발전기 8가 발전기 1에게 5.08 전력을 줌
#
# [t=13 s=4]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 22.83 ([0] 0.00 [1] 1.32 [2] 0.18 [3] 8.53 [4] 0.00 [5] 0.00 [6] 12.80 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 17.10 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 1.11 [5] 4.12 [6] 0.00 [7] 2.72 [8] 2.72 [9] 6.42 )
# e+ 합계: 5.73 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 5.73 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 7에게 0.71 전력을 줌
# 발전기 1가 발전기 8에게 0.61 전력을 줌
# 발전기 2가 발전기 4에게 0.18 전력을 줌
# 발전기 3가 발전기 8에게 2.11 전력을 줌
# 발전기 3가 발전기 9에게 6.42 전력을 줌
# 발전기 6가 발전기 4에게 0.93 전력을 줌
# 발전기 6가 발전기 5에게 4.12 전력을 줌
# 발전기 6가 발전기 7에게 2.01 전력을 줌
#
# [t=13 s=5]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 28.11 ([0] 1.03 [1] 0.00 [2] 6.21 [3] 4.10 [4] 0.65 [5] 0.00 [6] 0.00 [7] 8.14 [8] 7.98 [9] 0.00 )
# y- 합계: 15.22 ([0] 0.00 [1] 1.11 [2] 0.00 [3] 0.00 [4] 0.00 [5] 6.50 [6] 1.50 [7] 0.00 [8] 0.00 [9] 6.11 )
# e+ 합계: 12.89 ([0] 1.03 [1] 0.00 [2] 0.75 [3] 3.12 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 7.98 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 9에게 5.46 전력을 줌
# 발전기 3가 발전기 5에게 0.98 전력을 줌
# 발전기 4가 발전기 9에게 0.65 전력을 줌
# 발전기 7가 발전기 1에게 1.11 전력을 줌
# 발전기 7가 발전기 5에게 5.52 전력을 줌
# 발전기 7가 발전기 6에게 1.50 전력을 줌
#
# [t=13 s=6]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 33.79 ([0] 11.41 [1] 0.00 [2] 7.67 [3] 0.00 [4] 0.00 [5] 0.00 [6] 6.94 [7] 6.65 [8] 0.00 [9] 1.13 )
# y- 합계: 7.60 ([0] 0.00 [1] 1.64 [2] 0.00 [3] 3.04 [4] 1.11 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.81 [9] 0.00 )
# e+ 합계: 26.19 ([0] 11.41 [1] 0.00 [2] 7.67 [3] 0.00 [4] 0.00 [5] 0.00 [6] 4.19 [7] 2.92 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 6가 발전기 1에게 1.64 전력을 줌
# 발전기 6가 발전기 4에게 1.11 전력을 줌
# 발전기 7가 발전기 3에게 1.91 전력을 줌
# 발전기 7가 발전기 8에게 1.81 전력을 줌
# 발전기 9가 발전기 3에게 1.13 전력을 줌
#
# [t=13 s=7]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 17.31 ([0] 3.41 [1] 0.00 [2] 12.19 [3] 0.00 [4] 0.00 [5] 0.00 [6] 1.39 [7] 0.32 [8] 0.00 [9] 0.00 )
# y- 합계: 17.31 ([0] 0.00 [1] 6.88 [2] 0.00 [3] 0.00 [4] 0.83 [5] 6.28 [6] 0.00 [7] 0.00 [8] 0.93 [9] 2.38 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 2.57 전력을 줌
# 발전기 0가 발전기 4에게 0.83 전력을 줌
# 발전기 2가 발전기 1에게 4.00 전력을 줌
# 발전기 2가 발전기 5에게 6.28 전력을 줌
# 발전기 2가 발전기 9에게 1.91 전력을 줌
# 발전기 6가 발전기 8에게 0.93 전력을 줌
# 발전기 6가 발전기 9에게 0.47 전력을 줌
# 발전기 7가 발전기 1에게 0.32 전력을 줌
#
# [t=13 s=8]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 28.96 ([0] 10.44 [1] 0.00 [2] 0.00 [3] 14.10 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 4.42 )
# y- 합계: 17.15 ([0] 0.00 [1] 2.61 [2] 2.27 [3] 0.00 [4] 1.11 [5] 3.52 [6] 3.08 [7] 2.72 [8] 1.83 [9] 0.00 )
# e+ 합계: 11.81 ([0] 10.44 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 1.37 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 3가 발전기 2에게 1.83 전력을 줌
# 발전기 3가 발전기 4에게 1.11 전력을 줌
# 발전기 3가 발전기 5에게 3.52 전력을 줌
# 발전기 3가 발전기 6에게 3.08 전력을 줌
# 발전기 3가 발전기 7에게 2.72 전력을 줌
# 발전기 3가 발전기 8에게 1.83 전력을 줌
# 발전기 9가 발전기 1에게 2.61 전력을 줌
# 발전기 9가 발전기 2에게 0.44 전력을 줌
#
# [t=13 s=9]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 36.05 ([0] 5.44 [1] 0.19 [2] 0.00 [3] 15.74 [4] 0.00 [5] 0.00 [6] 0.87 [7] 9.32 [8] 0.00 [9] 4.49 )
# y- 합계: 11.56 ([0] 0.00 [1] 0.00 [2] 1.45 [3] 0.00 [4] 1.11 [5] 6.88 [6] 0.00 [7] 0.00 [8] 2.13 [9] 0.00 )
# e+ 합계: 24.49 ([0] 5.44 [1] 0.00 [2] 0.00 [3] 15.74 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 3.32 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 4에게 0.19 전력을 줌
# 발전기 6가 발전기 2에게 0.87 전력을 줌
# 발전기 7가 발전기 4에게 0.92 전력을 줌
# 발전기 7가 발전기 5에게 6.28 전력을 줌
# 발전기 7가 발전기 8에게 2.13 전력을 줌
# 발전기 9가 발전기 2에게 0.58 전력을 줌
# 발전기 9가 발전기 5에게 0.60 전력을 줌
#
# [t=13 s=10]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 36.07 ([0] 1.96 [1] 0.00 [2] 12.12 [3] 0.00 [4] 0.44 [5] 0.00 [6] 15.26 [7] 5.34 [8] 0.26 [9] 0.69 )
# y- 합계: 12.84 ([0] 0.00 [1] 6.88 [2] 0.00 [3] 3.04 [4] 0.00 [5] 2.92 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 23.23 ([0] 1.96 [1] 0.00 [2] 8.93 [3] 0.00 [4] 0.00 [5] 0.00 [6] 12.34 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 1에게 0.85 전력을 줌
# 발전기 2가 발전기 3에게 2.34 전력을 줌
# 발전기 4가 발전기 1에게 0.44 전력을 줌
# 발전기 6가 발전기 5에게 2.92 전력을 줌
# 발전기 7가 발전기 1에게 5.34 전력을 줌
# 발전기 8가 발전기 1에게 0.26 전력을 줌
# 발전기 9가 발전기 3에게 0.69 전력을 줌
#
# [t=13 s=11]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 13.67 ([0] 0.00 [1] 0.00 [2] 11.18 [3] 0.00 [4] 2.49 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 14.14 ([0] 2.13 [1] 1.59 [2] 0.00 [3] 2.43 [4] 0.00 [5] 6.88 [6] 0.62 [7] 0.00 [8] 0.00 [9] 0.49 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.47 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.47 )
# 거래 내역:
# 발전기 2가 발전기 0에게 0.28 전력을 줌
# 발전기 2가 발전기 1에게 1.59 전력을 줌
# 발전기 2가 발전기 3에게 2.43 전력을 줌
# 발전기 2가 발전기 5에게 6.88 전력을 줌
# 발전기 4가 발전기 0에게 1.85 전력을 줌
# 발전기 4가 발전기 6에게 0.62 전력을 줌
# 발전기 4가 발전기 9에게 0.02 전력을 줌
#
# [t=13 s=12]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 17.11 ([0] 0.00 [1] 0.00 [2] 0.97 [3] 2.62 [4] 0.00 [5] 7.26 [6] 0.00 [7] 0.00 [8] 6.26 [9] 0.00 )
# y- 합계: 16.92 ([0] 2.22 [1] 6.88 [2] 0.00 [3] 0.00 [4] 1.11 [5] 0.00 [6] 0.00 [7] 0.29 [8] 0.00 [9] 6.42 )
# e+ 합계: 0.19 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.19 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 1에게 0.10 전력을 줌
# 발전기 2가 발전기 9에게 0.87 전력을 줌
# 발전기 3가 발전기 0에게 2.22 전력을 줌
# 발전기 3가 발전기 9에게 0.39 전력을 줌
# 발전기 5가 발전기 1에게 6.78 전력을 줌
# 발전기 5가 발전기 7에게 0.29 전력을 줌
# 발전기 8가 발전기 4에게 1.11 전력을 줌
# 발전기 8가 발전기 9에게 5.16 전력을 줌
#
# [t=13 s=13]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 46.73 ([0] 15.47 [1] 0.00 [2] 1.84 [3] 10.63 [4] 0.00 [5] 1.62 [6] 8.57 [7] 1.66 [8] 0.00 [9] 6.94 )
# y- 합계: 8.50 ([0] 0.00 [1] 5.12 [2] 0.00 [3] 0.00 [4] 1.11 [5] 0.00 [6] 0.00 [7] 0.00 [8] 2.27 [9] 0.00 )
# e+ 합계: 38.23 ([0] 14.36 [1] 0.00 [2] 0.00 [3] 10.63 [4] 0.00 [5] 1.62 [6] 8.57 [7] 0.00 [8] 0.00 [9] 3.05 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 4에게 1.11 전력을 줌
# 발전기 2가 발전기 1에게 1.84 전력을 줌
# 발전기 7가 발전기 8에게 1.66 전력을 줌
# 발전기 9가 발전기 1에게 3.28 전력을 줌
# 발전기 9가 발전기 8에게 0.61 전력을 줌
#
# [t=13 s=14]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 38.84 ([0] 5.44 [1] 0.00 [2] 11.02 [3] 6.16 [4] 0.00 [5] 0.00 [6] 1.30 [7] 9.01 [8] 0.00 [9] 5.89 )
# y- 합계: 10.03 ([0] 0.00 [1] 4.57 [2] 0.00 [3] 0.00 [4] 1.11 [5] 1.03 [6] 0.00 [7] 0.00 [8] 3.33 [9] 0.00 )
# e+ 합계: 28.81 ([0] 0.00 [1] 0.00 [2] 8.77 [3] 5.13 [4] 0.00 [5] 0.00 [6] 0.00 [7] 9.01 [8] 0.00 [9] 5.89 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 1.01 전력을 줌
# 발전기 0가 발전기 4에게 1.11 전력을 줌
# 발전기 0가 발전기 8에게 3.33 전력을 줌
# 발전기 2가 발전기 1에게 2.25 전력을 줌
# 발전기 3가 발전기 5에게 1.03 전력을 줌
# 발전기 6가 발전기 1에게 1.30 전력을 줌
#
# [t=13 s=15]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 15.01 ([0] 0.00 [1] 1.10 [2] 7.35 [3] 5.72 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.83 )
# y- 합계: 18.75 ([0] 2.22 [1] 0.00 [2] 0.00 [3] 0.00 [4] 1.11 [5] 6.88 [6] 1.62 [7] 2.72 [8] 4.21 [9] 0.00 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 3.74 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 1.11 [5] 0.00 [6] 0.00 [7] 0.00 [8] 2.64 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 8에게 1.10 전력을 줌
# 발전기 2가 발전기 0에게 2.22 전력을 줌
# 발전기 2가 발전기 5에게 1.62 전력을 줌
# 발전기 2가 발전기 6에게 0.79 전력을 줌
# 발전기 2가 발전기 7에게 2.72 전력을 줌
# 발전기 3가 발전기 5에게 5.26 전력을 줌
# 발전기 3가 발전기 8에게 0.47 전력을 줌
# 발전기 9가 발전기 6에게 0.83 전력을 줌
#
# [t=13 s=16]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 33.89 ([0] 0.51 [1] 0.00 [2] 7.31 [3] 6.42 [4] 2.26 [5] 5.79 [6] 3.36 [7] 3.72 [8] 4.51 [9] 0.00 )
# y- 합계: 4.63 ([0] 0.00 [1] 4.30 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.33 )
# e+ 합계: 29.26 ([0] 0.00 [1] 0.00 [2] 7.31 [3] 6.42 [4] 2.26 [5] 5.79 [6] 3.36 [7] 3.72 [8] 0.39 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 0.51 전력을 줌
# 발전기 8가 발전기 1에게 3.79 전력을 줌
# 발전기 8가 발전기 9에게 0.33 전력을 줌
#
# [t=13 s=17]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 53.06 ([0] 7.90 [1] 0.00 [2] 0.00 [3] 9.74 [4] 13.44 [5] 0.00 [6] 11.06 [7] 0.00 [8] 3.08 [9] 7.83 )
# y- 합계: 15.06 ([0] 0.00 [1] 6.88 [2] 2.47 [3] 0.00 [4] 0.00 [5] 3.81 [6] 0.00 [7] 1.90 [8] 0.00 [9] 0.00 )
# e+ 합계: 38.00 ([0] 4.10 [1] 0.00 [2] 0.00 [3] 7.27 [4] 4.66 [5] 0.00 [6] 11.06 [7] 0.00 [8] 3.08 [9] 7.83 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 5에게 3.81 전력을 줌
# 발전기 3가 발전기 2에게 2.47 전력을 줌
# 발전기 4가 발전기 1에게 6.88 전력을 줌
# 발전기 4가 발전기 7에게 1.90 전력을 줌
#
# [t=13 s=18]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 22.01 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 13.56 [5] 0.00 [6] 0.00 [7] 5.44 [8] 3.01 [9] 0.00 )
# y- 합계: 22.80 ([0] 1.01 [1] 0.00 [2] 2.47 [3] 2.94 [4] 0.00 [5] 6.88 [6] 3.08 [7] 0.00 [8] 0.00 [9] 6.42 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.79 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.79 )
# 거래 내역:
# 발전기 4가 발전기 2에게 2.47 전력을 줌
# 발전기 4가 발전기 3에게 2.94 전력을 줌
# 발전기 4가 발전기 5에게 2.51 전력을 줌
# 발전기 4가 발전기 9에게 5.63 전력을 줌
# 발전기 7가 발전기 0에게 1.01 전력을 줌
# 발전기 7가 발전기 5에게 1.35 전력을 줌
# 발전기 7가 발전기 6에게 3.08 전력을 줌
# 발전기 8가 발전기 5에게 3.01 전력을 줌
#
# [t=13 s=19]
# x 합계: 39.04 ([0] 2.22 [1] 6.88 [2] 2.47 [3] 3.04 [4] 1.11 [5] 6.88 [6] 3.08 [7] 2.72 [8] 4.21 [9] 6.42 )
# y+ 합계: 24.01 ([0] 8.71 [1] 0.57 [2] 0.00 [3] 4.99 [4] 4.79 [5] 2.29 [6] 0.00 [7] 1.04 [8] 0.00 [9] 1.63 )
# y- 합계: 8.33 ([0] 0.00 [1] 0.00 [2] 2.47 [3] 0.00 [4] 0.00 [5] 0.00 [6] 1.64 [7] 0.00 [8] 4.21 [9] 0.00 )
# e+ 합계: 15.69 ([0] 7.37 [1] 0.00 [2] 0.00 [3] 4.99 [4] 0.00 [5] 2.29 [6] 0.00 [7] 1.04 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 2에게 1.34 전력을 줌
# 발전기 1가 발전기 6에게 0.57 전력을 줌
# 발전기 4가 발전기 6에게 1.08 전력을 줌
# 발전기 4가 발전기 8에게 3.71 전력을 줌
# 발전기 9가 발전기 2에게 1.13 전력을 줌
# 발전기 9가 발전기 8에게 0.49 전력을 줌
#
# [t=14 s=0]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 27.83 ([0] 1.48 [1] 0.54 [2] 0.00 [3] 7.96 [4] 0.00 [5] 0.93 [6] 3.67 [7] 4.03 [8] 9.22 [9] 0.00 )
# y- 합계: 9.80 ([0] 0.00 [1] 0.00 [2] 2.84 [3] 0.00 [4] 3.87 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 3.09 )
# e+ 합계: 18.04 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 7.96 [4] 0.00 [5] 0.00 [6] 3.67 [7] 4.03 [8] 2.38 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 9에게 1.48 전력을 줌
# 발전기 1가 발전기 9에게 0.54 전력을 줌
# 발전기 5가 발전기 2에게 0.93 전력을 줌
# 발전기 8가 발전기 2에게 1.90 전력을 줌
# 발전기 8가 발전기 4에게 3.87 전력을 줌
# 발전기 8가 발전기 9에게 1.07 전력을 줌
#
# [t=14 s=1]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 17.67 ([0] 8.82 [1] 0.00 [2] 0.00 [3] 0.37 [4] 0.00 [5] 6.54 [6] 0.00 [7] 0.00 [8] 0.00 [9] 1.93 )
# y- 합계: 17.67 ([0] 0.00 [1] 2.35 [2] 4.87 [3] 0.00 [4] 2.87 [5] 0.00 [6] 1.70 [7] 4.23 [8] 1.64 [9] 0.00 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 0.42 전력을 줌
# 발전기 0가 발전기 2에게 4.50 전력을 줌
# 발전기 0가 발전기 4에게 0.57 전력을 줌
# 발전기 0가 발전기 6에게 1.70 전력을 줌
# 발전기 0가 발전기 8에게 1.64 전력을 줌
# 발전기 3가 발전기 2에게 0.37 전력을 줌
# 발전기 5가 발전기 4에게 2.31 전력을 줌
# 발전기 5가 발전기 7에게 4.23 전력을 줌
# 발전기 9가 발전기 1에게 1.93 전력을 줌
#
# [t=14 s=2]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 13.12 ([0] 0.00 [1] 0.00 [2] 2.24 [3] 0.00 [4] 0.00 [5] 3.87 [6] 0.00 [7] 4.38 [8] 0.00 [9] 2.63 )
# y- 합계: 11.30 ([0] 0.95 [1] 2.18 [2] 0.00 [3] 0.93 [4] 3.87 [5] 0.00 [6] 2.74 [7] 0.00 [8] 0.64 [9] 0.00 )
# e+ 합계: 1.81 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.72 [8] 0.00 [9] 1.09 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 0에게 0.95 전력을 줌
# 발전기 2가 발전기 1에게 0.65 전력을 줌
# 발전기 2가 발전기 8에게 0.64 전력을 줌
# 발전기 5가 발전기 3에게 0.93 전력을 줌
# 발전기 5가 발전기 4에게 2.94 전력을 줌
# 발전기 7가 발전기 4에게 0.93 전력을 줌
# 발전기 7가 발전기 6에게 2.74 전력을 줌
# 발전기 9가 발전기 1에게 1.54 전력을 줌
#
# [t=14 s=3]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 35.66 ([0] 0.00 [1] 6.42 [2] 4.40 [3] 0.00 [4] 0.00 [5] 9.75 [6] 1.07 [7] 8.35 [8] 0.00 [9] 5.67 )
# y- 합계: 9.56 ([0] 1.87 [1] 0.00 [2] 0.00 [3] 5.04 [4] 1.02 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.64 [9] 0.00 )
# e+ 합계: 26.09 ([0] 0.00 [1] 6.42 [2] 4.40 [3] 0.00 [4] 0.00 [5] 2.84 [6] 0.00 [7] 6.76 [8] 0.00 [9] 5.67 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 5가 발전기 0에게 1.87 전력을 줌
# 발전기 5가 발전기 3에게 5.04 전력을 줌
# 발전기 6가 발전기 8에게 1.07 전력을 줌
# 발전기 7가 발전기 4에게 1.02 전력을 줌
# 발전기 7가 발전기 8에게 0.57 전력을 줌
#
# [t=14 s=4]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 43.29 ([0] 7.58 [1] 3.39 [2] 0.00 [3] 3.04 [4] 7.82 [5] 3.09 [6] 12.91 [7] 1.24 [8] 4.22 [9] 0.00 )
# y- 합계: 5.57 ([0] 0.00 [1] 0.00 [2] 2.47 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 3.09 )
# e+ 합계: 37.73 ([0] 7.58 [1] 3.39 [2] 0.00 [3] 3.04 [4] 5.35 [5] 0.00 [6] 12.91 [7] 1.24 [8] 4.22 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 4가 발전기 2에게 2.47 전력을 줌
# 발전기 5가 발전기 2에게 0.00 전력을 줌
# 발전기 5가 발전기 9에게 3.09 전력을 줌
#
# [t=14 s=5]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 39.61 ([0] 4.58 [1] 0.00 [2] 10.26 [3] 0.00 [4] 1.00 [5] 6.83 [6] 12.94 [7] 1.67 [8] 2.32 [9] 0.00 )
# y- 합계: 10.49 ([0] 0.00 [1] 2.35 [2] 0.00 [3] 5.04 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 3.09 )
# e+ 합계: 29.12 ([0] 4.58 [1] 0.00 [2] 10.26 [3] 0.00 [4] 0.00 [5] 0.00 [6] 12.94 [7] 1.34 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 4가 발전기 9에게 1.00 전력을 줌
# 발전기 5가 발전기 1에게 1.79 전력을 줌
# 발전기 5가 발전기 3에게 5.04 전력을 줌
# 발전기 7가 발전기 9에게 0.33 전력을 줌
# 발전기 8가 발전기 1에게 0.56 전력을 줌
# 발전기 8가 발전기 9에게 1.76 전력을 줌
#
# [t=14 s=6]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 40.57 ([0] 4.47 [1] 6.73 [2] 0.00 [3] 7.63 [4] 1.91 [5] 1.08 [6] 10.35 [7] 6.30 [8] 0.00 [9] 2.10 )
# y- 합계: 5.91 ([0] 0.00 [1] 0.00 [2] 4.87 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.04 [9] 0.00 )
# e+ 합계: 34.66 ([0] 4.47 [1] 0.82 [2] 0.00 [3] 7.63 [4] 1.91 [5] 1.08 [6] 10.35 [7] 6.30 [8] 0.00 [9] 2.10 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 2에게 4.87 전력을 줌
# 발전기 1가 발전기 8에게 1.04 전력을 줌
#
# [t=14 s=7]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 14.37 ([0] 4.29 [1] 0.00 [2] 0.00 [3] 7.73 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 2.35 [9] 0.00 )
# y- 합계: 20.58 ([0] 0.00 [1] 2.35 [2] 3.14 [3] 0.00 [4] 2.49 [5] 3.48 [6] 1.69 [7] 4.34 [8] 0.00 [9] 3.09 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 6.20 ([0] 0.00 [1] 1.87 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 4.34 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 0.49 전력을 줌
# 발전기 0가 발전기 2에게 1.37 전력을 줌
# 발전기 0가 발전기 6에게 1.69 전력을 줌
# 발전기 0가 발전기 9에게 0.74 전력을 줌
# 발전기 3가 발전기 2에게 1.76 전력을 줌
# 발전기 3가 발전기 4에게 2.49 전력을 줌
# 발전기 3가 발전기 5에게 3.48 전력을 줌
# 발전기 8가 발전기 9에게 2.35 전력을 줌
#
# [t=14 s=8]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 22.40 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 6.44 [6] 7.37 [7] 0.00 [8] 8.59 [9] 0.00 )
# y- 합계: 18.26 ([0] 0.94 [1] 2.35 [2] 1.72 [3] 5.04 [4] 3.87 [5] 0.00 [6] 0.00 [7] 4.34 [8] 0.00 [9] 0.00 )
# e+ 합계: 4.14 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 2.95 [6] 0.00 [7] 0.00 [8] 1.19 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 5가 발전기 0에게 0.94 전력을 줌
# 발전기 5가 발전기 2에게 1.72 전력을 줌
# 발전기 5가 발전기 7에게 0.83 전력을 줌
# 발전기 6가 발전기 4에게 3.87 전력을 줌
# 발전기 6가 발전기 7에게 3.50 전력을 줌
# 발전기 8가 발전기 1에게 2.35 전력을 줌
# 발전기 8가 발전기 3에게 5.04 전력을 줌
#
# [t=14 s=9]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 32.46 ([0] 0.00 [1] 1.41 [2] 4.30 [3] 0.00 [4] 0.00 [5] 4.11 [6] 0.00 [7] 4.88 [8] 6.32 [9] 11.44 )
# y- 합계: 13.61 ([0] 1.87 [1] 0.00 [2] 0.00 [3] 5.04 [4] 2.37 [5] 0.00 [6] 4.34 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 18.84 ([0] 0.00 [1] 1.41 [2] 4.14 [3] 0.00 [4] 0.00 [5] 4.11 [6] 0.00 [7] 0.00 [8] 0.00 [9] 9.19 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 3에게 0.16 전력을 줌
# 발전기 7가 발전기 3에게 4.88 전력을 줌
# 발전기 8가 발전기 0에게 1.87 전력을 줌
# 발전기 8가 발전기 4에게 0.12 전력을 줌
# 발전기 8가 발전기 6에게 4.34 전력을 줌
# 발전기 9가 발전기 4에게 2.25 전력을 줌
#
# [t=14 s=10]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 30.74 ([0] 0.00 [1] 8.70 [2] 0.00 [3] 0.00 [4] 6.28 [5] 12.26 [6] 0.00 [7] 3.51 [8] 0.00 [9] 0.00 )
# y- 합계: 14.93 ([0] 1.87 [1] 0.00 [2] 3.30 [3] 5.04 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.64 [9] 3.09 )
# e+ 합계: 15.81 ([0] 0.00 [1] 8.70 [2] 0.00 [3] 0.00 [4] 3.60 [5] 0.00 [6] 0.00 [7] 3.51 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 4가 발전기 9에게 2.68 전력을 줌
# 발전기 5가 발전기 0에게 1.87 전력을 줌
# 발전기 5가 발전기 2에게 3.30 전력을 줌
# 발전기 5가 발전기 3에게 5.04 전력을 줌
# 발전기 5가 발전기 8에게 1.64 전력을 줌
# 발전기 5가 발전기 9에게 0.42 전력을 줌
#
# [t=14 s=11]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 31.28 ([0] 0.00 [1] 8.76 [2] 5.27 [3] 0.00 [4] 0.00 [5] 5.95 [6] 6.24 [7] 4.57 [8] 0.00 [9] 0.49 )
# y- 합계: 6.62 ([0] 0.11 [1] 0.00 [2] 0.00 [3] 1.01 [4] 3.87 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.64 [9] 0.00 )
# e+ 합계: 24.65 ([0] 0.00 [1] 8.76 [2] 5.27 [3] 0.00 [4] 0.00 [5] 0.00 [6] 6.05 [7] 4.57 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 5가 발전기 0에게 0.11 전력을 줌
# 발전기 5가 발전기 3에게 0.34 전력을 줌
# 발전기 5가 발전기 4에게 3.87 전력을 줌
# 발전기 5가 발전기 8에게 1.64 전력을 줌
# 발전기 6가 발전기 3에게 0.19 전력을 줌
# 발전기 9가 발전기 3에게 0.49 전력을 줌
#
# [t=14 s=12]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 23.69 ([0] 0.00 [1] 1.12 [2] 5.54 [3] 5.64 [4] 0.00 [5] 3.67 [6] 3.61 [7] 0.00 [8] 0.00 [9] 4.11 )
# y- 합계: 11.71 ([0] 1.87 [1] 0.00 [2] 0.00 [3] 0.00 [4] 3.87 [5] 0.00 [6] 0.00 [7] 4.34 [8] 1.64 [9] 0.00 )
# e+ 합계: 11.98 ([0] 0.00 [1] 1.12 [2] 5.01 [3] 0.00 [4] 0.00 [5] 0.00 [6] 3.61 [7] 0.00 [8] 0.00 [9] 2.24 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 4에게 0.53 전력을 줌
# 발전기 3가 발전기 7에게 4.00 전력을 줌
# 발전기 3가 발전기 8에게 1.64 전력을 줌
# 발전기 5가 발전기 4에게 3.34 전력을 줌
# 발전기 5가 발전기 7에게 0.33 전력을 줌
# 발전기 9가 발전기 0에게 1.87 전력을 줌
#
# [t=14 s=13]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 30.44 ([0] 0.00 [1] 8.96 [2] 2.66 [3] 0.00 [4] 0.00 [5] 0.60 [6] 11.62 [7] 6.60 [8] 0.00 [9] 0.00 )
# y- 합계: 9.67 ([0] 1.57 [1] 0.00 [2] 0.00 [3] 1.16 [4] 2.54 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.31 [9] 3.09 )
# e+ 합계: 20.78 ([0] 0.00 [1] 8.96 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.20 [6] 11.62 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 4에게 1.35 전력을 줌
# 발전기 2가 발전기 8에게 1.31 전력을 줌
# 발전기 5가 발전기 9에게 0.40 전력을 줌
# 발전기 7가 발전기 0에게 1.57 전력을 줌
# 발전기 7가 발전기 3에게 1.16 전력을 줌
# 발전기 7가 발전기 4에게 1.19 전력을 줌
# 발전기 7가 발전기 9에게 2.69 전력을 줌
#
# [t=14 s=14]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 36.10 ([0] 9.74 [1] 0.00 [2] 0.00 [3] 11.85 [4] 0.00 [5] 0.00 [6] 9.18 [7] 5.33 [8] 0.00 [9] 0.00 )
# y- 합계: 8.27 ([0] 0.00 [1] 2.35 [2] 0.00 [3] 0.00 [4] 1.57 [5] 1.57 [6] 0.00 [7] 0.00 [8] 1.64 [9] 1.14 )
# e+ 합계: 27.84 ([0] 6.81 [1] 0.00 [2] 0.00 [3] 11.85 [4] 0.00 [5] 0.00 [6] 9.18 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 5에게 1.30 전력을 줌
# 발전기 0가 발전기 8에게 1.64 전력을 줌
# 발전기 7가 발전기 1에게 2.35 전력을 줌
# 발전기 7가 발전기 4에게 1.57 전력을 줌
# 발전기 7가 발전기 5에게 0.27 전력을 줌
# 발전기 7가 발전기 9에게 1.14 전력을 줌
#
# [t=14 s=15]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 10.45 ([0] 0.00 [1] 0.00 [2] 5.44 [3] 0.00 [4] 0.00 [5] 3.75 [6] 0.51 [7] 0.00 [8] 0.75 [9] 0.00 )
# y- 합계: 14.31 ([0] 1.87 [1] 0.00 [2] 0.00 [3] 1.15 [4] 3.87 [5] 0.00 [6] 0.00 [7] 4.34 [8] 0.00 [9] 3.09 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 3.86 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 3.86 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 0에게 1.12 전력을 줌
# 발전기 2가 발전기 3에게 1.15 전력을 줌
# 발전기 2가 발전기 7에게 3.17 전력을 줌
# 발전기 5가 발전기 7에게 1.17 전력을 줌
# 발전기 5가 발전기 9에게 2.58 전력을 줌
# 발전기 6가 발전기 4에게 0.01 전력을 줌
# 발전기 6가 발전기 9에게 0.51 전력을 줌
# 발전기 8가 발전기 0에게 0.75 전력을 줌
#
# [t=14 s=16]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 24.97 ([0] 7.71 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 7.09 [6] 6.87 [7] 1.20 [8] 2.10 [9] 0.00 )
# y- 합계: 12.66 ([0] 0.00 [1] 2.35 [2] 4.87 [3] 2.65 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 2.79 )
# e+ 합계: 12.30 ([0] 4.92 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 4.73 [6] 0.00 [7] 1.20 [8] 1.45 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 9에게 2.79 전력을 줌
# 발전기 5가 발전기 1에게 2.35 전력을 줌
# 발전기 6가 발전기 2에게 4.21 전력을 줌
# 발전기 6가 발전기 3에게 2.65 전력을 줌
# 발전기 8가 발전기 2에게 0.65 전력을 줌
#
# [t=14 s=17]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 37.79 ([0] 0.00 [1] 1.89 [2] 0.85 [3] 0.00 [4] 0.00 [5] 0.14 [6] 9.42 [7] 9.74 [8] 8.30 [9] 7.43 )
# y- 합계: 5.73 ([0] 1.87 [1] 0.00 [2] 0.00 [3] 0.00 [4] 3.87 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 32.05 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 9.42 [7] 8.87 [8] 8.30 [9] 5.46 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 4에게 1.89 전력을 줌
# 발전기 2가 발전기 0에게 0.85 전력을 줌
# 발전기 5가 발전기 0에게 0.14 전력을 줌
# 발전기 7가 발전기 0에게 0.87 전력을 줌
# 발전기 9가 발전기 4에게 1.97 전력을 줌
#
# [t=14 s=18]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 12.64 ([0] 0.00 [1] 0.00 [2] 5.59 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 7.05 [9] 0.00 )
# y- 합계: 17.76 ([0] 0.00 [1] 2.35 [2] 0.00 [3] 4.47 [4] 0.03 [5] 3.48 [6] 4.34 [7] 0.00 [8] 0.00 [9] 3.09 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 5.12 ([0] 0.00 [1] 1.10 [2] 0.00 [3] 0.00 [4] 0.03 [5] 3.48 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.51 )
# 거래 내역:
# 발전기 2가 발전기 1에게 1.25 전력을 줌
# 발전기 2가 발전기 6에게 4.34 전력을 줌
# 발전기 8가 발전기 3에게 4.47 전력을 줌
# 발전기 8가 발전기 9에게 2.58 전력을 줌
#
# [t=14 s=19]
# x 합계: 34.88 ([0] 1.87 [1] 2.35 [2] 4.87 [3] 5.04 [4] 3.87 [5] 3.48 [6] 4.34 [7] 4.34 [8] 1.64 [9] 3.09 )
# y+ 합계: 18.34 ([0] 6.35 [1] 2.25 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 9.63 [8] 0.00 [9] 0.10 )
# y- 합계: 16.62 ([0] 0.00 [1] 0.00 [2] 2.27 [3] 5.04 [4] 3.87 [5] 3.48 [6] 1.96 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 1.72 ([0] 0.00 [1] 1.72 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 2에게 2.27 전력을 줌
# 발전기 0가 발전기 3에게 4.09 전력을 줌
# 발전기 1가 발전기 5에게 0.54 전력을 줌
# 발전기 7가 발전기 3에게 0.95 전력을 줌
# 발전기 7가 발전기 4에게 3.87 전력을 줌
# 발전기 7가 발전기 5에게 2.85 전력을 줌
# 발전기 7가 발전기 6에게 1.96 전력을 줌
# 발전기 9가 발전기 5에게 0.10 전력을 줌
#
# [t=15 s=0]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 21.84 ([0] 0.36 [1] 0.64 [2] 1.10 [3] 0.00 [4] 0.75 [5] 0.00 [6] 0.00 [7] 9.58 [8] 0.00 [9] 9.41 )
# y- 합계: 6.77 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.34 [4] 0.00 [5] 0.90 [6] 4.91 [7] 0.00 [8] 0.62 [9] 0.00 )
# e+ 합계: 15.06 ([0] 0.00 [1] 0.00 [2] 1.10 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 8.67 [8] 0.00 [9] 5.29 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 3에게 0.34 전력을 줌
# 발전기 0가 발전기 8에게 0.02 전력을 줌
# 발전기 1가 발전기 6에게 0.04 전력을 줌
# 발전기 1가 발전기 8에게 0.60 전력을 줌
# 발전기 4가 발전기 6에게 0.75 전력을 줌
# 발전기 7가 발전기 5에게 0.90 전력을 줌
# 발전기 9가 발전기 6에게 4.13 전력을 줌
#
# [t=15 s=1]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 16.01 ([0] 0.00 [1] 0.14 [2] 0.00 [3] 0.00 [4] 0.74 [5] 0.00 [6] 3.95 [7] 6.12 [8] 5.06 [9] 0.00 )
# y- 합계: 12.55 ([0] 5.49 [1] 0.00 [2] 1.57 [3] 2.71 [4] 0.00 [5] 0.90 [6] 0.00 [7] 0.00 [8] 0.00 [9] 1.88 )
# e+ 합계: 3.46 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 2.09 [7] 1.38 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 2에게 0.12 전력을 줌
# 발전기 1가 발전기 9에게 0.02 전력을 줌
# 발전기 4가 발전기 0에게 0.74 전력을 줌
# 발전기 6가 발전기 9에게 1.86 전력을 줌
# 발전기 7가 발전기 0에게 4.74 전력을 줌
# 발전기 8가 발전기 2에게 1.45 전력을 줌
# 발전기 8가 발전기 3에게 2.71 전력을 줌
# 발전기 8가 발전기 5에게 0.90 전력을 줌
#
# [t=15 s=2]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 28.40 ([0] 0.00 [1] 2.85 [2] 0.00 [3] 5.62 [4] 0.00 [5] 7.49 [6] 6.24 [7] 0.59 [8] 0.00 [9] 5.61 )
# y- 합계: 6.62 ([0] 5.49 [1] 0.00 [2] 0.52 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.62 [9] 0.00 )
# e+ 합계: 21.78 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 5.62 [4] 0.00 [5] 6.97 [6] 6.24 [7] 0.59 [8] 0.00 [9] 2.36 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 0에게 2.23 전력을 줌
# 발전기 1가 발전기 8에게 0.62 전력을 줌
# 발전기 5가 발전기 2에게 0.52 전력을 줌
# 발전기 9가 발전기 0에게 3.26 전력을 줌
#
# [t=15 s=3]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 15.45 ([0] 2.74 [1] 0.00 [2] 7.97 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 3.25 [9] 1.49 )
# y- 합계: 15.02 ([0] 0.00 [1] 1.71 [2] 0.00 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 1.02 [8] 0.00 [9] 0.00 )
# e+ 합계: 0.44 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.44 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 1.71 전력을 줌
# 발전기 0가 발전기 4에게 0.86 전력을 줌
# 발전기 0가 발전기 5에게 0.18 전력을 줌
# 발전기 2가 발전기 5에게 0.62 전력을 줌
# 발전기 2가 발전기 6에게 7.35 전력을 줌
# 발전기 8가 발전기 3에게 2.71 전력을 줌
# 발전기 8가 발전기 5에게 0.11 전력을 줌
# 발전기 9가 발전기 4에게 0.46 전력을 줌
# 발전기 9가 발전기 7에게 1.02 전력을 줌
#
# [t=15 s=4]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 21.52 ([0] 0.00 [1] 8.51 [2] 2.26 [3] 0.80 [4] 0.00 [5] 4.77 [6] 4.65 [7] 0.00 [8] 0.52 [9] 0.00 )
# y- 합계: 10.40 ([0] 5.49 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.93 [5] 0.00 [6] 0.00 [7] 2.10 [8] 0.00 [9] 1.88 )
# e+ 합계: 11.12 ([0] 0.00 [1] 4.92 [2] 2.26 [3] 0.00 [4] 0.00 [5] 0.00 [6] 3.94 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 4에게 0.12 전력을 줌
# 발전기 1가 발전기 7에게 1.58 전력을 줌
# 발전기 1가 발전기 9에게 1.88 전력을 줌
# 발전기 3가 발전기 4에게 0.80 전력을 줌
# 발전기 5가 발전기 0에게 4.77 전력을 줌
# 발전기 6가 발전기 0에게 0.71 전력을 줌
# 발전기 8가 발전기 7에게 0.52 전력을 줌
#
# [t=15 s=5]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 33.27 ([0] 0.00 [1] 0.00 [2] 7.54 [3] 4.71 [4] 0.00 [5] 11.96 [6] 0.00 [7] 4.59 [8] 4.47 [9] 0.00 )
# y- 합계: 13.64 ([0] 3.08 [1] 0.00 [2] 0.00 [3] 0.00 [4] 1.32 [5] 0.00 [6] 7.35 [7] 0.00 [8] 0.00 [9] 1.88 )
# e+ 합계: 19.63 ([0] 0.00 [1] 0.00 [2] 7.54 [3] 2.83 [4] 0.00 [5] 4.67 [6] 0.00 [7] 4.59 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 3가 발전기 9에게 1.88 전력을 줌
# 발전기 5가 발전기 4에게 1.32 전력을 줌
# 발전기 5가 발전기 6에게 5.97 전력을 줌
# 발전기 8가 발전기 0에게 3.08 전력을 줌
# 발전기 8가 발전기 6에게 1.39 전력을 줌
#
# [t=15 s=6]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 14.48 ([0] 0.00 [1] 4.19 [2] 0.00 [3] 0.01 [4] 0.00 [5] 10.28 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 15.02 ([0] 5.49 [1] 0.00 [2] 1.57 [3] 0.00 [4] 1.32 [5] 0.00 [6] 2.81 [7] 2.20 [8] 0.62 [9] 1.01 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.54 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.54 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 4에게 1.32 전력을 줌
# 발전기 1가 발전기 6에게 2.81 전력을 줌
# 발전기 1가 발전기 7에게 0.06 전력을 줌
# 발전기 3가 발전기 9에게 0.01 전력을 줌
# 발전기 5가 발전기 0에게 5.49 전력을 줌
# 발전기 5가 발전기 2에게 1.57 전력을 줌
# 발전기 5가 발전기 7에게 2.14 전력을 줌
# 발전기 5가 발전기 8에게 0.08 전력을 줌
# 발전기 5가 발전기 9에게 1.01 전력을 줌
#
# [t=15 s=7]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 15.35 ([0] 1.72 [1] 3.36 [2] 0.00 [3] 0.00 [4] 2.86 [5] 7.41 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 13.63 ([0] 0.00 [1] 0.00 [2] 1.57 [3] 2.71 [4] 0.00 [5] 0.00 [6] 7.35 [7] 0.00 [8] 0.12 [9] 1.88 )
# e+ 합계: 1.71 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 1.71 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 6에게 1.60 전력을 줌
# 발전기 0가 발전기 8에게 0.12 전력을 줌
# 발전기 1가 발전기 6에게 2.90 전력을 줌
# 발전기 1가 발전기 9에게 0.46 전력을 줌
# 발전기 4가 발전기 6에게 2.86 전력을 줌
# 발전기 5가 발전기 2에게 1.57 전력을 줌
# 발전기 5가 발전기 3에게 2.71 전력을 줌
# 발전기 5가 발전기 9에게 1.42 전력을 줌
#
# [t=15 s=8]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 17.94 ([0] 0.00 [1] 6.29 [2] 1.49 [3] 0.00 [4] 0.00 [5] 1.46 [6] 1.46 [7] 1.33 [8] 5.90 [9] 0.00 )
# y- 합계: 4.96 ([0] 2.05 [1] 0.00 [2] 0.00 [3] 1.07 [4] 1.32 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.52 )
# e+ 합계: 12.98 ([0] 0.00 [1] 6.29 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 1.46 [7] 1.33 [8] 3.90 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 3에게 0.97 전력을 줌
# 발전기 2가 발전기 9에게 0.52 전력을 줌
# 발전기 5가 발전기 0에게 0.04 전력을 줌
# 발전기 5가 발전기 3에게 0.10 전력을 줌
# 발전기 5가 발전기 4에게 1.32 전력을 줌
# 발전기 8가 발전기 0에게 2.01 전력을 줌
#
# [t=15 s=9]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 43.08 ([0] 0.00 [1] 0.00 [2] 2.63 [3] 0.00 [4] 2.02 [5] 12.83 [6] 6.98 [7] 9.43 [8] 0.00 [9] 9.19 )
# y- 합계: 9.78 ([0] 5.49 [1] 0.96 [2] 0.00 [3] 2.71 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.62 [9] 0.00 )
# e+ 합계: 33.30 ([0] 0.00 [1] 0.00 [2] 2.63 [3] 0.00 [4] 0.00 [5] 8.75 [6] 6.98 [7] 5.76 [8] 0.00 [9] 9.19 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 4가 발전기 0에게 2.02 전력을 줌
# 발전기 5가 발전기 0에게 3.46 전력을 줌
# 발전기 5가 발전기 8에게 0.62 전력을 줌
# 발전기 7가 발전기 1에게 0.96 전력을 줌
# 발전기 7가 발전기 3에게 2.71 전력을 줌
#
# [t=15 s=10]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 8.60 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 1.20 [5] 0.00 [6] 2.53 [7] 4.87 [8] 0.00 [9] 0.00 )
# y- 합계: 9.64 ([0] 0.96 [1] 1.01 [2] 1.57 [3] 2.71 [4] 0.00 [5] 0.90 [6] 0.00 [7] 0.00 [8] 0.62 [9] 1.88 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 1.05 ([0] 0.96 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.09 [9] 0.00 )
# 거래 내역:
# 발전기 4가 발전기 3에게 1.20 전력을 줌
# 발전기 6가 발전기 1에게 1.01 전력을 줌
# 발전기 6가 발전기 2에게 0.09 전력을 줌
# 발전기 6가 발전기 5에게 0.90 전력을 줌
# 발전기 6가 발전기 8에게 0.53 전력을 줌
# 발전기 7가 발전기 2에게 1.48 전력을 줌
# 발전기 7가 발전기 3에게 1.51 전력을 줌
# 발전기 7가 발전기 9에게 1.88 전력을 줌
#
# [t=15 s=11]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 19.33 ([0] 5.20 [1] 0.39 [2] 0.00 [3] 0.00 [4] 0.00 [5] 6.61 [6] 0.00 [7] 1.78 [8] 5.35 [9] 0.00 )
# y- 합계: 12.90 ([0] 0.00 [1] 0.00 [2] 1.57 [3] 0.77 [4] 1.32 [5] 0.00 [6] 7.35 [7] 0.00 [8] 0.00 [9] 1.88 )
# e+ 합계: 6.43 ([0] 3.88 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 2.55 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 4에게 1.32 전력을 줌
# 발전기 1가 발전기 3에게 0.39 전력을 줌
# 발전기 5가 발전기 2에게 1.03 전력을 줌
# 발전기 5가 발전기 6에게 5.58 전력을 줌
# 발전기 7가 발전기 6에게 1.78 전력을 줌
# 발전기 8가 발전기 2에게 0.54 전력을 줌
# 발전기 8가 발전기 3에게 0.38 전력을 줌
# 발전기 8가 발전기 9에게 1.88 전력을 줌
#
# [t=15 s=12]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 37.34 ([0] 7.72 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 8.08 [6] 0.00 [7] 0.95 [8] 10.82 [9] 9.78 )
# y- 합계: 13.56 ([0] 0.00 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.00 [6] 6.25 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 23.78 ([0] 7.72 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 7.54 [9] 8.52 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 5가 발전기 3에게 2.71 전력을 줌
# 발전기 5가 발전기 4에게 0.06 전력을 줌
# 발전기 5가 발전기 6에게 5.30 전력을 줌
# 발전기 7가 발전기 6에게 0.95 전력을 줌
# 발전기 8가 발전기 1에게 1.71 전력을 줌
# 발전기 8가 발전기 2에게 1.57 전력을 줌
# 발전기 9가 발전기 4에게 1.26 전력을 줌
#
# [t=15 s=13]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 20.92 ([0] 6.49 [1] 0.00 [2] 0.62 [3] 0.00 [4] 5.87 [5] 0.00 [6] 5.00 [7] 2.94 [8] 0.00 [9] 0.00 )
# y- 합계: 4.66 ([0] 0.00 [1] 1.71 [2] 0.00 [3] 2.71 [4] 0.00 [5] 0.05 [6] 0.00 [7] 0.00 [8] 0.19 [9] 0.00 )
# e+ 합계: 16.25 ([0] 6.49 [1] 0.00 [2] 0.00 [3] 0.00 [4] 1.83 [5] 0.00 [6] 5.00 [7] 2.94 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 1에게 0.43 전력을 줌
# 발전기 2가 발전기 8에게 0.19 전력을 줌
# 발전기 4가 발전기 1에게 1.28 전력을 줌
# 발전기 4가 발전기 3에게 2.71 전력을 줌
# 발전기 4가 발전기 5에게 0.05 전력을 줌
#
# [t=15 s=14]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 10.00 ([0] 4.56 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 4.03 [6] 0.00 [7] 1.41 [8] 0.00 [9] 0.00 )
# y- 합계: 10.00 ([0] 0.00 [1] 0.98 [2] 0.28 [3] 2.67 [4] 1.32 [5] 0.00 [6] 2.25 [7] 0.00 [8] 0.62 [9] 1.88 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 2에게 0.28 전력을 줌
# 발전기 0가 발전기 3에게 2.03 전력을 줌
# 발전기 0가 발전기 6에게 2.25 전력을 줌
# 발전기 5가 발전기 3에게 0.21 전력을 줌
# 발전기 5가 발전기 4에게 1.32 전력을 줌
# 발전기 5가 발전기 8에게 0.62 전력을 줌
# 발전기 5가 발전기 9에게 1.88 전력을 줌
# 발전기 7가 발전기 1에게 0.98 전력을 줌
# 발전기 7가 발전기 3에게 0.43 전력을 줌
#
# [t=15 s=15]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 20.71 ([0] 0.00 [1] 6.27 [2] 3.22 [3] 0.00 [4] 0.00 [5] 0.00 [6] 3.60 [7] 0.00 [8] 7.62 [9] 0.00 )
# y- 합계: 14.50 ([0] 5.49 [1] 0.00 [2] 0.00 [3] 2.71 [4] 1.32 [5] 0.90 [6] 0.00 [7] 2.20 [8] 0.00 [9] 1.88 )
# e+ 합계: 6.21 ([0] 0.00 [1] 6.21 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 0에게 0.06 전력을 줌
# 발전기 2가 발전기 0에게 0.02 전력을 줌
# 발전기 2가 발전기 4에게 1.32 전력을 줌
# 발전기 2가 발전기 9에게 1.88 전력을 줌
# 발전기 6가 발전기 0에게 1.39 전력을 줌
# 발전기 6가 발전기 7에게 2.20 전력을 줌
# 발전기 8가 발전기 0에게 4.01 전력을 줌
# 발전기 8가 발전기 3에게 2.71 전력을 줌
# 발전기 8가 발전기 5에게 0.90 전력을 줌
#
# [t=15 s=16]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 4.73 ([0] 0.00 [1] 0.78 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 1.72 [7] 0.00 [8] 2.24 [9] 0.00 )
# y- 합계: 15.72 ([0] 5.49 [1] 0.00 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 0.00 [7] 2.20 [8] 0.00 [9] 1.53 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 10.99 ([0] 5.30 [1] 0.00 [2] 1.57 [3] 1.93 [4] 1.32 [5] 0.87 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 3에게 0.78 전력을 줌
# 발전기 6가 발전기 0에게 0.19 전력을 줌
# 발전기 6가 발전기 9에게 1.53 전력을 줌
# 발전기 8가 발전기 5에게 0.04 전력을 줌
# 발전기 8가 발전기 7에게 2.20 전력을 줌
#
# [t=15 s=17]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 25.01 ([0] 0.00 [1] 6.87 [2] 0.00 [3] 0.00 [4] 0.00 [5] 2.07 [6] 4.18 [7] 2.39 [8] 5.85 [9] 3.65 )
# y- 합계: 8.90 ([0] 3.30 [1] 0.00 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 16.11 ([0] 0.00 [1] 6.23 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 4.18 [7] 2.05 [8] 0.00 [9] 3.65 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 3에게 0.64 전력을 줌
# 발전기 5가 발전기 3에게 2.07 전력을 줌
# 발전기 7가 발전기 4에게 0.34 전력을 줌
# 발전기 8가 발전기 0에게 3.30 전력을 줌
# 발전기 8가 발전기 2에게 1.57 전력을 줌
# 발전기 8가 발전기 4에게 0.98 전력을 줌
#
# [t=15 s=18]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 14.78 ([0] 0.00 [1] 1.19 [2] 9.59 [3] 0.00 [4] 0.00 [5] 0.00 [6] 1.68 [7] 1.52 [8] 0.80 [9] 0.00 )
# y- 합계: 7.92 ([0] 2.31 [1] 0.00 [2] 0.00 [3] 2.71 [4] 0.12 [5] 0.90 [6] 0.00 [7] 0.00 [8] 0.00 [9] 1.88 )
# e+ 합계: 6.86 ([0] 0.00 [1] 0.00 [2] 6.86 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 9에게 1.19 전력을 줌
# 발전기 2가 발전기 0에게 0.63 전력을 줌
# 발전기 2가 발전기 3에게 1.19 전력을 줌
# 발전기 2가 발전기 5에게 0.22 전력을 줌
# 발전기 2가 발전기 9에게 0.69 전력을 줌
# 발전기 6가 발전기 0에게 1.68 전력을 줌
# 발전기 7가 발전기 3에게 1.52 전력을 줌
# 발전기 8가 발전기 4에게 0.12 전력을 줌
# 발전기 8가 발전기 5에게 0.68 전력을 줌
#
# [t=15 s=19]
# x 합계: 25.75 ([0] 5.49 [1] 1.71 [2] 1.57 [3] 2.71 [4] 1.32 [5] 0.90 [6] 7.35 [7] 2.20 [8] 0.62 [9] 1.88 )
# y+ 합계: 6.71 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 4.31 [5] 0.00 [6] 2.41 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 11.59 ([0] 0.00 [1] 1.71 [2] 1.57 [3] 2.71 [4] 0.00 [5] 0.90 [6] 0.00 [7] 2.20 [8] 0.62 [9] 1.88 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 4.88 ([0] 0.00 [1] 1.71 [2] 0.00 [3] 0.67 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.62 [9] 1.88 )
# 거래 내역:
# 발전기 4가 발전기 2에게 1.57 전력을 줌
# 발전기 4가 발전기 5에게 0.90 전력을 줌
# 발전기 4가 발전기 7에게 1.84 전력을 줌
# 발전기 6가 발전기 3에게 2.04 전력을 줌
# 발전기 6가 발전기 7에게 0.36 전력을 줌

# %%
for t in range(T):
    avg_e_plus = sum(e_plus_vals[i, t, s] for i in range(I) for s in range(S)) / S
    avg_e_minus = sum(e_minus_vals[i, t, s] for i in range(I) for s in range(S)) / S
    print(
        f"[시간 {t}] x: {sum(x_vals[i, t] for i in range(I)):.3f}, e+: {avg_e_plus:.3f}, e-: {avg_e_minus:.3f}"
    )

total_x = sum(x_vals[i, t] for i in range(I) for t in range(T))
print(f"총 하루 commitment: {total_x:.3f}")
# Out:
# [시간 0] x: 0.000, e+: 0.000, e-: 0.000
# [시간 1] x: 0.000, e+: 0.000, e-: 0.000
# [시간 2] x: 0.000, e+: 0.000, e-: 0.000
# [시간 3] x: 0.000, e+: 0.000, e-: 0.000
# [시간 4] x: 0.000, e+: 0.000, e-: 0.000
# [시간 5] x: 0.000, e+: 0.000, e-: 0.000
# [시간 6] x: 0.000, e+: 0.000, e-: 0.000
# [시간 7] x: 0.000, e+: 0.000, e-: 0.000
# [시간 8] x: 0.816, e+: 1.258, e-: 0.077
# [시간 9] x: 7.714, e+: 5.072, e-: 0.318
# [시간 10] x: 24.230, e+: 8.442, e-: 0.089
# [시간 11] x: 28.485, e+: 16.456, e-: 1.217
# [시간 12] x: 38.932, e+: 16.756, e-: 0.429
# [시간 13] x: 39.040, e+: 18.203, e-: 0.250
# [시간 14] x: 34.879, e+: 15.878, e-: 0.759
# [시간 15] x: 25.752, e+: 9.758, e-: 0.873
# [시간 16] x: 11.038, e+: 8.142, e-: 1.000
# [시간 17] x: 1.574, e+: 3.297, e-: 0.116
# [시간 18] x: 0.000, e+: 0.495, e-: 0.000
# [시간 19] x: 0.000, e+: 0.000, e-: 0.000
# [시간 20] x: 0.000, e+: 0.000, e-: 0.000
# [시간 21] x: 0.000, e+: 0.000, e-: 0.000
# [시간 22] x: 0.000, e+: 0.000, e-: 0.000
# [시간 23] x: 0.000, e+: 0.000, e-: 0.000
# 총 하루 commitment: 212.461

# %%
d_given = np.zeros(I)
d_received = np.zeros(I)

for i in range(I):
    d_given[i] = sum(
        sum(d_vals[i, j, t, s] for j in range(I) if j != i for t in range(T)) / S
        for s in range(S)
    )
    d_received[i] = sum(
        sum(d_vals[j, i, t, s] for j in range(I) if j != i for t in range(T)) / S
        for s in range(S)
    )

set_d = pd.DataFrame({"set_d_given": d_given, "set_d_received": d_received})
set_d.to_csv("result/result_set3_d.csv", index=False)

# %% [markdown]
# ### 정산

# %%
total_der_profit = 0
der_profit = {}
for i in range(I):
    der_profit[i] = sum(P_DA[t] * x[i,t].x + sum(1/S * (P_RT[t,s] * e_plus[i,t,s].x - P_PN[t] * e_minus[i,t,s].x) for s in range(S)) for t in range(T))
    total_der_profit += der_profit[i]

print(f"\n모든 der의 profit 합계: {total_der_profit:.2f}")

print("\n최종 profit:")
for i in range(I):
    print(f"[{i}] {der_profit[i]:.2f} ({profit_increase[i].x * 100:.2f}%)")
# Out:
# 모든 der의 profit 합계: 11878.13
#
# 최종 profit:
# [0] 1341.90 (11.41%)
# [1] 972.06 (11.41%)
# [2] 1378.64 (11.41%)
# [3] 1257.22 (11.41%)
# [4] 806.84 (11.41%)
# [5] 1073.40 (11.41%)
# [6] 1930.33 (11.41%)
# [7] 1224.27 (11.41%)
# [8] 856.63 (11.41%)
# [9] 1036.83 (11.41%)

# %% [markdown]
# ### 결과 저장

# %%
set_profit_value = pd.DataFrame({'set_profit_value': der_profit})
set_profit_value.to_csv('result/result_set3_profit.csv', index=False)

set_obj = pd.DataFrame({'set_obj': [set.objVal]})
set_obj.to_csv('result/result_set3_obj.csv', index=False)
