# %% [markdown]
# ### data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gurobipy as gp
from gurobipy import GRB

R_flat = pd.read_csv("result/result_R.csv")

I_len = R_flat["generator"].nunique()
T_len = R_flat["time"].nunique() 
S_len = R_flat["scenario"].nunique()

R = R_flat.pivot_table(
    values="value",
    index="generator",
    columns=["time", "scenario"]
).to_numpy()
R = R.reshape(I_len, T_len, S_len)

I, T, S = R.shape

price_q = pd.read_csv(
    "/Users/jangseohyun/Documents/workspace/symply/DER/DATA_price.csv"
)
price_q["Time"] = pd.to_datetime(price_q["Time"], format="%Y-%m-%d %H:%M")

price_q["Hour"] = price_q["Time"].dt.floor("h")
price_h = price_q.groupby("Hour").mean(numeric_only=True)

price = price_h.iloc[: S * T]

P_DA = np.array(
    [sum(price["Price"].iloc[t + s * T] for s in range(S)) / S * 1.2 for t in range(T)]
)
P_RT = np.array([[price["Price"].iloc[t + s * T] for s in range(S)] for t in range(T)])
P_PN = np.array(
    [sum(price["Price"].iloc[t + s * T] for s in range(S)) / S * 2 for t in range(T)]
)

only_profit = pd.read_csv('result/result_only_profit.csv').values

# %% [markdown]
# ### settlement model

# %%
def my_callback(model, where):
    if where == GRB.Callback.MIP:
        obj_best = model.cbGet(GRB.Callback.MIP_OBJBST)
        obj_bound = model.cbGet(GRB.Callback.MIP_OBJBND)

        # MIP Gap 계산
        if obj_best != 0:  # obj_best가 0이 아닌 경우에만 계산
            mip_gap = abs(obj_best - obj_bound) / abs(obj_best)
        else:
            mip_gap = float("inf")  # obj_best가 0인 경우 무한대로 설정

        print(f"obj_best: {obj_best}, obj_bound: {obj_bound}, MIP Gap: {mip_gap:.4f}")


set = gp.Model("Settlement")
# set.Params.OutputFlag = 0
# set.setParam('TimeLimit', 3600)
# set.setParam('Presolve', 0)
set.setParam("PoolSolutions", 15)
set.setParam("PoolSearchMode", 2)
set.setParam("PoolGap", 0.05)

x = set.addVars(I, T, vtype=GRB.CONTINUOUS, lb=0, name="x")
y_plus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="y_plus")
y_minus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="y_minus")
M_y = max(R[i, t, s] for i in range(I) for t in range(T) for s in range(S))
z_y = set.addVars(I, T, S, vtype=GRB.BINARY, name="z_y")

d = set.addVars(I, I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="d")
e_plus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="e_plus")
e_minus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="e_minus")
M_e = max(sum(R[i, t, s] for i in range(I)) for t in range(T) for s in range(S))
z_e = set.addVars(T, S, vtype=GRB.BINARY, name="z_e")

set.update()

# obj. func.
obj = gp.quicksum(
    P_DA[t] * x[i, t] for i in range(I) for t in range(T)
) + gp.quicksum(
    1/S * (P_RT[t, s] * e_plus[i, t, s] - P_PN[t] * e_minus[i, t, s])
    for i in range(I) for t in range(T) for s in range(S)
)

set.setObjective(obj, GRB.MAXIMIZE)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2611964
# Academic license - for non-commercial use only - expires 2026-01-20
# Set parameter PoolSolutions to value 15
# Set parameter PoolSearchMode to value 2
# Set parameter PoolGap to value 0.05

# %%
# x로 y+, y- 결정 지어주기
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(R[i, t, s] - x[i, t] == y_plus[i, t, s] - y_minus[i, t, s])

# y+, y- 둘 중 하나는 0이어야함
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(y_plus[i, t, s] <= M_y * z_y[i, t, s])
            set.addConstr(y_minus[i, t, s] <= M_y * (1 - z_y[i, t, s]))

# rt 조건
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(y_plus[i, t, s] <= R[i, t, s])

# sum e+, sum e- 결정 지어주기
for t in range(T):
    for s in range(S):
        set.addConstr(
            gp.quicksum(R[i, t, s] for i in range(I))
            - gp.quicksum(x[i, t] for i in range(I))
            == gp.quicksum(e_plus[i, t, s] for i in range(I))
            - gp.quicksum(e_minus[i, t, s] for i in range(I))
        )

# sum e+, sum e- 둘 중 하나는 0이어야 함
for t in range(T):
    for s in range(S):
        set.addConstr(gp.quicksum(e_plus[i, t, s] for i in range(I)) <= M_e * z_e[t, s])
        set.addConstr(
            gp.quicksum(e_minus[i, t, s] for i in range(I)) <= M_e * (1 - z_e[t, s])
        )

# e+, e- 정의
for i in range(I):
    for t in range(T):
        for s in range(S):
            # e_plus: 초과량에서 준 양을 뺀 것
            set.addConstr(
                e_plus[i, t, s]
                == y_plus[i, t, s]
                - gp.quicksum(d[i, j, t, s] for j in range(I) if j != i)
            )
            # e_minus: 부족량에서 받은 양을 뺀 것
            set.addConstr(
                e_minus[i, t, s]
                == y_minus[i, t, s]
                - gp.quicksum(d[j, i, t, s] for j in range(I) if j != i)
            )

# sum e+ <= sum R
for t in range(T):
    for s in range(S):
        set.addConstr(
            gp.quicksum(e_plus[i, t, s] for i in range(I))
            <= gp.quicksum(R[i, t, s] for i in range(I))
        )

# 전력 이동 제한
for i in range(I):
    for t in range(T):
        for s in range(S):
            # 본인이 주는 양은 자신의 y+을 넘을 수 없음
            set.addConstr(
                gp.quicksum(d[i, j, t, s] for j in range(I) if j != i)
                <= y_plus[i, t, s]
            )
            # 본인이 받는 양은 자신의 y-을 넘을 수 없음
            set.addConstr(
                gp.quicksum(d[j, i, t, s] for j in range(I) if j != i)
                <= y_minus[i, t, s]
            )

# 자기 자신과의 거래 방지
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(d[i, i, t, s] == 0)

# 개별 commit profit보다 높아야 함
for i in range(I):
    set.addConstr(
        gp.quicksum(
            P_DA[t] * x[i, t]
            + 1 / S
            * gp.quicksum(
                P_RT[t, s] * e_plus[i, t, s] - P_PN[t] * e_minus[i, t, s]
                for s in range(S)
            )
            for t in range(T)
        )
        >= only_profit[i].item()
    )

# %%
set.optimize()

if set.status == GRB.OPTIMAL:
    x_vals = np.array([[x[i, t].x for t in range(T)] for i in range(I)])
    y_plus_vals = np.array(
        [[[y_plus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    y_minus_vals = np.array(
        [[[y_minus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    d_vals = np.array(
        [
            [[[d[i, j, t, s].x for s in range(S)] for t in range(T)] for j in range(I)]
            for i in range(I)
        ]
    )
    e_plus_vals = np.array(
        [[[e_plus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    e_minus_vals = np.array(
        [[[e_minus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    print("\n- - - - - - - - - - - - - - - - - - - - - - - -")
    print("Optimal solution found!")
    print(set.objVal)
else:
    print("\nNo optimal solution found.")
# Out:
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.3.0 24D70)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# PoolSolutions  15
# PoolSearchMode  2
# PoolGap  0.05
#
# Optimize a model with 45130 rows, 72720 columns and 284380 nonzeros
# Model fingerprint: 0x962c98e8
# Variable types: 67440 continuous, 5280 integer (5280 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 9e+01]
#   Objective range  [4e-04, 4e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-02, 2e+03]
# Presolve removed 34958 rows and 51967 columns
# Presolve time: 0.08s
# Presolved: 10172 rows, 20753 columns, 58215 nonzeros
# Variable types: 15473 continuous, 5280 integer (5280 binary)
#
# Root relaxation: objective 1.203099e+04, 7871 iterations, 0.19 seconds (0.26 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 12030.9909    0   61          - 12030.9909      -     -    0s
#      0     0 12013.7708    0  335          - 12013.7708      -     -    1s
# H    0     0                    11877.859118 11981.3937  0.87%     -    1s
#      0     0 11981.3937    0  342 11877.8591 11981.3937  0.87%     -    1s
# H    0     0                    11878.130049 11878.7275  0.01%     -    1s
#      0     0 11878.7275    0  189 11878.1300 11878.7275  0.01%     -    1s
#      0     0 11878.5202    0  171 11878.1300 11878.5202  0.00%     -    2s
#      0     0 11878.1300    0   94 11878.1300 11878.1300  0.00%     -    2s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 11878.1300    0   88          - 11878.1300      -     -    2s
#      0     0 11878.1300    0   81          - 11878.1300      -     -    2s
#      0     0 11878.1300    0   78          - 11878.1300      -     -    2s
#      0     0 11878.1300    0   66          - 11878.1300      -     -    2s
#      0     0 11878.1300    0   38          - 11878.1300      -     -    2s
#      0     0 11878.1300    0   35          - 11878.1300      -     -    2s
#      0     0          -    0               - 11878.1300      -     -    3s
#      0     0          -    0               - 11878.1300      -     -    3s
#      0     0          -    0               - 11878.1300      -     -    3s
#      0     2          -    0               - 11878.1300      -     -    3s
#
# Cutting planes:
#   Gomory: 20
#   Cover: 299
#   Implied bound: 696
#   Clique: 270
#   MIR: 93
#   Flow cover: 174
#   RLT: 677
#   Relax-and-lift: 250
#   BQP: 8
#   PSD: 3
#
# Explored 70 nodes (39089 simplex iterations) in 3.56 seconds (5.52 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 15: 11878.1 11878.1 11878.1 ... 11878.1
# No other solutions better than 11878.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.187813004865e+04, best bound 1.187813004865e+04, gap 0.0000%
#
# - - - - - - - - - - - - - - - - - - - - - - - -
# Optimal solution found!
# 11878.130048654552

# %% [markdown]
# ### solution pool

# %%
print(f"Status: {set.status}")
if set.status == GRB.OPTIMAL:
    print("모델이 Optimal입니다")

    # Solution pool 확인
    print("\nSolution Pool 정보:")
    print(f"찾은 해의 개수: {set.SolCount}")

    # Best solution의 objective value
    best_obj = set.ObjVal
    print(f"\nBest Solution의 Objective Value: {best_obj}")

    # 각 솔루션의 목적함수 값 출력 및 best solution 여부 확인
    solutions = []
    for i in range(set.SolCount):
        set.params.SolutionNumber = i
        solutions.append((i, set.PoolObjVal))
        print(f"\nSolution {i}:")
        print(f"Objective value: {set.PoolObjVal}")
        print(f"Objective bound: {set.PoolObjBound}")
        print(
            f"Is Best Solution: {abs(set.PoolObjVal - best_obj) < 1e-9}"
        )  # 수치 오차 고려

        # Gap 계산 (best solution에 대해서만)
        if abs(set.PoolObjVal - best_obj) < 1e-9:
            gap = abs(set.PoolObjVal - set.ObjBound) / abs(set.PoolObjVal)
            print(f"Gap: {gap * 100:.2f}%")

    # Solution pool 파라미터 확인
    print("\nSolution Pool 파라미터:")
    print(f"PoolSolutions: {set.Params.PoolSolutions}")
    print(f"PoolSearchMode: {set.Params.PoolSearchMode}")
    print(f"PoolGap: {set.Params.PoolGap}")
elif set.status == GRB.UNBOUNDED:
    print("모델이 Unbounded입니다")
    # Unbounded ray 확인
    set.computeIIS()
    set.write("model.ilp")
elif set.status == GRB.INFEASIBLE:
    print("모델이 Infeasible입니다")
    # IIS 계산
    set.computeIIS()
    set.write("model.ilp")
elif set.status == GRB.INF_OR_UNBD:
    print("모델이 Infeasible 또는 Unbounded입니다")
    # Presolve를 끄고 다시 시도
    set.setParam("Presolve", 0)
    set.optimize()
elif set.status == GRB.TIME_LIMIT:
    print("시간 제한에 도달했습니다")
    if set.SolCount > 0:
        print(f"현재까지의 최선해: {set.objVal}")
        print(f"Optimality Gap: {set.MIPGap}")
# Out:
# Status: 2
# 모델이 Optimal입니다
#
# Solution Pool 정보:
# 찾은 해의 개수: 15
#
# Best Solution의 Objective Value: 11878.130048654552
#
# Solution 0:
# Objective value: 11878.130048654552
# Objective bound: 11878.130048654488
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 1:
# Objective value: 11878.130048654539
# Objective bound: 11878.130048654488
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 2:
# Objective value: 11878.13004865453
# Objective bound: 11878.130048654488
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 3:
# Objective value: 11878.13004865453
# Objective bound: 11878.130048654488
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 4:
# Objective value: 11878.130048654522
# Objective bound: 11878.130048654488
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 5:
# Objective value: 11878.13004865452
# Objective bound: 11878.130048654488
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 6:
# Objective value: 11878.130048654515
# Objective bound: 11878.130048654488
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 7:
# Objective value: 11878.130048654513
# Objective bound: 11878.130048654488
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 8:
# Objective value: 11878.13004865451
# Objective bound: 11878.130048654488
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 9:
# Objective value: 11878.130048654508
# Objective bound: 11878.130048654488
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 10:
# Objective value: 11878.130048654506
# Objective bound: 11878.130048654488
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 11:
# Objective value: 11878.130048654499
# Objective bound: 11878.130048654488
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 12:
# Objective value: 11878.13004865449
# Objective bound: 11878.130048654488
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 13:
# Objective value: 11878.13004865449
# Objective bound: 11878.130048654488
# Is Best Solution: True
# Gap: 0.00%
#
# Solution 14:
# Objective value: 11878.130048654488
# Objective bound: 11878.130048654488
# Is Best Solution: True
# Gap: 0.00%
#
# Solution Pool 파라미터:
# PoolSolutions: 15
# PoolSearchMode: 2
# PoolGap: 0.05

# %%
# 솔루션 풀에서 해 확인
solution_count = set.SolCount
print(f"총 {solution_count}개의 해가 저장되었습니다.")

for i in range(solution_count):
    set.setParam(GRB.Param.SolutionNumber, i)
    print(f"\n해 {i+1}: 목적 함수 값 = {set.PoolObjVal}")
    # x 변수 값 출력
    for t in range(14, 15):
        for i in range(1, 5):
            print(f"x[{i},{t}] = {x[i, t].Xn}")
# Out:
# 총 15개의 해가 저장되었습니다.
#
# 해 1: 목적 함수 값 = 11878.130048654552
# x[1,14] = 7.762843936131683
# x[2,14] = 14.867804967064844
# x[3,14] = 0.0
# x[4,14] = 1.49825272886127
#
# 해 2: 목적 함수 값 = 11878.130048654539
# x[1,14] = 7.762843936131683
# x[2,14] = 14.867804967064844
# x[3,14] = 0.0
# x[4,14] = 1.49825272886127
#
# 해 3: 목적 함수 값 = 11878.13004865453
# x[1,14] = 7.762843936131683
# x[2,14] = 14.867804967064844
# x[3,14] = 0.0
# x[4,14] = 1.49825272886127
#
# 해 4: 목적 함수 값 = 11878.13004865453
# x[1,14] = 7.762843936131683
# x[2,14] = 14.867804967064844
# x[3,14] = 0.0
# x[4,14] = 1.49825272886127
#
# 해 5: 목적 함수 값 = 11878.130048654522
# x[1,14] = 6.7367021489625465
# x[2,14] = 15.089083926117414
# x[3,14] = 0.0
# x[4,14] = 1.3798081710985048
#
# 해 6: 목적 함수 값 = 11878.13004865452
# x[1,14] = 7.762843936131683
# x[2,14] = 14.867804967064844
# x[3,14] = 0.0
# x[4,14] = 1.49825272886127
#
# 해 7: 목적 함수 값 = 11878.130048654515
# x[1,14] = 7.762843936131683
# x[2,14] = 14.867804967064844
# x[3,14] = 0.0
# x[4,14] = 1.49825272886127
#
# 해 8: 목적 함수 값 = 11878.130048654513
# x[1,14] = 7.762843936131683
# x[2,14] = 14.867804967064844
# x[3,14] = 0.0
# x[4,14] = 1.49825272886127
#
# 해 9: 목적 함수 값 = 11878.13004865451
# x[1,14] = 2.354447475023508
# x[2,14] = 12.977368095179472
# x[3,14] = 0.5715646362046964
# x[4,14] = 3.839174552242076
#
# 해 10: 목적 함수 값 = 11878.130048654508
# x[1,14] = 8.775245131752868
# x[2,14] = 14.384644146525504
# x[3,14] = 0.0
# x[4,14] = 1.3798081710985048
#
# 해 11: 목적 함수 값 = 11878.130048654506
# x[1,14] = 7.762843936131683
# x[2,14] = 14.867804967064844
# x[3,14] = 0.0
# x[4,14] = 1.49825272886127
#
# 해 12: 목적 함수 값 = 11878.130048654499
# x[1,14] = 7.263040995738341
# x[2,14] = 14.885871160645632
# x[3,14] = 0.0
# x[4,14] = 1.49825272886127
#
# 해 13: 목적 함수 값 = 11878.13004865449
# x[1,14] = 7.2460943568688165
# x[2,14] = 14.942966478473691
# x[3,14] = 0.0
# x[4,14] = 1.3798081710985315
#
# 해 14: 목적 함수 값 = 11878.13004865449
# x[1,14] = 7.4998538411441515
# x[2,14] = 14.005008281901043
# x[3,14] = 0.0
# x[4,14] = 1.3798081710985315
#
# 해 15: 목적 함수 값 = 11878.130048654488
# x[1,14] = 2.3544474750235196
# x[2,14] = 12.97736809517947
# x[3,14] = 0.5715646362046964
# x[4,14] = 3.839174552242076

# %% [markdown]
# ### 결과 분석

# %% [markdown]
# #### 수익 분석

# %%
# Day-ahead 수익 비교
total_da_profit_obj = 0
for i in range(I):
    for t in range(T):
        total_da_profit_obj += P_DA[t] * x[i, t].x

# Real-time 수익 비교
total_rt_profit_obj = 0
for i in range(I):
    for t in range(T):
        for s in range(S):
            rt_profit_obj = P_RT[t, s] * e_plus[i, t, s].x
            total_rt_profit_obj += 1 / S * rt_profit_obj

# 패널티 비용 비교
total_penalty_cost_obj = 0
for i in range(I):
    for t in range(T):
        for s in range(S):
            penalty_cost_obj = P_PN[t] * e_minus[i, t, s].x
            total_penalty_cost_obj += 1 / S * penalty_cost_obj

# 총 시스템 이익 (목적 함수 기반)
total_system_profit_obj = (
    total_da_profit_obj + total_rt_profit_obj - total_penalty_cost_obj
)

# 결과 출력
print(f"DA: {total_da_profit_obj:.2f}")
print(f"RT: {total_rt_profit_obj:.2f}")
print(f"Penalty: {total_penalty_cost_obj:.2f}")
print(f"목적 함수 기반 총 이익 (_obj): {total_system_profit_obj:.2f}")
# Out:
# DA: 8602.60
# RT: 3616.68
# Penalty: 341.16
# 목적 함수 기반 총 이익 (_obj): 11878.13

# %% [markdown]
# #### 하루 aggregated 커밋량 분석

# %%
for t in range(T):
    avg_e_plus = sum(e_plus_vals[i, t, s] for i in range(I) for s in range(S)) / S
    avg_e_minus = sum(e_minus_vals[i, t, s] for i in range(I) for s in range(S)) / S
    print(f"[시간 {t}] x: {sum(x_vals[i, t] for i in range(I)):.3f}, e+: {avg_e_plus:.3f}, e-: {avg_e_minus:.3f}")

total_x = sum(x_vals[i, t] for i in range(I) for t in range(T))
print(f"총 하루 commitment: {total_x:.3f}")
# Out:
# [시간 0] x: 0.000, e+: 0.000, e-: 0.000
# [시간 1] x: 0.000, e+: 0.000, e-: 0.000
# [시간 2] x: 0.000, e+: 0.000, e-: 0.000
# [시간 3] x: 0.000, e+: 0.000, e-: 0.000
# [시간 4] x: 0.000, e+: 0.000, e-: 0.000
# [시간 5] x: 0.000, e+: 0.000, e-: 0.000
# [시간 6] x: 0.000, e+: 0.000, e-: 0.000
# [시간 7] x: 0.000, e+: 0.000, e-: 0.000
# [시간 8] x: 0.816, e+: 1.258, e-: 0.077
# [시간 9] x: 7.714, e+: 5.072, e-: 0.318
# [시간 10] x: 24.230, e+: 8.442, e-: 0.089
# [시간 11] x: 28.485, e+: 16.456, e-: 1.217
# [시간 12] x: 38.932, e+: 16.756, e-: 0.429
# [시간 13] x: 39.040, e+: 18.203, e-: 0.250
# [시간 14] x: 34.879, e+: 15.878, e-: 0.759
# [시간 15] x: 25.752, e+: 9.758, e-: 0.873
# [시간 16] x: 11.038, e+: 8.142, e-: 1.000
# [시간 17] x: 1.574, e+: 3.297, e-: 0.116
# [시간 18] x: 0.000, e+: 0.495, e-: 0.000
# [시간 19] x: 0.000, e+: 0.000, e-: 0.000
# [시간 20] x: 0.000, e+: 0.000, e-: 0.000
# [시간 21] x: 0.000, e+: 0.000, e-: 0.000
# [시간 22] x: 0.000, e+: 0.000, e-: 0.000
# [시간 23] x: 0.000, e+: 0.000, e-: 0.000
# 총 하루 commitment: 212.461

# %% [markdown]
# #### exchange process

# %%
for t in range(12,16):
    x_sum = sum(x_vals[i, t] for i in range(I))

    for s in range(S):
        y_plus_sum = sum(y_plus_vals[i, t, s] for i in range(I))
        y_minus_sum = sum(y_minus_vals[i, t, s] for i in range(I))

        e_plus_sum = sum(e_plus_vals[i, t, s] for i in range(I))
        e_minus_sum = sum(e_minus_vals[i, t, s] for i in range(I))

        print(f"[t={t} s={s}]")

        print(f"x 합계: {x_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {x_vals[i,t]:.2f}", end=" ")
        print(")")

        print(f"y+ 합계: {y_plus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {y_plus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print(f"y- 합계: {y_minus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {y_minus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print(f"e+ 합계: {e_plus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {e_plus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print(f"e- 합계: {e_minus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {e_minus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print("거래 내역:")
        for i in range(I):
            for j in range(I):
                if d_vals[i, j, t, s] > 1e-6:
                    print(
                        f"발전기 {i}가 발전기 {j}에게 {d_vals[i,j,t,s]:.2f} 전력을 줌"
                    )
        print()
# Out:
# [t=12 s=0]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 24.74 ([0] 9.34 [1] 0.00 [2] 7.81 [3] 0.00 [4] 0.31 [5] 4.60 [6] 0.00 [7] 0.00 [8] 2.67 [9] 0.00 )
# y- 합계: 9.96 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.18 [4] 0.00 [5] 0.00 [6] 5.33 [7] 1.78 [8] 0.00 [9] 2.66 )
# e+ 합계: 14.78 ([0] 4.01 [1] 0.00 [2] 7.81 [3] 0.00 [4] 0.00 [5] 2.96 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 6에게 2.67 전력을 줌
# 발전기 0가 발전기 9에게 2.66 전력을 줌
# 발전기 4가 발전기 3에게 0.18 전력을 줌
# 발전기 4가 발전기 6에게 0.14 전력을 줌
# 발전기 5가 발전기 6에게 1.64 전력을 줌
# 발전기 8가 발전기 6에게 0.89 전력을 줌
# 발전기 8가 발전기 7에게 1.78 전력을 줌
#
# [t=12 s=1]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 33.63 ([0] 0.00 [1] 9.64 [2] 12.76 [3] 0.00 [4] 0.00 [5] 3.28 [6] 0.00 [7] 6.20 [8] 0.00 [9] 1.75 )
# y- 합계: 14.26 ([0] 0.85 [1] 0.00 [2] 0.00 [3] 0.18 [4] 2.85 [5] 0.00 [6] 8.59 [7] 0.00 [8] 1.79 [9] 0.00 )
# e+ 합계: 19.37 ([0] 0.00 [1] 9.64 [2] 0.00 [3] 0.00 [4] 0.00 [5] 3.28 [6] 0.00 [7] 6.20 [8] 0.00 [9] 0.24 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 0에게 0.85 전력을 줌
# 발전기 2가 발전기 3에게 0.18 전력을 줌
# 발전기 2가 발전기 4에게 1.35 전력을 줌
# 발전기 2가 발전기 6에게 8.59 전력을 줌
# 발전기 2가 발전기 8에게 1.79 전력을 줌
# 발전기 9가 발전기 4에게 1.51 전력을 줌
#
# [t=12 s=2]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 34.62 ([0] 9.78 [1] 0.00 [2] 2.41 [3] 10.27 [4] 0.00 [5] 11.27 [6] 0.00 [7] 0.89 [8] 0.00 [9] 0.00 )
# y- 합계: 12.19 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 5.42 [5] 0.00 [6] 4.36 [7] 0.00 [8] 1.79 [9] 0.62 )
# e+ 합계: 22.43 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 10.27 [4] 0.00 [5] 11.27 [6] 0.00 [7] 0.89 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 4에게 5.42 전력을 줌
# 발전기 0가 발전기 6에게 4.36 전력을 줌
# 발전기 2가 발전기 8에게 1.79 전력을 줌
# 발전기 2가 발전기 9에게 0.62 전력을 줌
#
# [t=12 s=3]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 55.03 ([0] 11.78 [1] 4.62 [2] 15.68 [3] 4.68 [4] 0.00 [5] 9.07 [6] 0.00 [7] 4.03 [8] 0.00 [9] 5.17 )
# y- 합계: 18.26 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 9.47 [5] 0.00 [6] 7.00 [7] 0.00 [8] 1.79 [9] 0.00 )
# e+ 합계: 36.77 ([0] 11.78 [1] 4.62 [2] 3.90 [3] 0.00 [4] 0.00 [5] 9.07 [6] 0.00 [7] 4.03 [8] 0.00 [9] 3.37 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 4에게 9.47 전력을 줌
# 발전기 2가 발전기 6에게 2.32 전력을 줌
# 발전기 3가 발전기 6에게 4.68 전력을 줌
# 발전기 9가 발전기 8에게 1.79 전력을 줌
#
# [t=12 s=4]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 23.33 ([0] 0.00 [1] 7.63 [2] 4.39 [3] 2.09 [4] 0.00 [5] 0.00 [6] 0.00 [7] 4.37 [8] 4.85 [9] 0.00 )
# y- 합계: 24.79 ([0] 1.72 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.97 [5] 0.00 [6] 17.01 [7] 0.00 [8] 0.00 [9] 5.10 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 1.46 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 1.46 )
# 거래 내역:
# 발전기 1가 발전기 0에게 1.72 전력을 줌
# 발전기 1가 발전기 6에게 2.28 전력을 줌
# 발전기 1가 발전기 9에게 3.63 전력을 줌
# 발전기 2가 발전기 6에게 4.39 전력을 줌
# 발전기 3가 발전기 6에게 2.09 전력을 줌
# 발전기 7가 발전기 6에게 4.37 전력을 줌
# 발전기 8가 발전기 4에게 0.97 전력을 줌
# 발전기 8가 발전기 6에게 3.88 전력을 줌
#
# [t=12 s=5]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 18.54 ([0] 8.95 [1] 0.00 [2] 1.45 [3] 3.97 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.25 [8] 0.44 [9] 3.48 )
# y- 합계: 6.87 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 6.83 [5] 0.04 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 11.67 ([0] 8.95 [1] 0.00 [2] 1.45 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.25 [8] 0.44 [9] 0.58 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 3가 발전기 4에게 3.93 전력을 줌
# 발전기 3가 발전기 5에게 0.04 전력을 줌
# 발전기 9가 발전기 4에게 2.90 전력을 줌
#
# [t=12 s=6]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 23.86 ([0] 0.00 [1] 0.00 [2] 12.78 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 4.26 [8] 1.11 [9] 5.72 )
# y- 합계: 8.09 ([0] 2.02 [1] 0.00 [2] 0.00 [3] 0.18 [4] 0.00 [5] 0.04 [6] 5.86 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 15.77 ([0] 0.00 [1] 0.00 [2] 6.93 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 4.26 [8] 0.00 [9] 4.59 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 6에게 5.86 전력을 줌
# 발전기 8가 발전기 0에게 1.07 전력을 줌
# 발전기 8가 발전기 5에게 0.04 전력을 줌
# 발전기 9가 발전기 0에게 0.95 전력을 줌
# 발전기 9가 발전기 3에게 0.18 전력을 줌
#
# [t=12 s=7]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 26.57 ([0] 7.64 [1] 9.86 [2] 2.22 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 6.75 [8] 0.09 [9] 0.00 )
# y- 합계: 25.44 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 13.54 [7] 0.00 [8] 0.00 [9] 2.22 )
# e+ 합계: 1.13 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 1.13 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 3에게 0.13 전력을 줌
# 발전기 0가 발전기 6에게 7.51 전력을 줌
# 발전기 1가 발전기 4에게 9.47 전력을 줌
# 발전기 1가 발전기 6에게 0.40 전력을 줌
# 발전기 2가 발전기 9에게 2.22 전력을 줌
# 발전기 7가 발전기 6에게 5.63 전력을 줌
# 발전기 8가 발전기 3에게 0.05 전력을 줌
# 발전기 8가 발전기 5에게 0.04 전력을 줌
#
# [t=12 s=8]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 45.31 ([0] 9.05 [1] 6.70 [2] 8.81 [3] 6.67 [4] 0.00 [5] 7.99 [6] 0.00 [7] 1.48 [8] 4.60 [9] 0.00 )
# y- 합계: 20.48 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 9.47 [5] 0.00 [6] 9.40 [7] 0.00 [8] 0.00 [9] 1.62 )
# e+ 합계: 24.82 ([0] 0.00 [1] 1.91 [2] 6.77 [3] 6.67 [4] 0.00 [5] 7.99 [6] 0.00 [7] 1.48 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 4에게 9.05 전력을 줌
# 발전기 1가 발전기 6에게 4.80 전력을 줌
# 발전기 2가 발전기 4에게 0.41 전력을 줌
# 발전기 2가 발전기 9에게 1.62 전력을 줌
# 발전기 8가 발전기 6에게 4.60 전력을 줌
#
# [t=12 s=9]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 22.75 ([0] 3.73 [1] 0.00 [2] 11.83 [3] 0.00 [4] 0.00 [5] 6.64 [6] 0.00 [7] 0.55 [8] 0.00 [9] 0.00 )
# y- 합계: 29.87 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.18 [4] 8.23 [5] 0.00 [6] 14.57 [7] 0.00 [8] 1.79 [9] 5.10 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 7.12 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 5.32 [7] 0.00 [8] 1.79 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 4에게 1.68 전력을 줌
# 발전기 0가 발전기 6에게 2.05 전력을 줌
# 발전기 2가 발전기 3에게 0.18 전력을 줌
# 발전기 2가 발전기 4에게 6.56 전력을 줌
# 발전기 2가 발전기 9에게 5.10 전력을 줌
# 발전기 5가 발전기 6에게 6.64 전력을 줌
# 발전기 7가 발전기 6에게 0.55 전력을 줌
#
# [t=12 s=10]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 44.69 ([0] 11.03 [1] 1.89 [2] 11.83 [3] 5.50 [4] 0.00 [5] 6.96 [6] 0.00 [7] 0.00 [8] 0.00 [9] 7.48 )
# y- 합계: 13.13 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 4.09 [5] 0.00 [6] 5.77 [7] 2.63 [8] 0.64 [9] 0.00 )
# e+ 합계: 31.56 ([0] 7.26 [1] 0.00 [2] 11.83 [3] 5.50 [4] 0.00 [5] 6.96 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 4에게 2.38 전력을 줌
# 발전기 0가 발전기 7에게 1.38 전력을 줌
# 발전기 1가 발전기 7에게 1.25 전력을 줌
# 발전기 1가 발전기 8에게 0.64 전력을 줌
# 발전기 9가 발전기 4에게 1.71 전력을 줌
# 발전기 9가 발전기 6에게 5.77 전력을 줌
#
# [t=12 s=11]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 25.39 ([0] 0.00 [1] 8.70 [2] 0.86 [3] 8.74 [4] 0.00 [5] 1.73 [6] 0.00 [7] 0.77 [8] 1.92 [9] 2.67 )
# y- 합계: 19.51 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.00 [4] 9.47 [5] 0.00 [6] 7.79 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 5.88 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 5.88 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 4에게 8.70 전력을 줌
# 발전기 2가 발전기 6에게 0.86 전력을 줌
# 발전기 3가 발전기 0에게 0.33 전력을 줌
# 발전기 3가 발전기 6에게 2.53 전력을 줌
# 발전기 5가 발전기 6에게 1.73 전력을 줌
# 발전기 7가 발전기 4에게 0.77 전력을 줌
# 발전기 8가 발전기 0에게 1.92 전력을 줌
# 발전기 9가 발전기 6에게 2.67 전력을 줌
#
# [t=12 s=12]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 23.01 ([0] 5.68 [1] 1.53 [2] 0.00 [3] 6.01 [4] 0.00 [5] 7.81 [6] 0.00 [7] 1.98 [8] 0.00 [9] 0.00 )
# y- 합계: 21.94 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 2.40 [5] 0.00 [6] 17.47 [7] 0.00 [8] 0.09 [9] 1.97 )
# e+ 합계: 1.07 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 1.07 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 6에게 5.68 전력을 줌
# 발전기 1가 발전기 6에게 1.53 전력을 줌
# 발전기 3가 발전기 4에게 2.40 전력을 줌
# 발전기 3가 발전기 6에게 0.47 전력을 줌
# 발전기 3가 발전기 8에게 0.09 전력을 줌
# 발전기 3가 발전기 9에게 1.97 전력을 줌
# 발전기 5가 발전기 6에게 7.81 전력을 줌
# 발전기 7가 발전기 6에게 1.98 전력을 줌
#
# [t=12 s=13]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 30.42 ([0] 0.00 [1] 11.83 [2] 7.03 [3] 9.12 [4] 0.00 [5] 2.44 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 30.42 ([0] 1.51 [1] 0.00 [2] 0.00 [3] 0.00 [4] 9.47 [5] 0.00 [6] 10.57 [7] 2.63 [8] 1.79 [9] 4.44 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 0에게 1.51 전력을 줌
# 발전기 1가 발전기 4에게 5.87 전력을 줌
# 발전기 1가 발전기 9에게 4.44 전력을 줌
# 발전기 2가 발전기 4에게 1.15 전력을 줌
# 발전기 2가 발전기 6에게 1.45 전력을 줌
# 발전기 2가 발전기 7에게 2.63 전력을 줌
# 발전기 2가 발전기 8에게 1.79 전력을 줌
# 발전기 3가 발전기 6에게 9.12 전력을 줌
# 발전기 5가 발전기 4에게 2.44 전력을 줌
#
# [t=12 s=14]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 40.42 ([0] 0.00 [1] 0.00 [2] 11.03 [3] 5.23 [4] 0.00 [5] 5.36 [6] 0.00 [7] 10.15 [8] 8.05 [9] 0.59 )
# y- 합계: 22.41 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.00 [4] 3.89 [5] 0.00 [6] 16.26 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 18.01 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 5.36 [6] 0.00 [7] 10.15 [8] 1.91 [9] 0.59 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 6에게 11.03 전력을 줌
# 발전기 3가 발전기 0에게 2.25 전력을 줌
# 발전기 3가 발전기 6에게 2.98 전력을 줌
# 발전기 8가 발전기 4에게 3.89 전력을 줌
# 발전기 8가 발전기 6에게 2.25 전력을 줌
#
# [t=12 s=15]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 58.00 ([0] 12.67 [1] 7.67 [2] 12.84 [3] 13.59 [4] 0.00 [5] 5.45 [6] 0.00 [7] 0.00 [8] 5.78 [9] 0.00 )
# y- 합계: 22.76 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 9.47 [5] 0.00 [6] 5.56 [7] 2.63 [8] 0.00 [9] 5.10 )
# e+ 합계: 35.24 ([0] 12.67 [1] 0.00 [2] 12.84 [3] 5.86 [4] 0.00 [5] 3.87 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 4에게 5.04 전력을 줌
# 발전기 1가 발전기 7에게 2.63 전력을 줌
# 발전기 3가 발전기 4에게 2.63 전력을 줌
# 발전기 3가 발전기 9에게 5.10 전력을 줌
# 발전기 5가 발전기 6에게 1.58 전력을 줌
# 발전기 8가 발전기 4에게 1.80 전력을 줌
# 발전기 8가 발전기 6에게 3.98 전력을 줌
#
# [t=12 s=16]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 31.92 ([0] 5.07 [1] 7.86 [2] 0.00 [3] 6.12 [4] 0.36 [5] 7.91 [6] 0.00 [7] 4.61 [8] 0.00 [9] 0.00 )
# y- 합계: 23.75 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 16.86 [7] 0.00 [8] 1.79 [9] 5.10 )
# e+ 합계: 8.17 ([0] 5.07 [1] 0.00 [2] 0.00 [3] 3.11 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 6에게 7.86 전력을 줌
# 발전기 3가 발전기 6에게 3.02 전력을 줌
# 발전기 4가 발전기 6에게 0.36 전력을 줌
# 발전기 5가 발전기 6에게 1.02 전력을 줌
# 발전기 5가 발전기 8에게 1.79 전력을 줌
# 발전기 5가 발전기 9에게 5.10 전력을 줌
# 발전기 7가 발전기 6에게 4.61 전력을 줌
#
# [t=12 s=17]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 39.47 ([0] 11.11 [1] 4.77 [2] 12.87 [3] 4.24 [4] 0.00 [5] 6.47 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 12.80 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 1.64 [5] 0.00 [6] 5.36 [7] 2.63 [8] 0.76 [9] 2.41 )
# e+ 합계: 26.67 ([0] 11.11 [1] 4.77 [2] 0.07 [3] 4.24 [4] 0.00 [5] 6.47 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 4에게 1.64 전력을 줌
# 발전기 2가 발전기 6에게 5.36 전력을 줌
# 발전기 2가 발전기 7에게 2.63 전력을 줌
# 발전기 2가 발전기 8에게 0.76 전력을 줌
# 발전기 2가 발전기 9에게 2.41 전력을 줌
#
# [t=12 s=18]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 46.44 ([0] 2.77 [1] 5.41 [2] 9.06 [3] 18.23 [4] 0.00 [5] 4.32 [6] 0.00 [7] 1.02 [8] 3.37 [9] 2.28 )
# y- 합계: 15.63 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 9.47 [5] 0.00 [6] 6.17 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 30.81 ([0] 0.00 [1] 5.41 [2] 9.06 [3] 14.07 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 2.28 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 4에게 2.77 전력을 줌
# 발전기 3가 발전기 4에게 2.38 전력을 줌
# 발전기 3가 발전기 6에게 1.79 전력을 줌
# 발전기 5가 발전기 4에게 4.32 전력을 줌
# 발전기 7가 발전기 6에게 1.02 전력을 줌
# 발전기 8가 발전기 6에게 3.37 전력을 줌
#
# [t=12 s=19]
# x 합계: 38.93 ([0] 2.25 [1] 0.00 [2] 0.00 [3] 0.18 [4] 9.47 [5] 0.04 [6] 17.47 [7] 2.63 [8] 1.79 [9] 5.10 )
# y+ 합계: 50.24 ([0] 0.00 [1] 12.55 [2] 14.21 [3] 0.00 [4] 0.00 [5] 3.95 [6] 0.00 [7] 7.99 [8] 0.00 [9] 11.54 )
# y- 합계: 19.27 ([0] 1.03 [1] 0.00 [2] 0.00 [3] 0.18 [4] 5.33 [5] 0.00 [6] 10.94 [7] 0.00 [8] 1.79 [9] 0.00 )
# e+ 합계: 30.97 ([0] 0.00 [1] 12.55 [2] 10.43 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 7.99 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 0에게 1.03 전력을 줌
# 발전기 2가 발전기 4에게 1.38 전력을 줌
# 발전기 2가 발전기 6에게 1.37 전력을 줌
# 발전기 5가 발전기 4에게 3.95 전력을 줌
# 발전기 9가 발전기 3에게 0.18 전력을 줌
# 발전기 9가 발전기 6에게 9.57 전력을 줌
# 발전기 9가 발전기 8에게 1.79 전력을 줌
#
# [t=13 s=0]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 47.86 ([0] 12.15 [1] 8.81 [2] 8.26 [3] 4.99 [4] 0.00 [5] 0.00 [6] 6.50 [7] 0.74 [8] 0.00 [9] 6.42 )
# y- 합계: 14.68 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 1.54 [5] 0.00 [6] 0.00 [7] 0.00 [8] 13.14 [9] 0.00 )
# e+ 합계: 33.18 ([0] 12.15 [1] 8.81 [2] 0.00 [3] 4.99 [4] 0.00 [5] 0.00 [6] 6.50 [7] 0.74 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 8에게 8.26 전력을 줌
# 발전기 9가 발전기 4에게 1.54 전력을 줌
# 발전기 9가 발전기 8에게 4.88 전력을 줌
#
# [t=13 s=1]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 39.99 ([0] 0.00 [1] 12.41 [2] 7.22 [3] 0.00 [4] 9.85 [5] 0.00 [6] 2.54 [7] 7.97 [8] 0.00 [9] 0.00 )
# y- 합계: 22.18 ([0] 1.21 [1] 0.00 [2] 0.00 [3] 0.99 [4] 0.00 [5] 7.57 [6] 0.00 [7] 0.00 [8] 12.40 [9] 0.00 )
# e+ 합계: 17.81 ([0] 0.00 [1] 0.08 [2] 7.22 [3] 0.00 [4] 0.00 [5] 0.00 [6] 2.54 [7] 7.97 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 8에게 12.33 전력을 줌
# 발전기 4가 발전기 0에게 1.21 전력을 줌
# 발전기 4가 발전기 3에게 0.99 전력을 줌
# 발전기 4가 발전기 5에게 7.57 전력을 줌
# 발전기 4가 발전기 8에게 0.08 전력을 줌
#
# [t=13 s=2]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 29.54 ([0] 0.00 [1] 8.58 [2] 4.61 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 7.18 [8] 0.00 [9] 9.17 )
# y- 합계: 18.09 ([0] 1.21 [1] 0.00 [2] 0.00 [3] 4.59 [4] 1.54 [5] 1.61 [6] 1.58 [7] 0.00 [8] 7.56 [9] 0.00 )
# e+ 합계: 11.45 ([0] 0.00 [1] 7.36 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 4.08 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 0에게 1.21 전력을 줌
# 발전기 2가 발전기 3에게 1.12 전력을 줌
# 발전기 2가 발전기 8에게 3.50 전력을 줌
# 발전기 7가 발전기 4에게 1.54 전력을 줌
# 발전기 7가 발전기 6에게 1.58 전력을 줌
# 발전기 7가 발전기 8에게 4.06 전력을 줌
# 발전기 9가 발전기 3에게 3.47 전력을 줌
# 발전기 9가 발전기 5에게 1.61 전력을 줌
#
# [t=13 s=3]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 55.02 ([0] 11.56 [1] 0.00 [2] 10.99 [3] 8.94 [4] 4.90 [5] 1.89 [6] 1.60 [7] 0.00 [8] 0.00 [9] 15.13 )
# y- 합계: 7.91 ([0] 0.00 [1] 1.35 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 1.63 [8] 4.93 [9] 0.00 )
# e+ 합계: 47.11 ([0] 11.56 [1] 0.00 [2] 10.99 [3] 8.94 [4] 1.86 [5] 0.00 [6] 0.25 [7] 0.00 [8] 0.00 [9] 13.50 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 4가 발전기 8에게 3.04 전력을 줌
# 발전기 5가 발전기 8에게 1.89 전력을 줌
# 발전기 6가 발전기 1에게 1.35 전력을 줌
# 발전기 9가 발전기 7에게 1.63 전력을 줌
#
# [t=13 s=4]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 29.77 ([0] 1.01 [1] 5.89 [2] 1.59 [3] 6.99 [4] 0.00 [5] 0.00 [6] 14.30 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 24.04 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 1.54 [5] 5.38 [6] 0.00 [7] 4.39 [8] 12.73 [9] 0.00 )
# e+ 합계: 5.73 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 5.73 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 8에게 1.01 전력을 줌
# 발전기 1가 발전기 8에게 5.89 전력을 줌
# 발전기 2가 발전기 8에게 1.59 전력을 줌
# 발전기 3가 발전기 5에게 1.01 전력을 줌
# 발전기 3가 발전기 8에게 0.25 전력을 줌
# 발전기 6가 발전기 4에게 1.54 전력을 줌
# 발전기 6가 발전기 5에게 4.38 전력을 줌
# 발전기 6가 발전기 7에게 4.39 전력을 줌
# 발전기 6가 발전기 8에게 4.00 전력을 줌
#
# [t=13 s=5]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 22.67 ([0] 2.03 [1] 3.46 [2] 7.62 [3] 2.56 [4] 0.21 [5] 0.00 [6] 0.00 [7] 6.47 [8] 0.00 [9] 0.32 )
# y- 합계: 9.78 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 7.76 [6] 0.00 [7] 0.00 [8] 2.03 [9] 0.00 )
# e+ 합계: 12.89 ([0] 0.00 [1] 0.00 [2] 7.62 [3] 2.56 [4] 0.21 [5] 0.00 [6] 0.00 [7] 2.50 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 5에게 2.03 전력을 줌
# 발전기 1가 발전기 5에게 3.46 전력을 줌
# 발전기 7가 발전기 5에게 1.95 전력을 줌
# 발전기 7가 발전기 8에게 2.03 전력을 줌
# 발전기 9가 발전기 5에게 0.32 전력을 줌
#
# [t=13 s=6]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 45.40 ([0] 12.42 [1] 2.93 [2] 9.08 [3] 0.00 [4] 0.00 [5] 0.00 [6] 8.44 [7] 4.98 [8] 0.00 [9] 7.55 )
# y- 합계: 19.21 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 4.59 [4] 1.54 [5] 1.26 [6] 0.00 [7] 0.00 [8] 11.82 [9] 0.00 )
# e+ 합계: 26.19 ([0] 6.57 [1] 0.00 [2] 7.73 [3] 0.00 [4] 0.00 [5] 0.00 [6] 6.90 [7] 4.98 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 3에게 4.59 전력을 줌
# 발전기 0가 발전기 5에게 1.26 전력을 줌
# 발전기 1가 발전기 8에게 2.93 전력을 줌
# 발전기 2가 발전기 8에게 1.34 전력을 줌
# 발전기 6가 발전기 4에게 1.54 전력을 줌
# 발전기 9가 발전기 8에게 7.55 전력을 줌
#
# [t=13 s=7]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 24.95 ([0] 4.41 [1] 0.00 [2] 13.60 [3] 0.00 [4] 0.00 [5] 0.00 [6] 2.90 [7] 0.00 [8] 0.00 [9] 4.04 )
# y- 합계: 24.95 ([0] 0.00 [1] 2.32 [2] 0.00 [3] 1.55 [4] 1.27 [5] 7.54 [6] 0.00 [7] 1.35 [8] 10.93 [9] 0.00 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 8에게 4.41 전력을 줌
# 발전기 2가 발전기 1에게 2.32 전력을 줌
# 발전기 2가 발전기 3에게 1.55 전력을 줌
# 발전기 2가 발전기 4에게 1.27 전력을 줌
# 발전기 2가 발전기 5에게 7.54 전력을 줌
# 발전기 2가 발전기 8에게 0.93 전력을 줌
# 발전기 6가 발전기 8에게 2.90 전력을 줌
# 발전기 9가 발전기 7에게 1.35 전력을 줌
# 발전기 9가 발전기 8에게 2.69 전력을 줌
#
# [t=13 s=8]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 36.80 ([0] 11.45 [1] 1.96 [2] 0.00 [3] 12.55 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 10.84 )
# y- 합계: 24.99 ([0] 0.00 [1] 0.00 [2] 0.86 [3] 0.00 [4] 1.54 [5] 4.78 [6] 1.58 [7] 4.39 [8] 11.84 [9] 0.00 )
# e+ 합계: 11.81 ([0] 6.67 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 5.14 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 5에게 4.78 전력을 줌
# 발전기 1가 발전기 2에게 0.38 전력을 줌
# 발전기 1가 발전기 6에게 1.58 전력을 줌
# 발전기 3가 발전기 2에게 0.48 전력을 줌
# 발전기 3가 발전기 4에게 1.54 전력을 줌
# 발전기 3가 발전기 7에게 4.39 전력을 줌
# 발전기 3가 발전기 8에게 6.14 전력을 줌
# 발전기 9가 발전기 8에게 5.70 전력을 줌
#
# [t=13 s=9]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 46.34 ([0] 6.45 [1] 4.76 [2] 0.00 [3] 14.19 [4] 0.00 [5] 0.00 [6] 2.38 [7] 7.66 [8] 0.00 [9] 10.91 )
# y- 합계: 21.85 ([0] 0.00 [1] 0.00 [2] 0.04 [3] 0.00 [4] 1.54 [5] 8.13 [6] 0.00 [7] 0.00 [8] 12.13 [9] 0.00 )
# e+ 합계: 24.49 ([0] 6.45 [1] 4.76 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 2.38 [7] 0.00 [8] 0.00 [9] 10.91 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 3가 발전기 2에게 0.04 전력을 줌
# 발전기 3가 발전기 4에게 1.54 전력을 줌
# 발전기 3가 발전기 5에게 0.47 전력을 줌
# 발전기 3가 발전기 8에게 12.13 전력을 줌
# 발전기 7가 발전기 5에게 7.66 전력을 줌
# 발전기 9가 발전기 2에게 0.00 전력을 줌
#
# [t=13 s=10]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 44.06 ([0] 2.97 [1] 0.00 [2] 13.53 [3] 0.00 [4] 0.00 [5] 0.00 [6] 16.76 [7] 3.68 [8] 0.00 [9] 7.12 )
# y- 합계: 20.83 ([0] 0.00 [1] 2.32 [2] 0.00 [3] 4.59 [4] 0.00 [5] 4.18 [6] 0.00 [7] 0.00 [8] 9.75 [9] 0.00 )
# e+ 합계: 23.23 ([0] 2.97 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 16.58 [7] 3.68 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 3에게 4.59 전력을 줌
# 발전기 2가 발전기 8에게 8.94 전력을 줌
# 발전기 6가 발전기 8에게 0.18 전력을 줌
# 발전기 9가 발전기 1에게 2.32 전력을 줌
# 발전기 9가 발전기 5에게 4.18 전력을 줌
# 발전기 9가 발전기 8에게 0.62 전력을 줌
#
# [t=13 s=11]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 24.44 ([0] 0.00 [1] 2.98 [2] 12.59 [3] 0.00 [4] 2.05 [5] 0.00 [6] 0.88 [7] 0.00 [8] 0.00 [9] 5.93 )
# y- 합계: 24.91 ([0] 1.13 [1] 0.00 [2] 0.00 [3] 3.98 [4] 0.00 [5] 8.13 [6] 0.00 [7] 1.66 [8] 10.01 [9] 0.00 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.47 ([0] 0.47 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 8에게 2.98 전력을 줌
# 발전기 2가 발전기 0에게 0.66 전력을 줌
# 발전기 2가 발전기 3에게 3.80 전력을 줌
# 발전기 2가 발전기 5에게 8.13 전력을 줌
# 발전기 4가 발전기 3에게 0.18 전력을 줌
# 발전기 4가 발전기 7에게 0.78 전력을 줌
# 발전기 4가 발전기 8에게 1.10 전력을 줌
# 발전기 6가 발전기 7에게 0.88 전력을 줌
# 발전기 9가 발전기 8에게 5.93 전력을 줌
#
# [t=13 s=12]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 10.96 ([0] 0.00 [1] 0.00 [2] 2.38 [3] 1.07 [4] 0.00 [5] 6.00 [6] 1.50 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 10.77 ([0] 1.21 [1] 2.32 [2] 0.00 [3] 0.00 [4] 1.54 [5] 0.00 [6] 0.00 [7] 1.95 [8] 3.75 [9] 0.00 )
# e+ 합계: 0.19 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.19 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 0에게 0.78 전력을 줌
# 발전기 2가 발전기 4에게 1.54 전력을 줌
# 발전기 2가 발전기 8에게 0.06 전력을 줌
# 발전기 3가 발전기 7에게 1.07 전력을 줌
# 발전기 5가 발전기 0에게 0.44 전력을 줌
# 발전기 5가 발전기 1에게 1.00 전력을 줌
# 발전기 5가 발전기 7에게 0.88 전력을 줌
# 발전기 5가 발전기 8에게 3.68 전력을 줌
# 발전기 6가 발전기 1에게 1.32 전력을 줌
#
# [t=13 s=13]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 52.61 ([0] 16.47 [1] 0.00 [2] 3.25 [3] 9.09 [4] 0.00 [5] 0.36 [6] 10.07 [7] 0.00 [8] 0.00 [9] 13.37 )
# y- 합계: 14.38 ([0] 0.00 [1] 0.55 [2] 0.00 [3] 0.00 [4] 1.54 [5] 0.00 [6] 0.00 [7] 0.00 [8] 12.28 [9] 0.00 )
# e+ 합계: 38.23 ([0] 16.47 [1] 0.00 [2] 0.00 [3] 9.09 [4] 0.00 [5] 0.36 [6] 10.07 [7] 0.00 [8] 0.00 [9] 2.24 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 4에게 1.54 전력을 줌
# 발전기 2가 발전기 8에게 1.71 전력을 줌
# 발전기 9가 발전기 1에게 0.55 전력을 줌
# 발전기 9가 발전기 8에게 10.57 전력을 줌
#
# [t=13 s=14]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 45.97 ([0] 6.45 [1] 0.00 [2] 12.43 [3] 4.61 [4] 0.00 [5] 0.00 [6] 2.81 [7] 7.35 [8] 0.00 [9] 12.32 )
# y- 합계: 17.16 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 1.54 [5] 2.28 [6] 0.00 [7] 0.00 [8] 13.34 [9] 0.00 )
# e+ 합계: 28.81 ([0] 0.00 [1] 0.00 [2] 12.43 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 4.06 [8] 0.00 [9] 12.32 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 4에게 1.54 전력을 줌
# 발전기 0가 발전기 8에게 4.91 전력을 줌
# 발전기 3가 발전기 8에게 4.61 전력을 줌
# 발전기 6가 발전기 5에게 2.28 전력을 줌
# 발전기 6가 발전기 8에게 0.52 전력을 줌
# 발전기 7가 발전기 8에게 3.29 전력을 줌
#
# [t=13 s=15]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 25.86 ([0] 0.00 [1] 5.67 [2] 8.76 [3] 4.18 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 7.25 )
# y- 합계: 29.61 ([0] 1.21 [1] 0.00 [2] 0.00 [3] 0.00 [4] 1.54 [5] 8.13 [6] 0.11 [7] 4.39 [8] 14.22 [9] 0.00 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 3.74 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 3.74 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 5에게 5.67 전력을 줌
# 발전기 2가 발전기 0에게 1.21 전력을 줌
# 발전기 2가 발전기 7에게 2.67 전력을 줌
# 발전기 2가 발전기 8에게 4.88 전력을 줌
# 발전기 3가 발전기 5에게 2.46 전력을 줌
# 발전기 3가 발전기 7에게 1.71 전력을 줌
# 발전기 9가 발전기 4에게 1.54 전력을 줌
# 발전기 9가 발전기 6에게 0.11 전력을 줌
# 발전기 9가 발전기 8에게 5.60 전력을 줌
#
# [t=13 s=16]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 34.76 ([0] 1.52 [1] 0.27 [2] 8.72 [3] 4.88 [4] 1.82 [5] 4.54 [6] 4.86 [7] 2.06 [8] 0.00 [9] 6.09 )
# y- 합계: 5.50 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 5.50 [9] 0.00 )
# e+ 합계: 29.26 ([0] 1.52 [1] 0.00 [2] 8.72 [3] 4.88 [4] 1.82 [5] 1.36 [6] 4.86 [7] 0.00 [8] 0.00 [9] 6.09 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 8에게 0.27 전력을 줌
# 발전기 5가 발전기 8에게 3.17 전력을 줌
# 발전기 7가 발전기 8에게 2.06 전력을 줌
#
# [t=13 s=17]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 56.93 ([0] 8.91 [1] 0.00 [2] 0.00 [3] 8.20 [4] 13.01 [5] 0.00 [6] 12.56 [7] 0.00 [8] 0.00 [9] 14.26 )
# y- 합계: 18.93 ([0] 0.00 [1] 2.32 [2] 1.06 [3] 0.00 [4] 0.00 [5] 5.06 [6] 0.00 [7] 3.56 [8] 6.93 [9] 0.00 )
# e+ 합계: 38.00 ([0] 8.91 [1] 0.00 [2] 0.00 [3] 8.20 [4] 11.26 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 9.63 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 4가 발전기 1에게 1.74 전력을 줌
# 발전기 6가 발전기 1에게 0.57 전력을 줌
# 발전기 6가 발전기 5에게 5.06 전력을 줌
# 발전기 6가 발전기 8에게 6.93 전력을 줌
# 발전기 9가 발전기 2에게 1.06 전력을 줌
# 발전기 9가 발전기 7에게 3.56 전력을 줌
#
# [t=13 s=18]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 21.47 ([0] 0.00 [1] 4.57 [2] 0.00 [3] 0.00 [4] 13.12 [5] 0.00 [6] 0.00 [7] 3.78 [8] 0.00 [9] 0.00 )
# y- 합계: 22.26 ([0] 0.00 [1] 0.00 [2] 1.06 [3] 4.48 [4] 0.00 [5] 8.13 [6] 1.58 [7] 0.00 [8] 7.00 [9] 0.00 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.79 ([0] 0.00 [1] 0.00 [2] 0.79 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 8에게 4.57 전력을 줌
# 발전기 4가 발전기 2에게 0.27 전력을 줌
# 발전기 4가 발전기 3에게 4.48 전력을 줌
# 발전기 4가 발전기 5에게 8.13 전력을 줌
# 발전기 4가 발전기 6에게 0.23 전력을 줌
# 발전기 7가 발전기 6에게 1.35 전력을 줌
# 발전기 7가 발전기 8에게 2.43 전력을 줌
#
# [t=13 s=19]
# x 합계: 39.04 ([0] 1.21 [1] 2.32 [2] 1.06 [3] 4.59 [4] 1.54 [5] 8.13 [6] 1.58 [7] 4.39 [8] 14.22 [9] 0.00 )
# y+ 합계: 31.73 ([0] 9.72 [1] 5.14 [2] 0.00 [3] 3.45 [4] 4.35 [5] 1.03 [6] 0.00 [7] 0.00 [8] 0.00 [9] 8.05 )
# y- 합계: 16.04 ([0] 0.00 [1] 0.00 [2] 1.06 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.14 [7] 0.62 [8] 14.22 [9] 0.00 )
# e+ 합계: 15.69 ([0] 9.72 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 1.03 [6] 0.00 [7] 0.00 [8] 0.00 [9] 4.94 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 2에게 1.06 전력을 줌
# 발전기 1가 발전기 6에게 0.14 전력을 줌
# 발전기 1가 발전기 8에게 3.93 전력을 줌
# 발전기 3가 발전기 7에게 0.62 전력을 줌
# 발전기 3가 발전기 8에게 2.82 전력을 줌
# 발전기 4가 발전기 8에게 4.35 전력을 줌
# 발전기 9가 발전기 8에게 3.11 전력을 줌
#
# [t=14 s=0]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 39.20 ([0] 0.32 [1] 0.00 [2] 0.00 [3] 13.00 [4] 0.00 [5] 4.41 [6] 5.63 [7] 5.98 [8] 9.86 [9] 0.00 )
# y- 합계: 21.16 ([0] 0.00 [1] 4.87 [2] 12.84 [3] 0.00 [4] 1.50 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 1.96 )
# e+ 합계: 18.04 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 12.20 [4] 0.00 [5] 0.00 [6] 0.00 [7] 5.84 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 9에게 0.32 전력을 줌
# 발전기 3가 발전기 9에게 0.80 전력을 줌
# 발전기 5가 발전기 1에게 0.74 전력을 줌
# 발전기 5가 발전기 2에게 3.68 전력을 줌
# 발전기 6가 발전기 1에게 4.13 전력을 줌
# 발전기 6가 발전기 4에게 1.50 전력을 줌
# 발전기 7가 발전기 9에게 0.14 전력을 줌
# 발전기 8가 발전기 2에게 9.16 전력을 줌
# 발전기 8가 발전기 9에게 0.70 전력을 줌
#
# [t=14 s=1]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 26.42 ([0] 7.66 [1] 0.00 [2] 0.00 [3] 5.41 [4] 0.00 [5] 10.02 [6] 0.26 [7] 0.00 [8] 0.00 [9] 3.07 )
# y- 합계: 26.42 ([0] 0.00 [1] 7.76 [2] 14.87 [3] 0.00 [4] 0.51 [5] 0.00 [6] 0.00 [7] 2.28 [8] 1.00 [9] 0.00 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 2에게 7.41 전력을 줌
# 발전기 0가 발전기 4에게 0.25 전력을 줌
# 발전기 3가 발전기 2에게 3.13 전력을 줌
# 발전기 3가 발전기 7에게 2.28 전력을 줌
# 발전기 5가 발전기 1에게 5.69 전력을 줌
# 발전기 5가 발전기 2에게 4.33 전력을 줌
# 발전기 6가 발전기 4에게 0.26 전력을 줌
# 발전기 9가 발전기 1에게 2.07 전력을 줌
# 발전기 9가 발전기 8에게 1.00 전력을 줌
#
# [t=14 s=2]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 21.56 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 4.11 [4] 0.00 [5] 7.35 [6] 0.00 [7] 6.33 [8] 0.00 [9] 3.77 )
# y- 합계: 19.75 ([0] 2.12 [1] 7.59 [2] 7.77 [3] 0.00 [4] 1.50 [5] 0.00 [6] 0.78 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 1.81 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 1.81 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 3가 발전기 2에게 1.53 전력을 줌
# 발전기 3가 발전기 6에게 0.78 전력을 줌
# 발전기 5가 발전기 1에게 1.11 전력을 줌
# 발전기 5가 발전기 2에게 6.24 전력을 줌
# 발전기 7가 발전기 1에게 4.83 전력을 줌
# 발전기 7가 발전기 4에게 1.50 전력을 줌
# 발전기 9가 발전기 0에게 2.12 전력을 줌
# 발전기 9가 발전기 1에게 1.65 전력을 줌
#
# [t=14 s=3]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 35.73 ([0] 0.00 [1] 1.01 [2] 0.00 [3] 0.00 [4] 1.35 [5] 13.23 [6] 3.03 [7] 10.30 [8] 0.00 [9] 6.80 )
# y- 합계: 9.63 ([0] 3.03 [1] 0.00 [2] 5.60 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.00 [9] 0.00 )
# e+ 합계: 26.09 ([0] 0.00 [1] 1.01 [2] 0.00 [3] 0.00 [4] 0.35 [5] 13.23 [6] 0.00 [7] 10.30 [8] 0.00 [9] 1.20 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 4가 발전기 8에게 1.00 전력을 줌
# 발전기 6가 발전기 0에게 3.03 전력을 줌
# 발전기 9가 발전기 2에게 5.60 전력을 줌
#
# [t=14 s=4]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 54.18 ([0] 6.42 [1] 0.00 [2] 0.00 [3] 8.08 [4] 10.19 [5] 6.57 [6] 14.87 [7] 3.19 [8] 4.86 [9] 0.00 )
# y- 합계: 16.45 ([0] 0.00 [1] 2.02 [2] 12.47 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 1.96 )
# e+ 합계: 37.73 ([0] 6.42 [1] 0.00 [2] 0.00 [3] 8.08 [4] 0.00 [5] 6.57 [6] 11.80 [7] 0.00 [8] 4.86 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 4가 발전기 2에게 8.23 전력을 줌
# 발전기 4가 발전기 9에게 1.96 전력을 줌
# 발전기 6가 발전기 2에게 3.07 전력을 줌
# 발전기 7가 발전기 1에게 2.02 전력을 줌
# 발전기 7가 발전기 2에게 1.17 전력을 줌
#
# [t=14 s=5]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 38.84 ([0] 3.42 [1] 0.00 [2] 0.26 [3] 0.00 [4] 3.37 [5] 10.31 [6] 14.91 [7] 3.62 [8] 2.96 [9] 0.00 )
# y- 합계: 9.72 ([0] 0.00 [1] 7.76 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 1.96 )
# e+ 합계: 29.12 ([0] 3.42 [1] 0.00 [2] 0.26 [3] 0.00 [4] 3.37 [5] 10.31 [6] 8.81 [7] 0.00 [8] 2.96 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 6가 발전기 1에게 6.10 전력을 줌
# 발전기 7가 발전기 1에게 1.66 전력을 줌
# 발전기 7가 발전기 9에게 1.96 전력을 줌
#
# [t=14 s=6]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 49.93 ([0] 3.30 [1] 1.32 [2] 0.00 [3] 12.67 [4] 4.28 [5] 4.56 [6] 12.31 [7] 8.26 [8] 0.00 [9] 3.24 )
# y- 합계: 15.27 ([0] 0.00 [1] 0.00 [2] 14.87 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.40 [9] 0.00 )
# e+ 합계: 34.66 ([0] 0.70 [1] 1.32 [2] 0.00 [3] 0.00 [4] 4.28 [5] 4.56 [6] 12.31 [7] 8.26 [8] 0.00 [9] 3.24 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 2에게 2.20 전력을 줌
# 발전기 0가 발전기 8에게 0.40 전력을 줌
# 발전기 3가 발전기 2에게 12.67 전력을 줌
#
# [t=14 s=7]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 19.15 ([0] 3.13 [1] 0.00 [2] 0.00 [3] 12.77 [4] 0.00 [5] 0.00 [6] 0.27 [7] 0.00 [8] 2.99 [9] 0.00 )
# y- 합계: 25.36 ([0] 0.00 [1] 7.76 [2] 13.14 [3] 0.00 [4] 0.12 [5] 0.00 [6] 0.00 [7] 2.38 [8] 0.00 [9] 1.96 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 6.20 ([0] 0.00 [1] 0.00 [2] 6.20 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 0.74 전력을 줌
# 발전기 0가 발전기 7에게 2.38 전력을 줌
# 발전기 3가 발전기 1에게 3.88 전력을 줌
# 발전기 3가 발전기 2에게 6.93 전력을 줌
# 발전기 3가 발전기 9에게 1.96 전력을 줌
# 발전기 6가 발전기 1에게 0.27 전력을 줌
# 발전기 8가 발전기 1에게 2.87 전력을 줌
# 발전기 8가 발전기 4에게 0.12 전력을 줌
#
# [t=14 s=8]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 29.61 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 9.92 [6] 9.33 [7] 0.00 [8] 9.22 [9] 1.14 )
# y- 합계: 25.47 ([0] 2.11 [1] 7.76 [2] 11.72 [3] 0.00 [4] 1.50 [5] 0.00 [6] 0.00 [7] 2.38 [8] 0.00 [9] 0.00 )
# e+ 합계: 4.14 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 4.14 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 5가 발전기 2에게 7.54 전력을 줌
# 발전기 5가 발전기 7에게 2.38 전력을 줌
# 발전기 6가 발전기 0에게 2.11 전력을 줌
# 발전기 6가 발전기 1에게 1.29 전력을 줌
# 발전기 6가 발전기 2에게 0.30 전력을 줌
# 발전기 6가 발전기 4에게 1.50 전력을 줌
# 발전기 8가 발전기 1에게 6.48 전력을 줌
# 발전기 8가 발전기 2에게 2.74 전력을 줌
# 발전기 9가 발전기 2에게 1.14 전력을 줌
#
# [t=14 s=9]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 33.95 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 7.59 [6] 0.00 [7] 6.83 [8] 6.96 [9] 12.58 )
# y- 합계: 15.11 ([0] 3.03 [1] 4.00 [2] 5.70 [3] 0.00 [4] 0.00 [5] 0.00 [6] 2.38 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 18.84 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 7.59 [6] 0.00 [7] 6.83 [8] 1.55 [9] 2.87 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 8가 발전기 0에게 3.03 전력을 줌
# 발전기 8가 발전기 6에게 2.38 전력을 줌
# 발전기 9가 발전기 1에게 4.00 전력을 줌
# 발전기 9가 발전기 2에게 5.70 전력을 줌
#
# [t=14 s=10]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 35.09 ([0] 0.00 [1] 3.29 [2] 0.00 [3] 0.00 [4] 8.65 [5] 15.73 [6] 1.96 [7] 5.46 [8] 0.00 [9] 0.00 )
# y- 합계: 19.29 ([0] 3.03 [1] 0.00 [2] 13.30 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.00 [9] 1.96 )
# e+ 합계: 15.81 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.07 [5] 15.73 [6] 0.01 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 2에게 2.29 전력을 줌
# 발전기 1가 발전기 8에게 1.00 전력을 줌
# 발전기 4가 발전기 0에게 3.03 전력을 줌
# 발전기 4가 발전기 2에게 5.55 전력을 줌
# 발전기 6가 발전기 9에게 1.96 전력을 줌
# 발전기 7가 발전기 2에게 5.46 전력을 줌
#
# [t=14 s=11]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 33.15 ([0] 0.00 [1] 3.35 [2] 0.00 [3] 4.03 [4] 0.00 [5] 9.43 [6] 8.20 [7] 6.53 [8] 0.00 [9] 1.62 )
# y- 합계: 8.50 ([0] 1.27 [1] 0.00 [2] 4.73 [3] 0.00 [4] 1.50 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.00 [9] 0.00 )
# e+ 합계: 24.65 ([0] 0.00 [1] 3.35 [2] 0.00 [3] 0.00 [4] 0.00 [5] 6.58 [6] 8.20 [7] 6.53 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 3가 발전기 2에게 4.03 전력을 줌
# 발전기 5가 발전기 2에게 0.35 전력을 줌
# 발전기 5가 발전기 4에게 1.50 전력을 줌
# 발전기 5가 발전기 8에게 1.00 전력을 줌
# 발전기 9가 발전기 0에게 1.27 전력을 줌
# 발전기 9가 발전기 2에게 0.35 전력을 줌
#
# [t=14 s=12]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 28.65 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 10.68 [4] 0.00 [5] 7.15 [6] 5.57 [7] 0.00 [8] 0.00 [9] 5.25 )
# y- 합계: 16.67 ([0] 3.03 [1] 4.29 [2] 4.46 [3] 0.00 [4] 1.50 [5] 0.00 [6] 0.00 [7] 2.38 [8] 1.00 [9] 0.00 )
# e+ 합계: 11.98 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 5.62 [4] 0.00 [5] 0.00 [6] 5.57 [7] 0.00 [8] 0.00 [9] 0.79 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 3가 발전기 1에게 2.56 전력을 줌
# 발전기 3가 발전기 4에게 1.50 전력을 줌
# 발전기 3가 발전기 8에게 1.00 전력을 줌
# 발전기 5가 발전기 0에게 3.03 전력을 줌
# 발전기 5가 발전기 1에게 1.73 전력을 줌
# 발전기 5가 발전기 7에게 2.38 전력을 줌
# 발전기 9가 발전기 2에게 4.46 전력을 줌
#
# [t=14 s=13]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 33.65 ([0] 0.00 [1] 3.55 [2] 0.00 [3] 3.88 [4] 0.00 [5] 4.08 [6] 13.59 [7] 8.55 [8] 0.00 [9] 0.00 )
# y- 합계: 12.87 ([0] 2.73 [1] 0.00 [2] 7.34 [3] 0.00 [4] 0.17 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.67 [9] 1.96 )
# e+ 합계: 20.78 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 2.09 [6] 10.13 [7] 8.55 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 0에게 0.75 전력을 줌
# 발전기 1가 발전기 4에게 0.17 전력을 줌
# 발전기 1가 발전기 8에게 0.67 전력을 줌
# 발전기 1가 발전기 9에게 1.96 전력을 줌
# 발전기 3가 발전기 2에게 3.88 전력을 줌
# 발전기 5가 발전기 0에게 1.98 전력을 줌
# 발전기 6가 발전기 2에게 3.46 전력을 줌
#
# [t=14 s=14]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 46.60 ([0] 8.58 [1] 0.00 [2] 0.00 [3] 16.88 [4] 0.80 [5] 1.91 [6] 11.14 [7] 7.28 [8] 0.00 [9] 0.00 )
# y- 합계: 18.76 ([0] 0.00 [1] 7.76 [2] 10.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.00 [9] 0.00 )
# e+ 합계: 27.84 ([0] 2.73 [1] 0.00 [2] 0.00 [3] 6.88 [4] 0.80 [5] 0.00 [6] 10.14 [7] 7.28 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 5.85 전력을 줌
# 발전기 3가 발전기 2에게 10.00 전력을 줌
# 발전기 5가 발전기 1에게 1.91 전력을 줌
# 발전기 6가 발전기 8에게 1.00 전력을 줌
#
# [t=14 s=15]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 14.98 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 3.89 [4] 0.00 [5] 7.23 [6] 2.48 [7] 0.00 [8] 1.38 [9] 0.00 )
# y- 합계: 18.84 ([0] 3.03 [1] 5.41 [2] 4.56 [3] 0.00 [4] 1.50 [5] 0.00 [6] 0.00 [7] 2.38 [8] 0.00 [9] 1.96 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 3.86 ([0] 0.00 [1] 0.00 [2] 3.05 [3] 0.00 [4] 0.81 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 3가 발전기 2에게 1.51 전력을 줌
# 발전기 3가 발전기 7에게 2.38 전력을 줌
# 발전기 5가 발전기 1에게 4.58 전력을 줌
# 발전기 5가 발전기 4에게 0.69 전력을 줌
# 발전기 5가 발전기 9에게 1.96 전력을 줌
# 발전기 6가 발전기 0에게 2.48 전력을 줌
# 발전기 8가 발전기 0에게 0.55 전력을 줌
# 발전기 8가 발전기 1에게 0.83 전력을 줌
#
# [t=14 s=16]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 36.58 ([0] 6.54 [1] 0.00 [2] 0.00 [3] 2.39 [4] 2.37 [5] 10.57 [6] 8.83 [7] 3.15 [8] 2.74 [9] 0.00 )
# y- 합계: 24.28 ([0] 0.00 [1] 7.76 [2] 14.87 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 1.65 )
# e+ 합계: 12.30 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 2.39 [4] 0.00 [5] 9.92 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 4.31 전력을 줌
# 발전기 0가 발전기 2에게 2.24 전력을 줌
# 발전기 4가 발전기 1에게 0.72 전력을 줌
# 발전기 4가 발전기 9에게 1.65 전력을 줌
# 발전기 5가 발전기 2에게 0.65 전력을 줌
# 발전기 6가 발전기 2에게 8.83 전력을 줌
# 발전기 7가 발전기 2에게 3.15 전력을 줌
# 발전기 8가 발전기 1에게 2.74 전력을 줌
#
# [t=14 s=17]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 49.24 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 5.04 [4] 0.00 [5] 3.62 [6] 11.38 [7] 11.69 [8] 8.94 [9] 8.57 )
# y- 합계: 17.19 ([0] 3.03 [1] 3.51 [2] 9.15 [3] 0.00 [4] 1.50 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 32.05 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.04 [4] 0.00 [5] 0.00 [6] 11.38 [7] 11.69 [8] 8.94 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 3가 발전기 2에게 3.50 전력을 줌
# 발전기 3가 발전기 4에게 1.50 전력을 줌
# 발전기 5가 발전기 2에게 3.62 전력을 줌
# 발전기 9가 발전기 0에게 3.03 전력을 줌
# 발전기 9가 발전기 1에게 3.51 전력을 줌
# 발전기 9가 발전기 2에게 2.02 전력을 줌
#
# [t=14 s=18]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 12.55 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.57 [4] 2.34 [5] 0.00 [6] 0.00 [7] 1.95 [8] 7.68 [9] 0.00 )
# y- 합계: 17.67 ([0] 1.17 [1] 7.76 [2] 4.41 [3] 0.00 [4] 0.00 [5] 0.00 [6] 2.38 [7] 0.00 [8] 0.00 [9] 1.96 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 5.12 ([0] 0.00 [1] 0.00 [2] 4.41 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.71 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 3가 발전기 9에게 0.57 전력을 줌
# 발전기 4가 발전기 6에게 0.96 전력을 줌
# 발전기 4가 발전기 9에게 1.38 전력을 줌
# 발전기 7가 발전기 0에게 1.17 전력을 줌
# 발전기 7가 발전기 1에게 0.08 전력을 줌
# 발전기 7가 발전기 6에게 0.71 전력을 줌
# 발전기 8가 발전기 1에게 7.68 전력을 줌
#
# [t=14 s=19]
# x 합계: 34.88 ([0] 3.03 [1] 7.76 [2] 14.87 [3] 0.00 [4] 1.50 [5] 0.00 [6] 2.38 [7] 2.38 [8] 1.00 [9] 1.96 )
# y+ 합계: 18.64 ([0] 5.19 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 11.58 [8] 0.64 [9] 1.23 )
# y- 합계: 16.92 ([0] 0.00 [1] 3.15 [2] 12.27 [3] 0.00 [4] 1.50 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 1.72 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 1.72 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 2.52 전력을 줌
# 발전기 0가 발전기 2에게 1.17 전력을 줌
# 발전기 0가 발전기 4에게 1.50 전력을 줌
# 발전기 7가 발전기 2에게 9.86 전력을 줌
# 발전기 8가 발전기 1에게 0.64 전력을 줌
# 발전기 9가 발전기 2에게 1.23 전력을 줌
#
# [t=15 s=0]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 18.54 ([0] 5.85 [1] 0.00 [2] 0.16 [3] 2.33 [4] 0.00 [5] 0.00 [6] 0.00 [7] 8.98 [8] 0.00 [9] 1.21 )
# y- 합계: 3.47 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 1.21 [5] 0.00 [6] 0.00 [7] 0.00 [8] 2.26 [9] 0.00 )
# e+ 합계: 15.06 ([0] 5.85 [1] 0.00 [2] 0.00 [3] 0.23 [4] 0.00 [5] 0.00 [6] 0.00 [7] 8.98 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 4에게 0.16 전력을 줌
# 발전기 3가 발전기 4에게 1.06 전력을 줌
# 발전기 3가 발전기 8에게 1.04 전력을 줌
# 발전기 9가 발전기 8에게 1.21 전력을 줌
#
# [t=15 s=1]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 17.81 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 8.86 [7] 5.53 [8] 3.42 [9] 0.00 )
# y- 합계: 14.35 ([0] 0.00 [1] 0.50 [2] 2.52 [3] 0.04 [4] 1.22 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 10.08 )
# e+ 합계: 3.46 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 3.46 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 6가 발전기 2에게 0.85 전력을 줌
# 발전기 6가 발전기 9에게 4.55 전력을 줌
# 발전기 7가 발전기 9에게 5.53 전력을 줌
# 발전기 8가 발전기 1에게 0.50 전력을 줌
# 발전기 8가 발전기 2에게 1.67 전력을 줌
# 발전기 8가 발전기 3에게 0.04 전력을 줌
# 발전기 8가 발전기 4에게 1.22 전력을 줌
#
# [t=15 s=2]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 30.04 ([0] 0.00 [1] 2.21 [2] 0.00 [3] 8.29 [4] 0.00 [5] 8.39 [6] 11.15 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 8.26 ([0] 0.00 [1] 0.00 [2] 1.46 [3] 0.00 [4] 1.96 [5] 0.00 [6] 0.00 [7] 0.00 [8] 2.26 [9] 2.59 )
# e+ 합계: 21.78 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 2.23 [4] 0.00 [5] 8.39 [6] 11.15 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 9에게 2.21 전력을 줌
# 발전기 3가 발전기 2에게 1.46 전력을 줌
# 발전기 3가 발전기 4에게 1.96 전력을 줌
# 발전기 3가 발전기 8에게 2.26 전력을 줌
# 발전기 3가 발전기 9에게 0.38 전력을 줌
#
# [t=15 s=3]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 16.87 ([0] 8.23 [1] 0.00 [2] 7.03 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.61 [9] 0.00 )
# y- 합계: 16.43 ([0] 0.00 [1] 2.35 [2] 0.00 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 1.61 [8] 0.00 [9] 6.71 )
# e+ 합계: 0.44 ([0] 0.44 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 3에게 0.04 전력을 줌
# 발전기 0가 발전기 4에게 3.28 전력을 줌
# 발전기 0가 발전기 6에게 2.44 전력을 줌
# 발전기 0가 발전기 9에게 2.04 전력을 줌
# 발전기 2가 발전기 1에게 2.35 전력을 줌
# 발전기 2가 발전기 9에게 4.68 전력을 줌
# 발전기 8가 발전기 7에게 1.61 전력을 줌
#
# [t=15 s=4]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 27.90 ([0] 0.00 [1] 7.87 [2] 1.32 [3] 3.47 [4] 0.00 [5] 5.67 [6] 9.57 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 16.78 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 2.89 [5] 0.00 [6] 0.00 [7] 2.69 [8] 1.12 [9] 10.08 )
# e+ 합계: 11.12 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 1.56 [6] 9.57 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 7에게 2.69 전력을 줌
# 발전기 1가 발전기 9에게 5.18 전력을 줌
# 발전기 2가 발전기 8에게 1.12 전력을 줌
# 발전기 2가 발전기 9에게 0.20 전력을 줌
# 발전기 3가 발전기 9에게 3.47 전력을 줌
# 발전기 5가 발전기 4에게 2.89 전력을 줌
# 발전기 5가 발전기 9에게 1.23 전력을 줌
#
# [t=15 s=5]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 36.07 ([0] 2.40 [1] 0.00 [2] 6.60 [3] 7.38 [4] 0.00 [5] 12.86 [6] 0.00 [7] 4.00 [8] 2.83 [9] 0.00 )
# y- 합계: 16.43 ([0] 0.00 [1] 0.64 [2] 0.00 [3] 0.00 [4] 3.28 [5] 0.00 [6] 2.44 [7] 0.00 [8] 0.00 [9] 10.08 )
# e+ 합계: 19.63 ([0] 0.00 [1] 0.00 [2] 1.83 [3] 7.38 [4] 0.00 [5] 10.42 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 4에게 1.09 전력을 줌
# 발전기 0가 발전기 9에게 1.32 전력을 줌
# 발전기 2가 발전기 9에게 4.77 전력을 줌
# 발전기 5가 발전기 6에게 2.44 전력을 줌
# 발전기 7가 발전기 9에게 4.00 전력을 줌
# 발전기 8가 발전기 1에게 0.64 전력을 줌
# 발전기 8가 발전기 4에게 2.19 전력을 줌
#
# [t=15 s=6]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 19.52 ([0] 0.00 [1] 3.55 [2] 0.00 [3] 2.67 [4] 0.00 [5] 11.18 [6] 2.10 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 20.06 ([0] 0.00 [1] 0.00 [2] 2.52 [3] 0.00 [4] 3.28 [5] 0.00 [6] 0.00 [7] 2.79 [8] 2.26 [9] 9.21 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.54 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.54 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 4에게 2.86 전력을 줌
# 발전기 1가 발전기 7에게 0.69 전력을 줌
# 발전기 3가 발전기 2에게 2.26 전력을 줌
# 발전기 3가 발전기 4에게 0.42 전력을 줌
# 발전기 5가 발전기 2에게 0.26 전력을 줌
# 발전기 5가 발전기 8에게 1.72 전력을 줌
# 발전기 5가 발전기 9에게 9.21 전력을 줌
# 발전기 6가 발전기 7에게 2.10 전력을 줌
#
# [t=15 s=7]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 19.13 ([0] 7.21 [1] 2.72 [2] 0.00 [3] 0.00 [4] 0.90 [5] 8.31 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 17.42 ([0] 0.00 [1] 0.00 [2] 2.52 [3] 0.04 [4] 0.00 [5] 0.00 [6] 2.44 [7] 0.59 [8] 1.76 [9] 10.08 )
# e+ 합계: 1.71 ([0] 1.71 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 2에게 1.29 전력을 줌
# 발전기 0가 발전기 6에게 2.44 전력을 줌
# 발전기 0가 발전기 9에게 1.77 전력을 줌
# 발전기 1가 발전기 2에게 1.23 전력을 줌
# 발전기 1가 발전기 7에게 0.59 전력을 줌
# 발전기 1가 발전기 8에게 0.90 전력을 줌
# 발전기 4가 발전기 3에게 0.04 전력을 줌
# 발전기 4가 발전기 8에게 0.86 전력을 줌
# 발전기 5가 발전기 9에게 8.31 전력을 줌
#
# [t=15 s=8]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 24.98 ([0] 3.43 [1] 5.65 [2] 0.54 [3] 1.60 [4] 0.00 [5] 2.36 [6] 6.37 [7] 0.74 [8] 4.26 [9] 0.00 )
# y- 합계: 12.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 3.28 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 8.72 )
# e+ 합계: 12.98 ([0] 3.43 [1] 5.65 [2] 0.00 [3] 0.00 [4] 0.00 [5] 2.36 [6] 0.00 [7] 0.00 [8] 1.53 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 4에게 0.54 전력을 줌
# 발전기 3가 발전기 9에게 1.60 전력을 줌
# 발전기 6가 발전기 9에게 6.37 전력을 줌
# 발전기 7가 발전기 4에게 0.74 전력을 줌
# 발전기 8가 발전기 4에게 1.99 전력을 줌
# 발전기 8가 발전기 9에게 0.74 전력을 줌
#
# [t=15 s=9]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 37.20 ([0] 0.00 [1] 0.00 [2] 1.69 [3] 0.00 [4] 0.06 [5] 13.73 [6] 11.90 [7] 8.84 [8] 0.00 [9] 0.99 )
# y- 합계: 3.90 ([0] 0.00 [1] 1.60 [2] 0.00 [3] 0.04 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 2.26 [9] 0.00 )
# e+ 합계: 33.30 ([0] 0.00 [1] 0.00 [2] 1.69 [3] 0.00 [4] 0.06 [5] 13.73 [6] 11.90 [7] 4.98 [8] 0.00 [9] 0.95 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 7가 발전기 1에게 1.60 전력을 줌
# 발전기 7가 발전기 8에게 2.26 전력을 줌
# 발전기 9가 발전기 3에게 0.04 전력을 줌
#
# [t=15 s=10]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 16.25 ([0] 4.53 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 7.44 [7] 4.28 [8] 0.00 [9] 0.00 )
# y- 합계: 17.30 ([0] 0.00 [1] 1.65 [2] 2.52 [3] 0.04 [4] 0.76 [5] 0.00 [6] 0.00 [7] 0.00 [8] 2.26 [9] 10.08 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 1.05 ([0] 0.00 [1] 1.05 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 8에게 1.86 전력을 줌
# 발전기 0가 발전기 9에게 2.67 전력을 줌
# 발전기 6가 발전기 3에게 0.04 전력을 줌
# 발전기 6가 발전기 9에게 7.40 전력을 줌
# 발전기 7가 발전기 1에게 0.60 전력을 줌
# 발전기 7가 발전기 2에게 2.52 전력을 줌
# 발전기 7가 발전기 4에게 0.76 전력을 줌
# 발전기 7가 발전기 8에게 0.40 전력을 줌
#
# [t=15 s=11]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 24.99 ([0] 10.68 [1] 0.00 [2] 0.00 [3] 1.90 [4] 0.00 [5] 7.51 [6] 0.00 [7] 1.19 [8] 3.71 [9] 0.00 )
# y- 합계: 18.56 ([0] 0.00 [1] 0.25 [2] 2.52 [3] 0.00 [4] 3.28 [5] 0.00 [6] 2.44 [7] 0.00 [8] 0.00 [9] 10.08 )
# e+ 합계: 6.43 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 6.43 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 0.25 전력을 줌
# 발전기 0가 발전기 2에게 2.52 전력을 줌
# 발전기 0가 발전기 4에게 3.28 전력을 줌
# 발전기 0가 발전기 6에게 2.44 전력을 줌
# 발전기 0가 발전기 9에게 2.20 전력을 줌
# 발전기 3가 발전기 9에게 1.90 전력을 줌
# 발전기 5가 발전기 9에게 1.08 전력을 줌
# 발전기 7가 발전기 9에게 1.19 전력을 줌
# 발전기 8가 발전기 9에게 3.71 전력을 줌
#
# [t=15 s=12]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 33.30 ([0] 13.21 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 8.98 [6] 0.00 [7] 0.35 [8] 9.18 [9] 1.58 )
# y- 합계: 9.52 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 1.33 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 23.78 ([0] 13.21 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 8.98 [6] 0.00 [7] 0.00 [8] 1.60 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 7가 발전기 2에게 0.35 전력을 줌
# 발전기 8가 발전기 1에게 2.35 전력을 줌
# 발전기 8가 발전기 2에게 2.16 전력을 줌
# 발전기 8가 발전기 4에게 1.74 전력을 줌
# 발전기 8가 발전기 6에게 1.33 전력을 줌
# 발전기 9가 발전기 3에게 0.04 전력을 줌
# 발전기 9가 발전기 4에게 1.54 전력을 줌
#
# [t=15 s=13]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 29.00 ([0] 11.98 [1] 0.00 [2] 0.00 [3] 0.00 [4] 3.91 [5] 0.85 [6] 9.91 [7] 2.34 [8] 0.00 [9] 0.00 )
# y- 합계: 12.74 ([0] 0.00 [1] 2.35 [2] 0.33 [3] 0.04 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.83 [9] 8.20 )
# e+ 합계: 16.25 ([0] 11.98 [1] 0.00 [2] 0.00 [3] 0.00 [4] 3.43 [5] 0.85 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 4가 발전기 9에게 0.48 전력을 줌
# 발전기 6가 발전기 1에게 0.01 전력을 줌
# 발전기 6가 발전기 2에게 0.33 전력을 줌
# 발전기 6가 발전기 3에게 0.04 전력을 줌
# 발전기 6가 발전기 8에게 1.83 전력을 줌
# 발전기 6가 발전기 9에게 7.71 전력을 줌
# 발전기 7가 발전기 1에게 2.34 전력을 줌
#
# [t=15 s=14]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 18.46 ([0] 10.04 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 4.93 [6] 2.67 [7] 0.82 [8] 0.00 [9] 0.00 )
# y- 합계: 18.46 ([0] 0.00 [1] 1.62 [2] 1.22 [3] 0.00 [4] 3.28 [5] 0.00 [6] 0.00 [7] 0.00 [8] 2.26 [9] 10.08 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 2에게 0.81 전력을 줌
# 발전기 0가 발전기 4에게 3.28 전력을 줌
# 발전기 0가 발전기 9에게 5.95 전력을 줌
# 발전기 5가 발전기 8에게 2.26 전력을 줌
# 발전기 5가 발전기 9에게 2.67 전력을 줌
# 발전기 6가 발전기 1에게 1.62 전력을 줌
# 발전기 6가 발전기 2에게 0.41 전력을 줌
# 발전기 6가 발전기 9에게 0.64 전력을 줌
# 발전기 7가 발전기 9에게 0.82 전력을 줌
#
# [t=15 s=15]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 22.40 ([0] 0.00 [1] 5.63 [2] 2.28 [3] 0.00 [4] 0.00 [5] 0.00 [6] 8.51 [7] 0.00 [8] 5.98 [9] 0.00 )
# y- 합계: 16.19 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.04 [4] 3.28 [5] 0.00 [6] 0.00 [7] 2.79 [8] 0.00 [9] 10.08 )
# e+ 합계: 6.21 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 6.21 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 9에게 5.63 전력을 줌
# 발전기 2가 발전기 9에게 2.28 전력을 줌
# 발전기 6가 발전기 4에게 2.26 전력을 줌
# 발전기 6가 발전기 7에게 0.04 전력을 줌
# 발전기 8가 발전기 3에게 0.04 전력을 줌
# 발전기 8가 발전기 4에게 1.02 전력을 줌
# 발전기 8가 발전기 7에게 2.75 전력을 줌
# 발전기 8가 발전기 9에게 2.16 전력을 줌
#
# [t=15 s=16]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 7.37 ([0] 0.00 [1] 0.14 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 6.63 [7] 0.00 [8] 0.60 [9] 0.00 )
# y- 합계: 18.36 ([0] 0.00 [1] 0.00 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 0.00 [7] 2.79 [8] 0.00 [9] 9.73 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 10.99 ([0] 0.00 [1] 0.00 [2] 2.52 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 8.47 )
# 거래 내역:
# 발전기 1가 발전기 3에게 0.04 전력을 줌
# 발전기 1가 발전기 9에게 0.10 전력을 줌
# 발전기 6가 발전기 4에게 2.68 전력을 줌
# 발전기 6가 발전기 7에게 2.79 전력을 줌
# 발전기 6가 발전기 9에게 1.16 전력을 줌
# 발전기 8가 발전기 4에게 0.60 전력을 줌
#
# [t=15 s=17]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 26.49 ([0] 2.19 [1] 6.23 [2] 0.00 [3] 0.00 [4] 0.00 [5] 2.97 [6] 9.10 [7] 1.80 [8] 4.21 [9] 0.00 )
# y- 합계: 10.38 ([0] 0.00 [1] 0.00 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 4.55 )
# e+ 합계: 16.11 ([0] 2.19 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 2.97 [6] 6.75 [7] 0.97 [8] 3.24 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 2에게 1.68 전력을 줌
# 발전기 1가 발전기 9에게 4.55 전력을 줌
# 발전기 6가 발전기 4에게 2.35 전력을 줌
# 발전기 7가 발전기 2에게 0.83 전력을 줌
# 발전기 8가 발전기 3에게 0.04 전력을 줌
# 발전기 8가 발전기 4에게 0.93 전력을 줌
#
# [t=15 s=18]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 19.90 ([0] 3.18 [1] 0.55 [2] 8.65 [3] 0.00 [4] 0.00 [5] 0.00 [6] 6.60 [7] 0.93 [8] 0.00 [9] 0.00 )
# y- 합계: 13.04 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.04 [4] 2.08 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.84 [9] 10.08 )
# e+ 합계: 6.86 ([0] 0.00 [1] 0.00 [2] 0.27 [3] 0.00 [4] 0.00 [5] 0.00 [6] 6.60 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 3에게 0.04 전력을 줌
# 발전기 0가 발전기 4에게 2.08 전력을 줌
# 발전기 0가 발전기 9에게 1.06 전력을 줌
# 발전기 1가 발전기 8에게 0.55 전력을 줌
# 발전기 2가 발전기 9에게 8.38 전력을 줌
# 발전기 7가 발전기 8에게 0.29 전력을 줌
# 발전기 7가 발전기 9에게 0.63 전력을 줌
#
# [t=15 s=19]
# x 합계: 25.75 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 3.28 [5] 0.00 [6] 2.44 [7] 2.79 [8] 2.26 [9] 10.08 )
# y+ 합계: 15.16 ([0] 5.49 [1] 0.00 [2] 0.00 [3] 0.00 [4] 2.35 [5] 0.00 [6] 7.32 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 20.03 ([0] 0.00 [1] 2.35 [2] 2.52 [3] 0.04 [4] 0.00 [5] 0.00 [6] 0.00 [7] 2.79 [8] 2.26 [9] 10.08 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 4.88 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.04 [4] 0.00 [5] 0.00 [6] 0.00 [7] 2.79 [8] 0.00 [9] 2.05 )
# 거래 내역:
# 발전기 0가 발전기 9에게 5.49 전력을 줌
# 발전기 4가 발전기 1에게 2.35 전력을 줌
# 발전기 6가 발전기 2에게 2.52 전력을 줌
# 발전기 6가 발전기 8에게 2.26 전력을 줌
# 발전기 6가 발전기 9에게 2.55 전력을 줌

# %%
d_given = np.zeros(I)
d_received = np.zeros(I)

for i in range(I):
    d_given[i] = sum(
        sum(d_vals[i, j, t, s] for j in range(I) if j != i for t in range(T)) / S
        for s in range(S)
    )
    d_received[i] = sum(
        sum(d_vals[j, i, t, s] for j in range(I) if j != i for t in range(T)) / S
        for s in range(S)
    )

set_d = pd.DataFrame({"set_d_given": d_given, "set_d_received": d_received})
set_d.to_csv("result/result_set2_d.csv", index=False)

# %% [markdown]
# ### 정산

# %%
total_der_profit = 0
der_profit = {}
for i in range(I):
    der_profit[i] = sum(P_DA[t] * x[i,t].x + sum(1/S * (P_RT[t,s] * e_plus[i,t,s].x - P_PN[t] * e_minus[i,t,s].x) for s in range(S)) for t in range(T))
    total_der_profit += der_profit[i]

print(f"\n모든 der의 profit 합계: {total_der_profit:.2f}")

print("\n최종 profit:")
for i, (profit, only) in enumerate(zip(der_profit.values(), only_profit.flatten())):
    increase_percentage = ((profit - only) / only) * 100
    print(f"[{i}] {profit:.2f} ({increase_percentage:.2f}%)")
# Out:
# 모든 der의 profit 합계: 11878.13
#
# 최종 profit:
# [0] 1207.44 (0.24%)
# [1] 872.55 (0.00%)
# [2] 1240.58 (0.25%)
# [3] 1138.00 (0.84%)
# [4] 974.53 (34.56%)
# [5] 1015.32 (5.38%)
# [6] 1811.06 (4.52%)
# [7] 1110.32 (1.04%)
# [8] 1200.34 (56.10%)
# [9] 1307.99 (40.54%)

# %% [markdown]
# ### 결과 저장

# %%
set_profit_value = pd.DataFrame({'set_profit_value': der_profit})
set_profit_value.to_csv('result/result_set2_profit.csv', index=False)

set_obj = pd.DataFrame({'set_obj': [set.objVal]})
set_obj.to_csv('result/result_set2_obj.csv', index=False)
