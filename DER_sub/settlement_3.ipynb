# %% [markdown]
# ### data

# %%
import pandas as pd
import numpy as np
import cvxpy as cp
import matplotlib.pyplot as plt
import gurobipy as gp
from gurobipy import GRB

# %%
alpha = pd.read_csv("result_alpha.csv").to_numpy().flatten()
beta_plus = pd.read_csv("result_beta_plus.csv").to_numpy()
beta_minus = pd.read_csv("result_beta_minus.csv").to_numpy()

R_flat = pd.read_csv("result_R.csv")

I_len = R_flat["generator"].nunique()
T_len = R_flat["time"].nunique() 
S_len = R_flat["scenario"].nunique()

R = R_flat.pivot_table(
    values="value",
    index="generator",
    columns=["time", "scenario"]
).to_numpy()
R = R.reshape(I_len, T_len, S_len)

I, T, S = R.shape

# %%
price_q = pd.read_csv(
    "/Users/jangseohyun/Documents/workspace/symply/DER/DATA_price.csv"
)
price_q["Time"] = pd.to_datetime(price_q["Time"], format="%Y-%m-%d %H:%M")

price_q["Hour"] = price_q["Time"].dt.floor("h")
price_h = price_q.groupby("Hour").mean(numeric_only=True)

price = price_h.iloc[: S * T]

P_DA = np.array(
    [sum(price["Price"].iloc[t + s * T] for s in range(S)) / S * 1.2 for t in range(T)]
)
P_RT = np.array([[price["Price"].iloc[t + s * T] for s in range(S)] for t in range(T)])
P_PN = np.array(
    [sum(price["Price"].iloc[t + s * T] for s in range(S)) / S * 2 for t in range(T)]
)

# %% [markdown]
# ### settlement model

# %%
set = gp.Model("Settlement")
set.Params.OutputFlag = 0
set.setParam('TimeLimit', 3600)
set.setParam('MIPGap', 0.01)
set.setParam('Presolve', 0)

x = set.addVars(I, T, vtype=GRB.CONTINUOUS, lb=0, name="x")
y_plus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="y_plus")
y_minus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="y_minus")
M = max(sum(R[i, t, s] for i in range(I)) for t in range(T) for s in range(S))
z_y = set.addVars(I, T, S, vtype=GRB.BINARY, name="z_y")

d = set.addVars(I, I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="d")
e_plus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="e_plus")
e_minus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="e_minus")

set.update()
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2611964
# Academic license - for non-commercial use only - expires 2026-01-20

# %%
obj = gp.quicksum(
    P_DA[t] * x[i, t] for i in range(I) for t in range(T)
) + gp.quicksum(
    1/S * (P_RT[t, s] * e_plus[i, t, s] - P_PN[t] * e_minus[i, t, s])
    for i in range(I) for t in range(T) for s in range(S)
)
set.setObjective(obj, GRB.MAXIMIZE)

# %%
# 기존 제약식

# x로 y+, y- 결정 지어주기
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(R[i, t, s] - x[i, t] == y_plus[i, t, s] - y_minus[i, t, s])

# real-time market 참여 제약
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(R[i,t,s] - y_plus[i, t, s] >= 0)

# y+, y- 둘 중 하나는 0이어야함
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(y_plus[i, t, s] <= M * z_y[i, t, s])
            set.addConstr(y_minus[i, t, s] <= M * (1 - z_y[i, t, s]))

# alpha는 모든 x의 합
for t in range(T):
    set.addConstr(
        gp.quicksum(x[i, t] for i in range(I)) == alpha[t]
    )

# 초과량이 있는 발전기만 다른 발전기에게 전력을 줄 수 있음
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(
                gp.quicksum(d[i, j, t, s] for j in range(I) if j != i)
                <= M * z_y[i, t, s]
            )

# 자기 자신과의 거래 방지
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(d[i, i, t, s] == 0)

# β+, β- 매칭
for t in range(T):
    for s in range(S):
        # 실제 남는 양(초과량 - 주는 양)의 합이 beta+와 같아야 함
        set.addConstr(
            gp.quicksum(
                e_plus[i, t, s]
                for i in range(I)
            )
            == beta_plus[t, s]
        )
        # 실제 부족한 양(부족량 - 받는 양)의 합이 beta-와 같아야 함
        set.addConstr(
            gp.quicksum(
                e_minus[i, t, s]
                for i in range(I)
            )
            == beta_minus[t, s]
        )

# 전력 이동 제한
for i in range(I):
    for t in range(T):
        for s in range(S):
            # 발전기가 주는 총량은 자신의 초과량을 넘을 수 없음
            set.addConstr(
                gp.quicksum(d[i, j, t, s] for j in range(I) if j != i)
                <= y_plus[i, t, s]
            )
            # 발전기가 받는 총량은 자신의 부족량을 넘을 수 없음
            set.addConstr(
                gp.quicksum(d[j, i, t, s] for j in range(I) if j != i)
                <= y_minus[i, t, s]
            )

# %%
# 거래 후 남은 양 정의
for i in range(I):
    for t in range(T):
        for s in range(S):
            # e_plus: 초과량에서 준 양을 뺀 것
            set.addConstr(
                e_plus[i,t,s] == y_plus[i,t,s] - gp.quicksum(d[i,j,t,s] for j in range(I) if j != i)
            )
            # e_minus: 부족량에서 받은 양을 뺀 것
            set.addConstr(
                e_minus[i,t,s] == y_minus[i,t,s] - gp.quicksum(d[j,i,t,s] for j in range(I) if j != i)
            )

# # x값 균등 분배 제약
# for t in range(T):
#     for i in range(I):
#         set.addConstr(x[i,t] <= alpha[t]/I)

# %%
set.optimize()

if set.status == GRB.OPTIMAL:
    x_vals = np.array([[x[i, t].x for t in range(T)] for i in range(I)])
    y_plus_vals = np.array(
        [[[y_plus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    y_minus_vals = np.array(
        [[[y_minus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    d_vals = np.array(
        [
            [[[d[i, j, t, s].x for s in range(S)] for t in range(T)] for j in range(I)]
            for i in range(I)
        ]
    )
    e_plus_vals = np.array(
        [[[e_plus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    e_minus_vals = np.array(
        [[[e_minus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    print("Optimal solution found!")
    print(set.objVal)
else:
    print("\nNo optimal solution found.")
# Out:
# Optimal solution found!
# 15918.10329532185

# %%
print(f"Status: {set.status}")
if set.status == GRB.OPTIMAL:
    print("모델이 Optimal입니다")
elif set.status == GRB.UNBOUNDED:
    print("모델이 Unbounded입니다")
    # Unbounded ray 확인
    set.computeIIS()
    set.write("model.ilp")
elif set.status == GRB.INFEASIBLE:
    print("모델이 Infeasible입니다")
    # IIS 계산
    set.computeIIS()
    set.write("model.ilp")
elif set.status == GRB.INF_OR_UNBD:
    print("모델이 Infeasible 또는 Unbounded입니다")
    # Presolve를 끄고 다시 시도
    set.setParam('Presolve', 0)
    set.optimize()
elif set.status == GRB.TIME_LIMIT:
    print("시간 제한에 도달했습니다")
    if set.SolCount > 0:
        print(f"현재까지의 최선해: {set.objVal}")
# Out:
# Status: 2
# 모델이 Optimal입니다

# %% [markdown]
# ### 결과 분석

# %%
for t in range(13,15):
    x_sum = sum(x_vals[i, t] for i in range(I))

    for s in range(S):
        y_plus_sum = sum(y_plus_vals[i, t, s] for i in range(I))
        y_minus_sum = sum(y_minus_vals[i, t, s] for i in range(I))

        e_plus_sum = sum(e_plus_vals[i, t, s] for i in range(I))
        e_minus_sum = sum(e_minus_vals[i, t, s] for i in range(I))

        print(f"[t={t} s={s}]")

        print(f"alpha: {alpha[t]:.2f}")

        print(f"x 합계: {x_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {x_vals[i,t]:.2f}", end=" ")
        print(")")

        print(f"y+ 합계: {y_plus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {y_plus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print(f"y- 합계: {y_minus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {y_minus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print(f"e+ 합계: {e_plus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {e_plus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print(f"e- 합계: {e_minus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {e_minus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print(f"beta+: {beta_plus[t,s]:.2f}")
        print(f"beta-: {beta_minus[t,s]:.2f}")

        print("거래 내역:")
        for i in range(I):
            for j in range(I):
                if d_vals[i, j, t, s] > 1e-6:
                    print(
                        f"발전기 {i}가 발전기 {j}에게 {d_vals[i,j,t,s]:.2f} 전력을 줌"
                    )
        print()
# Out:
# [t=13 s=0]
# alpha: 70.54
# x 합계: 70.54 ([0] 3.71 [1] 3.71 [2] 3.71 [3] 3.71 [4] 3.71 [5] 3.71 [6] 3.71 [7] 3.71 [8] 3.71 [9] 3.71 [10] 3.71 [11] 3.71 [12] 3.71 [13] 3.71 [14] 3.71 [15] 3.71 [16] 3.71 [17] 3.71 [18] 3.71 )
# y+ 합계: 41.69 ([0] 0.00 [1] 0.00 [2] 4.11 [3] 0.00 [4] 0.00 [5] 6.32 [6] 1.13 [7] 2.75 [8] 0.33 [9] 4.36 [10] 5.82 [11] 0.00 [12] 6.48 [13] 2.65 [14] 0.00 [15] 3.71 [16] 0.00 [17] 4.03 [18] 0.00 )
# y- 합계: 18.57 ([0] 3.68 [1] 1.33 [2] 0.00 [3] 1.82 [4] 0.08 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 [10] 0.00 [11] 3.71 [12] 0.00 [13] 0.00 [14] 1.72 [15] 0.00 [16] 3.71 [17] 0.00 [18] 2.50 )
# e+ 합계: 23.12 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6]
 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 [10] 0.00 [11] 0.00 [12] 0.00 [13] 0.00 [14] 0.00 [15] 0.00 [16] 0.00 [17] 0.00 [18] 0.00 )
# beta+: 4.44
# beta-: 0.00
# 거래 내역:
# 발전기 2가 발전기 1에게 1.45 전력을 줌
# 발전기 2가 발전기 3에게 0.12 전력을 줌
# 발전기 2가 발전기 4에게 3.71 전력을 줌
# 발전기 2가 발전기 5에게 0.84 전력을 줌
# 발전기 6가 발전기 7에게 0.67 전력을 줌
# 발전기 6가 발전기 11에게 3.17 전력을 줌
# 발전기 6가 발전기 12에게 2.20 전력을 줌
# 발전기 8가 발전기 12에게 0.18 전력을 줌
# 발전기 8가 발전기 17에게 0.18 전력을 줌
# 발전기 8가 발전기 18에게 1.77 전력을 줌
# 발전기 9가 발전기 14에게 2.13 전력을 줌
# 발전기 9가 발전기 15에게 0.77 전력을 줌
# 발전기 9가 발전기 16에게 1.93 전력을 줌
# 발전기 10가 발전기 18에게 1.72 전력을 줌
# 발전기 13가 발전기 5에게 2.87 전력을 줌
# 발전기 13가 발전기 16에게 1.78 전력을 줌
# 발전기 13가 발전기 17에게 3.54 전력을 줌
#
# [t=13 s=5]
# alpha: 70.54
# x 합계: 70.54 ([0] 3.71 [1] 3.71 [2] 3.71 [3] 3.71 [4] 3.71 [5] 3.71 [6] 3.71 [7] 3.71 [8] 3.71 [9] 3.71 [10] 3.71 [11] 3.71 [12] 3.71 [13] 3.71 [14] 3.71 [15] 3.71 [16] 3.71 [17] 3.71 [18] 3.71 )
# y+ 합계: 23.38 ([0] 2.86 [1] 0.00 [2] 7.48 [3] 0.00 [4] 0.00 [5] 0.00 [6] 3.19 [7] 6.10 [8] 0.11 [9] 0.00 [10] 0.00 [11] 0.19 [12] 0.00 [13] 0.00 [14] 3.46 [15] 0.00 [16] 0.00 [17] 0.00 [18] 0.00 )
# y- 합계: 32.61 ([0] 0.00 [1] 1.44 [2] 0.00 [3] 1.27 [4] 3.71 [5] 1.87 [6] 0.00 [7] 0.00 [8] 0.00 [9] 3.71 [10] 2.99 [11] 0.00 [12] 3.71 [13] 3.71 [14] 0.00 [15] 2.52 [16] 1.70 [17] 3.71 [18] 2.25 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 [10] 0.00 [11] 0.00 [12] 0.00 [13] 0.00 [14] 0.00 [15] 0.00 [16] 0.00 [17] 0.00 [18] 0.00 )
# e- 합계: 9.23 ([0] 0.00 [1] -0.00 [2] 0.00 [3] -0.00 [4] 0.00 [5] 0.82 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.23 [10] 0.00 [11] 0.00 [12] 0.60 [13] 0.26 [14] 0.00 [15] 0.00 [16] 1.70 [17] 3.71 [18] 1.91 )
# beta+: 0.00
# beta-: 9.23
# 거래 내역:
# 발전기 0가 발전기 15에게 2.52 전력을 줌
# 발전기 0가 발전기 18에게 0.34 전력을 줌
# 발전기 2가 발전기 1에게 1.44 전력을 줌
# 발전기 2가 발전기 3에게 1.27 전력을 줌
# 발전기 2가 발전기 4에게 3.71 전력을 줌
# 발전기 2가 발전기 5에게 1.05 전력을 줌
# 발전기 6가 발전기 9에게 3.19 전력을 줌
# 발전기 7가 발전기 10에게 2.99 전력을 줌
# 발전기 7가 발전기 12에게 3.11 전력을 줌
# 발전기 6가 발전기 1에게 1.55 전력을 줌
# 발전기 6가 발전기 2에게 3.71 전력을 줌
# 발전기 6가 발전기 5에게 0.10 전력을 줌
# 발전기 7가 발전기 3에게 0.92 전력을 줌
# 발전기 9가 발전기 3에게 1.07 전력을 줌
# 발전기 9가 발전기 5에게 0.25 전력을 줌
# 발전기 12가 발전기 5에게 0.86 전력을 줌
# 발전기 13가 발전기 8에게 3.71 전력을 줌
# 발전기 13가 발전기 10에게 1.26 전력을 줌
# 발전기 13가 발전기 11에게 3.35 전력을 줌
# 발전기 14가 발전기 5에게 1.01 전력을 줌
# 발전기 14가 발전기 11에게 0.36 전력을 줌
# 발전기 14가 발전기 16에게 0.06 전력을 줌
# 발전기 14가 발전기 17에게 0.48 전력을 줌
# 발전기 18가 발전기 17에게 2.43 전력을 줌
#
# [t=13 s=9]
# alpha: 70.54
# x 합계: 70.54 ([0] 3.71 [1] 3.71 [2] 3.71 [3] 3.71 [4] 3.71 [5] 3.71 [6] 3.71 [7] 3.71 [8] 3.71 [9] 3.71 [10] 3.71 [11] 3.71 [12] 3.71 [13] 3.71 [14] 3.71 [15] 3.71 [16] 3.71 [17] 3.71 [18] 3.71 )
# y+ 합계: 32.57 ([0] 6.91 [1] 2.73 [2] 3.31 [3] 0.00 [4] 0.00 [5] 0.00 [6] 8.01 [7] 0.00 [8] 1.31 [9] 2.27 [10] 0.00 [11] 0.00 [12] 0.00 [13] 1.95 [14] 0.00 [15] 3.80 [16] 0.00 [17] 2.27 [18] 0.00 )
# y- 합계: 20.29 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 1.67 [4] 0.20 [5] 2.39 [6] 0.00 [7] 1.09 [8] 0.00 [9] 0.00 [10] 1.38 [11] 0.28 [12] 3.71 [13] 0.00 [14] 3.71 [15] 0.00 [16] 2.29 [17] 0.00 [18] 3.57 )
# e+ 합계: 12.28 ([0] 0.00 [1] 2.73 [2] 3.31 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.31 [9] 2.27 [10] 0.00 [11] 0.00 [12] 0.00 [13] 1.95 [14] 0.00 [15] 0.70 [16] 0.00 [17] 0.00 [18] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 [10] 0.00 [11] 0.00 [12] 0.00 [13] 0.00 [14] 0.00 [15] 0.00 [16] 0.00 [17] 0.00 [18] 0.00 )
# beta+: 12.28
# beta-: 0.00
# 거래 내역:
# 발전기 0가 발전기 14에게 3.71 전력을 줌
# 발전기 0가 발전기 16에게 2.29 전력을 줌
# 발전기 0가 발전기 18에게 0.91 전력을 줌
# 발전기 6가 발전기 3에게 1.67 전력을 줌
# 발전기 6가 발전기 4에게 0.20 전력을 줌
# 발전기 6가 발전기 5에게 2.39 전력을 줌
# 발전기 6가 발전기 7에게 1.09 전력을 줌
# 발전기 6가 발전기 10에게 1.38 전력을 줌
# 발전기 6가 발전기 11에게 0.28 전력을 줌
# 발전기 6가 발전기 12에게 1.00 전력을 줌
# 발전기 15가 발전기 12에게 0.44 전력을 줌
# 발전기 15가 발전기 18에게 2.66 전력을 줌
# 발전기 17가 발전기 12에게 2.27 전력을 줌
#
# [t=14 s=0]
# alpha: 55.12
([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 1.91 [7] 4.80 [8] 1.24 [9] 0.00 [10] 0.00 [11] 0.00 [12] 2.26 [13] 0.00 [14] 0.00 [15] 0.00 [16] 0.00 [17] 0.00 [18] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 [10] 0.00 [11] 0.00 [12] 0.00 [13] 0.00 [14] 0.00 [15] 0.00 [16] 0.00 [17] 0.00 [18] 0.00 )
# beta+: 10.22
# beta-: 0.00
# 거래 내역:
# 발전기 2가 발전기 0에게 2.28 전력을 줌
# 발전기 2가 발전기 1에게 2.90 전력을 줌
# 발전기 2가 발전기 4에게 1.22 전력을 줌
# 발전기 3가 발전기 5에게 2.90 전력을 줌
# 발전기 3가 발전기 9에게 2.90 전력을 줌
# 발전기 3가 발전기 10에게 2.26 전력을 줌
# 발전기 12가 발전기 15에게 0.29 전력을 줌
# 발전기 14가 발전기 15에게 0.78 전력을 줌
# 발전기 14가 발전기 16에게 2.90 전력을 줌
# 발전기 17가 발전기 4에게 1.46 전력을 줌
# 발전기 17가 발전기 10에게 0.64 전력을 줌
# 발전기 17가 발전기 11에게 1.27 전력을 줌
# 발전기 17가 발전기 13에게 1.87 전력을 줌
# 발전기 17가 발전기 15에게 1.45 전력을 줌
# 발전기 18가 발전기 4에게 0.22 전력을 줌
#
# [t=14 s=2]
# alpha: 55.12
# x 합계: 55.12 ([0] 2.90 [1] 2.90 [2] 2.90 [3] 2.90 [4] 2.90 [5] 2.90 [6] 2.90 [7] 2.90 [8] 2.90 [9] 2.90 [10] 2.90 [11] 2.90 [12] 2.90 [13] 2.90 [14] 2.90 [15] 2.90 [16] 2.90 [17] 2.90 [18] 2.90 )
# y+ 합계: 23.73 ([0] 0.00 [1] 0.41 [2] 2.72 [3] 0.00 [4] 0.00 [5] 9.11 [6] 5.74 [7] 4.97 [8] 0.00 [9] 0.00 [10] 0.47 [11] 0.00 [12] 0.31 [13] 0.00 [14] 0.00 [15] 0.00 [16] 0.00 [17] 0.00 [18] 0.00 )
# y- 합계: 24.56 ([0] 2.24 [1] 0.00 [2] 0.00 [3] 1.32 [4] 1.44 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.38 [9] 2.90 [10] 0.00 [11] 2.90 [12] 0.00 [13] 2.90 [14] 1.01 [15] 2.90 [16] 2.90 [17] 1.61 [18] 1.04 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 [10] 0.00 [11] 0.00 [12] 0.00 [13] 0.00 [14] 0.00 [15] 0.00 [16] 0.00 [17] 0.00 [18] 0.00 )
# e- 합계: 0.82 ([0] 0.43 [1] 0.00 [2] 0.00 [3] -0.00 [4] -0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 [10] 0.00 [11] 0.00 [12] 0.00 [13] 0.40 [14] 0.00 [15] 0.00 [16] 0.00 [17] 0.00 [18] 0.00 )
# beta+: 0.00
# beta-: 0.82
# 거래 내역:
# 발전기 1가 발전기 0에게 0.41 전력을 줌
# 발전기 2가 발전기 0에게 1.40 전력을 줌
# 발전기 2가 발전기 3에게 1.32 전력을 줌
# 발전기 5가 발전기 4에게 1.44 전력을 줌
# 발전기 5가 발전기 8에게 1.38 전력을 줌
# 발전기 5가 발전기 9에게 2.90 전력을 줌
# 발전기 5가 발전기 11에게 2.90 전력을 줌
# 발전기 5가 발전기 13에게 0.49 전력을 줌
# 발전기 6가 발전기 13에게 1.22 전력을 줌
# 발전기 6가 발전기 15에게 2.90 전력을 줌
# 발전기 6가 발전기 17에게 1.61 전력을 줌
# 발전기 7가 발전기 13에게 0.01 전력을 줌
# 발전기 7가 발전기 14에게 1.01 전력을 줌
# 발전기 7가 발전기 16에게 2.90 전력을 줌
# 발전기 7가 발전기 18에게 1.04 전력을 줌
# 발전기 10가 발전기 13에게 0.47 전력을 줌
# 발전기 12가 발전기 13에게 0.31 전력을 줌
#
# [t=14 s=3]
# alpha: 55.12
# x 합계: 55.12 ([0] 2.90 [1] 2.90 [2] 2.90 [3] 2.90 [4] 2.90 [5] 2.90 [6] 2.90 [7] 2.90 [8] 2.90 [9] 2.90 [10] 2.90 [11] 2.90 [12] 2.90 [13] 2.90 [14] 2.90 [15] 2.90 [16] 2.90 [17] 2.90 [18] 2.90 )
# y+ 합계: 22.88 ([0] 1.74 [1] 2.30 [2] 0.00 [3] 0.01 [4] 0.19 [5] 0.00 [6] 6.57 [7] 1.13 [8] 0.00 [9] 0.00 [10] 0.00 [11] 0.00 [12] 8.43 [13] 0.00 [14] 0.00 [15] 0.00 [16] 0.00 [17] 2.51 [18] 0.00 )
# y- 합계: 29.99 ([0] 0.00 [1] 0.00 [2] 2.50 [3] 0.00 [4] 0.00 [5] 2.90 [6] 0.00 [7] 0.00 [8] 2.90 [9] 2.90 [10] 1.53 [11] 2.90 [12] 0.00 [13] 2.90 [14] 2.90 [15] 2.75 [16] 2.90 [17] 0.00 [18] 2.90 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 [10] 0.00 [11] 0.00 [12] 0.00 [13] 0.00 [14] 0.00 [15] 0.00 [16] 0.00 [17] 0.00 [18] 0.00 )
# e- 합계: 7.10 ([0] 0.00 [1] 0.00 [2] 2.30 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 2.13 [9] 0.00 [10] 0.40 [11] 0.12 [12] 0.00 [13] 0.00 [14] 1.16 [15] 0.00 [16] 0.99 [17] 0.00 [18] 0.00 )
# beta+: 0.00
# beta-: 7.10
# 거래 내역:
# 발전기 0가 발전기 14에게 1.74 전력을 줌
# 발전기 1가 발전기 18에게 2.30 전력을 줌
# 발전기 3가 발전기 2에게 0.01 전력을 줌
# 발전기 4가 발전기 2에게 0.19 전력을 줌
# 발전기 6가 발전기 5에게 2.90 전력을 줌
# 발전기 6가 발전기 8에게 0.77 전력을 줌
# 발전기 6가 발전기 9에게 2.90 전력을 줌
# 발전기 7가 발전기 10에게 1.13 전력을 줌
# 발전기 12가 발전기 11에게 2.78 전력을 줌
# 발전기 12가 발전기 13에게 2.90 전력을 줌
# 발전기 12가 발전기 15에게 2.75 전력을 줌
# 발전기 17가 발전기 16에게 1.91 전력을 줌
# 발전기 17가 발전기 18에게 0.60 전력을 줌
#
# [t=14 s=4]
# alpha: 55.12
# x 합계: 55.12 ([0] 2.90 [1] 2.90 [2] 2.90 [3] 2.90 [4] 2.90 [5] 2.90 [6] 2.90 [7] 2.90 [8] 2.90 [9] 2.90 [10] 2.90 [11] 2.90 [12] 2.90 [13] 2.90 [14] 2.90 [15] 2.90 [16] 2.90 [17] 2.90 [18] 2.90 )
 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 [10] 0.00 [11] 0.00 [12] 0.00 [13] 0.00 [14] 0.00 [15] 0.00 [16] 0.00 [17] 0.00 [18] 0.00 )
# beta+: 16.16
# beta-: 0.00
# 거래 내역:
# 발전기 6가 발전기 13에게 1.06 전력을 줌
# 발전기 6가 발전기 14에게 0.04 전력을 줌
# 발전기 6가 발전기 15에게 2.90 전력을 줌
# 발전기 6가 발전기 16에게 2.90 전력을 줌
# 발전기 6가 발전기 17에게 1.31 전력을 줌
# 발전기 12가 발전기 13에게 0.02 전력을 줌
# 발전기 18가 발전기 0에게 1.22 전력을 줌
# 발전기 18가 발전기 4에게 2.90 전력을 줌
# 발전기 18가 발전기 5에게 1.19 전력을 줌
# 발전기 18가 발전기 10에게 0.94 전력을 줌
# 발전기 18가 발전기 11에게 2.90 전력을 줌
# 발전기 18가 발전기 13에게 0.36 전력을 줌
#
# [t=14 s=6]
# alpha: 55.12
# x 합계: 55.12 ([0] 2.90 [1] 2.90 [2] 2.90 [3] 2.90 [4] 2.90 [5] 2.90 [6] 2.90 [7] 2.90 [8] 2.90 [9] 2.90 [10] 2.90 [11] 2.90 [12] 2.90 [13] 2.90 [14] 2.90 [15] 2.90 [16] 2.90 [17] 2.90 [18] 2.90 )
# y+ 합계: 42.42 ([0] 0.00 [1] 0.77 [2] 2.03 [3] 2.47 [4] 0.00 [5] 7.01 [6] 11.24 [7] 0.00 [8] 0.00 [9] 0.00 [10] 4.70 [11] 0.00 [12] 0.41 [13] 5.56 [14] 0.00 [15] 3.82 [16] 0.00 [17] 3.37 [18] 1.03 )
# y- 합계: 16.55 ([0] 2.90 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.77 [5] 0.00 [6] 0.00 [7] 0.37 [8] 0.91 [9] 2.90 [10] 0.00 [11] 2.90 [12] 0.00 [13] 0.00 [14] 2.90 [15] 0.00 [16] 2.90 [17] 0.00 [18] 0.00 )
# e+ 합계: 25.86 ([0] 0.00 [1] 0.77 [2] 2.03 [3] 2.47 [4] 0.00 [5] 0.00 [6] 2.54 [7] 0.00 [8] 0.00 [9] 0.00 [10] 4.70 [11] 0.00 [12] 0.41 [13] 5.56 [14] 0.00 [15] 3.82 [16] 0.00 [17] 3.37 [18] 0.19 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 [10] 0.00 [11] 0.00 [12] 0.00 [13] 0.00 [14] 0.00 [15] 0.00 [16] 0.00 [17] 0.00 [18] 0.00 )
# beta+: 25.86
# beta-: 0.00
# 거래 내역:
# 발전기 5가 발전기 0에게 2.90 전력을 줌
# 발전기 5가 발전기 4에게 0.77 전력을 줌
# 발전기 5가 발전기 7에게 0.37 전력을 줌
# 발전기 5가 발전기 8에게 0.91 전력을 줌
# 발전기 5가 발전기 9에게 2.06 전력을 줌
# 발전기 6가 발전기 11에게 2.90 전력을 줌
# 발전기 6가 발전기 14에게 2.90 전력을 줌
# 발전기 6가 발전기 16에게 2.90 전력을 줌
# 발전기 18가 발전기 9에게 0.85 전력을 줌
#
# [t=14 s=7]
# alpha: 55.12
# x 합계: 55.12 ([0] 2.90 [1] 2.90 [2] 2.90 [3] 2.90 [4] 2.90 [5] 2.90 [6] 2.90 [7] 2.90 [8] 2.90 [9] 2.90 [10] 2.90 [11] 2.90 [12] 2.90 [13] 2.90 [14] 2.90 [15] 2.90 [16] 2.90 [17] 2.90 [18] 2.90 )
# y+ 합계: 20.98 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 6.78 [4] 0.00 [5] 0.00 [6] 1.04 [7] 0.29 [8] 0.00 [9] 6.13 [10] 0.00 [11] 0.00 [12] 3.19 [13] 0.00 [14] 0.00 [15] 0.00 [16] 0.00 [17] 0.00 [18] 3.55 )
# y- 합계: 26.44 ([0] 1.25 [1] 0.29 [2] 2.15 [3] 0.00 [4] 2.90 [5] 2.90 [6] 0.00 [7] 0.00 [8] 1.33 [9] 0.00 [10] 2.48 [11] 2.90 [12] 0.00 [13] 0.30 [14] 2.90 [15] 2.90 [16] 2.90 [17] 1.24 [18] 0.00 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 [10] 0.00 [11] 0.00 [12] 0.00 [13] 0.00 [14] 0.00 [15] 0.00 [16] 0.00 [17] 0.00 [18] 0.00 )
# e- 합계: 5.46 ([0] -0.00 [1] -0.00 [2] -0.00 [3] 0.00 [4] 0.00 [5] 2.72 [6] 0.00 [7] 0.00 [8] 1.33 [9] 0.00 [10] 0.00 [11] 0.00 [12] 0.00 [13] 0.30 [14] 1.11 [15] 0.00 [16] 0.00 [17] 0.00 [18] 0.00 )
# beta+: 0.00
# beta-: 5.46
# 거래 내역:
# 발전기 3가 발전기 0에게 1.25 전력을 줌
# 발전기 3가 발전기 1에게 0.29 전력을 줌
# 발전기 3가 발전기 2에게 2.15 전력을 줌
# 발전기 3가 발전기 4에게 2.90 전력을 줌
# 발전기 3가 발전기 5에게 0.18 전력을 줌
# 발전기 6가 발전기 17에게 1.04 전력을 줌
# 발전기 7가 발전기 14에게 0.10 전력을 줌
# 발전기 7가 발전기 17에게 0.19 전력을 줌
# 발전기 9가 발전기 10에게 2.48 전력을 줌
# 발전기 9가 발전기 11에게 2.90 전력을 줌
# 발전기 9가 발전기 14에게 0.75 전력을 줌
# 발전기 12가 발전기 14에게 0.29 전력을 줌
# 발전기 12가 발전기 15에게 2.90 전력을 줌
# 발전기 18가 발전기 14에게 0.65 전력을 줌
# 발전기 18가 발전기 16에게 2.90 전력을 줌
#
# [t=14 s=8]
# alpha: 55.12
# x 합계: 55.12 ([0] 2.90 [1] 2.90 [2] 2.90 [3] 2.90 [4] 2.90 [5] 2.90 [6] 2.90 [7] 2.90 [8] 2.90 [9] 2.90 [10] 2.90 [11] 2.90 [12] 2.90 [13] 2.90 [14] 2.90 [15] 2.90 [16] 2.90 [17] 2.90 [18] 2.90 )
# y+ 합계: 29.75 ([0] 0.00 [1] 5.90 [2] 0.94 [3] 0.00 [4] 0.00 [5] 0.00 [6] 5.09 [7] 2.37 [8] 5.03 [9] 0.00 [10] 0.00 [11] 0.00 [12] 1.30 [13] 4.08 [14] 0.40 [15] 4.64 [16] 0.00 [17] 0.00 [18] 0.00 )
# y- 합계: 21.81 ([0] 0.69 [1] 0.00 [2] 0.00 [3] 0.61 [4] 2.41 [5] 2.90 [6] 0.00 [7] 0.00 [8] 0.00 [9] 2.90 [10] 2.90 [11] 2.90 [12] 0.00 [13] 0.00 [14] 0.00 [15] 0.00 [16] 2.90 [17] 0.69 [18] 2.90 )
# e+ 합계: 7.95 ([0] 0.00 [1] 0.00 [2] 0.94 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 2.37 [8] 0.00 [9] 0.00 [10] 0.00 [11] 0.00 [12] 1.30 [13] 0.49 [14] 0.40 [15] 2.44 [16] 0.00 [17] 0.00 [18] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 [10] 0.00 [11] 0.00 [12] 0.00 [13] 0.00 [14] 0.00 [15] 0.00 [16] 0.00 [17] 0.00 [18] 0.00 )
# beta+: 7.95
# beta-: 0.00
# 거래 내역:
# 발전기 1가 발전기 0에게 0.69 전력을 줌
# 발전기 1가 발전기 3에게 0.61 전력을 줌
# 발전기 1가 발전기 4에게 2.41 전력을 줌
# 발전기 1가 발전기 5에게 2.19 전력을 줌
# 발전기 6가 발전기 9에게 2.90 전력을 줌
# 발전기 6가 발전기 10에게 2.19 전력을 줌
# 발전기 8가 발전기 11에게 2.90 전력을 줌
# 발전기 8가 발전기 16에게 2.13 전력을 줌
# 발전기 13가 발전기 17에게 0.69 전력을 줌
# 발전기 13가 발전기 18에게 2.90 전력을 줌
# 발전기 15가 발전기 5에게 0.71 전력을 줌
# 발전기 15가 발전기 10에게 0.71 전력을 줌
# 발전기 15가 발전기 16에게 0.77 전력을 줌
#
# [t=14 s=9]
# alpha: 55.12
# x 합계: 55.12 ([0] 2.90 [1] 2.90 [2] 2.90 [3] 2.90 [4] 2.90 [5] 2.90 [6] 2.90 [7] 2.90 [8] 2.90 [9] 2.90 [10] 2.90 [11] 2.90 [12] 2.90 [13] 2.90 [14] 2.90 [15] 2.90 [16] 2.90 [17] 2.90 [18] 2.90 )
# y+ 합계: 22.90 ([0] 0.00 [1] 4.33 [2] 1.40 [3] 0.52 [4] 0.00 [5] 0.00 [6] 4.34 [7] 1.20 [8] 0.00 [9] 2.06 [10] 0.00 [11] 0.00 [12] 0.00 [13] 0.00 [14] 0.00 [15] 2.65 [16] 0.00 [17] 3.35 [18] 3.04 )
# y- 합계: 22.90 ([0] 2.90 [1] 0.00 [2] 0.00 [3] 0.00 [4] 1.62 [5] 2.90 [6] 0.00 [7] 0.00 [8] 2.90 [9] 0.00 [10] 2.90 [11] 2.90 [12] 0.12 [13] 2.90 [14] 0.85 [15] 0.00 [16] 2.90 [17] 0.00 [18] 0.00 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 [10] 0.00 [11] 0.00 [12] 0.00 [13] 0.00 [14] 0.00 [15] 0.00 [16] 0.00 [17] 0.00 [18] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 [10] 0.00 [11] 0.00 [12] 0.00 [13] 0.00 [14] 0.00 [15] 0.00 [16] 0.00 [17] 0.00 [18] 0.00 )
# beta+: 0.00
# beta-: 0.00
# 거래 내역:
# 발전기 1가 발전기 0에게 2.90 전력을 줌
# 발전기 1가 발전기 4에게 1.43 전력을 줌
# 발전기 2가 발전기 5에게 1.40 전력을 줌
# 발전기 3가 발전기 5에게 0.52 전력을 줌
# 발전기 6가 발전기 8에게 2.90 전력을 줌
# 발전기 6가 발전기 10에게 1.44 전력을 줌
# 발전기 7가 발전기 4에게 0.19 전력을 줌
# 발전기 7가 발전기 5에게 0.98 전력을 줌
# 발전기 7가 발전기 16에게 0.03 전력을 줌
# 발전기 9가 발전기 11에게 2.06 전력을 줌
# 발전기 15가 발전기 12에게 0.12 전력을 줌
# 발전기 15가 발전기 13에게 2.53 전력을 줌
# 발전기 17가 발전기 14에게 0.85 전력을 줌
# 발전기 17가 발전기 16에게 2.50 전력을 줌
# 발전기 18가 발전기 10에게 1.46 전력을 줌
# 발전기 18가 발전기 11에게 0.84 전력을 줌
# 발전기 18가 발전기 13에게 0.37 전력을 줌
# 발전기 18가 발전기 16에게 0.37 전력을 줌

# %%
# Day-ahead 수익 비교
total_da_profit_obj = 0
for i in range(I):
    for t in range(T):
        total_da_profit_obj += P_DA[t] * x[i,t].x

# Real-time 수익 비교
total_rt_profit_obj = 0
for i in range(I):
    for t in range(T):
        for s in range(S):
            rt_profit_obj = P_RT[t, s] * e_plus[i, t, s].x
            total_rt_profit_obj += 1/S * rt_profit_obj

# 패널티 비용 비교
total_penalty_cost_obj = 0
for i in range(I):
    for t in range(T):
        for s in range(S):
            penalty_cost_obj = P_PN[t] * e_minus[i, t, s].x
            total_penalty_cost_obj += 1/S * penalty_cost_obj

# 총 시스템 이익 (목적 함수 기반)
total_system_profit_obj = total_da_profit_obj + total_rt_profit_obj - total_penalty_cost_obj

# 결과 출력
print(f"총 Day-ahead 수익 (_obj): {total_da_profit_obj:.2f}")
print(f"총 Real-time 수익 (_obj): {total_rt_profit_obj:.2f}")
print(f"총 Penalty 비용 (_obj): {total_penalty_cost_obj:.2f}")
print(f"목적 함수 기반 총 이익 (_obj): {total_system_profit_obj:.2f}")
# Out:
# 총 Day-ahead 수익 (_obj): 13898.50
# 총 Real-time 수익 (_obj): 2420.42
# 총 Penalty 비용 (_obj): 400.82
# 목적 함수 기반 총 이익 (_obj): 15918.10

# %%
# 모든 der의 profit 합계 계산
total_der_profit = 0
der_profit = {}
for i in range(I):
    # 각 der i의 profit 합계 계산
    der_profit[i] = sum(P_DA[t] * x[i,t].x + sum(1/S * (P_RT[t,s] * e_plus[i,t,s].x - P_PN[t] * e_minus[i,t,s].x) for s in range(S)) for t in range(T))
    total_der_profit += der_profit[i]

print("\nder_profit:")
for i in range(I):
    print(f"{[i]} {der_profit[i]:.2f}")

print(f"\n모든 der의 profit 합계: {total_der_profit:.2f}")
# Out:
# der_profit:
# [0] 884.65
# [1] 862.93
# [2] 853.65
# [3] 875.97
# [4] 855.86
# [5] 776.35
# [6] 941.93
# [7] 997.49
# [8] 818.14
# [9] 868.92
# [10] 866.91
# [11] 707.93
# [12] 955.22
# [13] 929.98
# [14] 782.69
# [15] 746.55
# [16] 688.40
# [17] 744.88
# [18] 759.66
#
# 모든 der의 profit 합계: 15918.10
