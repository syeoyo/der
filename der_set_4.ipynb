# %% [markdown]
# ### data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import gurobipy as gp
from gurobipy import GRB

R_flat = pd.read_csv("result/result_R.csv")

I_len = R_flat["generator"].nunique()
T_len = R_flat["time"].nunique() 
S_len = R_flat["scenario"].nunique()

R = R_flat.pivot_table(
    values="value",
    index="generator",
    columns=["time", "scenario"]
).to_numpy()
R = R.reshape(I_len, T_len, S_len)

I, T, S = R.shape

price_q = pd.read_csv(
    "/Users/jangseohyun/Documents/workspace/symply/DER/DATA_price.csv"
)
price_q["Time"] = pd.to_datetime(price_q["Time"], format="%Y-%m-%d %H:%M")

price_q["Hour"] = price_q["Time"].dt.floor("h")
price_h = price_q.groupby("Hour").mean(numeric_only=True)

price = price_h.iloc[: S * T]

P_DA = np.array(
    [sum(price["Price"].iloc[t + s * T] for s in range(S)) / S * 1.2 for t in range(T)]
)
P_RT = np.array([[price["Price"].iloc[t + s * T] for s in range(S)] for t in range(T)])
P_PN = np.array(
    [sum(price["Price"].iloc[t + s * T] for s in range(S)) / S * 2 for t in range(T)]
)

only_profit = pd.read_csv('result/result_only_profit.csv').values

# %% [markdown]
# ### settlement model

# %%
def my_callback(model, where):
    if where == GRB.Callback.MIP:
        obj_best = model.cbGet(GRB.Callback.MIP_OBJBST)
        obj_bound = model.cbGet(GRB.Callback.MIP_OBJBND)

        # MIP Gap 계산
        if obj_best != 0:  # obj_best가 0이 아닌 경우에만 계산
            mip_gap = abs(obj_best - obj_bound) / abs(obj_best)
        else:
            mip_gap = float("inf")  # obj_best가 0인 경우 무한대로 설정

        print(f"obj_best: {obj_best}, obj_bound: {obj_bound}, MIP Gap: {mip_gap:.4f}")


set = gp.Model("Settlement")
# set.Params.OutputFlag = 0
# set.setParam('TimeLimit', 600)
# set.setParam('Presolve', 0)
# set.setParam("PoolSolutions", 15)
# set.setParam("PoolSearchMode", 2)
# set.setParam("PoolGap", 0.05)
# set.setParam("MIPGap", 1e-3)

x = set.addVars(I, T, vtype=GRB.CONTINUOUS, lb=0, name="x")
y_plus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="y_plus")
y_minus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="y_minus")
M_y = max(R[i, t, s] for i in range(I) for t in range(T) for s in range(S))
z_y = set.addVars(I, T, S, vtype=GRB.BINARY, name="z_y")

d = set.addVars(I, I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="d")
d_max_H = set.addVars(T, S, vtype=GRB.CONTINUOUS, name="d_max_H")
# d_min_H = set.addVars(T, S, vtype=GRB.CONTINUOUS, name="d_min_H")

e_plus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="e_plus")
e_minus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="e_minus")
M_e = max(sum(R[i, t, s] for i in range(I)) for t in range(T) for s in range(S))
z_e = set.addVars(T, S, vtype=GRB.BINARY, name="z_e")

profit_increase = set.addVars(I, vtype=GRB.CONTINUOUS, lb=0, name="profit_increase")

set.update()

# obj. func.
obj = gp.quicksum(
    P_DA[t] * x[i, t] for i in range(I) for t in range(T)
) + gp.quicksum(
    1/S * (P_RT[t, s] * e_plus[i, t, s] - P_PN[t] * e_minus[i, t, s])
    for i in range(I) for t in range(T) for s in range(S)
)

set.setObjective(obj, GRB.MAXIMIZE)

# %%
# x로 y+, y- 결정 지어주기
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(R[i, t, s] - x[i, t] == y_plus[i, t, s] - y_minus[i, t, s])

# y+, y- 둘 중 하나는 0이어야함
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(y_plus[i, t, s] <= M_y * z_y[i, t, s])
            set.addConstr(y_minus[i, t, s] <= M_y * (1 - z_y[i, t, s]))

# rt 조건
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(y_plus[i, t, s] <= R[i, t, s])

# sum e+, sum e- 결정 지어주기
for t in range(T):
    for s in range(S):
        set.addConstr(
            gp.quicksum(R[i, t, s] for i in range(I))
            - gp.quicksum(x[i, t] for i in range(I))
            == gp.quicksum(e_plus[i, t, s] for i in range(I))
            - gp.quicksum(e_minus[i, t, s] for i in range(I))
        )

# sum e+, sum e- 둘 중 하나는 0이어야 함
for t in range(T):
    for s in range(S):
        set.addConstr(gp.quicksum(e_plus[i, t, s] for i in range(I)) <= M_e * z_e[t, s])
        set.addConstr(
            gp.quicksum(e_minus[i, t, s] for i in range(I)) <= M_e * (1 - z_e[t, s])
        )

# e+, e- 정의
for i in range(I):
    for t in range(T):
        for s in range(S):
            # e_plus: 초과량에서 준 양을 뺀 것
            set.addConstr(
                e_plus[i, t, s]
                == y_plus[i, t, s]
                - gp.quicksum(d[i, j, t, s] for j in range(I) if j != i)
            )
            # e_minus: 부족량에서 받은 양을 뺀 것
            set.addConstr(
                e_minus[i, t, s]
                == y_minus[i, t, s]
                - gp.quicksum(d[j, i, t, s] for j in range(I) if j != i)
            )

# sum e+ <= sum R
for t in range(T):
    for s in range(S):
        set.addConstr(
            gp.quicksum(e_plus[i, t, s] for i in range(I))
            <= gp.quicksum(R[i, t, s] for i in range(I))
        )

# 전력 이동 제한
for i in range(I):
    for t in range(T):
        for s in range(S):
            # 본인이 주는 양은 자신의 y+을 넘을 수 없음
            set.addConstr(
                gp.quicksum(d[i, j, t, s] for j in range(I) if j != i)
                <= y_plus[i, t, s]
            )
            # 본인이 받는 양은 자신의 y-을 넘을 수 없음
            set.addConstr(
                gp.quicksum(d[j, i, t, s] for j in range(I) if j != i)
                <= y_minus[i, t, s]
            )

# 자기 자신과의 거래 방지
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(d[i, i, t, s] == 0)

# # 수익증가율 정의
# for i in range(I):
#     set.addConstr(profit_increase[i] == (
#         gp.quicksum(
#             P_DA[t] * x[i, t]
#             + 1 / S * gp.quicksum(P_RT[t, s] * e_plus[i, t, s] - P_PN[t] * e_minus[i, t, s] for s in range(S))
#             for t in range(T)
#         ) - only_profit[i].item()
#     ) / only_profit[i].item())

# # 수익증가율이 사람마다 같아야함
# for i in range(I):
#     set.addConstr(
#         profit_increase[i] == gp.quicksum(profit_increase[j] for j in range(I)) / I
#     )
    
# d_max_H 정의
for t in range(T):
    for s in range(S):
        for i in range(I):
                set.addConstr(
                    d_max_H[t, s] >= gp.quicksum(d[i, j, t, s] for j in range(I) if j != i)
            )

# d_max 제한
for t in range(T):
    for s in range(S):
        set.addConstr(
            d_max_H[t, s] <= 0.5 * gp.quicksum(y_plus[i, t, s] for i in range(I))
        )


# # d_min 정의
# for t in range(T):
#     for s in range(S):
#         for i in range(I):
#             set.addGenConstrIndicator(
#                 z_y[i, t, s],
#                 1,
#                 d_min_H[t, s] <= gp.quicksum(d[i, j, t, s] for j in range(I) if j != i)
#             )

# # 시간별 거래량 차이를 제한
# for t in range(T):
#     for s in range(S):
#         set.addConstr(
#             d_max_H[t, s] - d_min_H[t, s] <= 10
#         )

# %%
set.optimize()

if set.status == GRB.OPTIMAL:
    x_vals = np.array([[x[i, t].x for t in range(T)] for i in range(I)])
    y_plus_vals = np.array(
        [[[y_plus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    y_minus_vals = np.array(
        [[[y_minus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    d_vals = np.array(
        [
            [[[d[i, j, t, s].x for s in range(S)] for t in range(T)] for j in range(I)]
            for i in range(I)
        ]
    )
    d_max_H_vals = np.array([[[d_max_H[t, s].x for s in range(S)] for t in range(T)] for i in range(I)])
    # d_min_H_vals = np.array([[[d_min_H[t, s].x for s in range(S)] for t in range(T)] for i in range(I)])
    e_plus_vals = np.array(
        [[[e_plus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    e_minus_vals = np.array(
        [[[e_minus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    z_y_vals = np.array(
        [[[z_y[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    z_e_vals = np.array([[z_e[t, s].x for s in range(S)] for t in range(T)])
    profit_increase_vals = np.array([[profit_increase[i].x for i in range(I)]])
    print("\n- - - - - - - - - - - - - - - - - - - - - - - -")
    print("Optimal solution found!")
    print(set.objVal)
else:
    print("\nNo optimal solution found.")
# Out:
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.3.0 24D70)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 50400 rows, 73210 columns and 327840 nonzeros
# Model fingerprint: 0x2c3a1dda
# Variable types: 67930 continuous, 5280 integer (5280 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 9e+01]
#   Objective range  [4e-04, 4e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-02, 9e+01]
# Presolve removed 49483 rows and 71050 columns
# Presolve time: 0.65s
# Presolved: 917 rows, 2160 columns, 7280 nonzeros
# Variable types: 1981 continuous, 179 integer (179 binary)
#
# Root relaxation: objective 1.191030e+04, 802 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 11910.2972    0   20          - 11910.2972      -     -    0s
# H    0     0                    11856.565941 11910.2972  0.45%     -    0s
# H    0     0                    11875.852238 11910.2972  0.29%     -    0s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 42
#   Implied bound: 16
#   Clique: 8
#   MIR: 36
#   Flow cover: 94
#   Flow path: 5
#   RLT: 48
#   Relax-and-lift: 15
#   PSD: 4
#
# Explored 1 nodes (1094 simplex iterations) in 0.73 seconds (1.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 11875.9 11856.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.187585223752e+04, best bound 1.187619994685e+04, gap 0.0029%
#
# - - - - - - - - - - - - - - - - - - - - - - - -
# Optimal solution found!
# 11875.85223752153

# %%
if set.SolCount > 0:
    print(f"Best objective found: {set.ObjVal}")
    for v in set.getVars():
        print(f"{v.VarName} = {v.X}")
else:
    print("No feasible solution found.")
# Out:
# Best objective found: 11875.85223752153
# x[0,0] = 0.0
# x[0,1] = 0.0
# x[0,2] = 0.0
# x[0,3] = 0.0
# x[0,4] = 0.0
# x[0,5] = 0.0
# x[0,6] = 0.0
# x[0,7] = 0.0
# x[0,8] = 0.0
# x[0,9] = 0.0
# x[0,10] = 3.890357437238184
# x[0,11] = 1.2928059861450052
# x[0,12] = 1.4032075686147216
# x[0,13] = 4.1841474923499415
# x[0,14] = 0.9249543163117776
# x[0,15] = 10.043085438966079
# x[0,16] = 0.4067704609004643
# x[0,17] = 0.0692330012461672
# x[0,18] = 0.0
# x[0,19] = 0.0
# x[0,20] = 0.0
# x[0,21] = 0.0
# x[0,22] = 0.0
# x[0,23] = 0.0
# x[1,0] = 0.0
# x[1,1] = 0.0
# x[1,2] = 0.0
# x[1,3] = 0.0
# x[1,4] = 0.0
# x[1,5] = 0.0
# x[1,6] = 0.0
# x[1,7] = 0.0
# x[1,8] = 0.0
# x[1,9] = 0.0
# x[1,10] = 3.5907231407575786
# x[1,11] = 0.4959473357874331
# x[1,12] = 4.617940711267469
# x[1,13] = 8.20429347709188
# x[1,14] = 2.8936295086383392
# x[1,15] = 0.0
# x[1,16] = 0.9471244937063892
# x[1,17] = 0.0
# x[1,18] = 0.0
# x[1,19] = 0.0
# x[1,20] = 0.0
# x[1,21] = 0.0
# x[1,22] = 0.0
# x[1,23] = 0.0
# x[2,0] = 0.0
# x[2,1] = 0.0
# x[2,2] = 0.0
# x[2,3] = 0.0
# x[2,4] = 0.0
# x[2,5] = 0.0
# x[2,6] = 0.0
# x[2,7] = 0.0
# x[2,8] = 0.0
# x[2,9] = 0.1303867085711605
# x[2,10] = 1.48130459905989
# x[2,11] = 15.345927420024093
# x[2,12] = 4.3854600252136935
# x[2,13] = 6.225980881657101
# x[2,14] = 5.670012548583053
# x[2,15] = 3.833671575455824
# x[2,16] = 0.0
# x[2,17] = 0.0
# x[2,18] = 0.0
# x[2,19] = 0.0
# x[2,20] = 0.0
# x[2,21] = 0.0
# x[2,22] = 0.0
# x[2,23] = 0.0
# x[3,0] = 0.0
# x[3,1] = 0.0
# x[3,2] = 0.0
# x[3,3] = 0.0
# x[3,4] = 0.0
# x[3,5] = 0.0
# x[3,6] = 0.0
# x[3,7] = 0.0
# x[3,8] = 0.0
# x[3,9] = 5.6331714923988905
# x[3,10] = 2.075406209325873
# x[3,11] = 0.0
# x[3,12] = 6.298415584365756
# x[3,13] = 0.6101806704690942
# x[3,14] = 4.5442714360194945
# x[3,15] = 1.2353472213293628
# x[3,16] = 5.961407064525245
# x[3,17] = 0.0
# x[3,18] = 0.0
# x[3,19] = 0.0
# x[3,20] = 0.0
# x[3,21] = 0.0
# x[3,22] = 0.0
# x[3,23] = 0.0
# x[4,0] = 0.0
# x[4,1] = 0.0
# x[4,2] = 0.0
# x[4,3] = 0.0
# x[4,4] = 0.0
# x[4,5] = 0.0
# x[4,6] = 0.0
# x[4,7] = 0.0
# x[4,8] = 0.0
# x[4,9] = 0.23851585979609
# x[4,10] = 3.1198672959852427
# x[4,11] = 6.501034723246903
# x[4,12] = 5.379848574737768
# x[4,13] = 5.865626818376686
# x[4,14] = 4.867546287552169
# x[4,15] = 0.13485618436715896
# x[4,16] = 3.5857488054633246
# x[4,17] = 0.0
# x[4,18] = 0.0
# x[4,19] = 0.0
# x[4,20] = 0.0
# x[4,21] = 0.0
# x[4,22] = 0.0
# x[4,23] = 0.0
# x[5,0] = 0.0
# x[5,1] = 0.0
# x[5,2] = 0.0
# x[5,3] = 0.0
# x[5,4] = 0.0
# x[5,5] = 0.0
# x[5,6] = 0.0
# x[5,7] = 0.0
# x[5,8] = 0.0
# x[5,9] = 0.0
# x[5,10] = 1.4959602194934227
# x[5,11] = 0.0
# x[5,12] = 4.635061311137399
# x[5,13] = 3.3521925417561778
# x[5,14] = 2.9550587962037866
# x[5,15] = 3.632860334469912
# x[5,16] = 0.0
# x[5,17] = 0.0
# x[5,18] = 0.0
# x[5,19] = 0.0
# x[5,20] = 0.0
# x[5,21] = 0.0
# x[5,22] = 0.0
# x[5,23] = 0.0
# x[6,0] = 0.0
# x[6,1] = 0.0
# x[6,2] = 0.0
# x[6,3] = 0.0
# x[6,4] = 0.0
# x[6,5] = 0.0
# x[6,6] = 0.0
# x[6,7] = 0.0
# x[6,8] = 0.2163210444655896
# x[6,9] = 0.0
# x[6,10] = 2.7408833457722404
# x[6,11] = 2.5940086874695183
# x[6,12] = 0.7617954802292326
# x[6,13] = 4.12329611209222
# x[6,14] = 7.9502937081191885
# x[6,15] = 4.264417422977611
# x[6,16] = 0.0
# x[6,17] = 0.0
# x[6,18] = 0.0
# x[6,19] = 0.0
# x[6,20] = 0.0
# x[6,21] = 0.0
# x[6,22] = 0.0
# x[6,23] = 0.0
# x[7,0] = 0.0
# x[7,1] = 0.0
# x[7,2] = 0.0
# x[7,3] = 0.0
# x[7,4] = 0.0
# x[7,5] = 0.0
# x[7,6] = 0.0
# x[7,7] = 0.0
# x[7,8] = 0.05947798171522004
# x[7,9] = 0.7434480797432899
# x[7,10] = 1.995426217740762
# x[7,11] = 2.255461417738225
# x[7,12] = 4.111678167818262
# x[7,13] = 3.7642295042535387
# x[7,14] = 0.8812133501017385
# x[7,15] = 0.746406557322552
# x[7,16] = 0.0
# x[7,17] = 0.2603671815614602
# x[7,18] = 0.0
# x[7,19] = 0.0
# x[7,20] = 0.0
# x[7,21] = 0.0
# x[7,22] = 0.0
# x[7,23] = 0.0
# x[8,0] = 0.0
# x[8,1] = 0.0
# x[8,2] = 0.0
# x[8,3] = 0.0
# x[8,4] = 0.0
# x[8,5] = 0.0
# x[8,6] = 0.0
# x[8,7] = 0.0
# x[8,8] = 0.2647715035224375
# x[8,9] = 0.9688897138794236
# x[8,10] = 3.4334421345192307
# x[8,11] = 0.0
# x[8,12] = 4.465473710048651
# x[8,13] = 2.3923465997099393
# x[8,14] = 1.0015125591133387
# x[8,15] = 0.4997349688809862
# x[8,16] = 0.13744163730432168
# x[8,17] = 0.42784413718795716
# x[8,18] = 0.0
# x[8,19] = 0.0
# x[8,20] = 0.0
# x[8,21] = 0.0
# x[8,22] = 0.0
# x[8,23] = 0.0
# x[9,0] = 0.0
# x[9,1] = 0.0
# x[9,2] = 0.0
# x[9,3] = 0.0
# x[9,4] = 0.0
# x[9,5] = 0.0
# x[9,6] = 0.0
# x[9,7] = 0.0
# x[9,8] = 0.0
# x[9,9] = 0.0
# x[9,10] = 0.4064972368102371
# x[9,11] = 0.0
# x[9,12] = 2.873165856071262
# x[9,13] = 0.3176309273322566
# x[9,14] = 3.1903418473965
# x[9,15] = 1.3614157270871168
# x[9,16] = 0.0
# x[9,17] = 0.0
# x[9,18] = 0.0
# x[9,19] = 0.0
# x[9,20] = 0.0
# x[9,21] = 0.0
# x[9,22] = 0.0
# x[9,23] = 0.0
# y_plus[0,0,0] = 0.0
# y_plus[0,0,1] = 0.0
# y_plus[0,0,2] = 0.0
# y_plus[0,0,3] = 0.0
# y_plus[0,0,4] = 0.0
# y_plus[0,0,5] = 0.0
# y_plus[0,0,6] = 0.0
# y_plus[0,0,7] = 0.0
# y_plus[0,0,8] = 0.0
# y_plus[0,0,9] = 0.0
# y_plus[0,0,10] = 0.0
# y_plus[0,0,11] = 0.0
# y_plus[0,0,12] = 0.0
# y_plus[0,0,13] = 0.0
# y_plus[0,0,14] = 0.0
# y_plus[0,0,15] = 0.0
# y_plus[0,0,16] = 0.0
# y_plus[0,0,17] = 0.0
# y_plus[0,0,18] = 0.0
# y_plus[0,0,19] = 0.0
# y_plus[0,1,0] = 0.0
# y_plus[0,1,1] = 0.0
# y_plus[0,1,2] = 0.0
# y_plus[0,1,3] = 0.0
# y_plus[0,1,4] = 0.0
# y_plus[0,1,5] = 0.0
# y_plus[0,1,6] = 0.0
# y_plus[0,1,7] = 0.0
# y_plus[0,1,8] = 0.0
# y_plus[0,1,9] = 0.0
# y_plus[0,1,10] = 0.0
# y_plus[0,1,11] = 0.0
# y_plus[0,1,12] = 0.0
# y_plus[0,1,13] = 0.0
# y_plus[0,1,14] = 0.0
# y_plus[0,1,15] = 0.0
# y_plus[0,1,16] = 0.0
# y_plus[0,1,17] = 0.0
# y_plus[0,1,18] = 0.0
# y_plus[0,1,19] = 0.0
# y_plus[0,2,0] = 0.0
# y_plus[0,2,1] = 0.0
# y_plus[0,2,2] = 0.0
# y_plus[0,2,3] = 0.0
# y_plus[0,2,4] = 0.0
# y_plus[0,2,5] = 0.0
# y_plus[0,2,6] = 0.0
# y_plus[0,2,7] = 0.0
# y_plus[0,2,8] = 0.0
# y_plus[0,2,9] = 0.0
# y_plus[0,2,10] = 0.0
# y_plus[0,2,11] = 0.0
# y_plus[0,2,12] = 0.0
# y_plus[0,2,13] = 0.0
# y_plus[0,2,14] = 0.0
# y_plus[0,2,15] = 0.0
# y_plus[0,2,16] = 0.0
# y_plus[0,2,17] = 0.0
# y_plus[0,2,18] = 0.0
# y_plus[0,2,19] = 0.0
# y_plus[0,3,0] = 0.0
# y_plus[0,3,1] = 0.0
# y_plus[0,3,2] = 0.0
# y_plus[0,3,3] = 0.0
# y_plus[0,3,4] = 0.0
# y_plus[0,3,5] = 0.0
# y_plus[0,3,6] = 0.0
# y_plus[0,3,7] = 0.0
# y_plus[0,3,8] = 0.0
# y_plus[0,3,9] = 0.0
# y_plus[0,3,10] = 0.0
# y_plus[0,3,11] = 0.0
# y_plus[0,3,12] = 0.0
# y_plus[0,3,13] = 0.0
# y_plus[0,3,14] = 0.0
# y_plus[0,3,15] = 0.0
# y_plus[0,3,16] = 0.0
# y_plus[0,3,17] = 0.0
# y_plus[0,3,18] = 0.0
# y_plus[0,3,19] = 0.0
# y_plus[0,4,0] = 0.0
# y_plus[0,4,1] = 0.0
# y_plus[0,4,2] = 0.0
# y_plus[0,4,3] = 0.0
# y_plus[0,4,4] = 0.0
# y_plus[0,4,5] = 0.0
# y_plus[0,4,6] = 0.0
# y_plus[0,4,7] = 0.0
# y_plus[0,4,8] = 0.0
# y_plus[0,4,9] = 0.0
# y_plus[0,4,10] = 0.0
# y_plus[0,4,11] = 0.0
# y_plus[0,4,12] = 0.0
# y_plus[0,4,13] = 0.0
# y_plus[0,4,14] = 0.0
# y_plus[0,4,15] = 0.0
# y_plus[0,4,16] = 0.0
# y_plus[0,4,17] = 0.0
# y_plus[0,4,18] = 0.0
# y_plus[0,4,19] = 0.0
# y_plus[0,5,0] = 0.0
# y_plus[0,5,1] = 0.0
# y_plus[0,5,2] = 0.0
# y_plus[0,5,3] = 0.0
# y_plus[0,5,4] = 0.0
# y_plus[0,5,5] = 0.0
# y_plus[0,5,6] = 0.0
# y_plus[0,5,7] = 0.0
# y_plus[0,5,8] = 0.0
# y_plus[0,5,9] = 0.0
# y_plus[0,5,10] = 0.0
# y_plus[0,5,11] = 0.0
# y_plus[0,5,12] = 0.0
# y_plus[0,5,13] = 0.0
# y_plus[0,5,14] = 0.0
# y_plus[0,5,15] = 0.0
# y_plus[0,5,16] = 0.0
# y_plus[0,5,17] = 0.0
# y_plus[0,5,18] = 0.0
# y_plus[0,5,19] = 0.0
# y_plus[0,6,0] = 0.0
# y_plus[0,6,1] = 0.0
# y_plus[0,6,2] = 0.0
# y_plus[0,6,3] = 0.0
# y_plus[0,6,4] = 0.0
# y_plus[0,6,5] = 0.0
# y_plus[0,6,6] = 0.0
# y_plus[0,6,7] = 0.0
# y_plus[0,6,8] = 0.0
# y_plus[0,6,9] = 0.0
# y_plus[0,6,10] = 0.0
# y_plus[0,6,11] = 0.0
# y_plus[0,6,12] = 0.0
# y_plus[0,6,13] = 0.0
# y_plus[0,6,14] = 0.0
# y_plus[0,6,15] = 0.0
# y_plus[0,6,16] = 0.0
# y_plus[0,6,17] = 0.0
# y_plus[0,6,18] = 0.0
# y_plus[0,6,19] = 0.0
# y_plus[0,7,0] = 0.0
# y_plus[0,7,1] = 0.0
# y_plus[0,7,2] = 0.0
# y_plus[0,7,3] = 0.0
# y_plus[0,7,4] = 0.0
# y_plus[0,7,5] = 0.0
# y_plus[0,7,6] = 0.0
# y_plus[0,7,7] = 0.0
# y_plus[0,7,8] = 0.0
# y_plus[0,7,9] = 0.0
# y_plus[0,7,10] = 0.0
# y_plus[0,7,11] = 0.0
# y_plus[0,7,12] = 0.0
# y_plus[0,7,13] = 0.0
# y_plus[0,7,14] = 0.0
# y_plus[0,7,15] = 0.0
# y_plus[0,7,16] = 0.0
# y_plus[0,7,17] = 0.0
# y_plus[0,7,18] = 0.0
# y_plus[0,7,19] = 0.0
# y_plus[0,8,0] = 0.0
# y_plus[0,8,1] = 0.0
# y_plus[0,8,2] = 1.1813836975634358
# y_plus[0,8,3] = 0.0
# y_plus[0,8,4] = 1.9731073197620852
# y_plus[0,8,5] = 0.0
# y_plus[0,8,6] = 0.0
# y_plus[0,8,7] = 0.0
# y_plus[0,8,8] = 0.0
# y_plus[0,8,9] = 0.5673287305014656
# y_plus[0,8,10] = 0.0
# y_plus[0,8,11] = 0.0
# y_plus[0,8,12] = 2.546958937725041
# y_plus[0,8,13] = 0.0
# y_plus[0,8,14] = 0.112528341876561
# y_plus[0,8,15] = 0.0
# y_plus[0,8,16] = 0.0469410310912459
# y_plus[0,8,17] = 0.0
# y_plus[0,8,18] = 0.0
# y_plus[0,8,19] = 1.3117954036251025
# y_plus[0,9,0] = 3.188986342625233
# y_plus[0,9,1] = 0.3557763820283086
# y_plus[0,9,2] = 6.119115775637996
# y_plus[0,9,3] = 1.8377931114668993
# y_plus[0,9,4] = 0.0
# y_plus[0,9,5] = 3.57180431124333
# y_plus[0,9,6] = 0.8151828877052179
# y_plus[0,9,7] = 0.194030966780156
# y_plus[0,9,8] = 7.527804012923143
# y_plus[0,9,9] = 6.916109915466219
# y_plus[0,9,10] = 0.0
# y_plus[0,9,11] = 0.713351216249904
# y_plus[0,9,12] = 1.6680027733958465
# y_plus[0,9,13] = 0.7985550544118132
# y_plus[0,9,14] = 1.7094916295909366
# y_plus[0,9,15] = 0.1738820077880944
# y_plus[0,9,16] = 4.996296279005327
# y_plus[0,9,17] = 0.3786082299940405
# y_plus[0,9,18] = 1.166807251071596
# y_plus[0,9,19] = 3.006455518102753
# y_plus[0,10,0] = 4.090341689809214
# y_plus[0,10,1] = 0.0
# y_plus[0,10,2] = 0.8290098433855215
# y_plus[0,10,3] = 10.170365966068285
# y_plus[0,10,4] = 0.0
# y_plus[0,10,5] = 0.0
# y_plus[0,10,6] = 0.0
# y_plus[0,10,7] = 2.0280762492022992
# y_plus[0,10,8] = 0.0
# y_plus[0,10,9] = 0.0
# y_plus[0,10,10] = 8.7668981109415
# y_plus[0,10,11] = 9.38763283141003
# y_plus[0,10,12] = 0.0
# y_plus[0,10,13] = 1.756538247552597
# y_plus[0,10,14] = 0.0
# y_plus[0,10,15] = 10.398957374097584
# y_plus[0,10,16] = 5.479796046894125
# y_plus[0,10,17] = 4.468799721188021
# y_plus[0,10,18] = 1.6749896361954466
# y_plus[0,10,19] = 0.0
# y_plus[0,11,0] = 4.866286985201057
# y_plus[0,11,1] = 0.0
# y_plus[0,11,2] = 4.020782979668823
# y_plus[0,11,3] = 1.3027101291954502
# y_plus[0,11,4] = 10.992180984513283
# y_plus[0,11,5] = 1.019169777779135
# y_plus[0,11,6] = 6.593908521342069
# y_plus[0,11,7] = 0.0
# y_plus[0,11,8] = 10.806509485424339
# y_plus[0,11,9] = 7.886145773345978
# y_plus[0,11,10] = 9.594921505500917
# y_plus[0,11,11] = 1.2199557648734753
# y_plus[0,11,12] = 10.977979416373831
# y_plus[0,11,13] = 0.0
# y_plus[0,11,14] = 6.926924241048223
# y_plus[0,11,15] = 8.61643038239625
# y_plus[0,11,16] = 2.215733308646552
# y_plus[0,11,17] = 3.1003458499584546
# y_plus[0,11,18] = 7.58645781053858
# y_plus[0,11,19] = 0.25595125904232496
# y_plus[0,12,0] = 10.195315518064302
# y_plus[0,12,1] = 0.0
# y_plus[0,12,2] = 10.634564151435502
# y_plus[0,12,3] = 12.631076851089336
# y_plus[0,12,4] = 0.0
# y_plus[0,12,5] = 9.799571360705228
# y_plus[0,12,6] = 0.0
# y_plus[0,12,7] = 8.492613049701017
# y_plus[0,12,8] = 9.90585979452558
# y_plus[0,12,9] = 4.580147318461739
# y_plus[0,12,10] = 11.878598733438604
# y_plus[0,12,11] = 0.0
# y_plus[0,12,12] = 6.5349681406002205
# y_plus[0,12,13] = 0.0
# y_plus[0,12,14] = 0.0
# y_plus[0,12,15] = 13.525622064870763
# y_plus[0,12,16] = 5.919371075440273
# y_plus[0,12,17] = 11.960000175557042
# y_plus[0,12,18] = 3.6229461074516234
# y_plus[0,12,19] = 0.0
# y_plus[0,13,0] = 9.180141966531632
# y_plus[0,13,1] = 0.0
# y_plus[0,13,2] = 0.0
# y_plus[0,13,3] = 8.587348107356739
# y_plus[0,13,4] = 0.0
# y_plus[0,13,5] = 0.0
# y_plus[0,13,6] = 9.447670957660947
# y_plus[0,13,7] = 1.445121732077732
# y_plus[0,13,8] = 8.477948578274047
# y_plus[0,13,9] = 3.47755691353151
# y_plus[0,13,10] = 0.0
# y_plus[0,13,11] = 0.0
# y_plus[0,13,12] = 0.0
# y_plus[0,13,13] = 13.502279352412456
# y_plus[0,13,14] = 3.4811636075253656
# y_plus[0,13,15] = 0.0
# y_plus[0,13,16] = 0.0
# y_plus[0,13,17] = 5.940405575560581
# y_plus[0,13,18] = 0.0
# y_plus[0,13,19] = 6.745891657371103
# y_plus[0,14,0] = 2.4252097954643594
# y_plus[0,14,1] = 9.765749077601212
# y_plus[0,14,2] = 0.0
# y_plus[0,14,3] = 0.0
# y_plus[0,14,4] = 8.52271744450327
# y_plus[0,14,5] = 5.5262725994453445
# y_plus[0,14,6] = 5.406948991122218
# y_plus[0,14,7] = 5.235604329366576
# y_plus[0,14,8] = 0.0
# y_plus[0,14,9] = 0.0
# y_plus[0,14,10] = 0.0
# y_plus[0,14,11] = 0.8349257650747514
# y_plus[0,14,12] = 0.0
# y_plus[0,14,13] = 0.0
# y_plus[0,14,14] = 10.6845874010631
# y_plus[0,14,15] = 0.0
# y_plus[0,14,16] = 8.650855616143488
# y_plus[0,14,17] = 0.0
# y_plus[0,14,18] = 0.941820622869353
# y_plus[0,14,19] = 7.29561237895201
# y_plus[0,15,0] = 0.0
# y_plus[0,15,1] = 0.0
# y_plus[0,15,2] = 0.0
# y_plus[0,15,3] = 0.0
# y_plus[0,15,4] = 0.0
# y_plus[0,15,5] = 0.0
# y_plus[0,15,6] = 0.0
# y_plus[0,15,7] = 0.0
# y_plus[0,15,8] = 0.0
# y_plus[0,15,9] = 0.0
# y_plus[0,15,10] = 0.0
# y_plus[0,15,11] = 0.6392855689047318
# y_plus[0,15,12] = 3.167064870451055
# y_plus[0,15,13] = 1.9371021726405058
# y_plus[0,15,14] = 0.0
# y_plus[0,15,15] = 0.0
# y_plus[0,15,16] = 0.0
# y_plus[0,15,17] = 0.0
# y_plus[0,15,18] = 0.0
# y_plus[0,15,19] = 0.0
# y_plus[0,16,0] = 0.6042015946437651
# y_plus[0,16,1] = 0.0
# y_plus[0,16,2] = 0.0
# y_plus[0,16,3] = 0.20741477950952003
# y_plus[0,16,4] = 0.0
# y_plus[0,16,5] = 0.0
# y_plus[0,16,6] = 0.0
# y_plus[0,16,7] = 0.0
# y_plus[0,16,8] = 7.117119406690032
# y_plus[0,16,9] = 0.0
# y_plus[0,16,10] = 4.404921759358437
# y_plus[0,16,11] = 0.0
# y_plus[0,16,12] = 0.0
# y_plus[0,16,13] = 4.701923025381572
# y_plus[0,16,14] = 0.0
# y_plus[0,16,15] = 2.5136697110273785
# y_plus[0,16,16] = 0.0
# y_plus[0,16,17] = 0.0
# y_plus[0,16,18] = 0.0
# y_plus[0,16,19] = 2.7456658894655646
# y_plus[0,17,0] = 0.0
# y_plus[0,17,1] = 0.0
# y_plus[0,17,2] = 0.0
# y_plus[0,17,3] = 0.0
# y_plus[0,17,4] = 0.0
# y_plus[0,17,5] = 0.0
# y_plus[0,17,6] = 0.0
# y_plus[0,17,7] = 0.0
# y_plus[0,17,8] = 0.0
# y_plus[0,17,9] = 0.0
# y_plus[0,17,10] = 0.0
# y_plus[0,17,11] = 0.0
# y_plus[0,17,12] = 0.0
# y_plus[0,17,13] = 0.0
# y_plus[0,17,14] = 0.0
# y_plus[0,17,15] = 0.0
# y_plus[0,17,16] = 0.0
# y_plus[0,17,17] = 0.0
# y_plus[0,17,18] = 2.714306929356561
# y_plus[0,17,19] = 0.0
# y_plus[0,18,0] = 0.0
# y_plus[0,18,1] = 0.0
# y_plus[0,18,2] = 0.0
# y_plus[0,18,3] = 0.0
# y_plus[0,18,4] = 0.0
# y_plus[0,18,5] = 0.0
# y_plus[0,18,6] = 0.0
# y_plus[0,18,7] = 0.0
# y_plus[0,18,8] = 0.0
# y_plus[0,18,9] = 0.0
# y_plus[0,18,10] = 0.0
# y_plus[0,18,11] = 0.0
# y_plus[0,18,12] = 0.0
# y_plus[0,18,13] = 0.0
# y_plus[0,18,14] = 0.0
# y_plus[0,18,15] = 0.0
# y_plus[0,18,16] = 0.0
# y_plus[0,18,17] = 0.0
# y_plus[0,18,18] = 0.0
# y_plus[0,18,19] = 0.0
# y_plus[0,19,0] = 0.0
# y_plus[0,19,1] = 0.0
# y_plus[0,19,2] = 0.0
# y_plus[0,19,3] = 0.0
# y_plus[0,19,4] = 0.0
# y_plus[0,19,5] = 0.0
# y_plus[0,19,6] = 0.0
# y_plus[0,19,7] = 0.0
# y_plus[0,19,8] = 0.0
# y_plus[0,19,9] = 0.0
# y_plus[0,19,10] = 0.0
# y_plus[0,19,11] = 0.0
# y_plus[0,19,12] = 0.0
# y_plus[0,19,13] = 0.0
# y_plus[0,19,14] = 0.0
# y_plus[0,19,15] = 0.0
# y_plus[0,19,16] = 0.0
# y_plus[0,19,17] = 0.0
# y_plus[0,19,18] = 0.0
# y_plus[0,19,19] = 0.0
# y_plus[0,20,0] = 0.0
# y_plus[0,20,1] = 0.0
# y_plus[0,20,2] = 0.0
# y_plus[0,20,3] = 0.0
# y_plus[0,20,4] = 0.0
# y_plus[0,20,5] = 0.0
# y_plus[0,20,6] = 0.0
# y_plus[0,20,7] = 0.0
# y_plus[0,20,8] = 0.0
# y_plus[0,20,9] = 0.0
# y_plus[0,20,10] = 0.0
# y_plus[0,20,11] = 0.0
# y_plus[0,20,12] = 0.0
# y_plus[0,20,13] = 0.0
# y_plus[0,20,14] = 0.0
# y_plus[0,20,15] = 0.0
# y_plus[0,20,16] = 0.0
# y_plus[0,20,17] = 0.0
# y_plus[0,20,18] = 0.0
# y_plus[0,20,19] = 0.0
# y_plus[0,21,0] = 0.0
# y_plus[0,21,1] = 0.0
# y_plus[0,21,2] = 0.0
# y_plus[0,21,3] = 0.0
# y_plus[0,21,4] = 0.0
# y_plus[0,21,5] = 0.0
# y_plus[0,21,6] = 0.0
# y_plus[0,21,7] = 0.0
# y_plus[0,21,8] = 0.0
# y_plus[0,21,9] = 0.0
# y_plus[0,21,10] = 0.0
# y_plus[0,21,11] = 0.0
# y_plus[0,21,12] = 0.0
# y_plus[0,21,13] = 0.0
# y_plus[0,21,14] = 0.0
# y_plus[0,21,15] = 0.0
# y_plus[0,21,16] = 0.0
# y_plus[0,21,17] = 0.0
# y_plus[0,21,18] = 0.0
# y_plus[0,21,19] = 0.0
# y_plus[0,22,0] = 0.0
# y_plus[0,22,1] = 0.0
# y_plus[0,22,2] = 0.0
# y_plus[0,22,3] = 0.0
# y_plus[0,22,4] = 0.0
# y_plus[0,22,5] = 0.0
# y_plus[0,22,6] = 0.0
# y_plus[0,22,7] = 0.0
# y_plus[0,22,8] = 0.0
# y_plus[0,22,9] = 0.0
# y_plus[0,22,10] = 0.0
# y_plus[0,22,11] = 0.0
# y_plus[0,22,12] = 0.0
# y_plus[0,22,13] = 0.0
# y_plus[0,22,14] = 0.0
# y_plus[0,22,15] = 0.0
# y_plus[0,22,16] = 0.0
# y_plus[0,22,17] = 0.0
# y_plus[0,22,18] = 0.0
# y_plus[0,22,19] = 0.0
# y_plus[0,23,0] = 0.0
# y_plus[0,23,1] = 0.0
# y_plus[0,23,2] = 0.0
# y_plus[0,23,3] = 0.0
# y_plus[0,23,4] = 0.0
# y_plus[0,23,5] = 0.0
# y_plus[0,23,6] = 0.0
# y_plus[0,23,7] = 0.0
# y_plus[0,23,8] = 0.0
# y_plus[0,23,9] = 0.0
# y_plus[0,23,10] = 0.0
# y_plus[0,23,11] = 0.0
# y_plus[0,23,12] = 0.0
# y_plus[0,23,13] = 0.0
# y_plus[0,23,14] = 0.0
# y_plus[0,23,15] = 0.0
# y_plus[0,23,16] = 0.0
# y_plus[0,23,17] = 0.0
# y_plus[0,23,18] = 0.0
# y_plus[0,23,19] = 0.0
# y_plus[1,0,0] = 0.0
# y_plus[1,0,1] = 0.0
# y_plus[1,0,2] = 0.0
# y_plus[1,0,3] = 0.0
# y_plus[1,0,4] = 0.0
# y_plus[1,0,5] = 0.0
# y_plus[1,0,6] = 0.0
# y_plus[1,0,7] = 0.0
# y_plus[1,0,8] = 0.0
# y_plus[1,0,9] = 0.0
# y_plus[1,0,10] = 0.0
# y_plus[1,0,11] = 0.0
# y_plus[1,0,12] = 0.0
# y_plus[1,0,13] = 0.0
# y_plus[1,0,14] = 0.0
# y_plus[1,0,15] = 0.0
# y_plus[1,0,16] = 0.0
# y_plus[1,0,17] = 0.0
# y_plus[1,0,18] = 0.0
# y_plus[1,0,19] = 0.0
# y_plus[1,1,0] = 0.0
# y_plus[1,1,1] = 0.0
# y_plus[1,1,2] = 0.0
# y_plus[1,1,3] = 0.0
# y_plus[1,1,4] = 0.0
# y_plus[1,1,5] = 0.0
# y_plus[1,1,6] = 0.0
# y_plus[1,1,7] = 0.0
# y_plus[1,1,8] = 0.0
# y_plus[1,1,9] = 0.0
# y_plus[1,1,10] = 0.0
# y_plus[1,1,11] = 0.0
# y_plus[1,1,12] = 0.0
# y_plus[1,1,13] = 0.0
# y_plus[1,1,14] = 0.0
# y_plus[1,1,15] = 0.0
# y_plus[1,1,16] = 0.0
# y_plus[1,1,17] = 0.0
# y_plus[1,1,18] = 0.0
# y_plus[1,1,19] = 0.0
# y_plus[1,2,0] = 0.0
# y_plus[1,2,1] = 0.0
# y_plus[1,2,2] = 0.0
# y_plus[1,2,3] = 0.0
# y_plus[1,2,4] = 0.0
# y_plus[1,2,5] = 0.0
# y_plus[1,2,6] = 0.0
# y_plus[1,2,7] = 0.0
# y_plus[1,2,8] = 0.0
# y_plus[1,2,9] = 0.0
# y_plus[1,2,10] = 0.0
# y_plus[1,2,11] = 0.0
# y_plus[1,2,12] = 0.0
# y_plus[1,2,13] = 0.0
# y_plus[1,2,14] = 0.0
# y_plus[1,2,15] = 0.0
# y_plus[1,2,16] = 0.0
# y_plus[1,2,17] = 0.0
# y_plus[1,2,18] = 0.0
# y_plus[1,2,19] = 0.0
# y_plus[1,3,0] = 0.0
# y_plus[1,3,1] = 0.0
# y_plus[1,3,2] = 0.0
# y_plus[1,3,3] = 0.0
# y_plus[1,3,4] = 0.0
# y_plus[1,3,5] = 0.0
# y_plus[1,3,6] = 0.0
# y_plus[1,3,7] = 0.0
# y_plus[1,3,8] = 0.0
# y_plus[1,3,9] = 0.0
# y_plus[1,3,10] = 0.0
# y_plus[1,3,11] = 0.0
# y_plus[1,3,12] = 0.0
# y_plus[1,3,13] = 0.0
# y_plus[1,3,14] = 0.0
# y_plus[1,3,15] = 0.0
# y_plus[1,3,16] = 0.0
# y_plus[1,3,17] = 0.0
# y_plus[1,3,18] = 0.0
# y_plus[1,3,19] = 0.0
# y_plus[1,4,0] = 0.0
# y_plus[1,4,1] = 0.0
# y_plus[1,4,2] = 0.0
# y_plus[1,4,3] = 0.0
# y_plus[1,4,4] = 0.0
# y_plus[1,4,5] = 0.0
# y_plus[1,4,6] = 0.0
# y_plus[1,4,7] = 0.0
# y_plus[1,4,8] = 0.0
# y_plus[1,4,9] = 0.0
# y_plus[1,4,10] = 0.0
# y_plus[1,4,11] = 0.0
# y_plus[1,4,12] = 0.0
# y_plus[1,4,13] = 0.0
# y_plus[1,4,14] = 0.0
# y_plus[1,4,15] = 0.0
# y_plus[1,4,16] = 0.0
# y_plus[1,4,17] = 0.0
# y_plus[1,4,18] = 0.0
# y_plus[1,4,19] = 0.0
# y_plus[1,5,0] = 0.0
# y_plus[1,5,1] = 0.0
# y_plus[1,5,2] = 0.0
# y_plus[1,5,3] = 0.0
# y_plus[1,5,4] = 0.0
# y_plus[1,5,5] = 0.0
# y_plus[1,5,6] = 0.0
# y_plus[1,5,7] = 0.0
# y_plus[1,5,8] = 0.0
# y_plus[1,5,9] = 0.0
# y_plus[1,5,10] = 0.0
# y_plus[1,5,11] = 0.0
# y_plus[1,5,12] = 0.0
# y_plus[1,5,13] = 0.0
# y_plus[1,5,14] = 0.0
# y_plus[1,5,15] = 0.0
# y_plus[1,5,16] = 0.0
# y_plus[1,5,17] = 0.0
# y_plus[1,5,18] = 0.0
# y_plus[1,5,19] = 0.0
# y_plus[1,6,0] = 0.0
# y_plus[1,6,1] = 0.0
# y_plus[1,6,2] = 0.0
# y_plus[1,6,3] = 0.0
# y_plus[1,6,4] = 0.0
# y_plus[1,6,5] = 0.0
# y_plus[1,6,6] = 0.0
# y_plus[1,6,7] = 0.0
# y_plus[1,6,8] = 0.0
# y_plus[1,6,9] = 0.0
# y_plus[1,6,10] = 0.0
# y_plus[1,6,11] = 0.0
# y_plus[1,6,12] = 0.0
# y_plus[1,6,13] = 0.0
# y_plus[1,6,14] = 0.0
# y_plus[1,6,15] = 0.0
# y_plus[1,6,16] = 0.0
# y_plus[1,6,17] = 0.0
# y_plus[1,6,18] = 0.0
# y_plus[1,6,19] = 0.0
# y_plus[1,7,0] = 0.0
# y_plus[1,7,1] = 0.0
# y_plus[1,7,2] = 0.0
# y_plus[1,7,3] = 0.0
# y_plus[1,7,4] = 0.0
# y_plus[1,7,5] = 0.0
# y_plus[1,7,6] = 0.0
# y_plus[1,7,7] = 0.0
# y_plus[1,7,8] = 0.0
# y_plus[1,7,9] = 0.0
# y_plus[1,7,10] = 0.0
# y_plus[1,7,11] = 0.0
# y_plus[1,7,12] = 0.0
# y_plus[1,7,13] = 0.0
# y_plus[1,7,14] = 0.0
# y_plus[1,7,15] = 0.0
# y_plus[1,7,16] = 0.0
# y_plus[1,7,17] = 0.0
# y_plus[1,7,18] = 0.0
# y_plus[1,7,19] = 0.0
# y_plus[1,8,0] = 0.0
# y_plus[1,8,1] = 0.0
# y_plus[1,8,2] = 0.0
# y_plus[1,8,3] = 0.0
# y_plus[1,8,4] = 1.127213421314908
# y_plus[1,8,5] = 0.0
# y_plus[1,8,6] = 0.0
# y_plus[1,8,7] = 0.0
# y_plus[1,8,8] = 0.0
# y_plus[1,8,9] = 0.0
# y_plus[1,8,10] = 0.0991228387299583
# y_plus[1,8,11] = 0.0
# y_plus[1,8,12] = 0.0
# y_plus[1,8,13] = 0.0158006053094181
# y_plus[1,8,14] = 0.0
# y_plus[1,8,15] = 0.0
# y_plus[1,8,16] = 0.0
# y_plus[1,8,17] = 0.0
# y_plus[1,8,18] = 0.0
# y_plus[1,8,19] = 0.0
# y_plus[1,9,0] = 0.0
# y_plus[1,9,1] = 0.0
# y_plus[1,9,2] = 1.9898380561211275
# y_plus[1,9,3] = 0.860225201659178
# y_plus[1,9,4] = 0.0
# y_plus[1,9,5] = 0.0
# y_plus[1,9,6] = 1.4185283674876694
# y_plus[1,9,7] = 0.0
# y_plus[1,9,8] = 0.8719753296473489
# y_plus[1,9,9] = 0.0
# y_plus[1,9,10] = 0.8224291750302735
# y_plus[1,9,11] = 0.0
# y_plus[1,9,12] = 0.0
# y_plus[1,9,13] = 0.0
# y_plus[1,9,14] = 0.0
# y_plus[1,9,15] = 0.0
# y_plus[1,9,16] = 0.0
# y_plus[1,9,17] = 2.9405735346931143
# y_plus[1,9,18] = 0.0
# y_plus[1,9,19] = 0.0
# y_plus[1,10,0] = 0.0
# y_plus[1,10,1] = 0.0
# y_plus[1,10,2] = 0.0
# y_plus[1,10,3] = 0.0
# y_plus[1,10,4] = 3.869869552791334
# y_plus[1,10,5] = 0.0
# y_plus[1,10,6] = 0.0
# y_plus[1,10,7] = 0.0
# y_plus[1,10,8] = 2.0328014412876456
# y_plus[1,10,9] = 1.2187193569958232
# y_plus[1,10,10] = 0.0
# y_plus[1,10,11] = 1.013813978417442
# y_plus[1,10,12] = 0.0
# y_plus[1,10,13] = 3.528470377537361
# y_plus[1,10,14] = 0.0
# y_plus[1,10,15] = 1.2097480898506108
# y_plus[1,10,16] = 1.5163858889641713
# y_plus[1,10,17] = 3.6692189036176153
# y_plus[1,10,18] = 0.0
# y_plus[1,10,19] = 0.0
# y_plus[1,11,0] = 0.0
# y_plus[1,11,1] = 8.02612767904442
# y_plus[1,11,2] = 0.0
# y_plus[1,11,3] = 2.3910346385682146
# y_plus[1,11,4] = 2.9753931387551127
# y_plus[1,11,5] = 8.617404159580632
# y_plus[1,11,6] = 1.0563164892016133
# y_plus[1,11,7] = 0.0
# y_plus[1,11,8] = 4.517135261719954
# y_plus[1,11,9] = 0.0
# y_plus[1,11,10] = 4.1465339839127235
# y_plus[1,11,11] = 5.788742147523177
# y_plus[1,11,12] = 0.0
# y_plus[1,11,13] = 10.528909597323883
# y_plus[1,11,14] = 2.9777925121804873
# y_plus[1,11,15] = 0.0
# y_plus[1,11,16] = 5.054904752823321
# y_plus[1,11,17] = 0.0
# y_plus[1,11,18] = 0.0
# y_plus[1,11,19] = 6.736698151372817
# y_plus[1,12,0] = 0.0
# y_plus[1,12,1] = 5.024740919776484
# y_plus[1,12,2] = 0.0
# y_plus[1,12,3] = 0.0
# y_plus[1,12,4] = 3.0130430253413536
# y_plus[1,12,5] = 0.0
# y_plus[1,12,6] = 0.0
# y_plus[1,12,7] = 5.244238088807975
# y_plus[1,12,8] = 2.085830135015992
# y_plus[1,12,9] = 0.0
# y_plus[1,12,10] = 0.0
# y_plus[1,12,11] = 4.079759869457901
# y_plus[1,12,12] = 0.0
# y_plus[1,12,13] = 7.209381953130617
# y_plus[1,12,14] = 0.0
# y_plus[1,12,15] = 3.0507147668290404
# y_plus[1,12,16] = 3.2402954708619163
# y_plus[1,12,17] = 0.15486347289092617
# y_plus[1,12,18] = 0.7888076529470069
# y_plus[1,12,19] = 7.93443734641879
# y_plus[1,13,0] = 2.9200879776995627
# y_plus[1,13,1] = 6.51633933344603
# y_plus[1,13,2] = 2.6900299551093667
# y_plus[1,13,3] = 0.0
# y_plus[1,13,4] = 0.0
# y_plus[1,13,5] = 0.0
# y_plus[1,13,6] = 0.0
# y_plus[1,13,7] = 0.0
# y_plus[1,13,8] = 0.0
# y_plus[1,13,9] = 0.0
# y_plus[1,13,10] = 0.0
# y_plus[1,13,11] = 0.0
# y_plus[1,13,12] = 0.0
# y_plus[1,13,13] = 0.0
# y_plus[1,13,14] = 0.0
# y_plus[1,13,15] = 0.0
# y_plus[1,13,16] = 0.0
# y_plus[1,13,17] = 0.0
# y_plus[1,13,18] = 0.0
# y_plus[1,13,19] = 0.0
# y_plus[1,14,0] = 0.0
# y_plus[1,14,1] = 0.0
# y_plus[1,14,2] = 0.0
# y_plus[1,14,3] = 5.881615623114529
# y_plus[1,14,4] = 2.8485130970337327
# y_plus[1,14,5] = 0.0
# y_plus[1,14,6] = 6.187438693857695
# y_plus[1,14,7] = 0.0
# y_plus[1,14,8] = 0.0
# y_plus[1,14,9] = 0.868816651757705
# y_plus[1,14,10] = 8.16120589253015
# y_plus[1,14,11] = 8.220388617410405
# y_plus[1,14,12] = 0.5767154993946906
# y_plus[1,14,13] = 8.41760482882925
# y_plus[1,14,14] = 0.0
# y_plus[1,14,15] = 0.0
# y_plus[1,14,16] = 0.0
# y_plus[1,14,17] = 1.3544872412138975
# y_plus[1,14,18] = 0.0
# y_plus[1,14,19] = 1.715114069907555
# y_plus[1,15,0] = 2.349904050114482
# y_plus[1,15,1] = 1.8526003367537456
# y_plus[1,15,2] = 4.5604485947962585
# y_plus[1,15,3] = 0.0
# y_plus[1,15,4] = 10.219353150826873
# y_plus[1,15,5] = 1.711086047282257
# y_plus[1,15,6] = 5.904488723079819
# y_plus[1,15,7] = 5.0690187967851905
# y_plus[1,15,8] = 8.002390257584523
# y_plus[1,15,9] = 0.7485439148783222
# y_plus[1,15,10] = 0.7046981630795353
# y_plus[1,15,11] = 2.1011810715136345
# y_plus[1,15,12] = 0.0
# y_plus[1,15,13] = 0.0
# y_plus[1,15,14] = 0.7286313534152917
# y_plus[1,15,15] = 7.98335761665085
# y_plus[1,15,16] = 2.4876079437451537
# y_plus[1,15,17] = 8.578946641477739
# y_plus[1,15,18] = 2.8997311125356173
# y_plus[1,15,19] = 0.0
# y_plus[1,16,0] = 0.0
# y_plus[1,16,1] = 0.0
# y_plus[1,16,2] = 0.0
# y_plus[1,16,3] = 0.3089476613228088
# y_plus[1,16,4] = 0.0
# y_plus[1,16,5] = 0.0
# y_plus[1,16,6] = 0.0
# y_plus[1,16,7] = 0.0
# y_plus[1,16,8] = 4.222186416129606
# y_plus[1,16,9] = 0.0
# y_plus[1,16,10] = 0.0
# y_plus[1,16,11] = 4.26134900650031
# y_plus[1,16,12] = 0.0
# y_plus[1,16,13] = 0.0
# y_plus[1,16,14] = 0.0
# y_plus[1,16,15] = 0.0
# y_plus[1,16,16] = 0.2568780009987286
# y_plus[1,16,17] = 2.071889921987032
# y_plus[1,16,18] = 4.503727094828509
# y_plus[1,16,19] = 0.0
# y_plus[1,17,0] = 0.0
# y_plus[1,17,1] = 3.2544120084509554
# y_plus[1,17,2] = 0.0
# y_plus[1,17,3] = 0.0
# y_plus[1,17,4] = 0.0
# y_plus[1,17,5] = 0.0
# y_plus[1,17,6] = 0.0
# y_plus[1,17,7] = 0.0
# y_plus[1,17,8] = 0.0
# y_plus[1,17,9] = 0.0
# y_plus[1,17,10] = 0.0
# y_plus[1,17,11] = 0.0
# y_plus[1,17,12] = 0.0
# y_plus[1,17,13] = 0.0
# y_plus[1,17,14] = 0.0
# y_plus[1,17,15] = 0.0
# y_plus[1,17,16] = 0.0
# y_plus[1,17,17] = 0.0
# y_plus[1,17,18] = 0.6783591830906728
# y_plus[1,17,19] = 0.0
# y_plus[1,18,0] = 0.0
# y_plus[1,18,1] = 0.0
# y_plus[1,18,2] = 0.0
# y_plus[1,18,3] = 0.0
# y_plus[1,18,4] = 0.0
# y_plus[1,18,5] = 0.0
# y_plus[1,18,6] = 0.0
# y_plus[1,18,7] = 0.0
# y_plus[1,18,8] = 0.0
# y_plus[1,18,9] = 0.0
# y_plus[1,18,10] = 0.0
# y_plus[1,18,11] = 0.0
# y_plus[1,18,12] = 0.0
# y_plus[1,18,13] = 0.0
# y_plus[1,18,14] = 0.0
# y_plus[1,18,15] = 0.0
# y_plus[1,18,16] = 0.0
# y_plus[1,18,17] = 0.0
# y_plus[1,18,18] = 0.0
# y_plus[1,18,19] = 0.0
# y_plus[1,19,0] = 0.0
# y_plus[1,19,1] = 0.0
# y_plus[1,19,2] = 0.0
# y_plus[1,19,3] = 0.0
# y_plus[1,19,4] = 0.0
# y_plus[1,19,5] = 0.0
# y_plus[1,19,6] = 0.0
# y_plus[1,19,7] = 0.0
# y_plus[1,19,8] = 0.0
# y_plus[1,19,9] = 0.0
# y_plus[1,19,10] = 0.0
# y_plus[1,19,11] = 0.0
# y_plus[1,19,12] = 0.0
# y_plus[1,19,13] = 0.0
# y_plus[1,19,14] = 0.0
# y_plus[1,19,15] = 0.0
# y_plus[1,19,16] = 0.0
# y_plus[1,19,17] = 0.0
# y_plus[1,19,18] = 0.0
# y_plus[1,19,19] = 0.0
# y_plus[1,20,0] = 0.0
# y_plus[1,20,1] = 0.0
# y_plus[1,20,2] = 0.0
# y_plus[1,20,3] = 0.0
# y_plus[1,20,4] = 0.0
# y_plus[1,20,5] = 0.0
# y_plus[1,20,6] = 0.0
# y_plus[1,20,7] = 0.0
# y_plus[1,20,8] = 0.0
# y_plus[1,20,9] = 0.0
# y_plus[1,20,10] = 0.0
# y_plus[1,20,11] = 0.0
# y_plus[1,20,12] = 0.0
# y_plus[1,20,13] = 0.0
# y_plus[1,20,14] = 0.0
# y_plus[1,20,15] = 0.0
# y_plus[1,20,16] = 0.0
# y_plus[1,20,17] = 0.0
# y_plus[1,20,18] = 0.0
# y_plus[1,20,19] = 0.0
# y_plus[1,21,0] = 0.0
# y_plus[1,21,1] = 0.0
# y_plus[1,21,2] = 0.0
# y_plus[1,21,3] = 0.0
# y_plus[1,21,4] = 0.0
# y_plus[1,21,5] = 0.0
# y_plus[1,21,6] = 0.0
# y_plus[1,21,7] = 0.0
# y_plus[1,21,8] = 0.0
# y_plus[1,21,9] = 0.0
# y_plus[1,21,10] = 0.0
# y_plus[1,21,11] = 0.0
# y_plus[1,21,12] = 0.0
# y_plus[1,21,13] = 0.0
# y_plus[1,21,14] = 0.0
# y_plus[1,21,15] = 0.0
# y_plus[1,21,16] = 0.0
# y_plus[1,21,17] = 0.0
# y_plus[1,21,18] = 0.0
# y_plus[1,21,19] = 0.0
# y_plus[1,22,0] = 0.0
# y_plus[1,22,1] = 0.0
# y_plus[1,22,2] = 0.0
# y_plus[1,22,3] = 0.0
# y_plus[1,22,4] = 0.0
# y_plus[1,22,5] = 0.0
# y_plus[1,22,6] = 0.0
# y_plus[1,22,7] = 0.0
# y_plus[1,22,8] = 0.0
# y_plus[1,22,9] = 0.0
# y_plus[1,22,10] = 0.0
# y_plus[1,22,11] = 0.0
# y_plus[1,22,12] = 0.0
# y_plus[1,22,13] = 0.0
# y_plus[1,22,14] = 0.0
# y_plus[1,22,15] = 0.0
# y_plus[1,22,16] = 0.0
# y_plus[1,22,17] = 0.0
# y_plus[1,22,18] = 0.0
# y_plus[1,22,19] = 0.0
# y_plus[1,23,0] = 0.0
# y_plus[1,23,1] = 0.0
# y_plus[1,23,2] = 0.0
# y_plus[1,23,3] = 0.0
# y_plus[1,23,4] = 0.0
# y_plus[1,23,5] = 0.0
# y_plus[1,23,6] = 0.0
# y_plus[1,23,7] = 0.0
# y_plus[1,23,8] = 0.0
# y_plus[1,23,9] = 0.0
# y_plus[1,23,10] = 0.0
# y_plus[1,23,11] = 0.0
# y_plus[1,23,12] = 0.0
# y_plus[1,23,13] = 0.0
# y_plus[1,23,14] = 0.0
# y_plus[1,23,15] = 0.0
# y_plus[1,23,16] = 0.0
# y_plus[1,23,17] = 0.0
# y_plus[1,23,18] = 0.0
# y_plus[1,23,19] = 0.0
# y_plus[2,0,0] = 0.0
# y_plus[2,0,1] = 0.0
# y_plus[2,0,2] = 0.0
# y_plus[2,0,3] = 0.0
# y_plus[2,0,4] = 0.0
# y_plus[2,0,5] = 0.0
# y_plus[2,0,6] = 0.0
# y_plus[2,0,7] = 0.0
# y_plus[2,0,8] = 0.0
# y_plus[2,0,9] = 0.0
# y_plus[2,0,10] = 0.0
# y_plus[2,0,11] = 0.0
# y_plus[2,0,12] = 0.0
# y_plus[2,0,13] = 0.0
# y_plus[2,0,14] = 0.0
# y_plus[2,0,15] = 0.0
# y_plus[2,0,16] = 0.0
# y_plus[2,0,17] = 0.0
# y_plus[2,0,18] = 0.0
# y_plus[2,0,19] = 0.0
# y_plus[2,1,0] = 0.0
# y_plus[2,1,1] = 0.0
# y_plus[2,1,2] = 0.0
# y_plus[2,1,3] = 0.0
# y_plus[2,1,4] = 0.0
# y_plus[2,1,5] = 0.0
# y_plus[2,1,6] = 0.0
# y_plus[2,1,7] = 0.0
# y_plus[2,1,8] = 0.0
# y_plus[2,1,9] = 0.0
# y_plus[2,1,10] = 0.0
# y_plus[2,1,11] = 0.0
# y_plus[2,1,12] = 0.0
# y_plus[2,1,13] = 0.0
# y_plus[2,1,14] = 0.0
# y_plus[2,1,15] = 0.0
# y_plus[2,1,16] = 0.0
# y_plus[2,1,17] = 0.0
# y_plus[2,1,18] = 0.0
# y_plus[2,1,19] = 0.0
# y_plus[2,2,0] = 0.0
# y_plus[2,2,1] = 0.0
# y_plus[2,2,2] = 0.0
# y_plus[2,2,3] = 0.0
# y_plus[2,2,4] = 0.0
# y_plus[2,2,5] = 0.0
# y_plus[2,2,6] = 0.0
# y_plus[2,2,7] = 0.0
# y_plus[2,2,8] = 0.0
# y_plus[2,2,9] = 0.0
# y_plus[2,2,10] = 0.0
# y_plus[2,2,11] = 0.0
# y_plus[2,2,12] = 0.0
# y_plus[2,2,13] = 0.0
# y_plus[2,2,14] = 0.0
# y_plus[2,2,15] = 0.0
# y_plus[2,2,16] = 0.0
# y_plus[2,2,17] = 0.0
# y_plus[2,2,18] = 0.0
# y_plus[2,2,19] = 0.0
# y_plus[2,3,0] = 0.0
# y_plus[2,3,1] = 0.0
# y_plus[2,3,2] = 0.0
# y_plus[2,3,3] = 0.0
# y_plus[2,3,4] = 0.0
# y_plus[2,3,5] = 0.0
# y_plus[2,3,6] = 0.0
# y_plus[2,3,7] = 0.0
# y_plus[2,3,8] = 0.0
# y_plus[2,3,9] = 0.0
# y_plus[2,3,10] = 0.0
# y_plus[2,3,11] = 0.0
# y_plus[2,3,12] = 0.0
# y_plus[2,3,13] = 0.0
# y_plus[2,3,14] = 0.0
# y_plus[2,3,15] = 0.0
# y_plus[2,3,16] = 0.0
# y_plus[2,3,17] = 0.0
# y_plus[2,3,18] = 0.0
# y_plus[2,3,19] = 0.0
# y_plus[2,4,0] = 0.0
# y_plus[2,4,1] = 0.0
# y_plus[2,4,2] = 0.0
# y_plus[2,4,3] = 0.0
# y_plus[2,4,4] = 0.0
# y_plus[2,4,5] = 0.0
# y_plus[2,4,6] = 0.0
# y_plus[2,4,7] = 0.0
# y_plus[2,4,8] = 0.0
# y_plus[2,4,9] = 0.0
# y_plus[2,4,10] = 0.0
# y_plus[2,4,11] = 0.0
# y_plus[2,4,12] = 0.0
# y_plus[2,4,13] = 0.0
# y_plus[2,4,14] = 0.0
# y_plus[2,4,15] = 0.0
# y_plus[2,4,16] = 0.0
# y_plus[2,4,17] = 0.0
# y_plus[2,4,18] = 0.0
# y_plus[2,4,19] = 0.0
# y_plus[2,5,0] = 0.0
# y_plus[2,5,1] = 0.0
# y_plus[2,5,2] = 0.0
# y_plus[2,5,3] = 0.0
# y_plus[2,5,4] = 0.0
# y_plus[2,5,5] = 0.0
# y_plus[2,5,6] = 0.0
# y_plus[2,5,7] = 0.0
# y_plus[2,5,8] = 0.0
# y_plus[2,5,9] = 0.0
# y_plus[2,5,10] = 0.0
# y_plus[2,5,11] = 0.0
# y_plus[2,5,12] = 0.0
# y_plus[2,5,13] = 0.0
# y_plus[2,5,14] = 0.0
# y_plus[2,5,15] = 0.0
# y_plus[2,5,16] = 0.0
# y_plus[2,5,17] = 0.0
# y_plus[2,5,18] = 0.0
# y_plus[2,5,19] = 0.0
# y_plus[2,6,0] = 0.0
# y_plus[2,6,1] = 0.0
# y_plus[2,6,2] = 0.0
# y_plus[2,6,3] = 0.0
# y_plus[2,6,4] = 0.0
# y_plus[2,6,5] = 0.0
# y_plus[2,6,6] = 0.0
# y_plus[2,6,7] = 0.0
# y_plus[2,6,8] = 0.0
# y_plus[2,6,9] = 0.0
# y_plus[2,6,10] = 0.0
# y_plus[2,6,11] = 0.0
# y_plus[2,6,12] = 0.0
# y_plus[2,6,13] = 0.0
# y_plus[2,6,14] = 0.0
# y_plus[2,6,15] = 0.0
# y_plus[2,6,16] = 0.0
# y_plus[2,6,17] = 0.0
# y_plus[2,6,18] = 0.0
# y_plus[2,6,19] = 0.0
# y_plus[2,7,0] = 0.0
# y_plus[2,7,1] = 0.0
# y_plus[2,7,2] = 0.0
# y_plus[2,7,3] = 0.0
# y_plus[2,7,4] = 0.0
# y_plus[2,7,5] = 0.0
# y_plus[2,7,6] = 0.0
# y_plus[2,7,7] = 0.0
# y_plus[2,7,8] = 0.0
# y_plus[2,7,9] = 0.0
# y_plus[2,7,10] = 0.0
# y_plus[2,7,11] = 0.0
# y_plus[2,7,12] = 0.0
# y_plus[2,7,13] = 0.0
# y_plus[2,7,14] = 0.0
# y_plus[2,7,15] = 0.0
# y_plus[2,7,16] = 0.0
# y_plus[2,7,17] = 0.0
# y_plus[2,7,18] = 0.0
# y_plus[2,7,19] = 0.0
# y_plus[2,8,0] = 0.0
# y_plus[2,8,1] = 0.0
# y_plus[2,8,2] = 1.1349731512141867
# y_plus[2,8,3] = 2.0940074656002174
# y_plus[2,8,4] = 0.0
# y_plus[2,8,5] = 0.0
# y_plus[2,8,6] = 0.0
# y_plus[2,8,7] = 0.0
# y_plus[2,8,8] = 0.0
# y_plus[2,8,9] = 1.904728184492765
# y_plus[2,8,10] = 0.0
# y_plus[2,8,11] = 0.0
# y_plus[2,8,12] = 0.0
# y_plus[2,8,13] = 0.0
# y_plus[2,8,14] = 0.1456475191607009
# y_plus[2,8,15] = 0.0
# y_plus[2,8,16] = 0.0
# y_plus[2,8,17] = 0.587877846314213
# y_plus[2,8,18] = 0.4022068835535973
# y_plus[2,8,19] = 0.0
# y_plus[2,9,0] = 1.5107742999920881
# y_plus[2,9,1] = 0.0
# y_plus[2,9,2] = 4.077523552980047
# y_plus[2,9,3] = 1.804456899113788
# y_plus[2,9,4] = 0.0
# y_plus[2,9,5] = 0.0
# y_plus[2,9,6] = 0.0
# y_plus[2,9,7] = 0.0
# y_plus[2,9,8] = 1.807472382706413
# y_plus[2,9,9] = 1.0897711596666433
# y_plus[2,9,10] = 0.9318038995213627
# y_plus[2,9,11] = 6.6914647919515975
# y_plus[2,9,12] = 0.7519494030237936
# y_plus[2,9,13] = 0.0
# y_plus[2,9,14] = 0.30647652394428526
# y_plus[2,9,15] = 1.3188293660539046
# y_plus[2,9,16] = 1.4825286071942543
# y_plus[2,9,17] = 2.340001441079222
# y_plus[2,9,18] = 2.991895419563333
# y_plus[2,9,19] = 2.0274960557466173
# y_plus[2,10,0] = 2.158023320983318
# y_plus[2,10,1] = 0.0
# y_plus[2,10,2] = 0.0
# y_plus[2,10,3] = 1.3570849075620222
# y_plus[2,10,4] = 0.0
# y_plus[2,10,5] = 6.217683510353306
# y_plus[2,10,6] = 0.0
# y_plus[2,10,7] = 0.0
# y_plus[2,10,8] = 6.3442998241662725
# y_plus[2,10,9] = 5.94188749102106
# y_plus[2,10,10] = 3.3254309823869614
# y_plus[2,10,11] = 7.818051850883285
# y_plus[2,10,12] = 0.0
# y_plus[2,10,13] = 0.9577551144264373
# y_plus[2,10,14] = 4.857019449229488
# y_plus[2,10,15] = 0.0
# y_plus[2,10,16] = 4.9061084226055875
# y_plus[2,10,17] = 5.129685538865717
# y_plus[2,10,18] = 6.607735611148942
# y_plus[2,10,19] = 9.046732943971007
# y_plus[2,11,0] = 0.0
# y_plus[2,11,1] = 0.0
# y_plus[2,11,2] = 0.0
# y_plus[2,11,3] = 0.0
# y_plus[2,11,4] = 0.0
# y_plus[2,11,5] = 0.0
# y_plus[2,11,6] = 0.0
# y_plus[2,11,7] = 0.0
# y_plus[2,11,8] = 0.0
# y_plus[2,11,9] = 0.0
# y_plus[2,11,10] = 0.0
# y_plus[2,11,11] = 0.0
# y_plus[2,11,12] = 0.0
# y_plus[2,11,13] = 0.0
# y_plus[2,11,14] = 0.0
# y_plus[2,11,15] = 0.0
# y_plus[2,11,16] = 0.0
# y_plus[2,11,17] = 0.0
# y_plus[2,11,18] = 0.0
# y_plus[2,11,19] = 0.0
# y_plus[2,12,0] = 3.423048981919586
# y_plus[2,12,1] = 8.373256392725526
# y_plus[2,12,2] = 0.0
# y_plus[2,12,3] = 11.296755729148998
# y_plus[2,12,4] = 0.0
# y_plus[2,12,5] = 0.0
# y_plus[2,12,6] = 8.397905249130574
# y_plus[2,12,7] = 0.0
# y_plus[2,12,8] = 4.421205472269979
# y_plus[2,12,9] = 7.444753761167926
# y_plus[2,12,10] = 7.446049891613742
# y_plus[2,12,11] = 0.0
# y_plus[2,12,12] = 0.0
# y_plus[2,12,13] = 2.6467249643439494
# y_plus[2,12,14] = 6.642374296912682
# y_plus[2,12,15] = 8.45342788737904
# y_plus[2,12,16] = 0.0
# y_plus[2,12,17] = 8.486271289537495
# y_plus[2,12,18] = 4.67465092547443
# y_plus[2,12,19] = 9.82637600922493
# y_plus[2,13,0] = 3.100724127854958
# y_plus[2,13,1] = 2.0581893802969944
# y_plus[2,13,2] = 0.0
# y_plus[2,13,3] = 5.833082371058403
# y_plus[2,13,4] = 0.0
# y_plus[2,13,5] = 2.456535968038196
# y_plus[2,13,6] = 3.9147150020088795
# y_plus[2,13,7] = 8.439616058793854
# y_plus[2,13,8] = 0.0
# y_plus[2,13,9] = 0.0
# y_plus[2,13,10] = 8.366294953818288
# y_plus[2,13,11] = 7.430928123891116
# y_plus[2,13,12] = 0.0
# y_plus[2,13,13] = 0.0
# y_plus[2,13,14] = 7.271117422052903
# y_plus[2,13,15] = 3.6029955869672285
# y_plus[2,13,16] = 3.561808569236259
# y_plus[2,13,17] = 0.0
# y_plus[2,13,18] = 0.0
# y_plus[2,13,19] = 0.0
# y_plus[2,14,0] = 0.0
# y_plus[2,14,1] = 0.0
# y_plus[2,14,2] = 1.432559919486561
# y_plus[2,14,3] = 3.599051556592004
# y_plus[2,14,4] = 0.0
# y_plus[2,14,5] = 9.458780288264034
# y_plus[2,14,6] = 0.0
# y_plus[2,14,7] = 0.0
# y_plus[2,14,8] = 0.0
# y_plus[2,14,9] = 3.4956068726495992
# y_plus[2,14,10] = 0.0
# y_plus[2,14,11] = 4.467623039409663
# y_plus[2,14,12] = 4.737948029397215
# y_plus[2,14,13] = 1.860595670963086
# y_plus[2,14,14] = 0.0
# y_plus[2,14,15] = 4.633330753197978
# y_plus[2,14,16] = 0.0
# y_plus[2,14,17] = 0.05168614852896969
# y_plus[2,14,18] = 4.786229301403566
# y_plus[2,14,19] = 0.0
# y_plus[2,15,0] = 0.0
# y_plus[2,15,1] = 0.0
# y_plus[2,15,2] = 0.0
# y_plus[2,15,3] = 5.707906955635281
# y_plus[2,15,4] = 0.0
# y_plus[2,15,5] = 5.2803374488112915
# y_plus[2,15,6] = 0.0
# y_plus[2,15,7] = 0.0
# y_plus[2,15,8] = 0.0
# y_plus[2,15,9] = 0.36927890530595064
# y_plus[2,15,10] = 0.0
# y_plus[2,15,11] = 0.0
# y_plus[2,15,12] = 0.0
# y_plus[2,15,13] = 0.0
# y_plus[2,15,14] = 0.0
# y_plus[2,15,15] = 0.96093385953513
# y_plus[2,15,16] = 0.0
# y_plus[2,15,17] = 0.0
# y_plus[2,15,18] = 7.331735867540422
# y_plus[2,15,19] = 0.0
# y_plus[2,16,0] = 3.107971296052323
# y_plus[2,16,1] = 3.3681558380376764
# y_plus[2,16,2] = 0.0
# y_plus[2,16,3] = 0.0
# y_plus[2,16,4] = 0.0
# y_plus[2,16,5] = 0.0
# y_plus[2,16,6] = 5.31727920159295
# y_plus[2,16,7] = 0.0
# y_plus[2,16,8] = 0.0
# y_plus[2,16,9] = 0.0
# y_plus[2,16,10] = 0.0
# y_plus[2,16,11] = 4.8926607388379315
# y_plus[2,16,12] = 0.0
# y_plus[2,16,13] = 0.0
# y_plus[2,16,14] = 0.0
# y_plus[2,16,15] = 0.0
# y_plus[2,16,16] = 0.0
# y_plus[2,16,17] = 0.0
# y_plus[2,16,18] = 0.0
# y_plus[2,16,19] = 0.0
# y_plus[2,17,0] = 0.0
# y_plus[2,17,1] = 0.0
# y_plus[2,17,2] = 0.0
# y_plus[2,17,3] = 0.0
# y_plus[2,17,4] = 0.0
# y_plus[2,17,5] = 1.6930879388275173
# y_plus[2,17,6] = 0.0
# y_plus[2,17,7] = 0.0
# y_plus[2,17,8] = 0.0
# y_plus[2,17,9] = 0.0
# y_plus[2,17,10] = 0.0
# y_plus[2,17,11] = 0.0
# y_plus[2,17,12] = 0.0
# y_plus[2,17,13] = 0.0
# y_plus[2,17,14] = 0.0
# y_plus[2,17,15] = 0.0
# y_plus[2,17,16] = 0.0
# y_plus[2,17,17] = 0.0
# y_plus[2,17,18] = 0.0
# y_plus[2,17,19] = 0.5039030260811446
# y_plus[2,18,0] = 0.0
# y_plus[2,18,1] = 0.0
# y_plus[2,18,2] = 0.0
# y_plus[2,18,3] = 0.0
# y_plus[2,18,4] = 0.0
# y_plus[2,18,5] = 0.0
# y_plus[2,18,6] = 0.0
# y_plus[2,18,7] = 0.0
# y_plus[2,18,8] = 0.0
# y_plus[2,18,9] = 0.0
# y_plus[2,18,10] = 0.0
# y_plus[2,18,11] = 0.0
# y_plus[2,18,12] = 0.0
# y_plus[2,18,13] = 0.0
# y_plus[2,18,14] = 0.0
# y_plus[2,18,15] = 0.0
# y_plus[2,18,16] = 0.0
# y_plus[2,18,17] = 0.0
# y_plus[2,18,18] = 0.0
# y_plus[2,18,19] = 0.0
# y_plus[2,19,0] = 0.0
# y_plus[2,19,1] = 0.0
# y_plus[2,19,2] = 0.0
# y_plus[2,19,3] = 0.0
# y_plus[2,19,4] = 0.0
# y_plus[2,19,5] = 0.0
# y_plus[2,19,6] = 0.0
# y_plus[2,19,7] = 0.0
# y_plus[2,19,8] = 0.0
# y_plus[2,19,9] = 0.0
# y_plus[2,19,10] = 0.0
# y_plus[2,19,11] = 0.0
# y_plus[2,19,12] = 0.0
# y_plus[2,19,13] = 0.0
# y_plus[2,19,14] = 0.0
# y_plus[2,19,15] = 0.0
# y_plus[2,19,16] = 0.0
# y_plus[2,19,17] = 0.0
# y_plus[2,19,18] = 0.0
# y_plus[2,19,19] = 0.0
# y_plus[2,20,0] = 0.0
# y_plus[2,20,1] = 0.0
# y_plus[2,20,2] = 0.0
# y_plus[2,20,3] = 0.0
# y_plus[2,20,4] = 0.0
# y_plus[2,20,5] = 0.0
# y_plus[2,20,6] = 0.0
# y_plus[2,20,7] = 0.0
# y_plus[2,20,8] = 0.0
# y_plus[2,20,9] = 0.0
# y_plus[2,20,10] = 0.0
# y_plus[2,20,11] = 0.0
# y_plus[2,20,12] = 0.0
# y_plus[2,20,13] = 0.0
# y_plus[2,20,14] = 0.0
# y_plus[2,20,15] = 0.0
# y_plus[2,20,16] = 0.0
# y_plus[2,20,17] = 0.0
# y_plus[2,20,18] = 0.0
# y_plus[2,20,19] = 0.0
# y_plus[2,21,0] = 0.0
# y_plus[2,21,1] = 0.0
# y_plus[2,21,2] = 0.0
# y_plus[2,21,3] = 0.0
# y_plus[2,21,4] = 0.0
# y_plus[2,21,5] = 0.0
# y_plus[2,21,6] = 0.0
# y_plus[2,21,7] = 0.0
# y_plus[2,21,8] = 0.0
# y_plus[2,21,9] = 0.0
# y_plus[2,21,10] = 0.0
# y_plus[2,21,11] = 0.0
# y_plus[2,21,12] = 0.0
# y_plus[2,21,13] = 0.0
# y_plus[2,21,14] = 0.0
# y_plus[2,21,15] = 0.0
# y_plus[2,21,16] = 0.0
# y_plus[2,21,17] = 0.0
# y_plus[2,21,18] = 0.0
# y_plus[2,21,19] = 0.0
# y_plus[2,22,0] = 0.0
# y_plus[2,22,1] = 0.0
# y_plus[2,22,2] = 0.0
# y_plus[2,22,3] = 0.0
# y_plus[2,22,4] = 0.0
# y_plus[2,22,5] = 0.0
# y_plus[2,22,6] = 0.0
# y_plus[2,22,7] = 0.0
# y_plus[2,22,8] = 0.0
# y_plus[2,22,9] = 0.0
# y_plus[2,22,10] = 0.0
# y_plus[2,22,11] = 0.0
# y_plus[2,22,12] = 0.0
# y_plus[2,22,13] = 0.0
# y_plus[2,22,14] = 0.0
# y_plus[2,22,15] = 0.0
# y_plus[2,22,16] = 0.0
# y_plus[2,22,17] = 0.0
# y_plus[2,22,18] = 0.0
# y_plus[2,22,19] = 0.0
# y_plus[2,23,0] = 0.0
# y_plus[2,23,1] = 0.0
# y_plus[2,23,2] = 0.0
# y_plus[2,23,3] = 0.0
# y_plus[2,23,4] = 0.0
# y_plus[2,23,5] = 0.0
# y_plus[2,23,6] = 0.0
# y_plus[2,23,7] = 0.0
# y_plus[2,23,8] = 0.0
# y_plus[2,23,9] = 0.0
# y_plus[2,23,10] = 0.0
# y_plus[2,23,11] = 0.0
# y_plus[2,23,12] = 0.0
# y_plus[2,23,13] = 0.0
# y_plus[2,23,14] = 0.0
# y_plus[2,23,15] = 0.0
# y_plus[2,23,16] = 0.0
# y_plus[2,23,17] = 0.0
# y_plus[2,23,18] = 0.0
# y_plus[2,23,19] = 0.0
# y_plus[3,0,0] = 0.0
# y_plus[3,0,1] = 0.0
# y_plus[3,0,2] = 0.0
# y_plus[3,0,3] = 0.0
# y_plus[3,0,4] = 0.0
# y_plus[3,0,5] = 0.0
# y_plus[3,0,6] = 0.0
# y_plus[3,0,7] = 0.0
# y_plus[3,0,8] = 0.0
# y_plus[3,0,9] = 0.0
# y_plus[3,0,10] = 0.0
# y_plus[3,0,11] = 0.0
# y_plus[3,0,12] = 0.0
# y_plus[3,0,13] = 0.0
# y_plus[3,0,14] = 0.0
# y_plus[3,0,15] = 0.0
# y_plus[3,0,16] = 0.0
# y_plus[3,0,17] = 0.0
# y_plus[3,0,18] = 0.0
# y_plus[3,0,19] = 0.0
# y_plus[3,1,0] = 0.0
# y_plus[3,1,1] = 0.0
# y_plus[3,1,2] = 0.0
# y_plus[3,1,3] = 0.0
# y_plus[3,1,4] = 0.0
# y_plus[3,1,5] = 0.0
# y_plus[3,1,6] = 0.0
# y_plus[3,1,7] = 0.0
# y_plus[3,1,8] = 0.0
# y_plus[3,1,9] = 0.0
# y_plus[3,1,10] = 0.0
# y_plus[3,1,11] = 0.0
# y_plus[3,1,12] = 0.0
# y_plus[3,1,13] = 0.0
# y_plus[3,1,14] = 0.0
# y_plus[3,1,15] = 0.0
# y_plus[3,1,16] = 0.0
# y_plus[3,1,17] = 0.0
# y_plus[3,1,18] = 0.0
# y_plus[3,1,19] = 0.0
# y_plus[3,2,0] = 0.0
# y_plus[3,2,1] = 0.0
# y_plus[3,2,2] = 0.0
# y_plus[3,2,3] = 0.0
# y_plus[3,2,4] = 0.0
# y_plus[3,2,5] = 0.0
# y_plus[3,2,6] = 0.0
# y_plus[3,2,7] = 0.0
# y_plus[3,2,8] = 0.0
# y_plus[3,2,9] = 0.0
# y_plus[3,2,10] = 0.0
# y_plus[3,2,11] = 0.0
# y_plus[3,2,12] = 0.0
# y_plus[3,2,13] = 0.0
# y_plus[3,2,14] = 0.0
# y_plus[3,2,15] = 0.0
# y_plus[3,2,16] = 0.0
# y_plus[3,2,17] = 0.0
# y_plus[3,2,18] = 0.0
# y_plus[3,2,19] = 0.0
# y_plus[3,3,0] = 0.0
# y_plus[3,3,1] = 0.0
# y_plus[3,3,2] = 0.0
# y_plus[3,3,3] = 0.0
# y_plus[3,3,4] = 0.0
# y_plus[3,3,5] = 0.0
# y_plus[3,3,6] = 0.0
# y_plus[3,3,7] = 0.0
# y_plus[3,3,8] = 0.0
# y_plus[3,3,9] = 0.0
# y_plus[3,3,10] = 0.0
# y_plus[3,3,11] = 0.0
# y_plus[3,3,12] = 0.0
# y_plus[3,3,13] = 0.0
# y_plus[3,3,14] = 0.0
# y_plus[3,3,15] = 0.0
# y_plus[3,3,16] = 0.0
# y_plus[3,3,17] = 0.0
# y_plus[3,3,18] = 0.0
# y_plus[3,3,19] = 0.0
# y_plus[3,4,0] = 0.0
# y_plus[3,4,1] = 0.0
# y_plus[3,4,2] = 0.0
# y_plus[3,4,3] = 0.0
# y_plus[3,4,4] = 0.0
# y_plus[3,4,5] = 0.0
# y_plus[3,4,6] = 0.0
# y_plus[3,4,7] = 0.0
# y_plus[3,4,8] = 0.0
# y_plus[3,4,9] = 0.0
# y_plus[3,4,10] = 0.0
# y_plus[3,4,11] = 0.0
# y_plus[3,4,12] = 0.0
# y_plus[3,4,13] = 0.0
# y_plus[3,4,14] = 0.0
# y_plus[3,4,15] = 0.0
# y_plus[3,4,16] = 0.0
# y_plus[3,4,17] = 0.0
# y_plus[3,4,18] = 0.0
# y_plus[3,4,19] = 0.0
# y_plus[3,5,0] = 0.0
# y_plus[3,5,1] = 0.0
# y_plus[3,5,2] = 0.0
# y_plus[3,5,3] = 0.0
# y_plus[3,5,4] = 0.0
# y_plus[3,5,5] = 0.0
# y_plus[3,5,6] = 0.0
# y_plus[3,5,7] = 0.0
# y_plus[3,5,8] = 0.0
# y_plus[3,5,9] = 0.0
# y_plus[3,5,10] = 0.0
# y_plus[3,5,11] = 0.0
# y_plus[3,5,12] = 0.0
# y_plus[3,5,13] = 0.0
# y_plus[3,5,14] = 0.0
# y_plus[3,5,15] = 0.0
# y_plus[3,5,16] = 0.0
# y_plus[3,5,17] = 0.0
# y_plus[3,5,18] = 0.0
# y_plus[3,5,19] = 0.0
# y_plus[3,6,0] = 0.0
# y_plus[3,6,1] = 0.0
# y_plus[3,6,2] = 0.0
# y_plus[3,6,3] = 0.0
# y_plus[3,6,4] = 0.0
# y_plus[3,6,5] = 0.0
# y_plus[3,6,6] = 0.0
# y_plus[3,6,7] = 0.0
# y_plus[3,6,8] = 0.0
# y_plus[3,6,9] = 0.0
# y_plus[3,6,10] = 0.0
# y_plus[3,6,11] = 0.0
# y_plus[3,6,12] = 0.0
# y_plus[3,6,13] = 0.0
# y_plus[3,6,14] = 0.0
# y_plus[3,6,15] = 0.0
# y_plus[3,6,16] = 0.0
# y_plus[3,6,17] = 0.0
# y_plus[3,6,18] = 0.0
# y_plus[3,6,19] = 0.0
# y_plus[3,7,0] = 0.0
# y_plus[3,7,1] = 0.0
# y_plus[3,7,2] = 0.0
# y_plus[3,7,3] = 0.0
# y_plus[3,7,4] = 0.0
# y_plus[3,7,5] = 0.0
# y_plus[3,7,6] = 0.0
# y_plus[3,7,7] = 0.0
# y_plus[3,7,8] = 0.0
# y_plus[3,7,9] = 0.0
# y_plus[3,7,10] = 0.0
# y_plus[3,7,11] = 0.0
# y_plus[3,7,12] = 0.0
# y_plus[3,7,13] = 0.0
# y_plus[3,7,14] = 0.0
# y_plus[3,7,15] = 0.0
# y_plus[3,7,16] = 0.0
# y_plus[3,7,17] = 0.0
# y_plus[3,7,18] = 0.0
# y_plus[3,7,19] = 0.0
# y_plus[3,8,0] = 0.0
# y_plus[3,8,1] = 1.3282753244558814
# y_plus[3,8,2] = 0.0
# y_plus[3,8,3] = 1.277550167541846
# y_plus[3,8,4] = 0.0
# y_plus[3,8,5] = 0.0
# y_plus[3,8,6] = 0.0
# y_plus[3,8,7] = 0.0
# y_plus[3,8,8] = 0.0
# y_plus[3,8,9] = 0.0
# y_plus[3,8,10] = 0.0
# y_plus[3,8,11] = 0.7465309752455593
# y_plus[3,8,12] = 0.0563566319930153
# y_plus[3,8,13] = 2.08991804051244
# y_plus[3,8,14] = 0.0
# y_plus[3,8,15] = 0.0
# y_plus[3,8,16] = 0.0
# y_plus[3,8,17] = 0.0
# y_plus[3,8,18] = 0.8263866616281086
# y_plus[3,8,19] = 0.0
# y_plus[3,9,0] = 0.0
# y_plus[3,9,1] = 0.0
# y_plus[3,9,2] = 0.0
# y_plus[3,9,3] = 0.0
# y_plus[3,9,4] = 0.0
# y_plus[3,9,5] = 3.0233506389125733
# y_plus[3,9,6] = 0.0
# y_plus[3,9,7] = 0.0
# y_plus[3,9,8] = 0.0
# y_plus[3,9,9] = 0.0
# y_plus[3,9,10] = 1.8115380899312399
# y_plus[3,9,11] = 0.0
# y_plus[3,9,12] = 0.0
# y_plus[3,9,13] = 1.8974241026724723
# y_plus[3,9,14] = 0.0
# y_plus[3,9,15] = 1.4945269878520575
# y_plus[3,9,16] = 0.0
# y_plus[3,9,17] = 0.0
# y_plus[3,9,18] = 0.0
# y_plus[3,9,19] = 0.0
# y_plus[3,10,0] = 6.842173920193442
# y_plus[3,10,1] = 7.4400656803203145
# y_plus[3,10,2] = 3.0138523122151266
# y_plus[3,10,3] = 0.48578052828864404
# y_plus[3,10,4] = 8.873619023722618
# y_plus[3,10,5] = 0.0
# y_plus[3,10,6] = 2.892671723553669
# y_plus[3,10,7] = 0.0
# y_plus[3,10,8] = 0.0
# y_plus[3,10,9] = 4.953628995994802
# y_plus[3,10,10] = 0.0
# y_plus[3,10,11] = 3.1026509967044884
# y_plus[3,10,12] = 0.0
# y_plus[3,10,13] = 0.0
# y_plus[3,10,14] = 8.263191070617223
# y_plus[3,10,15] = 0.0
# y_plus[3,10,16] = 0.0
# y_plus[3,10,17] = 3.356797688678947
# y_plus[3,10,18] = 0.0
# y_plus[3,10,19] = 2.304365423935997
# y_plus[3,11,0] = 0.0
# y_plus[3,11,1] = 16.810804966284934
# y_plus[3,11,2] = 0.0
# y_plus[3,11,3] = 1.647136440303094
# y_plus[3,11,4] = 6.724734721274667
# y_plus[3,11,5] = 9.169254457397695
# y_plus[3,11,6] = 0.0
# y_plus[3,11,7] = 0.0
# y_plus[3,11,8] = 8.696448887395857
# y_plus[3,11,9] = 15.177415027845298
# y_plus[3,11,10] = 3.2010124657887644
# y_plus[3,11,11] = 11.345494733279754
# y_plus[3,11,12] = 0.8162327181342226
# y_plus[3,11,13] = 15.334359271338196
# y_plus[3,11,14] = 0.8337287787988383
# y_plus[3,11,15] = 11.84596591746911
# y_plus[3,11,16] = 7.398488681361943
# y_plus[3,11,17] = 4.188953219170786
# y_plus[3,11,18] = 6.292967355312477
# y_plus[3,11,19] = 7.009776977814615
# y_plus[3,12,0] = 0.0
# y_plus[3,12,1] = 0.0
# y_plus[3,12,2] = 4.146196729433427
# y_plus[3,12,3] = 0.0
# y_plus[3,12,4] = 0.0
# y_plus[3,12,5] = 0.0
# y_plus[3,12,6] = 0.0
# y_plus[3,12,7] = 0.0
# y_plus[3,12,8] = 0.5535246148692003
# y_plus[3,12,9] = 0.0
# y_plus[3,12,10] = 0.0
# y_plus[3,12,11] = 2.622116839298661
# y_plus[3,12,12] = 0.0
# y_plus[3,12,13] = 2.9980174330474796
# y_plus[3,12,14] = 0.0
# y_plus[3,12,15] = 7.4647137713777045
# y_plus[3,12,16] = 0.0
# y_plus[3,12,17] = 0.0
# y_plus[3,12,18] = 12.108875995830903
# y_plus[3,12,19] = 0.0
# y_plus[3,13,0] = 8.96409521558807
# y_plus[3,13,1] = 2.984784010444831
# y_plus[3,13,2] = 0.0
# y_plus[3,13,3] = 12.916951986004989
# y_plus[3,13,4] = 10.964213277873345
# y_plus[3,13,5] = 6.532613386542294
# y_plus[3,13,6] = 0.0
# y_plus[3,13,7] = 2.4292985188993614
# y_plus[3,13,8] = 16.5286202591516
# y_plus[3,13,9] = 18.165205141705705
# y_plus[3,13,10] = 0.0
# y_plus[3,13,11] = 0.0
# y_plus[3,13,12] = 5.044656528393714
# y_plus[3,13,13] = 13.063727443663371
# y_plus[3,13,14] = 8.589139247294906
# y_plus[3,13,15] = 8.153674038834527
# y_plus[3,13,16] = 8.853870035548187
# y_plus[3,13,17] = 12.172408393193848
# y_plus[3,13,18] = 0.0
# y_plus[3,13,19] = 7.421320971189796
# y_plus[3,14,0] = 8.456707165687988
# y_plus[3,14,1] = 0.8655539902107652
# y_plus[3,14,2] = 0.0
# y_plus[3,14,3] = 0.0
# y_plus[3,14,4] = 3.539131361574144
# y_plus[3,14,5] = 0.0
# y_plus[3,14,6] = 8.122525552940072
# y_plus[3,14,7] = 8.22302322708649
# y_plus[3,14,8] = 0.0
# y_plus[3,14,9] = 0.0
# y_plus[3,14,10] = 0.0
# y_plus[3,14,11] = 0.0
# y_plus[3,14,12] = 6.136159151720294
# y_plus[3,14,13] = 0.0
# y_plus[3,14,14] = 12.34062721141767
# y_plus[3,14,15] = 0.0
# y_plus[3,14,16] = 0.0
# y_plus[3,14,17] = 0.49450625612556554
# y_plus[3,14,18] = 0.0
# y_plus[3,14,19] = 0.0
# y_plus[3,15,0] = 1.1345230978890495
# y_plus[3,15,1] = 0.0
# y_plus[3,15,2] = 7.091052789506875
# y_plus[3,15,3] = 0.0
# y_plus[3,15,4] = 2.2766400142000016
# y_plus[3,15,5] = 6.185347847343021
# y_plus[3,15,6] = 1.4785629948468308
# y_plus[3,15,7] = 0.0
# y_plus[3,15,8] = 0.4041598002568447
# y_plus[3,15,9] = 0.0
# y_plus[3,15,10] = 0.0
# y_plus[3,15,11] = 0.7005077635324053
# y_plus[3,15,12] = 0.0
# y_plus[3,15,13] = 0.0
# y_plus[3,15,14] = 0.0
# y_plus[3,15,15] = 0.0
# y_plus[3,15,16] = 0.0
# y_plus[3,15,17] = 0.0
# y_plus[3,15,18] = 0.0
# y_plus[3,15,19] = 0.0
# y_plus[3,16,0] = 0.0
# y_plus[3,16,1] = 0.0
# y_plus[3,16,2] = 0.0
# y_plus[3,16,3] = 1.5831324945249872
# y_plus[3,16,4] = 0.0
# y_plus[3,16,5] = 0.0
# y_plus[3,16,6] = 0.0
# y_plus[3,16,7] = 1.3243867193954983
# y_plus[3,16,8] = 0.0
# y_plus[3,16,9] = 0.03971783338066981
# y_plus[3,16,10] = 0.0
# y_plus[3,16,11] = 0.0
# y_plus[3,16,12] = 0.0
# y_plus[3,16,13] = 0.0
# y_plus[3,16,14] = 0.0
# y_plus[3,16,15] = 0.0
# y_plus[3,16,16] = 0.0
# y_plus[3,16,17] = 0.0
# y_plus[3,16,18] = 0.0
# y_plus[3,16,19] = 0.0
# y_plus[3,17,0] = 0.0
# y_plus[3,17,1] = 0.0
# y_plus[3,17,2] = 0.0
# y_plus[3,17,3] = 0.0
# y_plus[3,17,4] = 0.0
# y_plus[3,17,5] = 0.0
# y_plus[3,17,6] = 0.0
# y_plus[3,17,7] = 0.0
# y_plus[3,17,8] = 1.573904415083681
# y_plus[3,17,9] = 0.0
# y_plus[3,17,10] = 0.0
# y_plus[3,17,11] = 0.0
# y_plus[3,17,12] = 0.0
# y_plus[3,17,13] = 1.248143333140625
# y_plus[3,17,14] = 0.0
# y_plus[3,17,15] = 0.0
# y_plus[3,17,16] = 0.0
# y_plus[3,17,17] = 0.0
# y_plus[3,17,18] = 0.0
# y_plus[3,17,19] = 0.0
# y_plus[3,18,0] = 0.0
# y_plus[3,18,1] = 0.0
# y_plus[3,18,2] = 0.0
# y_plus[3,18,3] = 0.0
# y_plus[3,18,4] = 0.0
# y_plus[3,18,5] = 0.0
# y_plus[3,18,6] = 0.0
# y_plus[3,18,7] = 0.0
# y_plus[3,18,8] = 0.0
# y_plus[3,18,9] = 0.0
# y_plus[3,18,10] = 0.0
# y_plus[3,18,11] = 0.0
# y_plus[3,18,12] = 0.0
# y_plus[3,18,13] = 0.0
# y_plus[3,18,14] = 0.0
# y_plus[3,18,15] = 0.0
# y_plus[3,18,16] = 0.0
# y_plus[3,18,17] = 0.0
# y_plus[3,18,18] = 0.0
# y_plus[3,18,19] = 0.0
# y_plus[3,19,0] = 0.0
# y_plus[3,19,1] = 0.0
# y_plus[3,19,2] = 0.0
# y_plus[3,19,3] = 0.0
# y_plus[3,19,4] = 0.0
# y_plus[3,19,5] = 0.0
# y_plus[3,19,6] = 0.0
# y_plus[3,19,7] = 0.0
# y_plus[3,19,8] = 0.0
# y_plus[3,19,9] = 0.0
# y_plus[3,19,10] = 0.0
# y_plus[3,19,11] = 0.0
# y_plus[3,19,12] = 0.0
# y_plus[3,19,13] = 0.0
# y_plus[3,19,14] = 0.0
# y_plus[3,19,15] = 0.0
# y_plus[3,19,16] = 0.0
# y_plus[3,19,17] = 0.0
# y_plus[3,19,18] = 0.0
# y_plus[3,19,19] = 0.0
# y_plus[3,20,0] = 0.0
# y_plus[3,20,1] = 0.0
# y_plus[3,20,2] = 0.0
# y_plus[3,20,3] = 0.0
# y_plus[3,20,4] = 0.0
# y_plus[3,20,5] = 0.0
# ...
# e_minus[9,6,3] = 0.0
# e_minus[9,6,4] = 0.0
# e_minus[9,6,5] = 0.0
# e_minus[9,6,6] = 0.0
# e_minus[9,6,7] = 0.0
# e_minus[9,6,8] = 0.0
# e_minus[9,6,9] = 0.0
# e_minus[9,6,10] = 0.0
# e_minus[9,6,11] = 0.0
# e_minus[9,6,12] = 0.0
# e_minus[9,6,13] = 0.0
# e_minus[9,6,14] = 0.0
# e_minus[9,6,15] = 0.0
# e_minus[9,6,16] = 0.0
# e_minus[9,6,17] = 0.0
# e_minus[9,6,18] = 0.0
# e_minus[9,6,19] = 0.0
# e_minus[9,7,0] = 0.0
# e_minus[9,7,1] = 0.0
# e_minus[9,7,2] = 0.0
# e_minus[9,7,3] = 0.0
# e_minus[9,7,4] = 0.0
# e_minus[9,7,5] = 0.0
# e_minus[9,7,6] = 0.0
# e_minus[9,7,7] = 0.0
# e_minus[9,7,8] = 0.0
# e_minus[9,7,9] = 0.0
# e_minus[9,7,10] = 0.0
# e_minus[9,7,11] = 0.0
# e_minus[9,7,12] = 0.0
# e_minus[9,7,13] = 0.0
# e_minus[9,7,14] = 0.0
# e_minus[9,7,15] = 0.0
# e_minus[9,7,16] = 0.0
# e_minus[9,7,17] = 0.0
# e_minus[9,7,18] = 0.0
# e_minus[9,7,19] = 0.0
# e_minus[9,8,0] = 0.0
# e_minus[9,8,1] = 0.0
# e_minus[9,8,2] = 0.0
# e_minus[9,8,3] = 0.0
# e_minus[9,8,4] = 0.0
# e_minus[9,8,5] = 0.0
# e_minus[9,8,6] = 0.0
# e_minus[9,8,7] = 0.0
# e_minus[9,8,8] = 0.0
# e_minus[9,8,9] = 0.0
# e_minus[9,8,10] = 0.0
# e_minus[9,8,11] = 0.0
# e_minus[9,8,12] = 0.0
# e_minus[9,8,13] = 0.0
# e_minus[9,8,14] = 0.0
# e_minus[9,8,15] = 0.0
# e_minus[9,8,16] = 0.0
# e_minus[9,8,17] = 0.0
# e_minus[9,8,18] = 0.0
# e_minus[9,8,19] = 0.0
# e_minus[9,9,0] = 0.0
# e_minus[9,9,1] = 0.0
# e_minus[9,9,2] = 0.0
# e_minus[9,9,3] = 0.0
# e_minus[9,9,4] = 0.0
# e_minus[9,9,5] = 0.0
# e_minus[9,9,6] = 0.0
# e_minus[9,9,7] = 0.0
# e_minus[9,9,8] = 0.0
# e_minus[9,9,9] = 0.0
# e_minus[9,9,10] = 0.0
# e_minus[9,9,11] = 0.0
# e_minus[9,9,12] = 0.0
# e_minus[9,9,13] = 0.0
# e_minus[9,9,14] = 0.0
# e_minus[9,9,15] = 0.0
# e_minus[9,9,16] = 0.0
# e_minus[9,9,17] = 0.0
# e_minus[9,9,18] = 0.0
# e_minus[9,9,19] = 0.0
# e_minus[9,10,0] = 0.0
# e_minus[9,10,1] = 0.0
# e_minus[9,10,2] = 0.0
# e_minus[9,10,3] = 0.0
# e_minus[9,10,4] = 0.0
# e_minus[9,10,5] = 0.0
# e_minus[9,10,6] = 0.0
# e_minus[9,10,7] = 0.0
# e_minus[9,10,8] = 0.0
# e_minus[9,10,9] = 0.0
# e_minus[9,10,10] = 0.0
# e_minus[9,10,11] = 0.0
# e_minus[9,10,12] = 0.0
# e_minus[9,10,13] = 0.0
# e_minus[9,10,14] = 0.0
# e_minus[9,10,15] = 0.0
# e_minus[9,10,16] = 0.0
# e_minus[9,10,17] = 0.0
# e_minus[9,10,18] = 0.0
# e_minus[9,10,19] = 0.0
# e_minus[9,11,0] = 0.0
# e_minus[9,11,1] = 0.0
# e_minus[9,11,2] = 0.0
# e_minus[9,11,3] = 0.0
# e_minus[9,11,4] = 0.0
# e_minus[9,11,5] = 0.0
# e_minus[9,11,6] = 0.0
# e_minus[9,11,7] = 0.0
# e_minus[9,11,8] = 0.0
# e_minus[9,11,9] = 0.0
# e_minus[9,11,10] = 0.0
# e_minus[9,11,11] = 0.0
# e_minus[9,11,12] = 0.0
# e_minus[9,11,13] = 0.0
# e_minus[9,11,14] = 0.0
# e_minus[9,11,15] = 0.0
# e_minus[9,11,16] = 0.0
# e_minus[9,11,17] = 0.0
# e_minus[9,11,18] = 0.0
# e_minus[9,11,19] = 0.0
# e_minus[9,12,0] = 0.0
# e_minus[9,12,1] = 0.0
# e_minus[9,12,2] = 0.0
# e_minus[9,12,3] = 0.0
# e_minus[9,12,4] = 0.0
# e_minus[9,12,5] = 0.0
# e_minus[9,12,6] = 0.0
# e_minus[9,12,7] = 0.0
# e_minus[9,12,8] = 0.0
# e_minus[9,12,9] = 0.7278665446229176
# e_minus[9,12,10] = 0.0
# e_minus[9,12,11] = 0.0
# e_minus[9,12,12] = 0.0
# e_minus[9,12,13] = 0.0
# e_minus[9,12,14] = 0.0
# e_minus[9,12,15] = 0.0
# e_minus[9,12,16] = 0.0
# e_minus[9,12,17] = 0.0
# e_minus[9,12,18] = 0.0
# e_minus[9,12,19] = 0.0
# e_minus[9,13,0] = 0.0
# e_minus[9,13,1] = 0.0
# e_minus[9,13,2] = 0.0
# e_minus[9,13,3] = 0.0
# e_minus[9,13,4] = 0.0
# e_minus[9,13,5] = 0.0
# e_minus[9,13,6] = 0.0
# e_minus[9,13,7] = 0.0
# e_minus[9,13,8] = 0.0
# e_minus[9,13,9] = 0.0
# e_minus[9,13,10] = 0.0
# e_minus[9,13,11] = 0.0
# e_minus[9,13,12] = 0.0
# e_minus[9,13,13] = 0.0
# e_minus[9,13,14] = 0.0
# e_minus[9,13,15] = 0.0
# e_minus[9,13,16] = 0.0
# e_minus[9,13,17] = 0.0
# e_minus[9,13,18] = 0.3176309273322566
# e_minus[9,13,19] = 0.0
# e_minus[9,14,0] = 0.0
# e_minus[9,14,1] = 0.0
# e_minus[9,14,2] = 0.0
# e_minus[9,14,3] = 0.0
# e_minus[9,14,4] = 0.0
# e_minus[9,14,5] = 0.0
# e_minus[9,14,6] = 0.0
# e_minus[9,14,7] = 0.0
# e_minus[9,14,8] = 0.0
# e_minus[9,14,9] = 0.0
# e_minus[9,14,10] = 0.0
# e_minus[9,14,11] = 0.0
# e_minus[9,14,12] = 0.0
# e_minus[9,14,13] = 0.0
# e_minus[9,14,14] = 0.0
# e_minus[9,14,15] = 0.0
# e_minus[9,14,16] = 0.0
# e_minus[9,14,17] = 0.0
# e_minus[9,14,18] = 0.0
# e_minus[9,14,19] = 0.0
# e_minus[9,15,0] = 0.0
# e_minus[9,15,1] = 0.0
# e_minus[9,15,2] = 0.0
# e_minus[9,15,3] = 0.0
# e_minus[9,15,4] = 0.0
# e_minus[9,15,5] = 0.0
# e_minus[9,15,6] = 0.21625000310721293
# e_minus[9,15,7] = 0.0
# e_minus[9,15,8] = 0.0
# e_minus[9,15,9] = 0.0
# e_minus[9,15,10] = 0.0
# e_minus[9,15,11] = 0.0
# e_minus[9,15,12] = 0.0
# e_minus[9,15,13] = 0.0
# e_minus[9,15,14] = 0.0
# e_minus[9,15,15] = 0.0
# e_minus[9,15,16] = 1.0119108442878177
# e_minus[9,15,17] = 0.0
# e_minus[9,15,18] = 0.0
# e_minus[9,15,19] = 0.0
# e_minus[9,16,0] = 0.0
# e_minus[9,16,1] = 0.0
# e_minus[9,16,2] = 0.0
# e_minus[9,16,3] = 0.0
# e_minus[9,16,4] = 0.0
# e_minus[9,16,5] = 0.0
# e_minus[9,16,6] = 0.0
# e_minus[9,16,7] = 0.0
# e_minus[9,16,8] = 0.0
# e_minus[9,16,9] = 0.0
# e_minus[9,16,10] = 0.0
# e_minus[9,16,11] = 0.0
# e_minus[9,16,12] = 0.0
# e_minus[9,16,13] = 0.0
# e_minus[9,16,14] = 0.0
# e_minus[9,16,15] = 0.0
# e_minus[9,16,16] = 0.0
# e_minus[9,16,17] = 0.0
# e_minus[9,16,18] = 0.0
# e_minus[9,16,19] = 0.0
# e_minus[9,17,0] = 0.0
# e_minus[9,17,1] = 0.0
# e_minus[9,17,2] = 0.0
# e_minus[9,17,3] = 0.0
# e_minus[9,17,4] = 0.0
# e_minus[9,17,5] = 0.0
# e_minus[9,17,6] = 0.0
# e_minus[9,17,7] = 0.0
# e_minus[9,17,8] = 0.0
# e_minus[9,17,9] = 0.0
# e_minus[9,17,10] = 0.0
# e_minus[9,17,11] = 0.0
# e_minus[9,17,12] = 0.0
# e_minus[9,17,13] = 0.0
# e_minus[9,17,14] = 0.0
# e_minus[9,17,15] = 0.0
# e_minus[9,17,16] = 0.0
# e_minus[9,17,17] = 0.0
# e_minus[9,17,18] = 0.0
# e_minus[9,17,19] = 0.0
# e_minus[9,18,0] = 0.0
# e_minus[9,18,1] = 0.0
# e_minus[9,18,2] = 0.0
# e_minus[9,18,3] = 0.0
# e_minus[9,18,4] = 0.0
# e_minus[9,18,5] = 0.0
# e_minus[9,18,6] = 0.0
# e_minus[9,18,7] = 0.0
# e_minus[9,18,8] = 0.0
# e_minus[9,18,9] = 0.0
# e_minus[9,18,10] = 0.0
# e_minus[9,18,11] = 0.0
# e_minus[9,18,12] = 0.0
# e_minus[9,18,13] = 0.0
# e_minus[9,18,14] = 0.0
# e_minus[9,18,15] = 0.0
# e_minus[9,18,16] = 0.0
# e_minus[9,18,17] = 0.0
# e_minus[9,18,18] = 0.0
# e_minus[9,18,19] = 0.0
# e_minus[9,19,0] = 0.0
# e_minus[9,19,1] = 0.0
# e_minus[9,19,2] = 0.0
# e_minus[9,19,3] = 0.0
# e_minus[9,19,4] = 0.0
# e_minus[9,19,5] = 0.0
# e_minus[9,19,6] = 0.0
# e_minus[9,19,7] = 0.0
# e_minus[9,19,8] = 0.0
# e_minus[9,19,9] = 0.0
# e_minus[9,19,10] = 0.0
# e_minus[9,19,11] = 0.0
# e_minus[9,19,12] = 0.0
# e_minus[9,19,13] = 0.0
# e_minus[9,19,14] = 0.0
# e_minus[9,19,15] = 0.0
# e_minus[9,19,16] = 0.0
# e_minus[9,19,17] = 0.0
# e_minus[9,19,18] = 0.0
# e_minus[9,19,19] = 0.0
# e_minus[9,20,0] = 0.0
# e_minus[9,20,1] = 0.0
# e_minus[9,20,2] = 0.0
# e_minus[9,20,3] = 0.0
# e_minus[9,20,4] = 0.0
# e_minus[9,20,5] = 0.0
# e_minus[9,20,6] = 0.0
# e_minus[9,20,7] = 0.0
# e_minus[9,20,8] = 0.0
# e_minus[9,20,9] = 0.0
# e_minus[9,20,10] = 0.0
# e_minus[9,20,11] = 0.0
# e_minus[9,20,12] = 0.0
# e_minus[9,20,13] = 0.0
# e_minus[9,20,14] = 0.0
# e_minus[9,20,15] = 0.0
# e_minus[9,20,16] = 0.0
# e_minus[9,20,17] = 0.0
# e_minus[9,20,18] = 0.0
# e_minus[9,20,19] = 0.0
# e_minus[9,21,0] = 0.0
# e_minus[9,21,1] = 0.0
# e_minus[9,21,2] = 0.0
# e_minus[9,21,3] = 0.0
# e_minus[9,21,4] = 0.0
# e_minus[9,21,5] = 0.0
# e_minus[9,21,6] = 0.0
# e_minus[9,21,7] = 0.0
# e_minus[9,21,8] = 0.0
# e_minus[9,21,9] = 0.0
# e_minus[9,21,10] = 0.0
# e_minus[9,21,11] = 0.0
# e_minus[9,21,12] = 0.0
# e_minus[9,21,13] = 0.0
# e_minus[9,21,14] = 0.0
# e_minus[9,21,15] = 0.0
# e_minus[9,21,16] = 0.0
# e_minus[9,21,17] = 0.0
# e_minus[9,21,18] = 0.0
# e_minus[9,21,19] = 0.0
# e_minus[9,22,0] = 0.0
# e_minus[9,22,1] = 0.0
# e_minus[9,22,2] = 0.0
# e_minus[9,22,3] = 0.0
# e_minus[9,22,4] = 0.0
# e_minus[9,22,5] = 0.0
# e_minus[9,22,6] = 0.0
# e_minus[9,22,7] = 0.0
# e_minus[9,22,8] = 0.0
# e_minus[9,22,9] = 0.0
# e_minus[9,22,10] = 0.0
# e_minus[9,22,11] = 0.0
# e_minus[9,22,12] = 0.0
# e_minus[9,22,13] = 0.0
# e_minus[9,22,14] = 0.0
# e_minus[9,22,15] = 0.0
# e_minus[9,22,16] = 0.0
# e_minus[9,22,17] = 0.0
# e_minus[9,22,18] = 0.0
# e_minus[9,22,19] = 0.0
# e_minus[9,23,0] = 0.0
# e_minus[9,23,1] = 0.0
# e_minus[9,23,2] = 0.0
# e_minus[9,23,3] = 0.0
# e_minus[9,23,4] = 0.0
# e_minus[9,23,5] = 0.0
# e_minus[9,23,6] = 0.0
# e_minus[9,23,7] = 0.0
# e_minus[9,23,8] = 0.0
# e_minus[9,23,9] = 0.0
# e_minus[9,23,10] = 0.0
# e_minus[9,23,11] = 0.0
# e_minus[9,23,12] = 0.0
# e_minus[9,23,13] = 0.0
# e_minus[9,23,14] = 0.0
# e_minus[9,23,15] = 0.0
# e_minus[9,23,16] = 0.0
# e_minus[9,23,17] = 0.0
# e_minus[9,23,18] = 0.0
# e_minus[9,23,19] = 0.0
# z_e[0,0] = 0.0
# z_e[0,1] = 0.0
# z_e[0,2] = 0.0
# z_e[0,3] = 0.0
# z_e[0,4] = 0.0
# z_e[0,5] = 0.0
# z_e[0,6] = 0.0
# z_e[0,7] = 0.0
# z_e[0,8] = 0.0
# z_e[0,9] = 0.0
# z_e[0,10] = 0.0
# z_e[0,11] = 0.0
# z_e[0,12] = 0.0
# z_e[0,13] = 0.0
# z_e[0,14] = 0.0
# z_e[0,15] = 0.0
# z_e[0,16] = 0.0
# z_e[0,17] = 0.0
# z_e[0,18] = 0.0
# z_e[0,19] = 0.0
# z_e[1,0] = 0.0
# z_e[1,1] = 0.0
# z_e[1,2] = 0.0
# z_e[1,3] = 0.0
# z_e[1,4] = 0.0
# z_e[1,5] = 0.0
# z_e[1,6] = 0.0
# z_e[1,7] = 0.0
# z_e[1,8] = 0.0
# z_e[1,9] = 0.0
# z_e[1,10] = 0.0
# z_e[1,11] = 0.0
# z_e[1,12] = 0.0
# z_e[1,13] = 0.0
# z_e[1,14] = 0.0
# z_e[1,15] = 0.0
# z_e[1,16] = 0.0
# z_e[1,17] = 0.0
# z_e[1,18] = 0.0
# z_e[1,19] = 0.0
# z_e[2,0] = 0.0
# z_e[2,1] = 0.0
# z_e[2,2] = 0.0
# z_e[2,3] = 0.0
# z_e[2,4] = 0.0
# z_e[2,5] = 0.0
# z_e[2,6] = 0.0
# z_e[2,7] = 0.0
# z_e[2,8] = 0.0
# z_e[2,9] = 0.0
# z_e[2,10] = 0.0
# z_e[2,11] = 0.0
# z_e[2,12] = 0.0
# z_e[2,13] = 0.0
# z_e[2,14] = 0.0
# z_e[2,15] = 0.0
# z_e[2,16] = 0.0
# z_e[2,17] = 0.0
# z_e[2,18] = 0.0
# z_e[2,19] = 0.0
# z_e[3,0] = 0.0
# z_e[3,1] = 0.0
# z_e[3,2] = 0.0
# z_e[3,3] = 0.0
# z_e[3,4] = 0.0
# z_e[3,5] = 0.0
# z_e[3,6] = 0.0
# z_e[3,7] = 0.0
# z_e[3,8] = 0.0
# z_e[3,9] = 0.0
# z_e[3,10] = 0.0
# z_e[3,11] = 0.0
# z_e[3,12] = 0.0
# z_e[3,13] = 0.0
# z_e[3,14] = 0.0
# z_e[3,15] = 0.0
# z_e[3,16] = 0.0
# z_e[3,17] = 0.0
# z_e[3,18] = 0.0
# z_e[3,19] = 0.0
# z_e[4,0] = 0.0
# z_e[4,1] = 0.0
# z_e[4,2] = 0.0
# z_e[4,3] = 0.0
# z_e[4,4] = 0.0
# z_e[4,5] = 0.0
# z_e[4,6] = 0.0
# z_e[4,7] = 0.0
# z_e[4,8] = 0.0
# z_e[4,9] = 0.0
# z_e[4,10] = 0.0
# z_e[4,11] = 0.0
# z_e[4,12] = 0.0
# z_e[4,13] = 0.0
# z_e[4,14] = 0.0
# z_e[4,15] = 0.0
# z_e[4,16] = 0.0
# z_e[4,17] = 0.0
# z_e[4,18] = 0.0
# z_e[4,19] = 0.0
# z_e[5,0] = 0.0
# z_e[5,1] = 0.0
# z_e[5,2] = 0.0
# z_e[5,3] = 0.0
# z_e[5,4] = 0.0
# z_e[5,5] = 0.0
# z_e[5,6] = 0.0
# z_e[5,7] = 0.0
# z_e[5,8] = 0.0
# z_e[5,9] = 0.0
# z_e[5,10] = 0.0
# z_e[5,11] = 0.0
# z_e[5,12] = 0.0
# z_e[5,13] = 0.0
# z_e[5,14] = 0.0
# z_e[5,15] = 0.0
# z_e[5,16] = 0.0
# z_e[5,17] = 0.0
# z_e[5,18] = 0.0
# z_e[5,19] = 0.0
# z_e[6,0] = 0.0
# z_e[6,1] = 0.0
# z_e[6,2] = 0.0
# z_e[6,3] = 0.0
# z_e[6,4] = 0.0
# z_e[6,5] = 0.0
# z_e[6,6] = 0.0
# z_e[6,7] = 0.0
# z_e[6,8] = 0.0
# z_e[6,9] = 0.0
# z_e[6,10] = 0.0
# z_e[6,11] = 0.0
# z_e[6,12] = 0.0
# z_e[6,13] = 0.0
# z_e[6,14] = 0.0
# z_e[6,15] = 0.0
# z_e[6,16] = 0.0
# z_e[6,17] = 0.0
# z_e[6,18] = 0.0
# z_e[6,19] = 0.0
# z_e[7,0] = 0.0
# z_e[7,1] = 0.0
# z_e[7,2] = 0.0
# z_e[7,3] = 0.0
# z_e[7,4] = 0.0
# z_e[7,5] = 0.0
# z_e[7,6] = 0.0
# z_e[7,7] = 0.0
# z_e[7,8] = 0.0
# z_e[7,9] = 0.0
# z_e[7,10] = 0.0
# z_e[7,11] = 0.0
# z_e[7,12] = 0.0
# z_e[7,13] = 0.0
# z_e[7,14] = 0.0
# z_e[7,15] = 0.0
# z_e[7,16] = 0.0
# z_e[7,17] = 0.0
# z_e[7,18] = 0.0
# z_e[7,19] = 0.0
# z_e[8,0] = 1.0
# z_e[8,1] = 1.0
# z_e[8,2] = 1.0
# z_e[8,3] = 1.0
# z_e[8,4] = 1.0
# z_e[8,5] = 1.0
# z_e[8,6] = 1.0
# z_e[8,7] = 0.0
# z_e[8,8] = 0.0
# z_e[8,9] = 1.0
# z_e[8,10] = 1.0
# z_e[8,11] = 1.0
# z_e[8,12] = 1.0
# z_e[8,13] = 1.0
# z_e[8,14] = 1.0
# z_e[8,15] = 1.0
# z_e[8,16] = 1.0
# z_e[8,17] = 1.0
# z_e[8,18] = 1.0
# z_e[8,19] = 1.0
# z_e[9,0] = 1.0
# z_e[9,1] = 1.0
# z_e[9,2] = 1.0
# z_e[9,3] = 1.0
# z_e[9,4] = 1.0
# z_e[9,5] = 1.0
# z_e[9,6] = 0.0
# z_e[9,7] = 0.0
# z_e[9,8] = 1.0
# z_e[9,9] = 1.0
# z_e[9,10] = 1.0
# z_e[9,11] = 1.0
# z_e[9,12] = 1.0
# z_e[9,13] = 1.0
# z_e[9,14] = 0.0
# z_e[9,15] = 1.0
# z_e[9,16] = 1.0
# z_e[9,17] = 1.0
# z_e[9,18] = 1.0
# z_e[9,19] = 1.0
# z_e[10,0] = 1.0
# z_e[10,1] = 1.0
# z_e[10,2] = 1.0
# z_e[10,3] = 1.0
# z_e[10,4] = 1.0
# z_e[10,5] = 1.0
# z_e[10,6] = 0.0
# z_e[10,7] = -0.0
# z_e[10,8] = 1.0
# z_e[10,9] = 1.0
# z_e[10,10] = 1.0
# z_e[10,11] = 1.0
# z_e[10,12] = 0.0
# z_e[10,13] = 1.0
# z_e[10,14] = 1.0
# z_e[10,15] = 1.0
# z_e[10,16] = 1.0
# z_e[10,17] = 1.0
# z_e[10,18] = 1.0
# z_e[10,19] = 1.0
# z_e[11,0] = 1.0
# z_e[11,1] = 1.0
# z_e[11,2] = 1.0
# z_e[11,3] = 1.0
# z_e[11,4] = 1.0
# z_e[11,5] = 1.0
# z_e[11,6] = 0.0
# z_e[11,7] = -0.0
# z_e[11,8] = 1.0
# z_e[11,9] = 1.0
# z_e[11,10] = 1.0
# z_e[11,11] = 1.0
# z_e[11,12] = 1.0
# z_e[11,13] = 1.0
# z_e[11,14] = 1.0
# z_e[11,15] = 0.0
# z_e[11,16] = 1.0
# z_e[11,17] = 1.0
# z_e[11,18] = 1.0
# z_e[11,19] = 1.0
# z_e[12,0] = 1.0
# z_e[12,1] = 1.0
# z_e[12,2] = 1.0
# z_e[12,3] = 1.0
# z_e[12,4] = 0.0
# z_e[12,5] = 1.0
# z_e[12,6] = 1.0
# z_e[12,7] = 1.0
# z_e[12,8] = 1.0
# z_e[12,9] = 0.0
# z_e[12,10] = 1.0
# z_e[12,11] = 1.0
# z_e[12,12] = 1.0
# z_e[12,13] = 0.0
# z_e[12,14] = 1.0
# z_e[12,15] = 1.0
# z_e[12,16] = 1.0
# z_e[12,17] = 1.0
# z_e[12,18] = 1.0
# z_e[12,19] = 1.0
# z_e[13,0] = 1.0
# z_e[13,1] = 1.0
# z_e[13,2] = 1.0
# z_e[13,3] = 1.0
# z_e[13,4] = 1.0
# z_e[13,5] = 1.0
# z_e[13,6] = 1.0
# z_e[13,7] = 0.0
# z_e[13,8] = 1.0
# z_e[13,9] = 1.0
# z_e[13,10] = 1.0
# z_e[13,11] = -0.0
# z_e[13,12] = 1.0
# z_e[13,13] = 1.0
# z_e[13,14] = 1.0
# z_e[13,15] = 0.0
# z_e[13,16] = 1.0
# z_e[13,17] = 1.0
# z_e[13,18] = 0.0
# z_e[13,19] = 1.0
# z_e[14,0] = 1.0
# z_e[14,1] = 1.0
# z_e[14,2] = 1.0
# z_e[14,3] = 1.0
# z_e[14,4] = 1.0
# z_e[14,5] = 1.0
# z_e[14,6] = 1.0
# z_e[14,7] = 0.0
# z_e[14,8] = 1.0
# z_e[14,9] = 1.0
# z_e[14,10] = 1.0
# z_e[14,11] = 1.0
# z_e[14,12] = 1.0
# z_e[14,13] = 1.0
# z_e[14,14] = 1.0
# z_e[14,15] = 0.0
# z_e[14,16] = 1.0
# z_e[14,17] = 1.0
# z_e[14,18] = 0.0
# z_e[14,19] = 1.0
# z_e[15,0] = 1.0
# z_e[15,1] = 1.0
# z_e[15,2] = 1.0
# z_e[15,3] = 1.0
# z_e[15,4] = 1.0
# z_e[15,5] = 1.0
# z_e[15,6] = -0.0
# z_e[15,7] = 1.0
# z_e[15,8] = 1.0
# z_e[15,9] = 1.0
# z_e[15,10] = 0.0
# z_e[15,11] = 1.0
# z_e[15,12] = 1.0
# z_e[15,13] = 1.0
# z_e[15,14] = 1.0
# z_e[15,15] = 1.0
# z_e[15,16] = -0.0
# z_e[15,17] = 1.0
# z_e[15,18] = 1.0
# z_e[15,19] = 0.0
# z_e[16,0] = -0.0
# z_e[16,1] = 1.0
# z_e[16,2] = 1.0
# z_e[16,3] = 1.0
# z_e[16,4] = 0.0
# z_e[16,5] = 1.0
# z_e[16,6] = 1.0
# z_e[16,7] = 1.0
# z_e[16,8] = 1.0
# z_e[16,9] = 1.0
# z_e[16,10] = 1.0
# z_e[16,11] = 1.0
# z_e[16,12] = 1.0
# z_e[16,13] = 1.0
# z_e[16,14] = 1.0
# z_e[16,15] = -0.0
# z_e[16,16] = 1.0
# z_e[16,17] = -0.0
# z_e[16,18] = 1.0
# z_e[16,19] = -0.0
# z_e[17,0] = 1.0
# z_e[17,1] = 1.0
# z_e[17,2] = 1.0
# z_e[17,3] = 1.0
# z_e[17,4] = 1.0
# z_e[17,5] = 1.0
# z_e[17,6] = 1.0
# z_e[17,7] = 1.0
# z_e[17,8] = 1.0
# z_e[17,9] = 1.0
# z_e[17,10] = 1.0
# z_e[17,11] = 1.0
# z_e[17,12] = 1.0
# z_e[17,13] = 1.0
# z_e[17,14] = -0.0
# z_e[17,15] = 1.0
# z_e[17,16] = 1.0
# z_e[17,17] = 1.0
# z_e[17,18] = 1.0
# z_e[17,19] = 1.0
# z_e[18,0] = 1.0
# z_e[18,1] = 1.0
# z_e[18,2] = 0.0
# z_e[18,3] = 0.0
# z_e[18,4] = 1.0
# z_e[18,5] = 0.0
# z_e[18,6] = 1.0
# z_e[18,7] = 1.0
# z_e[18,8] = 1.0
# z_e[18,9] = 0.0
# z_e[18,10] = 1.0
# z_e[18,11] = 1.0
# z_e[18,12] = 1.0
# z_e[18,13] = 1.0
# z_e[18,14] = 1.0
# z_e[18,15] = 0.0
# z_e[18,16] = 1.0
# z_e[18,17] = 0.0
# z_e[18,18] = 1.0
# z_e[18,19] = 0.0
# z_e[19,0] = 0.0
# z_e[19,1] = 0.0
# z_e[19,2] = 0.0
# z_e[19,3] = 0.0
# z_e[19,4] = 0.0
# z_e[19,5] = 0.0
# z_e[19,6] = 0.0
# z_e[19,7] = 0.0
# z_e[19,8] = 0.0
# z_e[19,9] = 0.0
# z_e[19,10] = 0.0
# z_e[19,11] = 0.0
# z_e[19,12] = 0.0
# z_e[19,13] = 0.0
# z_e[19,14] = 0.0
# z_e[19,15] = 0.0
# z_e[19,16] = 0.0
# z_e[19,17] = 0.0
# z_e[19,18] = 0.0
# z_e[19,19] = 0.0
# z_e[20,0] = 0.0
# z_e[20,1] = 0.0
# z_e[20,2] = 0.0
# z_e[20,3] = 0.0
# z_e[20,4] = 0.0
# z_e[20,5] = 0.0
# z_e[20,6] = 0.0
# z_e[20,7] = 0.0
# z_e[20,8] = 0.0
# z_e[20,9] = 0.0
# z_e[20,10] = 0.0
# z_e[20,11] = 0.0
# z_e[20,12] = 0.0
# z_e[20,13] = 0.0
# z_e[20,14] = 0.0
# z_e[20,15] = 0.0
# z_e[20,16] = 0.0
# z_e[20,17] = 0.0
# z_e[20,18] = 0.0
# z_e[20,19] = 0.0
# z_e[21,0] = 0.0
# z_e[21,1] = 0.0
# z_e[21,2] = 0.0
# z_e[21,3] = 0.0
# z_e[21,4] = 0.0
# z_e[21,5] = 0.0
# z_e[21,6] = 0.0
# z_e[21,7] = 0.0
# z_e[21,8] = 0.0
# z_e[21,9] = 0.0
# z_e[21,10] = 0.0
# z_e[21,11] = 0.0
# z_e[21,12] = 0.0
# z_e[21,13] = 0.0
# z_e[21,14] = 0.0
# z_e[21,15] = 0.0
# z_e[21,16] = 0.0
# z_e[21,17] = 0.0
# z_e[21,18] = 0.0
# z_e[21,19] = 0.0
# z_e[22,0] = 0.0
# z_e[22,1] = 0.0
# z_e[22,2] = 0.0
# z_e[22,3] = 0.0
# z_e[22,4] = 0.0
# z_e[22,5] = 0.0
# z_e[22,6] = 0.0
# z_e[22,7] = 0.0
# z_e[22,8] = 0.0
# z_e[22,9] = 0.0
# z_e[22,10] = 0.0
# z_e[22,11] = 0.0
# z_e[22,12] = 0.0
# z_e[22,13] = 0.0
# z_e[22,14] = 0.0
# z_e[22,15] = 0.0
# z_e[22,16] = 0.0
# z_e[22,17] = 0.0
# z_e[22,18] = 0.0
# z_e[22,19] = 0.0
# z_e[23,0] = 0.0
# z_e[23,1] = 0.0
# z_e[23,2] = 0.0
# z_e[23,3] = 0.0
# z_e[23,4] = 0.0
# z_e[23,5] = 0.0
# z_e[23,6] = 0.0
# z_e[23,7] = 0.0
# z_e[23,8] = 0.0
# z_e[23,9] = 0.0
# z_e[23,10] = 0.0
# z_e[23,11] = 0.0
# z_e[23,12] = 0.0
# z_e[23,13] = 0.0
# z_e[23,14] = 0.0
# z_e[23,15] = 0.0
# z_e[23,16] = 0.0
# z_e[23,17] = 0.0
# z_e[23,18] = 0.0
# z_e[23,19] = 0.0
# profit_increase[0] = 0.0
# profit_increase[1] = 0.0
# profit_increase[2] = 0.0
# profit_increase[3] = 0.0
# profit_increase[4] = 0.0
# profit_increase[5] = 0.0
# profit_increase[6] = 0.0
# profit_increase[7] = 0.0
# profit_increase[8] = 0.0
# profit_increase[9] = 0.0

# %% [markdown]
# ### solution pool

# %%
print(f"Status: {set.status}")
if set.status == GRB.OPTIMAL:
    print("모델이 Optimal입니다")

    # Solution pool 확인
    print("\nSolution Pool 정보:")
    print(f"찾은 해의 개수: {set.SolCount}")

    # Best solution의 objective value
    best_obj = set.ObjVal
    print(f"\nBest Solution의 Objective Value: {best_obj}")

    # 각 솔루션의 목적함수 값 출력 및 best solution 여부 확인
    solutions = []
    for i in range(set.SolCount):
        set.params.SolutionNumber = i
        solutions.append((i, set.PoolObjVal))
        print(f"\nSolution {i}:")
        print(f"Objective value: {set.PoolObjVal}")
        print(f"Objective bound: {set.PoolObjBound}")
    # Solution pool 파라미터 확인
    print("\nSolution Pool 파라미터:")
    print(f"PoolSolutions: {set.Params.PoolSolutions}")
    print(f"PoolSearchMode: {set.Params.PoolSearchMode}")
    print(f"PoolGap: {set.Params.PoolGap}")
elif set.status == GRB.UNBOUNDED:
    print("모델이 Unbounded입니다")
    # Unbounded ray 확인
    set.computeIIS()
    set.write("model.ilp")
elif set.status == GRB.INFEASIBLE:
    print("모델이 Infeasible입니다")
    # IIS 계산
    set.computeIIS()
    set.write("model.ilp")
elif set.status == GRB.INF_OR_UNBD:
    print("모델이 Infeasible 또는 Unbounded입니다")
    # Presolve를 끄고 다시 시도
    set.setParam("Presolve", 0)
    set.optimize()
elif set.status == GRB.TIME_LIMIT:
    print("시간 제한에 도달했습니다")
    if set.SolCount > 0:
        print(f"현재까지의 최선해: {set.objVal}")
        print(f"Optimality Gap: {set.MIPGap}")
# Out:
# Status: 2
# 모델이 Optimal입니다
#
# Solution Pool 정보:
# 찾은 해의 개수: 2
#
# Best Solution의 Objective Value: 11875.85223752153
#
# Solution 0:
# Objective value: 11875.85223752153
# Objective bound: 11876.199946851708
#
# Solution 1:
# Objective value: 11856.565941234956
# Objective bound: 11876.199946851708
#
# Solution Pool 파라미터:
# PoolSolutions: 10
# PoolSearchMode: 0
# PoolGap: inf

# %%
# 솔루션 풀에서 해 확인
solution_count = set.SolCount
print(f"총 {solution_count}개의 해가 저장되었습니다.")

for i in range(solution_count):
    set.setParam(GRB.Param.SolutionNumber, i)
    print(f"\n해 {i+1}: 목적 함수 값 = {set.PoolObjVal}")
    # x 변수 값 출력
    for t in range(14, 15):
        for i in range(1, 5):
            print(f"x[{i},{t}] = {x[i, t].Xn}")
# Out:
# 총 2개의 해가 저장되었습니다.
#
# 해 1: 목적 함수 값 = 11875.85223752153
# x[1,14] = 2.8936295086383392
# x[2,14] = 5.670012548583053
# x[3,14] = 4.5442714360194945
# x[4,14] = 4.867546287552169
#
# 해 2: 목적 함수 값 = 11856.565941234956
# x[1,14] = 2.8936295086383392
# x[2,14] = 5.670012548583053
# x[3,14] = 4.5442714360194945
# x[4,14] = 4.867546287552169

# %% [markdown]
# ### 결과 분석

# %% [markdown]
# #### 수익 분석

# %%
# Day-ahead 수익 비교
total_da_profit_obj = 0
for i in range(I):
    for t in range(T):
        total_da_profit_obj += P_DA[t] * x[i, t].x

# Real-time 수익 비교
total_rt_profit_obj = 0
for i in range(I):
    for t in range(T):
        for s in range(S):
            rt_profit_obj = P_RT[t, s] * e_plus[i, t, s].x
            total_rt_profit_obj += 1 / S * rt_profit_obj

# 패널티 비용 비교
total_penalty_cost_obj = 0
for i in range(I):
    for t in range(T):
        for s in range(S):
            penalty_cost_obj = P_PN[t] * e_minus[i, t, s].x
            total_penalty_cost_obj += 1 / S * penalty_cost_obj

# 총 시스템 이익 (목적 함수 기반)
total_system_profit_obj = (
    total_da_profit_obj + total_rt_profit_obj - total_penalty_cost_obj
)

# 결과 출력
print(f"DA: {total_da_profit_obj:.2f}")
print(f"RT: {total_rt_profit_obj:.2f}")
print(f"Penalty: {total_penalty_cost_obj:.2f}")
print(f"목적 함수 기반 총 이익 (_obj): {total_system_profit_obj:.2f}")
# Out:
# DA: 8561.60
# RT: 3648.34
# Penalty: 334.09
# 목적 함수 기반 총 이익 (_obj): 11875.85

# %%
for t in range(T):
    avg_e_plus = sum(e_plus_vals[i, t, s] for i in range(I) for s in range(S)) / S
    avg_e_minus = sum(e_minus_vals[i, t, s] for i in range(I) for s in range(S)) / S
    print(
        f"[시간 {t}] x: {sum(x_vals[i, t] for i in range(I)):.3f}, e+: {avg_e_plus:.3f}, e-: {avg_e_minus:.3f}"
    )

total_x = sum(x_vals[i, t] for i in range(I) for t in range(T))
print(f"총 하루 commitment: {total_x:.3f}")
# Out:
# [시간 0] x: 0.000, e+: 0.000, e-: 0.000
# [시간 1] x: 0.000, e+: 0.000, e-: 0.000
# [시간 2] x: 0.000, e+: 0.000, e-: 0.000
# [시간 3] x: 0.000, e+: 0.000, e-: 0.000
# [시간 4] x: 0.000, e+: 0.000, e-: 0.000
# [시간 5] x: 0.000, e+: 0.000, e-: 0.000
# [시간 6] x: 0.000, e+: 0.000, e-: 0.000
# [시간 7] x: 0.000, e+: 0.000, e-: 0.000
# [시간 8] x: 0.541, e+: 1.500, e-: 0.043
# [시간 9] x: 7.714, e+: 5.072, e-: 0.318
# [시간 10] x: 24.230, e+: 8.442, e-: 0.089
# [시간 11] x: 28.485, e+: 16.456, e-: 1.217
# [시간 12] x: 38.932, e+: 16.756, e-: 0.429
# [시간 13] x: 39.040, e+: 18.203, e-: 0.250
# [시간 14] x: 34.879, e+: 15.878, e-: 0.759
# [시간 15] x: 25.752, e+: 9.758, e-: 0.873
# [시간 16] x: 11.038, e+: 8.142, e-: 1.000
# [시간 17] x: 0.757, e+: 4.032, e-: 0.034
# [시간 18] x: 0.000, e+: 0.495, e-: 0.000
# [시간 19] x: 0.000, e+: 0.000, e-: 0.000
# [시간 20] x: 0.000, e+: 0.000, e-: 0.000
# [시간 21] x: 0.000, e+: 0.000, e-: 0.000
# [시간 22] x: 0.000, e+: 0.000, e-: 0.000
# [시간 23] x: 0.000, e+: 0.000, e-: 0.000
# 총 하루 commitment: 211.369

# %% [markdown]
# ### exchange process

# %%
for t in range(12,14):
    x_sum = sum(x_vals[i, t] for i in range(I))

    for s in range(S):
        y_plus_sum = sum(y_plus_vals[i, t, s] for i in range(I))
        y_minus_sum = sum(y_minus_vals[i, t, s] for i in range(I))

        e_plus_sum = sum(e_plus_vals[i, t, s] for i in range(I))
        e_minus_sum = sum(e_minus_vals[i, t, s] for i in range(I))

        print(f"[t={t} s={s}]")

        print(f"x 합계: {x_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {x_vals[i,t]:.2f}", end=" ")
        print(")")

        print(f"y+ 합계: {y_plus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {y_plus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print(f"y- 합계: {y_minus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {y_minus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print(f"e+ 합계: {e_plus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {e_plus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print(f"e- 합계: {e_minus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {e_minus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print("거래 내역:")
        print(f"d_max: {d_max_H[t,s].x:.2f}")
        for i in range(I):
            for j in range(I):
                if d_vals[i, j, t, s] > 1e-6:
                    print(
                        f"발전기 {i}가 발전기 {j}에게 {d_vals[i,j,t,s]:.2f} 전력을 줌"
                    )
        print()
# Out:
# [t=12 s=0]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 29.40 ([0] 10.20 [1] 0.00 [2] 3.42 [3] 0.00 [4] 4.40 [5] 0.00 [6] 11.38 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 14.62 ([0] 0.00 [1] 4.62 [2] 0.00 [3] 6.30 [4] 0.00 [5] 0.00 [6] 0.00 [7] 3.26 [8] 0.00 [9] 0.44 )
# e+ 합계: 14.78 ([0] 10.20 [1] 0.00 [2] 3.42 [3] 0.00 [4] 1.16 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 14.70
# 발전기 4가 발전기 3에게 2.80 전력을 줌
# 발전기 4가 발전기 9에게 0.44 전력을 줌
# 발전기 6가 발전기 1에게 4.62 전력을 줌
# 발전기 6가 발전기 3에게 3.50 전력을 줌
# 발전기 6가 발전기 7에게 3.26 전력을 줌
#
# [t=12 s=1]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 31.45 ([0] 0.00 [1] 5.02 [2] 8.37 [3] 0.00 [4] 1.23 [5] 0.00 [6] 8.12 [7] 4.73 [8] 0.00 [9] 3.97 )
# y- 합계: 12.08 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 6.30 [4] 0.00 [5] 1.32 [6] 0.00 [7] 0.00 [8] 4.47 [9] 0.00 )
# e+ 합계: 19.37 ([0] 0.00 [1] 0.00 [2] 2.07 [3] 0.00 [4] 1.23 [5] 0.00 [6] 7.36 [7] 4.73 [8] 0.00 [9] 3.97 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 15.73
# 발전기 1가 발전기 5에게 0.56 전력을 줌
# 발전기 1가 발전기 8에게 4.47 전력을 줌
# 발전기 2가 발전기 3에게 6.30 전력을 줌
# 발전기 6가 발전기 5에게 0.76 전력을 줌
#
# [t=12 s=2]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 35.41 ([0] 10.63 [1] 0.00 [2] 0.00 [3] 4.15 [4] 0.00 [5] 6.67 [6] 12.35 [7] 0.00 [8] 0.00 [9] 1.61 )
# y- 합계: 12.99 ([0] 0.00 [1] 4.62 [2] 1.98 [3] 0.00 [4] 1.33 [5] 0.00 [6] 0.00 [7] 0.59 [8] 4.47 [9] 0.00 )
# e+ 합계: 22.43 ([0] 10.63 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 1.62 [6] 10.17 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 17.71
# 발전기 3가 발전기 1에게 4.15 전력을 줌
# 발전기 5가 발전기 7에게 0.59 전력을 줌
# 발전기 5가 발전기 8에게 4.47 전력을 줌
# 발전기 6가 발전기 1에게 0.47 전력을 줌
# 발전기 6가 발전기 2에게 1.70 전력을 줌
# 발전기 9가 발전기 2에게 0.27 전력을 줌
# 발전기 9가 발전기 4에게 1.33 전력을 줌
#
# [t=12 s=3]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 48.05 ([0] 12.63 [1] 0.00 [2] 11.30 [3] 0.00 [4] 0.00 [5] 4.47 [6] 9.71 [7] 2.55 [8] 0.00 [9] 7.39 )
# y- 합계: 11.28 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 1.44 [4] 5.38 [5] 0.00 [6] 0.00 [7] 0.00 [8] 4.47 [9] 0.00 )
# e+ 합계: 36.77 ([0] 12.63 [1] 0.00 [2] 6.83 [3] 0.00 [4] 0.00 [5] 4.47 [6] 8.27 [7] 2.55 [8] 0.00 [9] 2.01 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 24.03
# 발전기 2가 발전기 8에게 4.47 전력을 줌
# 발전기 6가 발전기 3에게 1.44 전력을 줌
# 발전기 9가 발전기 4에게 5.38 전력을 줌
#
# [t=12 s=4]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 11.20 ([0] 0.00 [1] 3.01 [2] 0.00 [3] 0.00 [4] 3.12 [5] 0.00 [6] 0.00 [7] 2.89 [8] 2.18 [9] 0.00 )
# y- 합계: 12.67 ([0] 0.87 [1] 0.00 [2] 0.00 [3] 4.03 [4] 0.00 [5] 4.60 [6] 0.30 [7] 0.00 [8] 0.00 [9] 2.87 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 1.46 ([0] 0.03 [1] 0.00 [2] 0.00 [3] 1.14 [4] 0.00 [5] 0.00 [6] 0.30 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 5.60
# 발전기 1가 발전기 5에게 0.14 전력을 줌
# 발전기 1가 발전기 9에게 2.87 전력을 줌
# 발전기 4가 발전기 0에게 0.84 전력을 줌
# 발전기 4가 발전기 5에게 2.28 전력을 줌
# 발전기 7가 발전기 3에게 2.89 전력을 줌
# 발전기 8가 발전기 5에게 2.18 전력을 줌
#
# [t=12 s=5]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 32.21 ([0] 9.80 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 16.71 [7] 0.00 [8] 0.00 [9] 5.70 )
# y- 합계: 20.54 ([0] 0.00 [1] 4.62 [2] 2.93 [3] 2.15 [4] 2.74 [5] 4.64 [6] 0.00 [7] 1.23 [8] 2.23 [9] 0.00 )
# e+ 합계: 11.67 ([0] 3.95 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 7.71 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 16.11
# 발전기 0가 발전기 1에게 4.62 전력을 줌
# 발전기 0가 발전기 7에게 1.23 전력을 줌
# 발전기 6가 발전기 2에게 2.93 전력을 줌
# 발전기 6가 발전기 3에게 2.15 전력을 줌
# 발전기 6가 발전기 4에게 1.68 전력을 줌
# 발전기 6가 발전기 8에게 2.23 전력을 줌
# 발전기 9가 발전기 4에게 1.07 전력을 줌
# 발전기 9가 발전기 5에게 4.64 전력을 줌
#
# [t=12 s=6]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 34.06 ([0] 0.00 [1] 0.00 [2] 8.40 [3] 0.00 [4] 4.09 [5] 0.00 [6] 10.86 [7] 2.78 [8] 0.00 [9] 7.94 )
# y- 합계: 18.28 ([0] 1.17 [1] 4.62 [2] 0.00 [3] 6.30 [4] 0.00 [5] 4.64 [6] 0.00 [7] 0.00 [8] 1.57 [9] 0.00 )
# e+ 합계: 15.77 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 2.92 [5] 0.00 [6] 7.43 [7] 0.00 [8] 0.00 [9] 5.42 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 17.03
# 발전기 2가 발전기 1에게 4.62 전력을 줌
# 발전기 2가 발전기 3에게 3.78 전력을 줌
# 발전기 4가 발전기 0에게 1.17 전력을 줌
# 발전기 6가 발전기 5에게 1.86 전력을 줌
# 발전기 6가 발전기 8에게 1.57 전력을 줌
# 발전기 7가 발전기 5에게 2.78 전력을 줌
# 발전기 9가 발전기 3에게 2.52 전력을 줌
#
# [t=12 s=7]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 22.19 ([0] 8.49 [1] 5.24 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 3.18 [7] 5.28 [8] 0.00 [9] 0.00 )
# y- 합계: 21.06 ([0] 0.00 [1] 0.00 [2] 2.16 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.00 [7] 0.00 [8] 2.58 [9] 0.00 )
# e+ 합계: 1.13 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 1.13 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 11.09
# 발전기 0가 발전기 3에게 4.74 전력을 줌
# 발전기 0가 발전기 5에게 3.76 전력을 줌
# 발전기 1가 발전기 2에게 2.16 전력을 줌
# 발전기 1가 발전기 4에게 2.20 전력을 줌
# 발전기 1가 발전기 5에게 0.88 전력을 줌
# 발전기 6가 발전기 4에게 3.18 전력을 줌
# 발전기 7가 발전기 3에게 1.56 전력을 줌
# 발전기 7가 발전기 8에게 2.58 전력을 줌
#
# [t=12 s=8]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 30.20 ([0] 9.91 [1] 2.09 [2] 4.42 [3] 0.55 [4] 0.00 [5] 3.40 [6] 7.32 [7] 0.00 [8] 1.92 [9] 0.60 )
# y- 합계: 5.38 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 5.38 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 24.82 ([0] 9.91 [1] 0.00 [2] 4.42 [3] 0.55 [4] 0.00 [5] 3.40 [6] 6.55 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 15.10
# 발전기 1가 발전기 4에게 2.09 전력을 줌
# 발전기 6가 발전기 4에게 0.77 전력을 줌
# 발전기 8가 발전기 4에게 1.92 전력을 줌
# 발전기 9가 발전기 4에게 0.60 전력을 줌
#
# [t=12 s=9]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 16.21 ([0] 4.58 [1] 0.00 [2] 7.44 [3] 0.00 [4] 0.00 [5] 2.04 [6] 2.15 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 23.33 ([0] 0.00 [1] 4.62 [2] 0.00 [3] 6.30 [4] 4.15 [5] 0.00 [6] 0.00 [7] 0.93 [8] 4.47 [9] 2.87 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 7.12 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 4.15 [5] 0.00 [6] 0.00 [7] 0.00 [8] 2.24 [9] 0.73 )
# 거래 내역:
# d_max: 8.11
# 발전기 0가 발전기 1에게 4.58 전력을 줌
# 발전기 2가 발전기 1에게 0.04 전력을 줌
# 발전기 2가 발전기 3에게 6.30 전력을 줌
# 발전기 2가 발전기 8에게 1.11 전력을 줌
# 발전기 5가 발전기 7에게 0.93 전력을 줌
# 발전기 5가 발전기 8에게 1.11 전력을 줌
# 발전기 6가 발전기 9에게 2.15 전력을 줌
#
# [t=12 s=10]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 42.33 ([0] 11.88 [1] 0.00 [2] 7.45 [3] 0.00 [4] 0.00 [5] 2.36 [6] 10.94 [7] 0.00 [8] 0.00 [9] 9.70 )
# y- 합계: 10.77 ([0] 0.00 [1] 2.73 [2] 0.00 [3] 0.62 [4] 0.00 [5] 0.00 [6] 0.00 [7] 4.11 [8] 3.31 [9] 0.00 )
# e+ 합계: 31.56 ([0] 7.95 [1] 0.00 [2] 4.72 [3] 0.00 [4] 0.00 [5] 2.36 [6] 10.94 [7] 0.00 [8] 0.00 [9] 5.59 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 21.16
# 발전기 0가 발전기 3에게 0.62 전력을 줌
# 발전기 0가 발전기 8에게 3.31 전력을 줌
# 발전기 2가 발전기 1에게 2.73 전력을 줌
# 발전기 9가 발전기 7에게 4.11 전력을 줌
#
# [t=12 s=11]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 20.52 ([0] 0.00 [1] 4.08 [2] 0.00 [3] 2.62 [4] 0.00 [5] 0.00 [6] 8.92 [7] 0.00 [8] 0.00 [9] 4.89 )
# y- 합계: 14.64 ([0] 1.40 [1] 0.00 [2] 3.52 [3] 0.00 [4] 5.38 [5] 2.87 [6] 0.00 [7] 0.71 [8] 0.75 [9] 0.00 )
# e+ 합계: 5.88 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.98 [7] 0.00 [8] 0.00 [9] 4.89 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 10.26
# 발전기 1가 발전기 4에게 4.08 전력을 줌
# 발전기 3가 발전기 0에게 1.40 전력을 줌
# 발전기 3가 발전기 4에게 1.22 전력을 줌
# 발전기 6가 발전기 2에게 3.52 전력을 줌
# 발전기 6가 발전기 4에게 0.08 전력을 줌
# 발전기 6가 발전기 5에게 2.87 전력을 줌
# 발전기 6가 발전기 7에게 0.71 전력을 줌
# 발전기 6가 발전기 8에게 0.75 전력을 줌
#
# [t=12 s=12]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 12.18 ([0] 6.53 [1] 0.00 [2] 0.00 [3] 0.00 [4] 1.68 [5] 3.21 [6] 0.00 [7] 0.50 [8] 0.00 [9] 0.25 )
# y- 합계: 11.11 ([0] 0.00 [1] 3.09 [2] 4.39 [3] 0.11 [4] 0.00 [5] 0.00 [6] 0.76 [7] 0.00 [8] 2.77 [9] 0.00 )
# e+ 합계: 1.07 ([0] 0.82 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.25 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 6.09
# 발전기 0가 발전기 1에게 1.40 전력을 줌
# 발전기 0가 발전기 2에게 4.31 전력을 줌
# 발전기 4가 발전기 1에게 1.68 전력을 줌
# 발전기 5가 발전기 2에게 0.07 전력을 줌
# 발전기 5가 발전기 3에게 0.11 전력을 줌
# 발전기 5가 발전기 6에게 0.76 전력을 줌
# 발전기 5가 발전기 8에게 2.27 전력을 줌
# 발전기 7가 발전기 8에게 0.50 전력을 줌
#
# [t=12 s=13]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 18.99 ([0] 0.00 [1] 7.21 [2] 2.65 [3] 3.00 [4] 0.00 [5] 0.00 [6] 6.14 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 18.99 ([0] 0.66 [1] 0.00 [2] 0.00 [3] 0.00 [4] 5.38 [5] 2.16 [6] 0.00 [7] 4.11 [8] 4.47 [9] 2.22 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 9.50
# 발전기 1가 발전기 4에게 2.73 전력을 줌
# 발전기 1가 발전기 5에게 2.16 전력을 줌
# 발전기 1가 발전기 7에게 2.32 전력을 줌
# 발전기 2가 발전기 4에게 2.65 전력을 줌
# 발전기 3가 발전기 0에게 0.66 전력을 줌
# 발전기 3가 발전기 8에게 0.12 전력을 줌
# 발전기 3가 발전기 9에게 2.22 전력을 줌
# 발전기 6가 발전기 7에게 1.79 전력을 줌
# 발전기 6가 발전기 8에게 4.35 전력을 줌
#
# [t=12 s=14]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 24.92 ([0] 0.00 [1] 0.00 [2] 6.64 [3] 0.00 [4] 0.19 [5] 0.77 [6] 0.45 [7] 8.67 [8] 5.38 [9] 2.81 )
# y- 합계: 6.91 ([0] 1.40 [1] 4.62 [2] 0.00 [3] 0.89 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 18.01 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.77 [6] 0.45 [7] 8.60 [8] 5.38 [9] 2.81 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 12.46
# 발전기 2가 발전기 0에게 1.33 전력을 줌
# 발전기 2가 발전기 1에게 4.62 전력을 줌
# 발전기 2가 발전기 3에게 0.69 전력을 줌
# 발전기 4가 발전기 3에게 0.19 전력을 줌
# 발전기 7가 발전기 0에게 0.07 전력을 줌
#
# [t=12 s=15]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 47.60 ([0] 13.53 [1] 3.05 [2] 8.45 [3] 7.46 [4] 0.00 [5] 0.85 [6] 11.15 [7] 0.00 [8] 3.11 [9] 0.00 )
# y- 합계: 12.36 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 5.38 [5] 0.00 [6] 0.00 [7] 4.11 [8] 0.00 [9] 2.87 )
# e+ 합계: 35.24 ([0] 13.53 [1] 0.00 [2] 8.45 [3] 2.08 [4] 0.00 [5] 0.00 [6] 10.94 [7] 0.00 [8] 0.24 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 23.80
# 발전기 1가 발전기 7에게 3.05 전력을 줌
# 발전기 3가 발전기 4에게 5.38 전력을 줌
# 발전기 5가 발전기 7에게 0.85 전력을 줌
# 발전기 6가 발전기 7에게 0.21 전력을 줌
# 발전기 8가 발전기 9에게 2.87 전력을 줌
#
# [t=12 s=16]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 20.05 ([0] 5.92 [1] 3.24 [2] 0.00 [3] 0.00 [4] 4.45 [5] 3.31 [6] 0.00 [7] 3.13 [8] 0.00 [9] 0.00 )
# y- 합계: 11.87 ([0] 0.00 [1] 0.00 [2] 4.39 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.15 [7] 0.00 [8] 4.47 [9] 2.87 )
# e+ 합계: 8.17 ([0] 5.77 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.50 [6] 0.00 [7] 1.91 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 10.02
# 발전기 0가 발전기 6에게 0.15 전력을 줌
# 발전기 1가 발전기 8에게 3.24 전력을 줌
# 발전기 4가 발전기 2에게 4.39 전력을 줌
# 발전기 4가 발전기 9에게 0.06 전력을 줌
# 발전기 5가 발전기 9에게 2.81 전력을 줌
# 발전기 7가 발전기 8에게 1.23 전력을 줌
#
# [t=12 s=17]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 36.28 ([0] 11.96 [1] 0.15 [2] 8.49 [3] 0.00 [4] 2.45 [5] 1.88 [6] 11.35 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 9.61 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 1.88 [4] 0.00 [5] 0.00 [6] 0.00 [7] 4.11 [8] 3.43 [9] 0.18 )
# e+ 합계: 26.67 ([0] 8.56 [1] 0.00 [2] 6.76 [3] 0.00 [4] 0.00 [5] 0.00 [6] 11.35 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 18.14
# 발전기 0가 발전기 7에게 1.67 전력을 줌
# 발전기 0가 발전기 8에게 1.74 전력을 줌
# 발전기 1가 발전기 3에게 0.15 전력을 줌
# 발전기 2가 발전기 3에게 1.72 전력을 줌
# 발전기 4가 발전기 7에게 2.45 전력을 줌
# 발전기 5가 발전기 8에게 1.69 전력을 줌
# 발전기 5가 발전기 9에게 0.18 전력을 줌
#
# [t=12 s=18]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 36.93 ([0] 3.62 [1] 0.79 [2] 4.67 [3] 12.11 [4] 0.00 [5] 0.00 [6] 10.54 [7] 0.00 [8] 0.69 [9] 4.50 )
# y- 합계: 6.12 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 5.38 [5] 0.28 [6] 0.00 [7] 0.46 [8] 0.00 [9] 0.00 )
# e+ 합계: 30.81 ([0] 3.62 [1] 0.79 [2] 4.67 [3] 6.45 [4] 0.00 [5] 0.00 [6] 10.54 [7] 0.00 [8] 0.69 [9] 4.04 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 18.47
# 발전기 3가 발전기 4에게 5.38 전력을 줌
# 발전기 3가 발전기 5에게 0.28 전력을 줌
# 발전기 9가 발전기 7에게 0.46 전력을 줌
#
# [t=12 s=19]
# x 합계: 38.93 ([0] 1.40 [1] 4.62 [2] 4.39 [3] 6.30 [4] 5.38 [5] 4.64 [6] 0.76 [7] 4.11 [8] 4.47 [9] 2.87 )
# y+ 합계: 43.80 ([0] 0.00 [1] 7.93 [2] 9.83 [3] 0.00 [4] 0.00 [5] 0.00 [6] 5.77 [7] 6.51 [8] 0.00 [9] 13.76 )
# y- 합계: 12.84 ([0] 0.18 [1] 0.00 [2] 0.00 [3] 6.30 [4] 1.24 [5] 0.65 [6] 0.00 [7] 0.00 [8] 4.47 [9] 0.00 )
# e+ 합계: 30.97 ([0] 0.00 [1] 1.40 [2] 3.53 [3] 0.00 [4] 0.00 [5] 0.00 [6] 5.77 [7] 6.51 [8] 0.00 [9] 13.76 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 21.90
# 발전기 1가 발전기 0에게 0.18 전력을 줌
# 발전기 1가 발전기 4에게 1.24 전력을 줌
# 발전기 1가 발전기 5에게 0.65 전력을 줌
# 발전기 1가 발전기 8에게 4.47 전력을 줌
# 발전기 2가 발전기 3에게 6.30 전력을 줌
#
# [t=13 s=0]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 40.36 ([0] 9.18 [1] 2.92 [2] 3.10 [3] 8.96 [4] 0.00 [5] 4.78 [6] 3.96 [7] 1.36 [8] 0.00 [9] 6.11 )
# y- 합계: 7.19 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 5.87 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.32 [9] 0.00 )
# e+ 합계: 33.18 ([0] 9.18 [1] 1.60 [2] 3.10 [3] 8.96 [4] 0.00 [5] 4.78 [6] 3.96 [7] 1.36 [8] 0.00 [9] 0.24 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 20.18
# 발전기 1가 발전기 8에게 1.32 전력을 줌
# 발전기 9가 발전기 4에게 5.87 전력을 줌
#
# [t=13 s=1]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 25.68 ([0] 0.00 [1] 6.52 [2] 2.06 [3] 2.98 [4] 5.53 [5] 0.00 [6] 0.00 [7] 8.60 [8] 0.00 [9] 0.00 )
# y- 합계: 7.87 ([0] 4.18 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 2.79 [6] 0.00 [7] 0.00 [8] 0.58 [9] 0.32 )
# e+ 합계: 17.81 ([0] 0.00 [1] 5.62 [2] 0.00 [3] 2.98 [4] 3.40 [5] 0.00 [6] 0.00 [7] 5.81 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 12.84
# 발전기 1가 발전기 8에게 0.58 전력을 줌
# 발전기 1가 발전기 9에게 0.32 전력을 줌
# 발전기 2가 발전기 0에게 2.06 전력을 줌
# 발전기 4가 발전기 0에게 2.13 전력을 줌
# 발전기 7가 발전기 5에게 2.79 전력을 줌
#
# [t=13 s=2]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 26.78 ([0] 0.00 [1] 2.69 [2] 0.00 [3] 0.00 [4] 0.00 [5] 3.17 [6] 0.00 [7] 7.80 [8] 4.27 [9] 8.85 )
# y- 합계: 15.33 ([0] 4.18 [1] 0.00 [2] 0.55 [3] 0.61 [4] 5.87 [5] 0.00 [6] 4.12 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 11.45 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 3.17 [6] 0.00 [7] 7.80 [8] 0.08 [9] 0.39 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 13.39
# 발전기 1가 발전기 4에게 2.69 전력을 줌
# 발전기 8가 발전기 0에게 4.18 전력을 줌
# 발전기 9가 발전기 2에게 0.55 전력을 줌
# 발전기 9가 발전기 3에게 0.61 전력을 줌
# 발전기 9가 발전기 4에게 3.18 전력을 줌
# 발전기 9가 발전기 6에게 4.12 전력을 줌
#
# [t=13 s=3]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 56.29 ([0] 8.59 [1] 0.00 [2] 5.83 [3] 12.92 [4] 0.58 [5] 6.67 [6] 0.00 [7] 0.00 [8] 6.90 [9] 14.82 )
# y- 합계: 9.18 ([0] 0.00 [1] 7.24 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.94 [7] 1.01 [8] 0.00 [9] 0.00 )
# e+ 합계: 47.11 ([0] 6.64 [1] 0.00 [2] 5.83 [3] 5.68 [4] 0.58 [5] 6.67 [6] 0.00 [7] 0.00 [8] 6.90 [9] 14.82 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 28.15
# 발전기 0가 발전기 6에게 0.94 전력을 줌
# 발전기 0가 발전기 7에게 1.01 전력을 줌
# 발전기 3가 발전기 1에게 7.24 전력을 줌
#
# [t=13 s=4]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 22.72 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 10.96 [4] 0.00 [5] 0.00 [6] 11.76 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 16.99 ([0] 1.96 [1] 0.00 [2] 3.57 [3] 0.00 [4] 5.87 [5] 0.60 [6] 0.00 [7] 3.76 [8] 0.91 [9] 0.32 )
# e+ 합계: 5.73 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 5.73 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 11.36
# 발전기 3가 발전기 0에게 1.96 전력을 줌
# 발전기 3가 발전기 4에게 5.87 전력을 줌
# 발전기 3가 발전기 7에게 3.14 전력을 줌
# 발전기 6가 발전기 2에게 3.57 전력을 줌
# 발전기 6가 발전기 5에게 0.60 전력을 줌
# 발전기 6가 발전기 7에게 0.63 전력을 줌
# 발전기 6가 발전기 8에게 0.91 전력을 줌
# 발전기 6가 발전기 9에게 0.32 전력을 줌
#
# [t=13 s=5]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 25.88 ([0] 0.00 [1] 0.00 [2] 2.46 [3] 6.53 [4] 0.00 [5] 0.00 [6] 0.00 [7] 7.10 [8] 9.80 [9] 0.00 )
# y- 합계: 13.00 ([0] 0.94 [1] 2.43 [2] 0.00 [3] 0.00 [4] 4.11 [5] 2.98 [6] 2.54 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 12.89 ([0] 0.00 [1] 0.00 [2] 0.47 [3] 2.62 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 9.80 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 12.94
# 발전기 2가 발전기 6에게 1.99 전력을 줌
# 발전기 3가 발전기 0에게 0.94 전력을 줌
# 발전기 3가 발전기 5에게 2.98 전력을 줌
# 발전기 7가 발전기 1에게 2.43 전력을 줌
# 발전기 7가 발전기 4에게 4.11 전력을 줌
# 발전기 7가 발전기 6에게 0.55 전력을 줌
#
# [t=13 s=6]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 35.63 ([0] 9.45 [1] 0.00 [2] 3.91 [3] 0.00 [4] 0.00 [5] 3.52 [6] 5.90 [7] 5.61 [8] 0.00 [9] 7.24 )
# y- 합계: 9.44 ([0] 0.00 [1] 2.96 [2] 0.00 [3] 0.61 [4] 5.87 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 26.19 ([0] 3.58 [1] 0.00 [2] 3.91 [3] 0.00 [4] 0.00 [5] 3.52 [6] 2.33 [7] 5.61 [8] 0.00 [9] 7.24 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 17.81
# 발전기 0가 발전기 4에게 5.87 전력을 줌
# 발전기 6가 발전기 1에게 2.96 전력을 줌
# 발전기 6가 발전기 3에게 0.61 전력을 줌
#
# [t=13 s=7]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 17.28 ([0] 1.45 [1] 0.00 [2] 8.44 [3] 2.43 [4] 0.00 [5] 0.00 [6] 0.36 [7] 0.00 [8] 0.89 [9] 3.72 )
# y- 합계: 17.28 ([0] 0.00 [1] 8.20 [2] 0.00 [3] 0.00 [4] 5.59 [5] 2.76 [6] 0.00 [7] 0.72 [8] 0.00 [9] 0.00 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 8.64
# 발전기 0가 발전기 1에게 1.45 전력을 줌
# 발전기 2가 발전기 1에게 6.57 전력을 줌
# 발전기 2가 발전기 5에게 1.87 전력을 줌
# 발전기 3가 발전기 1에게 0.19 전력을 줌
# 발전기 3가 발전기 4에게 1.87 전력을 줌
# 발전기 3가 발전기 7에게 0.37 전력을 줌
# 발전기 6가 발전기 7에게 0.36 전력을 줌
# 발전기 8가 발전기 5에게 0.89 전력을 줌
# 발전기 9가 발전기 4에게 3.72 전력을 줌
#
# [t=13 s=8]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 35.53 ([0] 8.48 [1] 0.00 [2] 0.00 [3] 16.53 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 10.52 )
# y- 합계: 23.72 ([0] 0.00 [1] 3.93 [2] 6.02 [3] 0.00 [4] 5.87 [5] 0.00 [6] 4.12 [7] 3.76 [8] 0.02 [9] 0.00 )
# e+ 합계: 11.81 ([0] 8.48 [1] 0.00 [2] 0.00 [3] 2.95 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.38 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 17.76
# 발전기 3가 발전기 1에게 3.93 전력을 줌
# 발전기 3가 발전기 4에게 5.87 전력을 줌
# 발전기 3가 발전기 7에게 3.76 전력을 줌
# 발전기 3가 발전기 8에게 0.02 전력을 줌
# 발전기 9가 발전기 2에게 6.02 전력을 줌
# 발전기 9가 발전기 6에게 4.12 전력을 줌
#
# [t=13 s=9]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 40.52 ([0] 3.48 [1] 0.00 [2] 0.00 [3] 18.17 [4] 0.00 [5] 0.00 [6] 0.00 [7] 8.28 [8] 0.00 [9] 10.59 )
# y- 합계: 16.03 ([0] 0.00 [1] 1.13 [2] 5.20 [3] 0.00 [4] 5.87 [5] 3.35 [6] 0.17 [7] 0.00 [8] 0.31 [9] 0.00 )
# e+ 합계: 24.49 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 14.21 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 10.28 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 20.26
# 발전기 0가 발전기 2에게 3.31 전력을 줌
# 발전기 0가 발전기 6에게 0.17 전력을 줌
# 발전기 3가 발전기 1에게 1.13 전력을 줌
# 발전기 3가 발전기 2에게 1.89 전력을 줌
# 발전기 3가 발전기 5에게 0.94 전력을 줌
# 발전기 7가 발전기 4에게 5.87 전력을 줌
# 발전기 7가 발전기 5에게 2.42 전력을 줌
# 발전기 9가 발전기 8에게 0.31 전력을 줌
#
# [t=13 s=10]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 36.37 ([0] 0.00 [1] 0.00 [2] 8.37 [3] 0.00 [4] 0.00 [5] 0.60 [6] 14.22 [7] 4.30 [8] 2.08 [9] 6.80 )
# y- 합계: 13.14 ([0] 0.00 [1] 8.20 [2] 0.00 [3] 0.61 [4] 4.33 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 23.23 ([0] 0.00 [1] 0.00 [2] 0.16 [3] 0.00 [4] 0.00 [5] 0.60 [6] 9.90 [7] 3.69 [8] 2.08 [9] 6.80 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 18.19
# 발전기 2가 발전기 1에게 8.20 전력을 줌
# 발전기 6가 발전기 4에게 4.33 전력을 줌
# 발전기 7가 발전기 3에게 0.61 전력을 줌
#
# [t=13 s=11]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 14.86 ([0] 0.00 [1] 0.00 [2] 7.43 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.81 [9] 5.62 )
# y- 합계: 15.33 ([0] 4.10 [1] 2.91 [2] 0.00 [3] 0.00 [4] 2.27 [5] 3.35 [6] 1.66 [7] 1.04 [8] 0.00 [9] 0.00 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.47 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.47 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 7.43
# 발전기 2가 발전기 4에게 1.80 전력을 줌
# 발전기 2가 발전기 5에게 3.35 전력을 줌
# 발전기 2가 발전기 6에게 1.66 전력을 줌
# 발전기 2가 발전기 7에게 0.62 전력을 줌
# 발전기 8가 발전기 1에게 1.81 전력을 줌
# 발전기 9가 발전기 0에게 4.10 전력을 줌
# 발전기 9가 발전기 1에게 1.10 전력을 줌
# 발전기 9가 발전기 7에게 0.42 전력을 줌
#
# [t=13 s=12]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 23.90 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 5.04 [4] 0.00 [5] 10.78 [6] 0.00 [7] 0.00 [8] 8.08 [9] 0.00 )
# y- 합계: 23.72 ([0] 4.18 [1] 8.20 [2] 2.78 [3] 0.00 [4] 5.87 [5] 0.00 [6] 1.04 [7] 1.33 [8] 0.00 [9] 0.32 )
# e+ 합계: 0.19 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.19 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 11.95
# 발전기 3가 발전기 4에게 5.04 전력을 줌
# 발전기 5가 발전기 1에게 5.13 전력을 줌
# 발전기 5가 발전기 2에게 2.78 전력을 줌
# 발전기 5가 발전기 6에게 1.04 전력을 줌
# 발전기 5가 발전기 7에게 1.33 전력을 줌
# 발전기 5가 발전기 9에게 0.32 전력을 줌
# 발전기 8가 발전기 0에게 4.18 전력을 줌
# 발전기 8가 발전기 1에게 3.07 전력을 줌
# 발전기 8가 발전기 4에게 0.82 전력을 줌
#
# [t=13 s=13]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 52.91 ([0] 13.50 [1] 0.00 [2] 0.00 [3] 13.06 [4] 0.00 [5] 5.14 [6] 7.53 [7] 0.62 [8] 0.00 [9] 13.05 )
# y- 합계: 14.67 ([0] 0.00 [1] 6.44 [2] 1.91 [3] 0.00 [4] 5.87 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.46 [9] 0.00 )
# e+ 합계: 38.23 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 13.06 [4] 0.00 [5] 5.14 [6] 6.36 [7] 0.62 [8] 0.00 [9] 13.05 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 26.45
# 발전기 0가 발전기 1에게 6.44 전력을 줌
# 발전기 0가 발전기 2에게 0.73 전력을 줌
# 발전기 0가 발전기 4에게 5.87 전력을 줌
# 발전기 0가 발전기 8에게 0.46 전력을 줌
# 발전기 6가 발전기 2에게 1.17 전력을 줌
#
# [t=13 s=14]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 42.08 ([0] 3.48 [1] 0.00 [2] 7.27 [3] 8.59 [4] 0.00 [5] 2.50 [6] 0.27 [7] 7.98 [8] 0.00 [9] 12.00 )
# y- 합계: 13.27 ([0] 0.00 [1] 5.89 [2] 0.00 [3] 0.00 [4] 5.87 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.51 [9] 0.00 )
# e+ 합계: 28.81 ([0] 3.48 [1] 0.00 [2] 7.27 [3] 2.72 [4] 0.00 [5] 0.98 [6] 0.27 [7] 7.98 [8] 0.00 [9] 6.11 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 21.04
# 발전기 3가 발전기 4에게 5.87 전력을 줌
# 발전기 5가 발전기 8에게 1.51 전력을 줌
# 발전기 9가 발전기 1에게 5.89 전력을 줌
#
# [t=13 s=15]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 18.69 ([0] 0.00 [1] 0.00 [2] 3.60 [3] 8.15 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 6.93 )
# y- 합계: 22.43 ([0] 4.18 [1] 0.22 [2] 0.00 [3] 0.00 [4] 5.87 [5] 3.35 [6] 2.66 [7] 3.76 [8] 2.39 [9] 0.00 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 3.74 ([0] 0.00 [1] 0.22 [2] 0.00 [3] 0.00 [4] 0.00 [5] 3.35 [6] 0.00 [7] 0.00 [8] 0.17 [9] 0.00 )
# 거래 내역:
# d_max: 9.35
# 발전기 2가 발전기 4에게 3.60 전력을 줌
# 발전기 3가 발전기 6에게 2.66 전력을 줌
# 발전기 3가 발전기 7에게 3.76 전력을 줌
# 발전기 3가 발전기 8에게 1.73 전력을 줌
# 발전기 9가 발전기 0에게 4.18 전력을 줌
# 발전기 9가 발전기 4에게 2.26 전력을 줌
# 발전기 9가 발전기 8에게 0.49 전력을 줌
#
# [t=13 s=16]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 38.83 ([0] 0.00 [1] 0.00 [2] 3.56 [3] 8.85 [4] 0.00 [5] 9.32 [6] 2.32 [7] 2.68 [8] 6.32 [9] 5.77 )
# y- 합계: 9.57 ([0] 1.45 [1] 5.62 [2] 0.00 [3] 0.00 [4] 2.50 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 29.26 ([0] 0.00 [1] 0.00 [2] 2.11 [3] 0.73 [4] 0.00 [5] 9.32 [6] 2.32 [7] 2.68 [8] 6.32 [9] 5.77 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 19.41
# 발전기 2가 발전기 0에게 1.45 전력을 줌
# 발전기 3가 발전기 1에게 5.62 전력을 줌
# 발전기 3가 발전기 4에게 2.50 전력을 줌
#
# [t=13 s=17]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 55.65 ([0] 5.94 [1] 0.00 [2] 0.00 [3] 12.17 [4] 8.68 [5] 0.00 [6] 10.02 [7] 0.00 [8] 4.90 [9] 13.94 )
# y- 합계: 17.65 ([0] 0.00 [1] 8.20 [2] 6.23 [3] 0.00 [4] 0.00 [5] 0.28 [6] 0.00 [7] 2.94 [8] 0.00 [9] 0.00 )
# e+ 합계: 38.00 ([0] 2.72 [1] 0.00 [2] 0.00 [3] 5.95 [4] 8.68 [5] 0.00 [6] 1.82 [7] 0.00 [8] 4.90 [9] 13.94 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 27.82
# 발전기 0가 발전기 5에게 0.28 전력을 줌
# 발전기 0가 발전기 7에게 2.94 전력을 줌
# 발전기 3가 발전기 2에게 6.23 전력을 줌
# 발전기 6가 발전기 1에게 8.20 전력을 줌
#
# [t=13 s=18]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 18.02 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 8.80 [5] 0.00 [6] 0.00 [7] 4.40 [8] 4.83 [9] 0.00 )
# y- 합계: 18.82 ([0] 2.97 [1] 1.32 [2] 6.23 [3] 0.51 [4] 0.00 [5] 3.35 [6] 4.12 [7] 0.00 [8] 0.00 [9] 0.32 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.79 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.47 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.32 )
# 거래 내역:
# d_max: 9.01
# 발전기 4가 발전기 2에게 5.92 전력을 줌
# 발전기 4가 발전기 5에게 2.88 전력을 줌
# 발전기 7가 발전기 1에게 1.32 전력을 줌
# 발전기 7가 발전기 2에게 0.31 전력을 줌
# 발전기 7가 발전기 6에게 2.77 전력을 줌
# 발전기 8가 발전기 0에게 2.97 전력을 줌
# 발전기 8가 발전기 3에게 0.51 전력을 줌
# 발전기 8가 발전기 6에게 1.35 전력을 줌
#
# [t=13 s=19]
# x 합계: 39.04 ([0] 4.18 [1] 8.20 [2] 6.23 [3] 0.61 [4] 5.87 [5] 3.35 [6] 4.12 [7] 3.76 [8] 2.39 [9] 0.32 )
# y+ 합계: 27.74 ([0] 6.75 [1] 0.00 [2] 0.00 [3] 7.42 [4] 0.03 [5] 5.81 [6] 0.00 [7] 0.00 [8] 0.00 [9] 7.73 )
# y- 합계: 12.05 ([0] 0.00 [1] 0.75 [2] 6.23 [3] 0.00 [4] 0.00 [5] 0.00 [6] 2.68 [7] 0.00 [8] 2.39 [9] 0.00 )
# e+ 합계: 15.69 ([0] 4.35 [1] 0.00 [2] 0.00 [3] 7.42 [4] 0.00 [5] 3.91 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# d_max: 13.87
# 발전기 0가 발전기 8에게 2.39 전력을 줌
# 발전기 4가 발전기 6에게 0.03 전력을 줌
# 발전기 5가 발전기 1에게 0.75 전력을 줌
# 발전기 5가 발전기 6에게 1.15 전력을 줌
# 발전기 9가 발전기 2에게 6.23 전력을 줌
# 발전기 9가 발전기 6에게 1.51 전력을 줌

# %%
d_given = np.zeros(I)
d_received = np.zeros(I)

for i in range(I):
    d_given[i] = sum(
        sum(d_vals[i, j, t, s] for j in range(I) if j != i for t in range(T)) / S
        for s in range(S)
    )
    d_received[i] = sum(
        sum(d_vals[j, i, t, s] for j in range(I) if j != i for t in range(T)) / S
        for s in range(S)
    )

set_d = pd.DataFrame({"set_d_given": d_given, "set_d_received": d_received})
set_d.to_csv("result/result_set4_d.csv", index=False)

# %% [markdown]
# ### 정산

# %%
total_der_profit = 0
der_profit = {}
for i in range(I):
    der_profit[i] = sum(P_DA[t] * x[i,t].x + sum(1/S * (P_RT[t,s] * e_plus[i,t,s].x - P_PN[t] * e_minus[i,t,s].x) for s in range(S)) for t in range(T))
    total_der_profit += der_profit[i]

print(f"\n모든 der의 profit 합계: {total_der_profit:.2f}")

print("\n최종 profit:")
for i in range(I):
    print(f"[{i}] {der_profit[i]:.2f} ({(der_profit[i]-only_profit[i].item())/only_profit[i].item() * 100:.2f}%)")
# Out:
# 모든 der의 profit 합계: 11875.85
#
# 최종 profit:
# [0] 1347.07 (11.83%)
# [1] 1049.45 (20.27%)
# [2] 1680.39 (35.79%)
# [3] 1255.81 (11.28%)
# [4] 1285.93 (77.56%)
# [5] 1023.84 (6.26%)
# [6] 1496.06 (-13.66%)
# [7] 1074.66 (-2.21%)
# [8] 847.92 (10.27%)
# [9] 814.73 (-12.46%)

# %% [markdown]
# ### 결과 저장

# %%
set_profit_value = pd.DataFrame({'set_profit_value': der_profit})
set_profit_value.to_csv('result/result_set4_profit.csv', index=False)

set_obj = pd.DataFrame({'set_obj': [set.objVal]})
set_obj.to_csv('result/result_set4_obj.csv', index=False)
