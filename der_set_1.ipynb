# %% [markdown]
# ### data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gurobipy as gp
from gurobipy import GRB

R_flat = pd.read_csv("result/result_R.csv")

I_len = R_flat["generator"].nunique()
T_len = R_flat["time"].nunique() 
S_len = R_flat["scenario"].nunique()

R = R_flat.pivot_table(
    values="value",
    index="generator",
    columns=["time", "scenario"]
).to_numpy()
R = R.reshape(I_len, T_len, S_len)

I, T, S = R.shape
prob = np.array([1 / S for _ in range(S)])

price_q = pd.read_csv(
    "/Users/jangseohyun/Documents/workspace/symply/DER/DATA_price.csv"
)
price_q["Time"] = pd.to_datetime(price_q["Time"], format="%Y-%m-%d %H:%M")

price_q["Hour"] = price_q["Time"].dt.floor("h")
price_h = price_q.groupby("Hour").mean(numeric_only=True)

price = price_h.iloc[: S * T]

P_DA = np.array(
    [sum(price["Price"].iloc[t + s * T] for s in range(S)) / S * 1.2 for t in range(T)]
)
P_RT = np.array([[price["Price"].iloc[t + s * T] for s in range(S)] for t in range(T)])
P_PN = np.array(
    [sum(price["Price"].iloc[t + s * T] for s in range(S)) / S * 2 for t in range(T)]
)

only_profit = np.array(pd.read_csv("result/result_only_profit.csv"))

# %% [markdown]
# ### settlement model

# %%
def my_callback(model, where):
    if where == GRB.Callback.MIP:
        obj_best = model.cbGet(GRB.Callback.MIP_OBJBST)
        obj_bound = model.cbGet(GRB.Callback.MIP_OBJBND)

        if obj_best != 0:  # obj_best가 0이 아닌 경우에만 계산
            mip_gap = abs(obj_best - obj_bound) / abs(obj_best)
        else:
            mip_gap = float("inf")  # obj_best가 0인 경우 무한대로 설정

        print(
            f"obj_best: {obj_best}, obj_bound: {obj_bound}, MIP Gap: {mip_gap:.4f}"
        )

set = gp.Model("Settlement")
# set.Params.OutputFlag = 0
# set.setParam('TimeLimit', 3600)
# set.setParam('Presolve', 0)
set.setParam("PoolSolutions", 15)
set.setParam("PoolSearchMode", 2)
set.setParam("PoolGap", 0.05)

x = set.addVars(I, T, vtype=GRB.CONTINUOUS, lb=0, name="x")
y_plus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="y_plus")
y_minus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="y_minus")
M_y = max(R[i, t, s] for i in range(I) for t in range(T) for s in range(S))
z_y = set.addVars(I, T, S, vtype=GRB.BINARY, name="z_y")

d = set.addVars(I, I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="d")
e_plus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="e_plus")
e_minus = set.addVars(I, T, S, vtype=GRB.CONTINUOUS, lb=0, name="e_minus")
M_e = max(sum(R[i, t, s] for i in range(I)) for t in range(T) for s in range(S))
z_e = set.addVars(T, S, vtype=GRB.BINARY, name="z_e") 
set.update()

# obj. func.
obj = gp.quicksum(
    P_DA[t] * x[i, t] for i in range(I) for t in range(T)
) + gp.quicksum(
    prob[s] * (P_RT[t, s] * e_plus[i, t, s] - P_PN[t] * e_minus[i, t, s])
    for i in range(I) for t in range(T) for s in range(S)
)

set.setObjective(obj, GRB.MAXIMIZE)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2611964
# Academic license - for non-commercial use only - expires 2026-01-20
# Set parameter PoolSolutions to value 15
# Set parameter PoolSearchMode to value 2
# Set parameter PoolGap to value 0.05

# %%
# x로 y+, y- 결정 지어주기
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(R[i, t, s] - x[i, t] == y_plus[i, t, s] - y_minus[i, t, s])

# y+, y- 둘 중 하나는 0이어야함
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(y_plus[i, t, s] <= M_y * z_y[i, t, s])
            set.addConstr(y_minus[i, t, s] <= M_y * (1 - z_y[i, t, s]))

# rt 조건
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(y_plus[i, t, s] <= R[i, t, s])

# sum e+, sum e- 결정 지어주기
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(gp.quicksum(R[i, t, s] for i in range(I)) - gp.quicksum(x[i, t] for i in range(I)) 
                          == gp.quicksum(e_plus[i, t, s] for i in range(I)) - gp.quicksum(e_minus[i, t, s] for i in range(I)))

# sum e+, sum e- 둘 중 하나는 0이어야 함
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(gp.quicksum(e_plus[i, t, s] for i in range(I)) <= M_e * z_e[t, s])
            set.addConstr(gp.quicksum(e_minus[i, t, s] for i in range(I)) <= M_e * (1 - z_e[t, s]))

# sum e+ <= sum R
for t in range(T):
    for s in range(S):
        set.addConstr(gp.quicksum(e_plus[i, t, s] for i in range(I)) <= gp.quicksum(R[i, t, s] for i in range(I)))

# e+, e- 정의
for i in range(I):
    for t in range(T):
        for s in range(S):
            # e_plus: 초과량에서 준 양을 뺀 것
            set.addConstr(
                e_plus[i,t,s] == y_plus[i,t,s] - gp.quicksum(d[i,j,t,s] for j in range(I) if j != i)
            )
            # e_minus: 부족량에서 받은 양을 뺀 것
            set.addConstr(
                e_minus[i,t,s] == y_minus[i,t,s] - gp.quicksum(d[j,i,t,s] for j in range(I) if j != i)
            )

# 전력 이동 제한
for i in range(I):
    for t in range(T):
        for s in range(S):
            # 본인이 주는 양은 자신의 y+을 넘을 수 없음
            set.addConstr(
                gp.quicksum(d[i, j, t, s] for j in range(I) if j != i)
                <= y_plus[i, t, s]
            )
            # 본인이 받는 양은 자신의 y-을 넘을 수 없음
            set.addConstr(
                gp.quicksum(d[j, i, t, s] for j in range(I) if j != i)
                <= y_minus[i, t, s]
            )

# 자기 자신과의 거래 방지
for i in range(I):
    for t in range(T):
        for s in range(S):
            set.addConstr(d[i, i, t, s] == 0)

# %%
set.optimize()

if set.status == GRB.OPTIMAL:
    x_vals = np.array([[x[i, t].x for t in range(T)] for i in range(I)])
    y_plus_vals = np.array(
        [[[y_plus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    y_minus_vals = np.array(
        [[[y_minus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    d_vals = np.array(
        [
            [[[d[i, j, t, s].x for s in range(S)] for t in range(T)] for j in range(I)]
            for i in range(I)
        ]
    )
    e_plus_vals = np.array(
        [[[e_plus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    e_minus_vals = np.array(
        [[[e_minus[i, t, s].x for s in range(S)] for t in range(T)] for i in range(I)]
    )
    print("\n- - - - - - - - - - - - - - - - - - - - - - - - -")
    print("Optimal solution found!")
    print(set.objVal)
    print(f"Optimality Gap: {set.MIPGap}")
else:
    print("\nNo optimal solution found.")
# Out:
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 24.3.0 24D70)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# PoolSolutions  15
# PoolSearchMode  2
# PoolGap  0.05
#
# Optimize a model with 58080 rows, 72720 columns and 499200 nonzeros
# Model fingerprint: 0xf5b2663f
# Variable types: 67440 continuous, 5280 integer (5280 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+01]
#   Objective range  [4e-04, 4e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-02, 9e+01]
# Presolve removed 47938 rows and 52147 columns
# Presolve time: 0.10s
# Presolved: 10142 rows, 20573 columns, 54309 nonzeros
# Variable types: 15293 continuous, 5280 integer (5280 binary)
#
# Root relaxation: objective 1.203099e+04, 6669 iterations, 0.05 seconds (0.09 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 12030.9909    0   72          - 12030.9909      -     -    0s
# H    0     0                    11872.725733 12026.7724  1.30%     -    0s
#      0     0 12026.7724    0  299 11872.7257 12026.7724  1.30%     -    0s
# H    0     0                    11878.020453 11998.6138  1.02%     -    0s
#      0     0 11998.6138    0  302 11878.0205 11998.6138  1.02%     -    0s
# H    0     0                    11878.130049 11998.6138  1.01%     -    0s
#      0     0 11878.7275    0    6 11878.1300 11878.7275  0.01%     -    0s
#      0     0 11878.5202    0    6 11878.1300 11878.5202  0.00%     -    0s
#      0     0 11878.5077    0   12 11878.1300 11878.5077  0.00%     -    0s
#      0     0 11878.4161    0    8 11878.1300 11878.4161  0.00%     -    0s
#      0     0 11878.4161    0   10 11878.1300 11878.4161  0.00%     -    0s
#      0     0 11878.4161    0   25 11878.1300 11878.4161  0.00%     -    1s
#      0     0 11878.4161    0   13 11878.1300 11878.4161  0.00%     -    1s
#      0     2 11878.4161    0   10 11878.1300 11878.4161  0.00%     -    1s
#
# Optimal solution found at node 3 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      3     8 11577.4430    2   14          - 11878.1300      -   515    1s
#
# Cutting planes:
#   Gomory: 29
#   Cover: 154
#   Implied bound: 405
#   Clique: 220
#   MIR: 79
#   Flow cover: 101
#   RLT: 470
#   Relax-and-lift: 105
#   BQP: 6
#   PSD: 6
#
# Explored 57 nodes (22202 simplex iterations) in 1.44 seconds (2.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 15: 11878.1 11878.1 11878.1 ... 11878.1
# No other solutions better than 11878.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.187813004865e+04, best bound 1.187813004865e+04, gap 0.0000%
#
# - - - - - - - - - - - - - - - - - - - - - - - - -
# Optimal solution found!
# 11878.130048654497
# Optimality Gap: 0.0

# %% [markdown]
# ### solution pool

# %%
print(f"Status: {set.status}")
if set.status == GRB.OPTIMAL:
    print("모델이 Optimal입니다")

    # Solution pool 확인
    print("\nSolution Pool 정보:")
    print(f"찾은 해의 개수: {set.SolCount}")

    # Best solution의 objective value
    best_obj = set.ObjVal
    print(f"\nBest Solution의 Objective Value: {best_obj}")

    # 각 솔루션의 목적함수 값 출력 및 best solution 여부 확인
    solutions = []
    for i in range(set.SolCount):
        set.params.SolutionNumber = i
        solutions.append((i, set.PoolObjVal))
        print(f"\nSolution {i}:")
        print(f"Objective value: {set.PoolObjVal}")
        print(f"Objective bound: {set.PoolObjBound}")
        print(
            f"Is Best Solution: {abs(set.PoolObjVal - best_obj) < 1e-9}"
        )  # 수치 오차 고려

        # Gap 계산 (best solution에 대해서만)
        if abs(set.PoolObjVal - best_obj) < 1e-9:
            gap = abs(set.PoolObjVal - set.ObjBound) / abs(set.PoolObjVal)
            print(f"Gap: {gap * 100:.3f}%")

    # Solution pool 파라미터 확인
    print("\nSolution Pool 파라미터:")
    print(f"PoolSolutions: {set.Params.PoolSolutions}")
    print(f"PoolSearchMode: {set.Params.PoolSearchMode}")
    print(f"PoolGap: {set.Params.PoolGap}")
elif set.status == GRB.UNBOUNDED:
    print("모델이 Unbounded입니다")
    # Unbounded ray 확인
    set.computeIIS()
    set.write("model.ilp")
elif set.status == GRB.INFEASIBLE:
    print("모델이 Infeasible입니다")
    # IIS 계산
    set.computeIIS()
    set.write("model.ilp")
elif set.status == GRB.INF_OR_UNBD:
    print("모델이 Infeasible 또는 Unbounded입니다")
    # Presolve를 끄고 다시 시도
    set.setParam('Presolve', 0)
    set.optimize()
elif set.status == GRB.TIME_LIMIT:
    print("시간 제한에 도달했습니다")
    if set.SolCount > 0:
        print(f"현재까지의 최선해: {set.objVal}")
        print(f"Optimality Gap: {set.MIPGap}")
# Out:
# Status: 2
# 모델이 Optimal입니다
#
# Solution Pool 정보:
# 찾은 해의 개수: 15
#
# Best Solution의 Objective Value: 11878.130048654497
#
# Solution 0:
# Objective value: 11878.130048654497
# Objective bound: 11878.13004865448
# Is Best Solution: True
# Gap: 0.000%
#
# Solution 1:
# Objective value: 11878.130048654495
# Objective bound: 11878.13004865448
# Is Best Solution: True
# Gap: 0.000%
#
# Solution 2:
# Objective value: 11878.130048654499
# Objective bound: 11878.13004865448
# Is Best Solution: True
# Gap: 0.000%
#
# Solution 3:
# Objective value: 11878.130048654497
# Objective bound: 11878.13004865448
# Is Best Solution: True
# Gap: 0.000%
#
# Solution 4:
# Objective value: 11878.130048654497
# Objective bound: 11878.13004865448
# Is Best Solution: True
# Gap: 0.000%
#
# Solution 5:
# Objective value: 11878.130048654497
# Objective bound: 11878.13004865448
# Is Best Solution: True
# Gap: 0.000%
#
# Solution 6:
# Objective value: 11878.130048654495
# Objective bound: 11878.13004865448
# Is Best Solution: True
# Gap: 0.000%
#
# Solution 7:
# Objective value: 11878.130048654495
# Objective bound: 11878.13004865448
# Is Best Solution: True
# Gap: 0.000%
#
# Solution 8:
# Objective value: 11878.130048654495
# Objective bound: 11878.13004865448
# Is Best Solution: True
# Gap: 0.000%
#
# Solution 9:
# Objective value: 11878.130048654493
# Objective bound: 11878.13004865448
# Is Best Solution: True
# Gap: 0.000%
#
# Solution 10:
# Objective value: 11878.130048654491
# Objective bound: 11878.13004865448
# Is Best Solution: True
# Gap: 0.000%
#
# Solution 11:
# Objective value: 11878.130048654479
# Objective bound: 11878.13004865448
# Is Best Solution: True
# Gap: 0.000%
#
# Solution 12:
# Objective value: 11878.13004865448
# Objective bound: 11878.13004865448
# Is Best Solution: True
# Gap: 0.000%
#
# Solution 13:
# Objective value: 11878.13004865448
# Objective bound: 11878.13004865448
# Is Best Solution: True
# Gap: 0.000%
#
# Solution 14:
# Objective value: 11878.13004865448
# Objective bound: 11878.13004865448
# Is Best Solution: True
# Gap: 0.000%
#
# Solution Pool 파라미터:
# PoolSolutions: 15
# PoolSearchMode: 2
# PoolGap: 0.05

# %%
solution_count = set.SolCount
print(f"총 {solution_count}개의 해가 저장되었습니다.")

for i in range(solution_count):
    set.setParam(GRB.Param.SolutionNumber, i)
    print(f"\n해 {i+1}: 목적 함수 값 = {set.PoolObjVal}")
    # x 변수 값 출력
    for t in range(13,14):
        for i in range(0,3):
            print(f"x[{i},{t}] = {x[i, t].Xn}")
# Out:
# 총 15개의 해가 저장되었습니다.
#
# 해 1: 목적 함수 값 = 11878.130048654497
# x[0,13] = 1.214528731058082
# x[1,13] = 13.791314225440981
# x[2,13] = 12.059063252715504
#
# 해 2: 목적 함수 값 = 11878.130048654495
# x[0,13] = 1.214528731058082
# x[1,13] = 13.791314225440981
# x[2,13] = 12.059063252715504
#
# 해 3: 목적 함수 값 = 11878.130048654499
# x[0,13] = 5.629269224427675
# x[1,13] = 5.292622131474802
# x[2,13] = 1.9579932850657453
#
# 해 4: 목적 함수 값 = 11878.130048654497
# x[0,13] = 5.629269224427675
# x[1,13] = 5.292622131474802
# x[2,13] = 1.9579932850657453
#
# 해 5: 목적 함수 값 = 11878.130048654497
# x[0,13] = 5.629269224427675
# x[1,13] = 5.292622131474802
# x[2,13] = 1.9579932850657453
#
# 해 6: 목적 함수 값 = 11878.130048654497
# x[0,13] = 5.629269224427675
# x[1,13] = 5.292622131474802
# x[2,13] = 1.9579932850657453
#
# 해 7: 목적 함수 값 = 11878.130048654495
# x[0,13] = 5.629269224427675
# x[1,13] = 5.292622131474802
# x[2,13] = 1.9579932850657453
#
# 해 8: 목적 함수 값 = 11878.130048654495
# x[0,13] = 5.629269224427675
# x[1,13] = 5.292622131474802
# x[2,13] = 1.9579932850657453
#
# 해 9: 목적 함수 값 = 11878.130048654495
# x[0,13] = 5.629269224427675
# x[1,13] = 5.292622131474802
# x[2,13] = 1.9579932850657453
#
# 해 10: 목적 함수 값 = 11878.130048654493
# x[0,13] = 5.629269224427675
# x[1,13] = 5.292622131474802
# x[2,13] = 1.9579932850657453
#
# 해 11: 목적 함수 값 = 11878.130048654491
# x[0,13] = 5.629269224427675
# x[1,13] = 5.292622131474802
# x[2,13] = 1.9579932850657453
#
# 해 12: 목적 함수 값 = 11878.130048654479
# x[0,13] = 1.214528731058067
# x[1,13] = 13.791314225440981
# x[2,13] = 12.059063252715507
#
# 해 13: 목적 함수 값 = 11878.13004865448
# x[0,13] = 5.629269224427675
# x[1,13] = 5.292622131474802
# x[2,13] = 1.9579932850657453
#
# 해 14: 목적 함수 값 = 11878.13004865448
# x[0,13] = 5.629269224427675
# x[1,13] = 5.292622131474802
# x[2,13] = 1.9579932850657453
#
# 해 15: 목적 함수 값 = 11878.13004865448
# x[0,13] = 5.629269224427675
# x[1,13] = 5.292622131474802
# x[2,13] = 1.9579932850657453

# %% [markdown]
# ### 결과 분석

# %% [markdown]
# #### 수익 분석

# %%
# Day-ahead 수익 비교
total_da_profit_obj = 0
for i in range(I):
    for t in range(T):
        total_da_profit_obj += P_DA[t] * x[i, t].x

# Real-time 수익 비교
total_rt_profit_obj = 0
for i in range(I):
    for t in range(T):
        for s in range(S):
            rt_profit_obj = P_RT[t, s] * e_plus[i, t, s].x
            total_rt_profit_obj += 1 / S * rt_profit_obj

# 패널티 비용 비교
total_penalty_cost_obj = 0
for i in range(I):
    for t in range(T):
        for s in range(S):
            penalty_cost_obj = P_PN[t] * e_minus[i, t, s].x
            total_penalty_cost_obj += 1 / S * penalty_cost_obj

# 총 시스템 이익 (목적 함수 기반)
total_system_profit_obj = (
    total_da_profit_obj + total_rt_profit_obj - total_penalty_cost_obj
)

# 결과 출력
print(f"DA: {total_da_profit_obj:.2f}")
print(f"RT: {total_rt_profit_obj:.2f}")
print(f"Penalty: {total_penalty_cost_obj:.2f}")
print(f"목적 함수 기반 총 이익 (_obj): {total_system_profit_obj:.2f}")
# Out:
# DA: 8602.60
# RT: 3616.68
# Penalty: 341.16
# 목적 함수 기반 총 이익 (_obj): 11878.13

# %% [markdown]
# #### 하루 aggregated 커밋량 분석

# %%
for t in range(T):
    avg_e_plus = sum(e_plus_vals[i, t, s] for i in range(I) for s in range(S)) / S
    avg_e_minus = sum(e_minus_vals[i, t, s] for i in range(I) for s in range(S)) / S
    print(f"[시간 {t}] x: {sum(x_vals[i, t] for i in range(I)):.3f}, e+: {avg_e_plus:.3f}, e-: {avg_e_minus:.3f}")

total_x = sum(x_vals[i, t] for i in range(I) for t in range(T))
print(f"총 하루 commitment: {total_x:.3f}")
# Out:
# [시간 0] x: 0.000, e+: 0.000, e-: 0.000
# [시간 1] x: 0.000, e+: 0.000, e-: 0.000
# [시간 2] x: 0.000, e+: 0.000, e-: 0.000
# [시간 3] x: 0.000, e+: 0.000, e-: 0.000
# [시간 4] x: 0.000, e+: 0.000, e-: 0.000
# [시간 5] x: 0.000, e+: 0.000, e-: 0.000
# [시간 6] x: 0.000, e+: 0.000, e-: 0.000
# [시간 7] x: 0.000, e+: 0.000, e-: 0.000
# [시간 8] x: 0.816, e+: 1.258, e-: 0.077
# [시간 9] x: 7.714, e+: 5.072, e-: 0.318
# [시간 10] x: 24.230, e+: 8.442, e-: 0.089
# [시간 11] x: 28.485, e+: 16.456, e-: 1.217
# [시간 12] x: 38.932, e+: 16.756, e-: 0.429
# [시간 13] x: 39.040, e+: 18.203, e-: 0.250
# [시간 14] x: 34.879, e+: 15.878, e-: 0.759
# [시간 15] x: 25.752, e+: 9.758, e-: 0.873
# [시간 16] x: 11.038, e+: 8.142, e-: 1.000
# [시간 17] x: 1.574, e+: 3.297, e-: 0.116
# [시간 18] x: 0.000, e+: 0.495, e-: 0.000
# [시간 19] x: 0.000, e+: 0.000, e-: 0.000
# [시간 20] x: 0.000, e+: 0.000, e-: 0.000
# [시간 21] x: 0.000, e+: 0.000, e-: 0.000
# [시간 22] x: 0.000, e+: 0.000, e-: 0.000
# [시간 23] x: 0.000, e+: 0.000, e-: 0.000
# 총 하루 commitment: 212.461

# %% [markdown]
# #### exchange process

# %%
for t in range(13,15):
    x_sum = sum(x_vals[i, t] for i in range(I))

    for s in range(S):
        y_plus_sum = sum(y_plus_vals[i, t, s] for i in range(I))
        y_minus_sum = sum(y_minus_vals[i, t, s] for i in range(I))

        e_plus_sum = sum(e_plus_vals[i, t, s] for i in range(I))
        e_minus_sum = sum(e_minus_vals[i, t, s] for i in range(I))

        R_sum = sum(R[i, t, s] for i in range(I))

        print(f"[t={t} s={s}]")

        print(f"x 합계: {x_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {x_vals[i,t]:.2f}", end=" ")
        print(")")

        print(f"R 합계: {R_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {R[i, t, s]:.2f}", end=" ")
        print(")")

        print(f"y+ 합계: {y_plus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {y_plus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print(f"y- 합계: {y_minus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {y_minus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print(f"e+ 합계: {e_plus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {e_plus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print(f"e- 합계: {e_minus_sum:.2f} (", end="")
        for i in range(I):
            print(f"[{i}] {e_minus_vals[i,t,s]:.2f}", end=" ")
        print(")")

        print("거래 내역:")
        for i in range(I):
            for j in range(I):
                if d_vals[i, j, t, s] > 1e-6:
                    print(
                        f"발전기 {i}가 발전기 {j}에게 {d_vals[i,j,t,s]:.2f} 전력을 줌"
                    )
        print()
# Out:
# [t=13 s=0]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 72.22 ([0] 13.36 [1] 11.12 [2] 9.33 [3] 9.57 [4] 0.00 [5] 8.13 [6] 8.08 [7] 5.12 [8] 1.07 [9] 6.42 )
# y+ 합계: 43.48 ([0] 12.15 [1] 0.00 [2] 0.00 [3] 8.96 [4] 0.00 [5] 7.54 [6] 8.08 [7] 4.30 [8] 0.00 [9] 2.45 )
# y- 합계: 10.30 ([0] 0.00 [1] 2.67 [2] 2.73 [3] 0.00 [4] 3.59 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.30 [9] 0.00 )
# e+ 합계: 33.18 ([0] 9.48 [1] 0.00 [2] 0.00 [3] 8.96 [4] 0.00 [5] 7.54 [6] 0.45 [7] 4.30 [8] 0.00 [9] 2.45 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 2.67 전력을 줌
# 발전기 6가 발전기 2에게 2.73 전력을 줌
# 발전기 6가 발전기 4에게 3.59 전력을 줌
# 발전기 6가 발전기 8에게 1.30 전력을 줌
#
# [t=13 s=1]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 56.85 ([0] 0.00 [1] 14.72 [2] 8.28 [3] 3.59 [4] 11.39 [5] 0.57 [6] 4.12 [7] 12.36 [8] 1.81 [9] 0.00 )
# y+ 합계: 27.37 ([0] 0.00 [1] 0.93 [2] 0.00 [3] 2.98 [4] 7.80 [5] 0.00 [6] 4.12 [7] 11.54 [8] 0.00 [9] 0.00 )
# y- 합계: 9.56 ([0] 1.21 [1] 0.00 [2] 3.77 [3] 0.00 [4] 0.00 [5] 0.03 [6] 0.00 [7] 0.00 [8] 0.56 [9] 3.97 )
# e+ 합계: 17.81 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 5.71 [5] 0.00 [6] 0.56 [7] 11.54 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 2에게 0.93 전력을 줌
# 발전기 3가 발전기 9에게 2.98 전력을 줌
# 발전기 4가 발전기 0에게 1.09 전력을 줌
# 발전기 4가 발전기 9에게 0.99 전력을 줌
# 발전기 6가 발전기 0에게 0.12 전력을 줌
# 발전기 6가 발전기 2에게 2.85 전력을 줌
# 발전기 6가 발전기 5에게 0.03 전력을 줌
# 발전기 6가 발전기 8에게 0.56 전력을 줌
#
# [t=13 s=2]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 50.49 ([0] 0.00 [1] 10.89 [2] 5.68 [3] 0.00 [4] 0.00 [5] 6.52 [6] 0.00 [7] 11.57 [8] 6.66 [9] 9.17 )
# y+ 합계: 26.14 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 5.92 [6] 0.00 [7] 10.74 [8] 4.28 [9] 5.19 )
# y- 합계: 14.70 ([0] 1.21 [1] 2.90 [2] 6.38 [3] 0.61 [4] 3.59 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 11.45 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 8.99 [8] 2.46 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 5가 발전기 2에게 4.09 전력을 줌
# 발전기 5가 발전기 4에게 1.84 전력을 줌
# 발전기 7가 발전기 4에게 1.76 전력을 줌
# 발전기 8가 발전기 0에게 1.21 전력을 줌
# 발전기 8가 발전기 3에게 0.61 전력을 줌
# 발전기 9가 발전기 1에게 2.90 전력을 줌
# 발전기 9가 발전기 2에게 2.29 전력을 줌
#
# [t=13 s=3]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 86.15 ([0] 12.77 [1] 0.97 [2] 12.06 [3] 13.53 [4] 6.44 [5] 10.02 [6] 3.18 [7] 2.76 [8] 9.29 [9] 15.13 )
# y+ 합계: 59.94 ([0] 11.56 [1] 0.00 [2] 0.00 [3] 12.92 [4] 2.85 [5] 9.43 [6] 3.18 [7] 1.93 [8] 6.91 [9] 11.16 )
# y- 합계: 12.82 ([0] 0.00 [1] 12.82 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 47.11 ([0] 11.56 [1] 0.00 [2] 0.00 [3] 12.92 [4] 0.00 [5] 4.57 [6] 0.00 [7] 0.00 [8] 6.91 [9] 11.16 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 4가 발전기 1에게 2.85 전력을 줌
# 발전기 5가 발전기 1에게 4.86 전력을 줌
# 발전기 6가 발전기 1에게 3.18 전력을 줌
# 발전기 7가 발전기 1에게 1.93 전력을 줌
#
# [t=13 s=4]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 44.77 ([0] 2.22 [1] 8.20 [2] 2.65 [3] 11.57 [4] 0.00 [5] 2.75 [6] 15.88 [7] 0.00 [8] 1.49 [9] 0.00 )
# y+ 합계: 30.01 ([0] 1.01 [1] 0.00 [2] 0.00 [3] 10.96 [4] 0.00 [5] 2.16 [6] 15.88 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 24.28 ([0] 0.00 [1] 5.59 [2] 9.41 [3] 0.00 [4] 3.59 [5] 0.00 [6] 0.00 [7] 0.82 [8] 0.89 [9] 3.97 )
# e+ 합계: 5.73 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 5.73 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 9에게 1.01 전력을 줌
# 발전기 3가 발전기 2에게 6.56 전력을 줌
# 발전기 3가 발전기 4에게 3.59 전력을 줌
# 발전기 3가 발전기 9에게 0.81 전력을 줌
# 발전기 5가 발전기 9에게 2.16 전력을 줌
# 발전기 6가 발전기 1에게 5.59 전력을 줌
# 발전기 6가 발전기 2에게 2.85 전력을 줌
# 발전기 6가 발전기 7에게 0.82 전력을 줌
# 발전기 6가 발전기 8에게 0.89 전력을 줌
#
# [t=13 s=5]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 51.93 ([0] 3.25 [1] 5.77 [2] 8.68 [3] 7.14 [4] 1.75 [5] 0.38 [6] 1.58 [7] 10.86 [8] 12.19 [9] 0.32 )
# y+ 합계: 30.00 ([0] 2.03 [1] 0.00 [2] 0.00 [3] 6.53 [4] 0.00 [5] 0.00 [6] 1.58 [7] 10.04 [8] 9.81 [9] 0.00 )
# y- 합계: 17.11 ([0] 0.00 [1] 8.02 [2] 3.38 [3] 0.00 [4] 1.84 [5] 0.22 [6] 0.00 [7] 0.00 [8] 0.00 [9] 3.66 )
# e+ 합계: 12.89 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 6.51 [4] 0.00 [5] 0.00 [6] 0.00 [7] 6.38 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 4에게 1.82 전력을 줌
# 발전기 0가 발전기 5에게 0.22 전력을 줌
# 발전기 3가 발전기 4에게 0.02 전력을 줌
# 발전기 6가 발전기 2에게 1.58 전력을 줌
# 발전기 7가 발전기 9에게 3.66 전력을 줌
# 발전기 8가 발전기 1에게 8.02 전력을 줌
# 발전기 8가 발전기 2에게 1.79 전력을 줌
#
# [t=13 s=6]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 65.23 ([0] 13.63 [1] 5.24 [2] 10.14 [3] 0.00 [4] 0.00 [5] 6.88 [6] 10.02 [7] 9.37 [8] 2.39 [9] 7.55 )
# y+ 합계: 40.86 ([0] 12.42 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 6.28 [6] 10.02 [7] 8.55 [8] 0.02 [9] 3.58 )
# y- 합계: 14.67 ([0] 0.00 [1] 8.55 [2] 1.92 [3] 0.61 [4] 3.59 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 26.19 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 4.04 [6] 10.02 [7] 8.55 [8] 0.00 [9] 3.58 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 7.94 전력을 줌
# 발전기 0가 발전기 2에게 1.92 전력을 줌
# 발전기 0가 발전기 3에게 0.61 전력을 줌
# 발전기 0가 발전기 4에게 1.95 전력을 줌
# 발전기 5가 발전기 1에게 0.61 전력을 줌
# 발전기 5가 발전기 4에게 1.63 전력을 줌
# 발전기 8가 발전기 4에게 0.02 전력을 줌
#
# [t=13 s=7]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 39.04 ([0] 5.63 [1] 0.00 [2] 14.67 [3] 3.04 [4] 0.27 [5] 0.59 [6] 4.48 [7] 3.04 [8] 3.28 [9] 4.04 )
# y+ 합계: 17.11 ([0] 4.41 [1] 0.00 [2] 2.61 [3] 2.43 [4] 0.00 [5] 0.00 [6] 4.48 [7] 2.22 [8] 0.90 [9] 0.07 )
# y- 합계: 17.11 ([0] 0.00 [1] 13.79 [2] 0.00 [3] 0.00 [4] 3.32 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 4.41 전력을 줌
# 발전기 2가 발전기 1에게 2.61 전력을 줌
# 발전기 3가 발전기 1에게 0.01 전력을 줌
# 발전기 3가 발전기 4에게 2.42 전력을 줌
# 발전기 6가 발전기 1에게 4.48 전력을 줌
# 발전기 7가 발전기 1에게 2.22 전력을 줌
# 발전기 8가 발전기 4에게 0.90 전력을 줌
# 발전기 9가 발전기 1에게 0.07 전력을 줌
#
# [t=13 s=8]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 50.85 ([0] 12.66 [1] 4.27 [2] 0.21 [3] 17.14 [4] 0.00 [5] 3.35 [6] 0.00 [7] 0.00 [8] 2.38 [9] 10.84 )
# y+ 합계: 37.60 ([0] 11.45 [1] 0.00 [2] 0.00 [3] 16.53 [4] 0.00 [5] 2.76 [6] 0.00 [7] 0.00 [8] 0.00 [9] 6.87 )
# y- 합계: 25.79 ([0] 0.00 [1] 9.52 [2] 11.85 [3] 0.00 [4] 3.59 [5] 0.00 [6] 0.00 [7] 0.82 [8] 0.00 [9] 0.00 )
# e+ 합계: 11.81 ([0] 1.93 [1] 0.00 [2] 0.00 [3] 3.84 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 6.04 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 9.52 전력을 줌
# 발전기 3가 발전기 2에게 11.85 전력을 줌
# 발전기 3가 발전기 4에게 0.84 전력을 줌
# 발전기 5가 발전기 4에게 2.76 전력을 줌
# 발전기 9가 발전기 7에게 0.82 전력을 줌
#
# [t=13 s=9]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 63.53 ([0] 7.66 [1] 7.07 [2] 1.02 [3] 18.78 [4] 0.00 [5] 0.00 [6] 3.96 [7] 12.05 [8] 2.08 [9] 10.91 )
# y+ 합계: 46.73 ([0] 6.45 [1] 0.00 [2] 0.00 [3] 18.17 [4] 0.00 [5] 0.00 [6] 3.96 [7] 11.22 [8] 0.00 [9] 6.94 )
# y- 합계: 22.24 ([0] 0.00 [1] 6.72 [2] 11.03 [3] 0.00 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.00 [8] 0.30 [9] 0.00 )
# e+ 합계: 24.49 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 13.05 [4] 0.00 [5] 0.00 [6] 0.00 [7] 4.50 [8] 0.00 [9] 6.94 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 2에게 1.96 전력을 줌
# 발전기 0가 발전기 4에게 3.59 전력을 줌
# 발전기 0가 발전기 5에게 0.59 전력을 줌
# 발전기 0가 발전기 8에게 0.30 전력을 줌
# 발전기 3가 발전기 2에게 5.11 전력을 줌
# 발전기 6가 발전기 1에게 3.96 전력을 줌
# 발전기 7가 발전기 1에게 2.76 전력을 줌
# 발전기 7가 발전기 2에게 3.96 전력을 줌
#
# [t=13 s=10]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 62.27 ([0] 4.18 [1] 0.00 [2] 14.59 [3] 0.00 [4] 1.54 [5] 3.96 [6] 18.34 [7] 8.07 [8] 4.47 [9] 7.12 )
# y+ 합계: 39.69 ([0] 2.97 [1] 0.00 [2] 2.53 [3] 0.00 [4] 0.00 [5] 3.36 [6] 18.34 [7] 7.24 [8] 2.09 [9] 3.14 )
# y- 합계: 16.46 ([0] 0.00 [1] 13.79 [2] 0.00 [3] 0.61 [4] 2.05 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 23.23 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 2.66 [6] 18.04 [7] 0.00 [8] 0.00 [9] 2.53 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 2.97 전력을 줌
# 발전기 2가 발전기 1에게 2.53 전력을 줌
# 발전기 5가 발전기 1에게 0.71 전력을 줌
# 발전기 6가 발전기 1에게 0.30 전력을 줌
# 발전기 7가 발전기 1에게 5.19 전력을 줌
# 발전기 7가 발전기 4에게 2.05 전력을 줌
# 발전기 8가 발전기 1에게 2.09 전력을 줌
# 발전기 9가 발전기 3에게 0.61 전력을 줌
#
# [t=13 s=11]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 38.57 ([0] 0.09 [1] 5.29 [2] 13.66 [3] 0.61 [4] 3.59 [5] 0.00 [6] 2.47 [7] 2.72 [8] 4.21 [9] 5.93 )
# y+ 합계: 9.75 ([0] 0.00 [1] 0.00 [2] 1.60 [3] 0.00 [4] 0.00 [5] 0.00 [6] 2.47 [7] 1.90 [8] 1.83 [9] 1.96 )
# y- 합계: 10.22 ([0] 1.13 [1] 8.50 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.59 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.47 ([0] 0.47 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 0에게 0.66 전력을 줌
# 발전기 2가 발전기 1에게 0.34 전력을 줌
# 발전기 2가 발전기 5에게 0.59 전력을 줌
# 발전기 6가 발전기 1에게 2.47 전력을 줌
# 발전기 7가 발전기 1에게 1.90 전력을 줌
# 발전기 8가 발전기 1에게 1.83 전력을 줌
# 발전기 9가 발전기 1에게 1.96 전력을 줌
#
# [t=13 s=12]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 39.23 ([0] 0.00 [1] 0.00 [2] 3.45 [3] 5.65 [4] 0.00 [5] 14.13 [6] 3.08 [7] 2.44 [8] 10.47 [9] 0.00 )
# y+ 합계: 31.37 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 5.04 [4] 0.00 [5] 13.54 [6] 3.08 [7] 1.61 [8] 8.09 [9] 0.00 )
# y- 합계: 31.18 ([0] 1.21 [1] 13.79 [2] 8.61 [3] 0.00 [4] 3.59 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 3.97 )
# e+ 합계: 0.19 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.19 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 3가 발전기 2에게 5.04 전력을 줌
# 발전기 5가 발전기 1에게 12.18 전력을 줌
# 발전기 5가 발전기 9에게 1.17 전력을 줌
# 발전기 6가 발전기 0에게 0.28 전력을 줌
# 발전기 6가 발전기 9에게 2.80 전력을 줌
# 발전기 7가 발전기 1에게 1.61 전력을 줌
# 발전기 8가 발전기 0에게 0.93 전력을 줌
# 발전기 8가 발전기 2에게 3.57 전력을 줌
# 발전기 8가 발전기 4에게 3.59 전력을 줌
#
# [t=13 s=13]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 77.27 ([0] 17.69 [1] 1.76 [2] 4.32 [3] 13.67 [4] 0.00 [5] 8.49 [6] 11.65 [7] 4.39 [8] 1.93 [9] 13.37 )
# y+ 합계: 62.04 ([0] 16.47 [1] 0.00 [2] 0.00 [3] 13.06 [4] 0.00 [5] 7.90 [6] 11.65 [7] 3.56 [8] 0.00 [9] 9.39 )
# y- 합계: 23.81 ([0] 0.00 [1] 12.03 [2] 7.74 [3] 0.00 [4] 3.59 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.44 [9] 0.00 )
# e+ 합계: 38.23 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 13.06 [4] 0.00 [5] 0.56 [6] 11.65 [7] 3.56 [8] 0.00 [9] 9.39 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 12.03 전력을 줌
# 발전기 0가 발전기 2에게 0.40 전력을 줌
# 발전기 0가 발전기 4에게 3.59 전력을 줌
# 발전기 0가 발전기 8에게 0.44 전력을 줌
# 발전기 5가 발전기 2에게 7.34 전력을 줌
#
# [t=13 s=14]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 67.85 ([0] 7.67 [1] 2.32 [2] 13.50 [3] 9.20 [4] 0.00 [5] 5.85 [6] 4.39 [7] 11.74 [8] 0.88 [9] 12.32 )
# y+ 합계: 45.38 ([0] 6.45 [1] 0.00 [2] 1.44 [3] 8.59 [4] 0.00 [5] 5.26 [6] 4.39 [7] 10.91 [8] 0.00 [9] 8.34 )
# y- 합계: 16.57 ([0] 0.00 [1] 11.48 [2] 0.00 [3] 0.00 [4] 3.59 [5] 0.00 [6] 0.00 [7] 0.00 [8] 1.50 [9] 0.00 )
# e+ 합계: 28.81 ([0] 2.46 [1] 0.00 [2] 0.00 [3] 7.09 [4] 0.00 [5] 0.00 [6] 0.00 [7] 10.91 [8] 0.00 [9] 8.34 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 1.83 전력을 줌
# 발전기 0가 발전기 4에게 2.16 전력을 줌
# 발전기 2가 발전기 4에게 1.44 전력을 줌
# 발전기 3가 발전기 8에게 1.50 전력을 줌
# 발전기 5가 발전기 1에게 5.26 전력을 줌
# 발전기 6가 발전기 1에게 4.39 전력을 줌
#
# [t=13 s=15]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 35.30 ([0] 0.00 [1] 7.99 [2] 9.83 [3] 8.76 [4] 0.00 [5] 0.00 [6] 1.47 [7] 0.00 [8] 0.00 [9] 7.25 )
# y+ 합계: 12.90 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 8.15 [4] 0.00 [5] 0.00 [6] 1.47 [7] 0.00 [8] 0.00 [9] 3.28 )
# y- 합계: 16.64 ([0] 1.21 [1] 5.81 [2] 2.23 [3] 0.00 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 0.00 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 3.74 ([0] 1.21 [1] 0.00 [2] 2.23 [3] 0.00 [4] 0.30 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 3가 발전기 1에게 1.06 전력을 줌
# 발전기 3가 발전기 4에게 3.30 전력을 줌
# 발전기 3가 발전기 5에게 0.59 전력을 줌
# 발전기 3가 발전기 7에게 0.82 전력을 줌
# 발전기 3가 발전기 8에게 2.38 전력을 줌
# 발전기 6가 발전기 1에게 1.47 전력을 줌
# 발전기 9가 발전기 1에게 3.28 전력을 줌
#
# [t=13 s=16]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 68.30 ([0] 2.73 [1] 2.58 [2] 9.79 [3] 9.46 [4] 3.36 [5] 12.67 [6] 6.44 [7] 6.45 [8] 8.71 [9] 6.09 )
# y+ 합계: 42.96 ([0] 1.52 [1] 0.00 [2] 0.00 [3] 8.85 [4] 0.00 [5] 12.08 [6] 6.44 [7] 5.62 [8] 6.34 [9] 2.12 )
# y- 합계: 13.71 ([0] 0.00 [1] 11.21 [2] 2.27 [3] 0.00 [4] 0.23 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 29.26 ([0] 0.23 [1] 0.00 [2] 0.00 [3] 8.85 [4] 0.00 [5] 0.64 [6] 6.44 [7] 5.62 [8] 6.34 [9] 1.13 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 2에게 1.29 전력을 줌
# 발전기 5가 발전기 1에게 11.21 전력을 줌
# 발전기 5가 발전기 4에게 0.23 전력을 줌
# 발전기 9가 발전기 2에게 0.98 전력을 줌
#
# [t=13 s=17]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 77.04 ([0] 10.12 [1] 0.00 [2] 0.00 [3] 12.78 [4] 14.55 [5] 3.07 [6] 14.14 [7] 0.82 [8] 7.29 [9] 14.26 )
# y+ 합계: 63.85 ([0] 8.91 [1] 0.00 [2] 0.00 [3] 12.17 [4] 10.95 [5] 2.48 [6] 14.14 [7] 0.00 [8] 4.91 [9] 10.28 )
# y- 합계: 25.85 ([0] 0.00 [1] 13.79 [2] 12.06 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 38.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 11.85 [4] 10.95 [5] 0.00 [6] 0.00 [7] 0.00 [8] 4.91 [9] 10.28 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 2에게 8.91 전력을 줌
# 발전기 3가 발전기 1에게 0.32 전력을 줌
# 발전기 5가 발전기 2에게 2.48 전력을 줌
# 발전기 6가 발전기 1에게 13.47 전력을 줌
# 발전기 6가 발전기 2에게 0.67 전력을 줌
#
# [t=13 s=18]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 38.25 ([0] 1.21 [1] 6.88 [2] 0.00 [3] 0.10 [4] 14.66 [5] 0.00 [6] 0.00 [7] 8.16 [8] 7.22 [9] 0.00 )
# y+ 합계: 23.25 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 11.07 [5] 0.00 [6] 0.00 [7] 7.34 [8] 4.84 [9] 0.00 )
# y- 합계: 24.04 ([0] 0.00 [1] 6.91 [2] 12.06 [3] 0.51 [4] 0.00 [5] 0.59 [6] 0.00 [7] 0.00 [8] 0.00 [9] 3.97 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.79 ([0] 0.00 [1] 0.00 [2] 0.79 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 4가 발전기 1에게 2.06 전력을 줌
# 발전기 4가 발전기 2에게 8.41 전력을 줌
# 발전기 4가 발전기 5에게 0.59 전력을 줌
# 발전기 7가 발전기 2에게 2.86 전력을 줌
# 발전기 7가 발전기 3에게 0.51 전력을 줌
# 발전기 7가 발전기 9에게 3.97 전력을 줌
# 발전기 8가 발전기 1에게 4.84 전력을 줌
#
# [t=13 s=19]
# x 합계: 39.04 ([0] 1.21 [1] 13.79 [2] 12.06 [3] 0.61 [4] 3.59 [5] 0.59 [6] 0.00 [7] 0.82 [8] 2.38 [9] 3.97 )
# R 합계: 54.73 ([0] 10.93 [1] 7.45 [2] 0.00 [3] 8.03 [4] 5.90 [5] 9.16 [6] 1.44 [7] 3.76 [8] 0.00 [9] 8.05 )
# y+ 합계: 36.46 ([0] 9.72 [1] 0.00 [2] 0.00 [3] 7.42 [4] 2.30 [5] 8.57 [6] 1.44 [7] 2.94 [8] 0.00 [9] 4.08 )
# y- 합계: 20.78 ([0] 0.00 [1] 6.34 [2] 12.06 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 2.38 [9] 0.00 )
# e+ 합계: 15.69 ([0] 9.72 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 3.85 [6] 0.00 [7] 2.12 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 3가 발전기 2에게 5.04 전력을 줌
# 발전기 3가 발전기 8에게 2.38 전력을 줌
# 발전기 4가 발전기 2에게 2.30 전력을 줌
# 발전기 5가 발전기 2에게 4.71 전력을 줌
# 발전기 6가 발전기 1에게 1.44 전력을 줌
# 발전기 7가 발전기 1에게 0.82 전력을 줌
# 발전기 9가 발전기 1에게 4.08 전력을 줌
#
# [t=14 s=0]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 52.92 ([0] 3.35 [1] 2.89 [2] 2.03 [3] 13.00 [4] 0.00 [5] 4.41 [6] 8.01 [7] 8.36 [8] 10.86 [9] 0.00 )
# y+ 합계: 28.58 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 9.12 [4] 0.00 [5] 0.00 [6] 8.01 [7] 4.34 [8] 7.12 [9] 0.00 )
# y- 합계: 10.55 ([0] 0.00 [1] 0.00 [2] 1.12 [3] 0.00 [4] 2.85 [5] 6.15 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.43 )
# e+ 합계: 18.04 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 2.97 [4] 0.00 [5] 0.00 [6] 8.01 [7] 4.34 [8] 2.73 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 3가 발전기 5에게 6.15 전력을 줌
# 발전기 8가 발전기 2에게 1.12 전력을 줌
# 발전기 8가 발전기 4에게 2.85 전력을 줌
# 발전기 8가 발전기 9에게 0.43 전력을 줌
#
# [t=14 s=1]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 34.88 ([0] 10.69 [1] 0.00 [2] 0.00 [3] 5.41 [4] 0.99 [5] 10.02 [6] 2.64 [7] 0.10 [8] 0.00 [9] 5.03 )
# y+ 합계: 16.10 ([0] 7.34 [1] 0.00 [2] 0.00 [3] 1.53 [4] 0.00 [5] 0.00 [6] 2.64 [7] 0.00 [8] 0.00 [9] 4.60 )
# y- 합계: 16.10 ([0] 0.00 [1] 2.89 [2] 3.15 [3] 0.00 [4] 1.86 [5] 0.55 [6] 0.00 [7] 3.92 [8] 3.74 [9] 0.00 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 0.15 전력을 줌
# 발전기 0가 발전기 7에게 3.45 전력을 줌
# 발전기 0가 발전기 8에게 3.74 전력을 줌
# 발전기 3가 발전기 2에게 1.06 전력을 줌
# 발전기 3가 발전기 7에게 0.47 전력을 줌
# 발전기 6가 발전기 2에게 2.09 전력을 줌
# 발전기 6가 발전기 5에게 0.55 전력을 줌
# 발전기 9가 발전기 1에게 2.74 전력을 줌
# 발전기 9가 발전기 4에게 1.86 전력을 줌
#
# [t=14 s=2]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 36.69 ([0] 0.91 [1] 0.17 [2] 7.10 [3] 4.11 [4] 0.00 [5] 7.35 [6] 1.60 [7] 8.72 [8] 1.00 [9] 5.72 )
# y+ 합계: 15.77 ([0] 0.00 [1] 0.00 [2] 3.96 [3] 0.23 [4] 0.00 [5] 0.00 [6] 1.60 [7] 4.69 [8] 0.00 [9] 5.29 )
# y- 합계: 13.96 ([0] 2.44 [1] 2.72 [2] 0.00 [3] 0.00 [4] 2.85 [5] 3.22 [6] 0.00 [7] 0.00 [8] 2.74 [9] 0.00 )
# e+ 합계: 1.81 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 1.60 [7] 0.21 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 5에게 1.45 전력을 줌
# 발전기 2가 발전기 8에게 2.50 전력을 줌
# 발전기 3가 발전기 8에게 0.23 전력을 줌
# 발전기 7가 발전기 1에게 0.74 전력을 줌
# 발전기 7가 발전기 4에게 1.98 전력을 줌
# 발전기 7가 발전기 5에게 1.77 전력을 줌
# 발전기 9가 발전기 0에게 2.44 전력을 줌
# 발전기 9가 발전기 1에게 1.99 전력을 줌
# 발전기 9가 발전기 4에게 0.87 전력을 줌
#
# [t=14 s=3]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 60.97 ([0] 0.00 [1] 8.78 [2] 9.27 [3] 0.00 [4] 2.85 [5] 13.23 [6] 5.41 [7] 12.69 [8] 0.00 [9] 8.76 )
# y+ 합계: 37.06 ([0] 0.00 [1] 5.88 [2] 6.12 [3] 0.00 [4] 0.00 [5] 2.66 [6] 5.41 [7] 8.66 [8] 0.00 [9] 8.33 )
# y- 합계: 10.97 ([0] 3.35 [1] 0.00 [2] 0.00 [3] 3.88 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 3.74 [9] 0.00 )
# e+ 합계: 26.09 ([0] 0.00 [1] 5.88 [2] 6.12 [3] 0.00 [4] 0.00 [5] 0.00 [6] 5.41 [7] 8.66 [8] 0.00 [9] 0.02 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 5가 발전기 8에게 2.66 전력을 줌
# 발전기 9가 발전기 0에게 3.35 전력을 줌
# 발전기 9가 발전기 3에게 3.88 전력을 줌
# 발전기 9가 발전기 8에게 1.08 전력을 줌
#
# [t=14 s=4]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 72.61 ([0] 9.45 [1] 5.74 [2] 2.39 [3] 8.08 [4] 11.69 [5] 6.57 [6] 17.25 [7] 5.58 [8] 5.86 [9] 0.00 )
# y+ 합계: 42.91 ([0] 6.10 [1] 2.85 [2] 0.00 [3] 4.20 [4] 8.84 [5] 0.00 [6] 17.25 [7] 1.55 [8] 2.12 [9] 0.00 )
# y- 합계: 5.18 ([0] 0.00 [1] 0.00 [2] 0.75 [3] 0.00 [4] 0.00 [5] 3.99 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.43 )
# e+ 합계: 37.73 ([0] 2.10 [1] 2.85 [2] 0.00 [3] 4.20 [4] 7.66 [5] 0.00 [6] 17.25 [7] 1.55 [8] 2.12 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 2에게 0.75 전력을 줌
# 발전기 0가 발전기 5에게 2.81 전력을 줌
# 발전기 0가 발전기 9에게 0.43 전력을 줌
# 발전기 4가 발전기 5에게 1.18 전력을 줌
#
# [t=14 s=5]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 64.00 ([0] 6.45 [1] 0.00 [2] 15.13 [3] 0.00 [4] 4.87 [5] 10.31 [6] 17.28 [7] 6.00 [8] 3.96 [9] 0.00 )
# y+ 합계: 36.59 ([0] 3.10 [1] 0.00 [2] 11.98 [3] 0.00 [4] 2.02 [5] 0.00 [6] 17.28 [7] 1.98 [8] 0.22 [9] 0.00 )
# y- 합계: 7.46 ([0] 0.00 [1] 2.89 [2] 0.00 [3] 3.88 [4] 0.00 [5] 0.26 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.43 )
# e+ 합계: 29.12 ([0] 2.84 [1] 0.00 [2] 11.11 [3] 0.00 [4] 0.00 [5] 0.00 [6] 12.97 [7] 1.98 [8] 0.22 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 5에게 0.26 전력을 줌
# 발전기 2가 발전기 1에게 0.87 전력을 줌
# 발전기 4가 발전기 1에게 2.02 전력을 줌
# 발전기 6가 발전기 3에게 3.88 전력을 줌
# 발전기 6가 발전기 9에게 0.43 전력을 줌
#
# [t=14 s=6]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 69.54 ([0] 6.33 [1] 9.08 [2] 0.00 [3] 12.67 [4] 5.78 [5] 4.56 [6] 14.69 [7] 10.64 [8] 0.60 [9] 5.19 )
# y+ 합계: 46.95 ([0] 2.98 [1] 6.19 [2] 0.00 [3] 8.78 [4] 2.93 [5] 0.00 [6] 14.69 [7] 6.61 [8] 0.00 [9] 4.76 )
# y- 합계: 12.29 ([0] 0.00 [1] 0.00 [2] 3.15 [3] 0.00 [4] 0.00 [5] 6.00 [6] 0.00 [7] 0.00 [8] 3.14 [9] 0.00 )
# e+ 합계: 34.66 ([0] 0.00 [1] 6.19 [2] 0.00 [3] 8.63 [4] 2.93 [5] 0.00 [6] 5.54 [7] 6.61 [8] 0.00 [9] 4.76 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 8에게 2.98 전력을 줌
# 발전기 3가 발전기 8에게 0.16 전력을 줌
# 발전기 6가 발전기 2에게 3.15 전력을 줌
# 발전기 6가 발전기 5에게 6.00 전력을 줌
#
# [t=14 s=7]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 28.67 ([0] 6.16 [1] 0.00 [2] 1.73 [3] 12.77 [4] 1.38 [5] 0.00 [6] 2.65 [7] 0.00 [8] 3.99 [9] 0.00 )
# y+ 합계: 14.59 ([0] 2.81 [1] 0.00 [2] 0.00 [3] 8.89 [4] 0.00 [5] 0.00 [6] 2.65 [7] 0.00 [8] 0.25 [9] 0.00 )
# y- 합계: 20.80 ([0] 0.00 [1] 2.89 [2] 1.42 [3] 0.00 [4] 1.47 [5] 10.57 [6] 0.00 [7] 4.02 [8] 0.00 [9] 0.43 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 6.20 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 6.20 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 7에게 2.81 전력을 줌
# 발전기 3가 발전기 1에게 2.64 전력을 줌
# 발전기 3가 발전기 4에게 1.47 전력을 줌
# 발전기 3가 발전기 5에게 3.56 전력을 줌
# 발전기 3가 발전기 7에게 1.21 전력을 줌
# 발전기 6가 발전기 2에게 1.42 전력을 줌
# 발전기 6가 발전기 5에게 0.80 전력을 줌
# 발전기 6가 발전기 9에게 0.43 전력을 줌
# 발전기 8가 발전기 1에게 0.25 전력을 줌
#
# [t=14 s=8]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 39.02 ([0] 0.92 [1] 0.00 [2] 3.15 [3] 0.00 [4] 0.00 [5] 9.92 [6] 11.71 [7] 0.00 [8] 10.22 [9] 3.09 )
# y+ 합계: 20.86 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 11.71 [7] 0.00 [8] 6.49 [9] 2.66 )
# y- 합계: 16.72 ([0] 2.43 [1] 2.89 [2] 0.00 [3] 3.88 [4] 2.85 [5] 0.64 [6] 0.00 [7] 4.02 [8] 0.00 [9] 0.00 )
# e+ 합계: 4.14 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 4.14 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 6가 발전기 0에게 1.78 전력을 줌
# 발전기 6가 발전기 1에게 2.89 전력을 줌
# 발전기 6가 발전기 3에게 3.88 전력을 줌
# 발전기 6가 발전기 4에게 2.85 전력을 줌
# 발전기 6가 발전기 5에게 0.30 전력을 줌
# 발전기 8가 발전기 0에게 0.64 전력을 줌
# 발전기 8가 발전기 7에게 1.70 전력을 줌
# 발전기 9가 발전기 5에게 0.34 전력을 줌
# 발전기 9가 발전기 7에게 2.32 전력을 줌
#
# [t=14 s=9]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 53.72 ([0] 0.00 [1] 3.76 [2] 9.17 [3] 0.00 [4] 1.50 [5] 7.59 [6] 0.00 [7] 9.21 [8] 7.96 [9] 14.53 )
# y+ 합계: 30.40 ([0] 0.00 [1] 0.87 [2] 6.02 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 5.19 [8] 4.22 [9] 14.10 )
# y- 합계: 11.56 ([0] 3.35 [1] 0.00 [2] 0.00 [3] 3.88 [4] 1.35 [5] 2.98 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 18.84 ([0] 0.00 [1] 0.00 [2] 3.04 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 1.70 [8] 0.00 [9] 14.10 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 0에게 0.48 전력을 줌
# 발전기 1가 발전기 3에게 0.39 전력을 줌
# 발전기 2가 발전기 5에게 2.98 전력을 줌
# 발전기 7가 발전기 3에게 3.49 전력을 줌
# 발전기 8가 발전기 0에게 2.87 전력을 줌
# 발전기 8가 발전기 4에게 1.35 전력을 줌
#
# [t=14 s=10]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 50.69 ([0] 0.00 [1] 11.05 [2] 1.57 [3] 0.00 [4] 10.15 [5] 15.73 [6] 4.34 [7] 7.84 [8] 0.00 [9] 0.00 )
# y+ 합계: 28.78 ([0] 0.00 [1] 8.16 [2] 0.00 [3] 0.00 [4] 7.30 [5] 5.17 [6] 4.34 [7] 3.82 [8] 0.00 [9] 0.00 )
# y- 합계: 12.98 ([0] 3.35 [1] 0.00 [2] 1.58 [3] 3.88 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 3.74 [9] 0.43 )
# e+ 합계: 15.81 ([0] 0.00 [1] 2.48 [2] 0.00 [3] 0.00 [4] 0.00 [5] 5.17 [6] 4.34 [7] 3.82 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 2에게 1.58 전력을 줌
# 발전기 1가 발전기 3에게 0.08 전력을 줌
# 발전기 1가 발전기 8에게 3.74 전력을 줌
# 발전기 1가 발전기 9에게 0.28 전력을 줌
# 발전기 4가 발전기 0에게 3.35 전력을 줌
# 발전기 4가 발전기 3에게 3.80 전력을 줌
# 발전기 4가 발전기 9에게 0.15 전력을 줌
#
# [t=14 s=11]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 59.53 ([0] 1.76 [1] 11.11 [2] 10.14 [3] 4.03 [4] 0.00 [5] 9.43 [6] 10.58 [7] 8.91 [8] 0.00 [9] 3.58 )
# y+ 합계: 33.97 ([0] 0.00 [1] 8.22 [2] 6.99 [3] 0.15 [4] 0.00 [5] 0.00 [6] 10.58 [7] 4.89 [8] 0.00 [9] 3.15 )
# y- 합계: 9.31 ([0] 1.59 [1] 0.00 [2] 0.00 [3] 0.00 [4] 2.85 [5] 1.14 [6] 0.00 [7] 0.00 [8] 3.74 [9] 0.00 )
# e+ 합계: 24.65 ([0] 0.00 [1] 0.04 [2] 5.85 [3] 0.15 [4] 0.00 [5] 0.00 [6] 10.58 [7] 4.89 [8] 0.00 [9] 3.15 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 0에게 0.45 전력을 줌
# 발전기 1가 발전기 4에게 2.85 전력을 줌
# 발전기 1가 발전기 5에게 1.14 전력을 줌
# 발전기 1가 발전기 8에게 3.74 전력을 줌
# 발전기 2가 발전기 0에게 1.14 전력을 줌
#
# [t=14 s=12]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 46.86 ([0] 0.00 [1] 3.47 [2] 10.41 [3] 10.68 [4] 0.00 [5] 7.15 [6] 7.95 [7] 0.00 [8] 0.00 [9] 7.20 )
# y+ 합계: 29.36 ([0] 0.00 [1] 0.58 [2] 7.26 [3] 6.80 [4] 0.00 [5] 0.00 [6] 7.95 [7] 0.00 [8] 0.00 [9] 6.77 )
# y- 합계: 17.38 ([0] 3.35 [1] 0.00 [2] 0.00 [3] 0.00 [4] 2.85 [5] 3.42 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.00 )
# e+ 합계: 11.98 ([0] 0.00 [1] 0.00 [2] 7.23 [3] 3.38 [4] 0.00 [5] 0.00 [6] 1.37 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 7에게 0.58 전력을 줌
# 발전기 2가 발전기 0에게 0.03 전력을 줌
# 발전기 3가 발전기 5에게 3.42 전력을 줌
# 발전기 6가 발전기 4에게 2.85 전력을 줌
# 발전기 6가 발전기 8에게 3.74 전력을 줌
# 발전기 9가 발전기 0에게 3.32 전력을 줌
# 발전기 9가 발전기 7에게 3.45 전력을 줌
#
# [t=14 s=13]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 55.66 ([0] 0.30 [1] 11.31 [2] 7.53 [3] 3.88 [4] 1.33 [5] 4.08 [6] 15.96 [7] 10.94 [8] 0.33 [9] 0.00 )
# y+ 합계: 35.68 ([0] 0.00 [1] 8.42 [2] 4.38 [3] 0.00 [4] 0.00 [5] 0.00 [6] 15.96 [7] 6.91 [8] 0.00 [9] 0.00 )
# y- 합계: 14.90 ([0] 3.05 [1] 0.00 [2] 0.00 [3] 0.00 [4] 1.52 [5] 6.49 [6] 0.00 [7] 0.00 [8] 3.41 [9] 0.43 )
# e+ 합계: 20.78 ([0] 0.00 [1] 4.82 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 15.96 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 5에게 3.60 전력을 줌
# 발전기 2가 발전기 4에게 1.07 전력을 줌
# 발전기 2가 발전기 5에게 2.89 전력을 줌
# 발전기 2가 발전기 9에게 0.43 전력을 줌
# 발전기 7가 발전기 0에게 3.05 전력을 줌
# 발전기 7가 발전기 4에게 0.46 전력을 줌
# 발전기 7가 발전기 8에게 3.41 전력을 줌
#
# [t=14 s=14]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 62.71 ([0] 11.61 [1] 0.00 [2] 4.87 [3] 16.88 [4] 2.30 [5] 1.91 [6] 13.52 [7] 9.67 [8] 0.00 [9] 1.96 )
# y+ 합계: 43.67 ([0] 8.26 [1] 0.00 [2] 1.72 [3] 13.00 [4] 0.00 [5] 0.00 [6] 13.52 [7] 5.64 [8] 0.00 [9] 1.53 )
# y- 합계: 15.84 ([0] 0.00 [1] 2.89 [2] 0.00 [3] 0.00 [4] 0.55 [5] 8.65 [6] 0.00 [7] 0.00 [8] 3.74 [9] 0.00 )
# e+ 합계: 27.84 ([0] 4.52 [1] 0.00 [2] 1.72 [3] 13.00 [4] 0.00 [5] 0.00 [6] 3.50 [7] 5.09 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 8에게 3.74 전력을 줌
# 발전기 6가 발전기 1에게 1.37 전력을 줌
# 발전기 6가 발전기 5에게 8.65 전력을 줌
# 발전기 7가 발전기 4에게 0.55 전력을 줌
# 발전기 9가 발전기 1에게 1.53 전력을 줌
#
# [t=14 s=15]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 31.02 ([0] 0.00 [1] 2.35 [2] 10.30 [3] 3.89 [4] 0.00 [5] 7.23 [6] 4.85 [7] 0.00 [8] 2.38 [9] 0.00 )
# y+ 합계: 12.02 ([0] 0.00 [1] 0.00 [2] 7.16 [3] 0.01 [4] 0.00 [5] 0.00 [6] 4.85 [7] 0.00 [8] 0.00 [9] 0.00 )
# y- 합계: 15.88 ([0] 3.35 [1] 0.54 [2] 0.00 [3] 0.00 [4] 2.85 [5] 3.34 [6] 0.00 [7] 4.02 [8] 1.35 [9] 0.43 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 3.86 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 3.86 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 0에게 3.35 전력을 줌
# 발전기 2가 발전기 1에게 0.53 전력을 줌
# 발전기 2가 발전기 4에게 2.85 전력을 줌
# 발전기 2가 발전기 9에게 0.43 전력을 줌
# 발전기 3가 발전기 1에게 0.01 전력을 줌
# 발전기 6가 발전기 5에게 3.34 전력을 줌
# 발전기 6가 발전기 7에게 0.16 전력을 줌
# 발전기 6가 발전기 8에게 1.35 전력을 줌
#
# [t=14 s=16]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 47.18 ([0] 9.58 [1] 0.00 [2] 0.00 [3] 2.39 [4] 3.87 [5] 10.57 [6] 11.21 [7] 5.54 [8] 3.74 [9] 0.31 )
# y+ 합계: 19.96 ([0] 6.23 [1] 0.00 [2] 0.00 [3] 0.00 [4] 1.02 [5] 0.00 [6] 11.21 [7] 1.51 [8] 0.00 [9] 0.00 )
# y- 합계: 7.66 ([0] 0.00 [1] 2.89 [2] 3.15 [3] 1.50 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.12 )
# e+ 합계: 12.30 ([0] 1.10 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 11.21 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 1에게 0.36 전력을 줌
# 발전기 0가 발전기 2에게 3.15 전력을 줌
# 발전기 0가 발전기 3에게 1.50 전력을 줌
# 발전기 0가 발전기 9에게 0.12 전력을 줌
# 발전기 4가 발전기 1에게 1.02 전력을 줌
# 발전기 7가 발전기 1에게 1.51 전력을 줌
#
# [t=14 s=17]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 66.93 ([0] 0.00 [1] 4.25 [2] 5.72 [3] 5.04 [4] 0.00 [5] 3.62 [6] 13.76 [7] 14.07 [8] 9.94 [9] 10.53 )
# y+ 합계: 45.19 ([0] 0.00 [1] 1.35 [2] 2.58 [3] 1.16 [4] 0.00 [5] 0.00 [6] 13.76 [7] 10.05 [8] 6.20 [9] 10.10 )
# y- 합계: 13.14 ([0] 3.35 [1] 0.00 [2] 0.00 [3] 0.00 [4] 2.85 [5] 6.94 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e+ 합계: 32.05 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 11.90 [7] 10.05 [8] 6.20 [9] 3.90 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 1가 발전기 5에게 1.35 전력을 줌
# 발전기 2가 발전기 5에게 2.58 전력을 줌
# 발전기 3가 발전기 4에게 1.16 전력을 줌
# 발전기 6가 발전기 5에게 1.86 전력을 줌
# 발전기 9가 발전기 0에게 3.35 전력을 줌
# 발전기 9가 발전기 4에게 1.69 전력을 줌
# 발전기 9가 발전기 5에게 1.16 전력을 줌
#
# [t=14 s=18]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 29.76 ([0] 1.87 [1] 0.00 [2] 10.46 [3] 0.57 [4] 3.84 [5] 0.00 [6] 0.00 [7] 4.34 [8] 8.69 [9] 0.00 )
# y+ 합계: 13.56 ([0] 0.00 [1] 0.00 [2] 7.31 [3] 0.00 [4] 0.99 [5] 0.00 [6] 0.00 [7] 0.31 [8] 4.95 [9] 0.00 )
# y- 합계: 18.68 ([0] 1.48 [1] 2.89 [2] 0.00 [3] 3.31 [4] 0.00 [5] 10.57 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.43 )
# e+ 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 5.12 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 5.12 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 2가 발전기 3에게 1.87 전력을 줌
# 발전기 2가 발전기 5에게 5.44 전력을 줌
# 발전기 4가 발전기 3에게 0.99 전력을 줌
# 발전기 7가 발전기 3에게 0.31 전력을 줌
# 발전기 8가 발전기 0에게 1.48 전력을 줌
# 발전기 8가 발전기 1에게 2.89 전력을 줌
# 발전기 8가 발전기 3에게 0.14 전력을 줌
# 발전기 8가 발전기 9에게 0.43 전력을 줌
#
# [t=14 s=19]
# x 합계: 34.88 ([0] 3.35 [1] 2.89 [2] 3.15 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 4.02 [8] 3.74 [9] 0.43 )
# R 합계: 36.60 ([0] 8.22 [1] 4.61 [2] 2.60 [3] 0.00 [4] 0.00 [5] 0.00 [6] 2.38 [7] 13.97 [8] 1.64 [9] 3.19 )
# y+ 합계: 21.66 ([0] 4.87 [1] 1.72 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 2.38 [7] 9.94 [8] 0.00 [9] 2.76 )
# y- 합계: 19.94 ([0] 0.00 [1] 0.00 [2] 0.55 [3] 3.88 [4] 2.85 [5] 10.57 [6] 0.00 [7] 0.00 [8] 2.10 [9] 0.00 )
# e+ 합계: 1.72 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 1.72 [7] 0.00 [8] 0.00 [9] 0.00 )
# e- 합계: 0.00 ([0] 0.00 [1] 0.00 [2] 0.00 [3] 0.00 [4] 0.00 [5] 0.00 [6] 0.00 [7] 0.00 [8] 0.00 [9] 0.00 )
# 거래 내역:
# 발전기 0가 발전기 3에게 2.11 전력을 줌
# 발전기 0가 발전기 4에게 1.13 전력을 줌
# 발전기 0가 발전기 8에게 1.62 전력을 줌
# 발전기 1가 발전기 4에게 1.72 전력을 줌
# 발전기 6가 발전기 2에게 0.55 전력을 줌
# 발전기 6가 발전기 3에게 0.11 전력을 줌
# 발전기 7가 발전기 5에게 9.47 전력을 줌
# 발전기 7가 발전기 8에게 0.48 전력을 줌
# 발전기 9가 발전기 3에게 1.66 전력을 줌
# 발전기 9가 발전기 5에게 1.10 전력을 줌

# %%
d_given = np.zeros(I)
d_received = np.zeros(I)

for i in range(I):
    d_given[i] = sum(
        sum(d_vals[i, j, t, s] for j in range(I) if j != i for t in range(T)) / S for s in range(S)
    )
    d_received[i] = sum(
        sum(d_vals[j, i, t, s] for j in range(I) if j != i for t in range(T)) / S for s in range(S)
    )

set_d = pd.DataFrame({"set_d_given": d_given, "set_d_received": d_received})
set_d.to_csv("result/result_set1_d.csv", index=False)

# %% [markdown]
# ### 정산

# %%
total_der_profit = 0
der_profit = {}
for i in range(I):
    der_profit[i] = sum(P_DA[t] * x[i,t].x + sum(1/S * (P_RT[t,s] * e_plus[i,t,s].x - P_PN[t] * e_minus[i,t,s].x) for s in range(S)) for t in range(T))
    total_der_profit += der_profit[i]

print(f"\n모든 der의 profit 합계: {total_der_profit:.2f}")

print("\n최종 profit:")
for i, (profit, only) in enumerate(zip(der_profit.values(), only_profit.flatten())):
    increase_percentage = ((profit - only) / only) * 100
    print(f"[{i}] {profit:.2f} ({increase_percentage:.2f}%)")
# Out:
# 모든 der의 profit 합계: 11878.13
#
# 최종 profit:
# [0] 985.77 (-18.16%)
# [1] 1571.31 (80.08%)
# [2] 1362.60 (10.11%)
# [3] 953.54 (-15.50%)
# [4] 880.11 (21.52%)
# [5] 1370.91 (42.28%)
# [6] 1302.69 (-24.82%)
# [7] 1045.21 (-4.89%)
# [8] 1554.79 (102.20%)
# [9] 851.21 (-8.54%)

# %% [markdown]
# ### 결과 저장

# %%
set_profit_value = pd.DataFrame({'set_profit_value': der_profit})
set_profit_value.to_csv('result/result_set1_profit.csv', index=False)

set_obj = pd.DataFrame({'set_obj': [set.objVal]})
set_obj.to_csv('result/result_set1_obj.csv', index=False)
